# %%
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)

audit_data_filename = '../navninja/data/investment_trust_data_audit.csv'

audit_df = pd.read_csv(audit_data_filename).drop(["isin"], axis=1)
audit_df['winding_down'] = audit_df['winding_down'].fillna(False)
# audit_df['auditable'] = audit_df['auditable'].fillna(False)
audit_df['audit_link'] = audit_df['audit_link'].fillna("")

audit_df
# Out:
#     symbol winding_down  auditable  \
# 0      3IN        False      False
# 1     AGVI        False       True
# 2      ASL        False       True
# 3     AAIF        False       True
# 4     ADIG         True       True
# ..     ...          ...        ...
# 368   PUAL        False      False
# 369   PU13        False      False
# 370    UAV        False      False
# 371   USFP        False      False
# 372    UTL        False      False
#
#                                             audit_link
# 0
# 1    https://www.aberforth.co.uk/trusts-and-funds/a...
# 2    https://www.aberforth.co.uk/trusts-and-funds/a...
# 3    https://www.asian-income.co.uk/en-gb/literatur...
# 4    https://www.abrdndiversified.co.uk/en-gb/liter...
# ..                                                 ...
# 368
# 369
# 370
# 371
# 372
#
# [373 rows x 4 columns]

# %%
trust_data_df = pd.read_csv('../data/investment_trust_data_241101.csv')
trust_data_df = trust_data_df.drop(columns=['Unnamed: 0'], axis=1)
trust_data_df
# Out:
#     symbol                                       name  estimate_nav  \
# 0      3IN                      3i Infrastructure plc        363.40
# 1     AGVI  Aberforth Geared Value & Income Trust Plc         98.40
# 2      ASL      Aberforth Smaller Companies Trust plc       1674.76
# 3     AAIF            Abrdn Asian Income Fund Limited        245.61
# 4     ADIG    Abrdn Diversified Income & Growth Trust         66.49
# ..     ...                                        ...           ...
# 365   PUAL                         Puma Alpha VCT plc        107.80
# 366   PU13                            Puma VCT 13 Plc        128.70
# 367    UAV                        Unicorn AIM VCT plc        102.00
# 368   USFP                          US Solar Fund Plc         74.67
# 369    UTL                                    UIL Ltd        167.58
#
#      latest_actual_nav latest_actual_nav_date nav_premium  \
# 0               362.30          31 March 2024     -11.12%
# 1                  NaN                    NaN     -12.60%
# 2              1675.17        30 October 2024     -10.20%
# 3               245.92        30 October 2024     -13.28%
# 4                66.57        30 October 2024     -34.13%
# ..                 ...                    ...         ...
# 365                NaN                    NaN       4.36%
# 366             127.82      30 September 2024      -4.82%
# 367             104.70      30 September 2024      -8.33%
# 368              57.63           30 June 2024     -37.06%
# 369             167.15        30 October 2024     -36.45%
#
#     average_12_month_nav_premium   nav_frequency     volume div_yld  ...  \
# 0                         -7.52%           Daily  1,377,816   3.72%  ...
# 1                          0.00%           Daily     67,655      0%  ...
# 2                        -10.52%           Daily    111,432   2.80%  ...
# 3                        -12.68%           Daily    189,949   5.52%  ...
# 4                        -30.67%           Daily    326,351  13.36%  ...
# ..                           ...             ...        ...     ...  ...
# 365                        1.42%   Semi-Annually          0   4.44%  ...
# 366                       -3.91%   Semi-Annually          0      0%  ...
# 367                      -10.09%         Monthly          0   6.95%  ...
# 368                      -36.15%       Quarterly     36,713  12.62%  ...
# 369                      -37.57%          Weekly     20,030   7.31%  ...
#
#     market_cap_mils                        structure        domicile  \
# 0            2979.0  Closed Ended Investment Company          Jersey
# 1              92.0  Closed Ended Investment Company  United Kingdom
# 2            1266.0  Closed Ended Investment Company  United Kingdom
# 3             326.0  Closed Ended Investment Company          Jersey
# 4             132.0  Closed Ended Investment Company  United Kingdom
# ..              ...                              ...             ...
# 365            32.0  Closed Ended Investment Company  United Kingdom
# 366           156.0  Closed Ended Investment Company  United Kingdom
# 367           178.0  Closed Ended Investment Company  United Kingdom
# 368           145.0  Closed Ended Investment Company  United Kingdom
# 369            99.0  Closed Ended Investment Company         Bermuda
#
#              isin                                          objective  \
# 0    JE00BF5FX167  The Company aims to build a diversified portfo...
# 1    GB00BPJMQ253  To provide Ordinary Shareholders with high tot...
# 2    GB0000066554  To achieve a NAV total return (with dividends ...
# 3    GB00B0P6J834  To provide investors with a total return prima...
# 4    GB0001297562  To conduct an orderly realisation of its asset...
# ..            ...                                                ...
# 365  GB00BGMG7F10  The Company may invest in a mix of qualifying ...
# 366  GB00BD5B1L68  To maximise distributions from capital gains a...
# 367  GB00B1RTFN43  To identify and invest in a diversified portfo...
# 368  GB00BJCWFX49  To provide investors with attractive and susta...
# 369  BMG917071026  The investment objective is to maximise shareh...
#
#                                       top_ten_holdings  \
# 0    [('Tcr', '17.32%'), ('Esvagt', '15.64%'), ('In...
# 1    [('Vesuvius plc Ordinary 10p', '4.03%'), ('Cen...
# 2    [('Wilmington plc Ordinary 5p', '3.43%'), ('Ju...
# 3    [('Taiwan Semiconductor Manufacturing Co Ltd',...
# 4    [('SL CAP INFRA EUR', '14.09%'), ('ABERDEEN ST...
# ..                                                 ...
# 365  [('Camera Matics (â\x80\x98My Safe Drive Limit...
# 366  [('Influencer Limited', '11.07%'), ('Le Col Ho...
# 367  [('Hasgrove PLC', '19.84%'), ('Cohort plc Ordi...
# 368                   [('Usf Holding Corp', '99.25%')]
# 369  [('Somers Ltd', '68.02%'), ('Zeta Resources Li...
#
#                                        top_ten_sectors  \
# 0                                                   []
# 1    [('Industrials', '24.38%'), ('Financial Servic...
# 2    [('Industrials', '28.13%'), ('Financial Servic...
# 3    [('Technology', '32.01%'), ('Financial Service...
# 4                                                   []
# ..                                                 ...
# 365                                                 []
# 366                                                 []
# 367  [('Communication Services', '23.37%'), ('Healt...
# 368                                                 []
# 369                                                 []
#
#                                      top_ten_countries tradeable  \
# 0                                                   []      True
# 1    [('United Kingdom', '91.06%'), ('Egypt', '3.80...      True
# 2    [('United Kingdom', '100.42%'), ('Egypt', '2.7...      True
# 3    [('Taiwan', '24.77%'), ('Singapore', '18.56%')...      True
# 4    [('Netherlands', '3.62%'), ('Australia', '0.43...      True
# ..                                                 ...       ...
# 365                                                 []     False
# 366  [('United Kingdom', '1.01%'), ('United States'...     False
# 367  [('United Kingdom', '81.84%'), ('United States...     False
# 368                                                 []      True
# 369  [('United Kingdom', '68.02%'), ('Australia', '...      True
#
#                                                   link
# 0    https://www.hl.co.uk/shares/shares-search-resu...
# 1    https://www.hl.co.uk/shares/shares-search-resu...
# 2    https://www.hl.co.uk/shares/shares-search-resu...
# 3    https://www.hl.co.uk/shares/shares-search-resu...
# 4    https://www.hl.co.uk/shares/shares-search-resu...
# ..                                                 ...
# 365  https://www.hl.co.uk/shares/shares-search-resu...
# 366  https://www.hl.co.uk/shares/shares-search-resu...
# 367  https://www.hl.co.uk/shares/shares-search-resu...
# 368  https://www.hl.co.uk/shares/shares-search-resu...
# 369  https://www.hl.co.uk/shares/shares-search-resu...
#
# [370 rows x 26 columns]

# %%
trusts_with_audit = pd.merge(trust_data_df, audit_df, on='symbol', how='inner')
trusts_with_audit.to_csv('../data/investment_trust_data_audit_241101.csv')
trusts_with_audit
# Out:
#     symbol                                       name  estimate_nav  \
# 0      3IN                      3i Infrastructure plc        363.40
# 1     AGVI  Aberforth Geared Value & Income Trust Plc         98.40
# 2      ASL      Aberforth Smaller Companies Trust plc       1674.76
# 3     AAIF            Abrdn Asian Income Fund Limited        245.61
# 4     ADIG    Abrdn Diversified Income & Growth Trust         66.49
# ..     ...                                        ...           ...
# 361   PUAL                         Puma Alpha VCT plc        107.80
# 362   PU13                            Puma VCT 13 Plc        128.70
# 363    UAV                        Unicorn AIM VCT plc        102.00
# 364   USFP                          US Solar Fund Plc         74.67
# 365    UTL                                    UIL Ltd        167.58
#
#      latest_actual_nav latest_actual_nav_date nav_premium  \
# 0               362.30          31 March 2024     -11.12%
# 1                  NaN                    NaN     -12.60%
# 2              1675.17        30 October 2024     -10.20%
# 3               245.92        30 October 2024     -13.28%
# 4                66.57        30 October 2024     -34.13%
# ..                 ...                    ...         ...
# 361                NaN                    NaN       4.36%
# 362             127.82      30 September 2024      -4.82%
# 363             104.70      30 September 2024      -8.33%
# 364              57.63           30 June 2024     -37.06%
# 365             167.15        30 October 2024     -36.45%
#
#     average_12_month_nav_premium   nav_frequency     volume div_yld  ...  \
# 0                         -7.52%           Daily  1,377,816   3.72%  ...
# 1                          0.00%           Daily     67,655      0%  ...
# 2                        -10.52%           Daily    111,432   2.80%  ...
# 3                        -12.68%           Daily    189,949   5.52%  ...
# 4                        -30.67%           Daily    326,351  13.36%  ...
# ..                           ...             ...        ...     ...  ...
# 361                        1.42%   Semi-Annually          0   4.44%  ...
# 362                       -3.91%   Semi-Annually          0      0%  ...
# 363                      -10.09%         Monthly          0   6.95%  ...
# 364                      -36.15%       Quarterly     36,713  12.62%  ...
# 365                      -37.57%          Weekly     20,030   7.31%  ...
#
#              isin                                          objective  \
# 0    JE00BF5FX167  The Company aims to build a diversified portfo...
# 1    GB00BPJMQ253  To provide Ordinary Shareholders with high tot...
# 2    GB0000066554  To achieve a NAV total return (with dividends ...
# 3    GB00B0P6J834  To provide investors with a total return prima...
# 4    GB0001297562  To conduct an orderly realisation of its asset...
# ..            ...                                                ...
# 361  GB00BGMG7F10  The Company may invest in a mix of qualifying ...
# 362  GB00BD5B1L68  To maximise distributions from capital gains a...
# 363  GB00B1RTFN43  To identify and invest in a diversified portfo...
# 364  GB00BJCWFX49  To provide investors with attractive and susta...
# 365  BMG917071026  The investment objective is to maximise shareh...
#
#                                       top_ten_holdings  \
# 0    [('Tcr', '17.32%'), ('Esvagt', '15.64%'), ('In...
# 1    [('Vesuvius plc Ordinary 10p', '4.03%'), ('Cen...
# 2    [('Wilmington plc Ordinary 5p', '3.43%'), ('Ju...
# 3    [('Taiwan Semiconductor Manufacturing Co Ltd',...
# 4    [('SL CAP INFRA EUR', '14.09%'), ('ABERDEEN ST...
# ..                                                 ...
# 361  [('Camera Matics (â\x80\x98My Safe Drive Limit...
# 362  [('Influencer Limited', '11.07%'), ('Le Col Ho...
# 363  [('Hasgrove PLC', '19.84%'), ('Cohort plc Ordi...
# 364                   [('Usf Holding Corp', '99.25%')]
# 365  [('Somers Ltd', '68.02%'), ('Zeta Resources Li...
#
#                                        top_ten_sectors  \
# 0                                                   []
# 1    [('Industrials', '24.38%'), ('Financial Servic...
# 2    [('Industrials', '28.13%'), ('Financial Servic...
# 3    [('Technology', '32.01%'), ('Financial Service...
# 4                                                   []
# ..                                                 ...
# 361                                                 []
# 362                                                 []
# 363  [('Communication Services', '23.37%'), ('Healt...
# 364                                                 []
# 365                                                 []
#
#                                      top_ten_countries tradeable  \
# 0                                                   []      True
# 1    [('United Kingdom', '91.06%'), ('Egypt', '3.80...      True
# 2    [('United Kingdom', '100.42%'), ('Egypt', '2.7...      True
# 3    [('Taiwan', '24.77%'), ('Singapore', '18.56%')...      True
# 4    [('Netherlands', '3.62%'), ('Australia', '0.43...      True
# ..                                                 ...       ...
# 361                                                 []     False
# 362  [('United Kingdom', '1.01%'), ('United States'...     False
# 363  [('United Kingdom', '81.84%'), ('United States...     False
# 364                                                 []      True
# 365  [('United Kingdom', '68.02%'), ('Australia', '...      True
#
#                                                   link winding_down auditable  \
# 0    https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 1    https://www.hl.co.uk/shares/shares-search-resu...        False      True
# 2    https://www.hl.co.uk/shares/shares-search-resu...        False      True
# 3    https://www.hl.co.uk/shares/shares-search-resu...        False      True
# 4    https://www.hl.co.uk/shares/shares-search-resu...         True      True
# ..                                                 ...          ...       ...
# 361  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 362  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 363  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 364  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 365  https://www.hl.co.uk/shares/shares-search-resu...        False     False
#
#                                             audit_link
# 0
# 1    https://www.aberforth.co.uk/trusts-and-funds/a...
# 2    https://www.aberforth.co.uk/trusts-and-funds/a...
# 3    https://www.asian-income.co.uk/en-gb/literatur...
# 4    https://www.abrdndiversified.co.uk/en-gb/liter...
# ..                                                 ...
# 361
# 362
# 363
# 364
# 365
#
# [366 rows x 29 columns]

# %%
from get_hl_trust_data import *
from investment_trust import InvestmentTrust


jema_trust = InvestmentTrust(symbol='JEMA', name='JPMorgan Russian', link='', tradeable=True, premium=0.0)
jema_data = get_dummy_symbol_data(jema_trust)
jema_data
# Out:
# TrustData(symbol='JEMA', name='JPMorgan Russian', estimate_nav=0, latest_actual_nav=0, latest_actual_nav_date='', nav_premium='', average_12_month_nav_premium='', nav_frequency='', volume=0, div_yld='', currency='', annual_mgmt_charge='', performance_fee=False, ongoing_charge='', total_assets_mils=0, gross_gearing='', market_cap_mils=0, structure='', domicile='', isin='', objective='', top_ten_holdings=[], top_ten_sectors=[], top_ten_countries=[], tradeable=True, link='')

# %%
jema_df = pd.DataFrame([jema_data.__dict__])
jema_df
# Out:
#   symbol              name  estimate_nav  latest_actual_nav  \
# 0   JEMA  JPMorgan Russian             0                  0
#
#   latest_actual_nav_date nav_premium average_12_month_nav_premium  \
# 0
#
#   nav_frequency  volume div_yld  ... market_cap_mils structure  domicile isin  \
# 0                     0          ...               0
#
#    objective top_ten_holdings  top_ten_sectors top_ten_countries tradeable  \
# 0                          []               []                []      True
#
#   link
# 0
#
# [1 rows x 26 columns]

# %%
df_with_audit = pd.merge(jema_df, audit_df, on='symbol', how='inner')
df_with_audit
# Out:
#   symbol              name  estimate_nav  latest_actual_nav  \
# 0   JEMA  JPMorgan Russian             0                  0
#
#   latest_actual_nav_date nav_premium average_12_month_nav_premium  \
# 0
#
#   nav_frequency  volume div_yld  ... isin objective  top_ten_holdings  \
# 0                     0          ...                               []
#
#   top_ten_sectors  top_ten_countries tradeable  link winding_down auditable  \
# 0              []                 []      True              False      True
#
#   audit_link
# 0
#
# [1 rows x 29 columns]
