# %%
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)

audit_data_filename = '../navninja/data/investment_trust_data_audit.csv'

audit_df = pd.read_csv(audit_data_filename).drop(["isin"], axis=1)
audit_df['winding_down'] = audit_df['winding_down'].fillna(False)
# audit_df['auditable'] = audit_df['auditable'].fillna(False)
audit_df['audit_link'] = audit_df['audit_link'].fillna("")

audit_df
# Out:
#     symbol winding_down  auditable  \
# 0      3IN        False      False
# 1     AGVI        False       True
# 2      ASL        False       True
# 3     AAIF        False       True
# 4     ADIG         True       True
# ..     ...          ...        ...
# 368   PUAL        False      False
# 369   PU13        False      False
# 370    UAV        False      False
# 371   USFP        False      False
# 372    UTL        False      False
#
#                                             audit_link
# 0
# 1    https://www.aberforth.co.uk/trusts-and-funds/a...
# 2    https://www.aberforth.co.uk/trusts-and-funds/a...
# 3    https://www.asian-income.co.uk/en-gb/literatur...
# 4    https://www.abrdndiversified.co.uk/en-gb/liter...
# ..                                                 ...
# 368
# 369
# 370
# 371
# 372
#
# [373 rows x 4 columns]

# %%
trust_data_df = pd.read_csv('../data/investment_trust_data_241201.csv')
trust_data_df = trust_data_df.drop(columns=['Unnamed: 0'], axis=1)
trust_data_df
# Out:
#     symbol                                       name  estimate_nav  \
# 0      3IN                      3i Infrastructure plc        370.42
# 1     AGVI  Aberforth Geared Value & Income Trust Plc         97.04
# 2      ASL      Aberforth Smaller Companies Trust plc       1655.63
# 3     AAIF            Abrdn Asian Income Fund Limited        249.31
# 4     ADIG    Abrdn Diversified Income & Growth Trust         67.71
# ..     ...                                        ...           ...
# 355   PUAL                         Puma Alpha VCT plc        108.22
# 356   PU13                            Puma VCT 13 Plc        126.54
# 357    UAV                        Unicorn AIM VCT plc        100.84
# 358   USFP                          US Solar Fund Plc         74.83
# 359    UTL                                    UIL Ltd        169.48
#
#      latest_actual_nav latest_actual_nav_date nav_premium  \
# 0               374.70      30 September 2024     -12.26%
# 1                  NaN                    NaN     -17.04%
# 2              1657.79       28 November 2024     -12.78%
# 3               249.80       27 November 2024     -12.96%
# 4                67.71       27 November 2024     -37.68%
# ..                 ...                    ...         ...
# 355                NaN                    NaN       3.95%
# 356             127.82      30 September 2024      -5.56%
# 357             102.22        31 October 2024     -10.75%
# 358              58.88      30 September 2024     -40.53%
# 359             170.36       28 November 2024     -33.62%
#
#     average_12_month_nav_premium   nav_frequency   volume div_yld  ...  \
# 0                         -8.05%           Daily  563,912   3.68%  ...
# 1                          0.00%           Daily  260,749      0%  ...
# 2                        -10.50%           Daily   77,128   2.85%  ...
# 3                        -12.57%           Daily  148,409   5.44%  ...
# 4                        -31.05%           Daily  248,717  13.40%  ...
# ..                           ...             ...      ...     ...  ...
# 355                        2.25%   Semi-Annually        0   4.44%  ...
# 356                       -3.82%   Semi-Annually        0      0%  ...
# 357                       -9.74%         Monthly        0   7.22%  ...
# 358                      -36.06%       Quarterly   39,921  12.98%  ...
# 359                      -37.40%          Weekly    3,035   7.11%  ...
#
#     market_cap_mils                        structure        domicile  \
# 0            2998.0  Closed Ended Investment Company          Jersey
# 1              86.0  Closed Ended Investment Company  United Kingdom
# 2            1215.0  Closed Ended Investment Company  United Kingdom
# 3             328.0  Closed Ended Investment Company          Jersey
# 4             127.0  Closed Ended Investment Company  United Kingdom
# ..              ...                              ...             ...
# 355            32.0  Closed Ended Investment Company  United Kingdom
# 356           162.0  Closed Ended Investment Company  United Kingdom
# 357           171.0  Closed Ended Investment Company  United Kingdom
# 358           137.0  Closed Ended Investment Company  United Kingdom
# 359           105.0  Closed Ended Investment Company         Bermuda
#
#              isin                                          objective  \
# 0    JE00BF5FX167  The Company aims to build a diversified portfo...
# 1    GB00BPJMQ253  To provide Ordinary Shareholders with high tot...
# 2    GB0000066554  To achieve a NAV total return (with dividends ...
# 3    GB00B0P6J834  To provide investors with a total return prima...
# 4    GB0001297562  To conduct an orderly realisation of its asset...
# ..            ...                                                ...
# 355  GB00BGMG7F10  The Company may invest in a mix of qualifying ...
# 356  GB00BD5B1L68  To maximise distributions from capital gains a...
# 357  GB00B1RTFN43  To identify and invest in a diversified portfo...
# 358  GB00BJCWFX49  To provide investors with attractive and susta...
# 359  BMG917071026  The investment objective is to maximise shareh...
#
#                                       top_ten_holdings  \
# 0    [('Tcr', '18.19%'), ('Esvagt', '15.89%'), ('In...
# 1    [('Vesuvius plc Ordinary 10p', '4.03%'), ('Cen...
# 2    [('Wilmington plc Ordinary 5p', '3.58%'), ('Ju...
# 3    [('Taiwan Semiconductor Manufacturing Co Ltd',...
# 4    [('SL CAP INFRA EUR', '14.09%'), ('ABERDEEN ST...
# ..                                                 ...
# 355  [('Camera Matics (â\x80\x98My Safe Drive Limit...
# 356  [('Influencer Limited', '11.07%'), ('Le Col Ho...
# 357  [('Hasgrove PLC', '20.45%'), ('Cohort plc Ordi...
# 358                   [('Usf Holding Corp', '99.25%')]
# 359  [('Somers Ltd', '68.02%'), ('Zeta Resources Li...
#
#                                        top_ten_sectors  \
# 0                                                   []
# 1    [('Industrials', '24.38%'), ('Financial Servic...
# 2    [('Industrials', '29.48%'), ('Financial Servic...
# 3    [('Technology', '33.20%'), ('Financial Service...
# 4                                                   []
# ..                                                 ...
# 355                                                 []
# 356                                                 []
# 357  [('Communication Services', '21.59%'), ('Healt...
# 358                                                 []
# 359                                                 []
#
#                                      top_ten_countries tradeable  \
# 0          [('Japan', '7.18%'), ('Colombia', '6.88%')]      True
# 1    [('United Kingdom', '91.06%'), ('Egypt', '3.80...      True
# 2    [('United Kingdom', '102.11%'), ('Singapore', ...      True
# 3    [('Taiwan', '27.46%'), ('Singapore', '18.41%')...      True
# 4    [('Netherlands', '3.62%'), ('Australia', '0.43...      True
# ..                                                 ...       ...
# 355                                                 []     False
# 356  [('United Kingdom', '1.01%'), ('United States'...     False
# 357  [('United Kingdom', '83.63%'), ('United States...     False
# 358                                                 []      True
# 359  [('United Kingdom', '68.02%'), ('Australia', '...      True
#
#                                                   link
# 0    https://www.hl.co.uk/shares/shares-search-resu...
# 1    https://www.hl.co.uk/shares/shares-search-resu...
# 2    https://www.hl.co.uk/shares/shares-search-resu...
# 3    https://www.hl.co.uk/shares/shares-search-resu...
# 4    https://www.hl.co.uk/shares/shares-search-resu...
# ..                                                 ...
# 355  https://www.hl.co.uk/shares/shares-search-resu...
# 356  https://www.hl.co.uk/shares/shares-search-resu...
# 357  https://www.hl.co.uk/shares/shares-search-resu...
# 358  https://www.hl.co.uk/shares/shares-search-resu...
# 359  https://www.hl.co.uk/shares/shares-search-resu...
#
# [360 rows x 26 columns]

# %%
trusts_with_audit = pd.merge(trust_data_df, audit_df, on='symbol', how='inner')
trusts_with_audit.to_csv('../data/investment_trust_data_audit_241201.csv')
trusts_with_audit
# Out:
#     symbol                                       name  estimate_nav  \
# 0      3IN                      3i Infrastructure plc        370.42
# 1     AGVI  Aberforth Geared Value & Income Trust Plc         97.04
# 2      ASL      Aberforth Smaller Companies Trust plc       1655.63
# 3     AAIF            Abrdn Asian Income Fund Limited        249.31
# 4     ADIG    Abrdn Diversified Income & Growth Trust         67.71
# ..     ...                                        ...           ...
# 350   PUAL                         Puma Alpha VCT plc        108.22
# 351   PU13                            Puma VCT 13 Plc        126.54
# 352    UAV                        Unicorn AIM VCT plc        100.84
# 353   USFP                          US Solar Fund Plc         74.83
# 354    UTL                                    UIL Ltd        169.48
#
#      latest_actual_nav latest_actual_nav_date nav_premium  \
# 0               374.70      30 September 2024     -12.26%
# 1                  NaN                    NaN     -17.04%
# 2              1657.79       28 November 2024     -12.78%
# 3               249.80       27 November 2024     -12.96%
# 4                67.71       27 November 2024     -37.68%
# ..                 ...                    ...         ...
# 350                NaN                    NaN       3.95%
# 351             127.82      30 September 2024      -5.56%
# 352             102.22        31 October 2024     -10.75%
# 353              58.88      30 September 2024     -40.53%
# 354             170.36       28 November 2024     -33.62%
#
#     average_12_month_nav_premium   nav_frequency   volume div_yld  ...  \
# 0                         -8.05%           Daily  563,912   3.68%  ...
# 1                          0.00%           Daily  260,749      0%  ...
# 2                        -10.50%           Daily   77,128   2.85%  ...
# 3                        -12.57%           Daily  148,409   5.44%  ...
# 4                        -31.05%           Daily  248,717  13.40%  ...
# ..                           ...             ...      ...     ...  ...
# 350                        2.25%   Semi-Annually        0   4.44%  ...
# 351                       -3.82%   Semi-Annually        0      0%  ...
# 352                       -9.74%         Monthly        0   7.22%  ...
# 353                      -36.06%       Quarterly   39,921  12.98%  ...
# 354                      -37.40%          Weekly    3,035   7.11%  ...
#
#              isin                                          objective  \
# 0    JE00BF5FX167  The Company aims to build a diversified portfo...
# 1    GB00BPJMQ253  To provide Ordinary Shareholders with high tot...
# 2    GB0000066554  To achieve a NAV total return (with dividends ...
# 3    GB00B0P6J834  To provide investors with a total return prima...
# 4    GB0001297562  To conduct an orderly realisation of its asset...
# ..            ...                                                ...
# 350  GB00BGMG7F10  The Company may invest in a mix of qualifying ...
# 351  GB00BD5B1L68  To maximise distributions from capital gains a...
# 352  GB00B1RTFN43  To identify and invest in a diversified portfo...
# 353  GB00BJCWFX49  To provide investors with attractive and susta...
# 354  BMG917071026  The investment objective is to maximise shareh...
#
#                                       top_ten_holdings  \
# 0    [('Tcr', '18.19%'), ('Esvagt', '15.89%'), ('In...
# 1    [('Vesuvius plc Ordinary 10p', '4.03%'), ('Cen...
# 2    [('Wilmington plc Ordinary 5p', '3.58%'), ('Ju...
# 3    [('Taiwan Semiconductor Manufacturing Co Ltd',...
# 4    [('SL CAP INFRA EUR', '14.09%'), ('ABERDEEN ST...
# ..                                                 ...
# 350  [('Camera Matics (â\x80\x98My Safe Drive Limit...
# 351  [('Influencer Limited', '11.07%'), ('Le Col Ho...
# 352  [('Hasgrove PLC', '20.45%'), ('Cohort plc Ordi...
# 353                   [('Usf Holding Corp', '99.25%')]
# 354  [('Somers Ltd', '68.02%'), ('Zeta Resources Li...
#
#                                        top_ten_sectors  \
# 0                                                   []
# 1    [('Industrials', '24.38%'), ('Financial Servic...
# 2    [('Industrials', '29.48%'), ('Financial Servic...
# 3    [('Technology', '33.20%'), ('Financial Service...
# 4                                                   []
# ..                                                 ...
# 350                                                 []
# 351                                                 []
# 352  [('Communication Services', '21.59%'), ('Healt...
# 353                                                 []
# 354                                                 []
#
#                                      top_ten_countries tradeable  \
# 0          [('Japan', '7.18%'), ('Colombia', '6.88%')]      True
# 1    [('United Kingdom', '91.06%'), ('Egypt', '3.80...      True
# 2    [('United Kingdom', '102.11%'), ('Singapore', ...      True
# 3    [('Taiwan', '27.46%'), ('Singapore', '18.41%')...      True
# 4    [('Netherlands', '3.62%'), ('Australia', '0.43...      True
# ..                                                 ...       ...
# 350                                                 []     False
# 351  [('United Kingdom', '1.01%'), ('United States'...     False
# 352  [('United Kingdom', '83.63%'), ('United States...     False
# 353                                                 []      True
# 354  [('United Kingdom', '68.02%'), ('Australia', '...      True
#
#                                                   link winding_down auditable  \
# 0    https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 1    https://www.hl.co.uk/shares/shares-search-resu...        False      True
# 2    https://www.hl.co.uk/shares/shares-search-resu...        False      True
# 3    https://www.hl.co.uk/shares/shares-search-resu...        False      True
# 4    https://www.hl.co.uk/shares/shares-search-resu...         True      True
# ..                                                 ...          ...       ...
# 350  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 351  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 352  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 353  https://www.hl.co.uk/shares/shares-search-resu...        False     False
# 354  https://www.hl.co.uk/shares/shares-search-resu...        False     False
#
#                                             audit_link
# 0
# 1    https://www.aberforth.co.uk/trusts-and-funds/a...
# 2    https://www.aberforth.co.uk/trusts-and-funds/a...
# 3    https://www.asian-income.co.uk/en-gb/literatur...
# 4    https://www.abrdndiversified.co.uk/en-gb/liter...
# ..                                                 ...
# 350
# 351
# 352
# 353
# 354
#
# [355 rows x 29 columns]

# %%
from get_hl_trust_data import *
from investment_trust import InvestmentTrust


jema_trust = InvestmentTrust(symbol='JEMA', name='JPMorgan Russian', link='', tradeable=True, premium=0.0)
jema_data = get_dummy_symbol_data(jema_trust)
jema_data
# Out:
# TrustData(symbol='JEMA', name='JPMorgan Russian', estimate_nav=0, latest_actual_nav=0, latest_actual_nav_date='', nav_premium='', average_12_month_nav_premium='', nav_frequency='', volume=0, div_yld='', currency='', annual_mgmt_charge='', performance_fee=False, ongoing_charge='', total_assets_mils=0, gross_gearing='', market_cap_mils=0, structure='', domicile='', isin='', objective='', top_ten_holdings=[], top_ten_sectors=[], top_ten_countries=[], tradeable=True, link='')

# %%
jema_df = pd.DataFrame([jema_data.__dict__])
jema_df
# Out:
#   symbol              name  estimate_nav  latest_actual_nav  \
# 0   JEMA  JPMorgan Russian             0                  0
#
#   latest_actual_nav_date nav_premium average_12_month_nav_premium  \
# 0
#
#   nav_frequency  volume div_yld  ... market_cap_mils structure  domicile isin  \
# 0                     0          ...               0
#
#    objective top_ten_holdings  top_ten_sectors top_ten_countries tradeable  \
# 0                          []               []                []      True
#
#   link
# 0
#
# [1 rows x 26 columns]

# %%
df_with_audit = pd.merge(jema_df, audit_df, on='symbol', how='inner')
df_with_audit
# Out:
#   symbol              name  estimate_nav  latest_actual_nav  \
# 0   JEMA  JPMorgan Russian             0                  0
#
#   latest_actual_nav_date nav_premium average_12_month_nav_premium  \
# 0
#
#   nav_frequency  volume div_yld  ... isin objective  top_ten_holdings  \
# 0                     0          ...                               []
#
#   top_ten_sectors  top_ten_countries tradeable  link winding_down auditable  \
# 0              []                 []      True              False      True
#
#   audit_link
# 0
#
# [1 rows x 29 columns]
