# %%
import pandas as pd
pd.set_option('future.no_silent_downcasting', True)

audit_data_filename = '../navninja/data/investment_trust_data_audit.csv'

audit_df = pd.read_csv(audit_data_filename).drop(["isin"], axis=1)
audit_df['winding_down'] = audit_df['winding_down'].fillna(False)
# audit_df['auditable'] = audit_df['auditable'].fillna(False)
audit_df['audit_link'] = audit_df['audit_link'].fillna("")

audit_df
# Out:
#     symbol winding_down auditable  \
# 0      3IN        False     False
# 1     AGVI        False      True
# 2      ASL        False      True
# 3     AAIF        False      True
# 4     ADIG         True      True
# ..     ...          ...       ...
# 368   PUAL        False     False
# 369   PU13        False     False
# 370    UAV        False     False
# 371   USFP        False     False
# 372    UTL        False       NaN
#
#                                             audit_link
# 0
# 1    https://www.aberforth.co.uk/trusts-and-funds/a...
# 2    https://www.aberforth.co.uk/trusts-and-funds/a...
# 3    https://www.asian-income.co.uk/en-gb/literatur...
# 4    https://www.abrdndiversified.co.uk/en-gb/liter...
# ..                                                 ...
# 368
# 369
# 370
# 371
# 372
#
# [373 rows x 4 columns]

# %%
trust_data_df = pd.read_csv('../data/investment_trust_data_241006.csv')
trust_data_df
# Out:
#      Unnamed: 0 symbol                                       name  \
# 0             0    3IN                      3i Infrastructure plc
# 1             1   AGVI  Aberforth Geared Value & Income Trust Plc
# 2             2    ASL      Aberforth Smaller Companies Trust plc
# 3             3   AAIF            Abrdn Asian Income Fund Limited
# 4             4   ADIG    Abrdn Diversified Income & Growth Trust
# ..          ...    ...                                        ...
# 277         277   WAFR                   Walls & Futures REIT plc
# 278         278    WHR                         Warehouse REIT plc
# 279         279   WKOF           Weiss Korea Opportunity Fund Ltd
# 280         280    WWH             Worldwide Healthcare Trust plc
# 281         281   WINV                  Worsley Investors Limited
#
#      estimate_nav  latest_actual_nav latest_actual_nav_date nav_premium  \
# 0          362.49             362.30          31 March 2024      -6.20%
# 1          100.83                NaN                    NaN     -16.10%
# 2         1691.09            1697.04         3 October 2024      -9.53%
# 3          255.36             255.02         2 October 2024     -13.46%
# 4           65.88              65.88         2 October 2024     -34.73%
# ..            ...                ...                    ...         ...
# 277          0.00               0.00                    NaN         NaN
# 278        124.65             124.50          31 March 2024     -30.77%
# 279        168.24             166.40         4 October 2024      -5.49%
# 280        385.95             384.26         2 October 2024      -9.83%
# 281         47.68              47.68           30 June 2024     -40.23%
#
#     average_12_month_nav_premium   nav_frequency     volume  ...  \
# 0                         -8.01%           Daily    515,157  ...
# 1                          0.00%           Daily    250,860  ...
# 2                        -10.80%           Daily    124,552  ...
# 3                        -12.73%           Daily    347,675  ...
# 4                        -30.30%           Daily    337,261  ...
# ..                           ...             ...        ...  ...
# 277                          NaN             NaN          0  ...
# 278                      -33.59%   Semi-Annually    573,998  ...
# 279                       -2.90%           Daily          0  ...
# 280                      -10.33%           Daily  1,345,796  ...
# 281                      -40.97%       Quarterly          0  ...
#
#     market_cap_mils                        structure        domicile  \
# 0            3136.0  Closed Ended Investment Company          Jersey
# 1              91.0  Closed Ended Investment Company  United Kingdom
# 2            1287.0  Closed Ended Investment Company  United Kingdom
# 3             342.0  Closed Ended Investment Company          Jersey
# 4             129.0  Closed Ended Investment Company  United Kingdom
# ..              ...                              ...             ...
# 277             0.0                              NaN             NaN
# 278           367.0  Closed Ended Investment Company  United Kingdom
# 279           110.0  Closed Ended Investment Company        Guernsey
# 280          1799.0  Closed Ended Investment Company  United Kingdom
# 281            10.0  Closed Ended Investment Company        Guernsey
#
#              isin                                          objective  \
# 0    JE00BF5FX167  The Company aims to build a diversified portfo...
# 1    GB00BPJMQ253  To provide Ordinary Shareholders with high tot...
# 2    GB0000066554  To achieve a NAV total return (with dividends ...
# 3    GB00B0P6J834  To provide investors with a total return prima...
# 4    GB0001297562  To conduct an orderly realisation of its asset...
# ..            ...                                                ...
# 277           NaN                                                NaN
# 278  GB00BD2NCM38  To provide shareholders with an attractive lev...
# 279  GG00B933LL68  The investment objective is to provide shareho...
# 280  GB00BN455J50  In order to achieve a high level of capital gr...
# 281  GG00BHXH0C87  To provide shareholders with an attractive lev...
#
#                                       top_ten_holdings  \
# 0    [('Tcr', '17.32%'), ('Esvagt', '15.64%'), ('In...
# 1    [('Vesuvius plc Ordinary 10p', '4.03%'), ('Cen...
# 2    [('Wilmington plc Ordinary 5p', '3.43%'), ('Ju...
# 3    [('Taiwan Semiconductor Manufacturing Co Ltd',...
# 4    [('SL CAP INFRA EUR', '13.56%'), ('ABERDEEN ST...
# ..                                                 ...
# 277                                                 []
# 278               [('Investment Property', '153.19%')]
# 279                                                 []
# 280  [('Eli Lilly and Co', '10.08%'), ('Boston Scie...
# 281  [('Uci Curno', '46.91%'), ('Smiths News PLC', ...
#
#                                        top_ten_sectors  \
# 0                                                   []
# 1    [('Industrials', '24.38%'), ('Financial Servic...
# 2    [('Industrials', '28.13%'), ('Financial Servic...
# 3    [('Technology', '35.34%'), ('Financial Service...
# 4                                                   []
# ..                                                 ...
# 277                                                 []
# 278                                                 []
# 279                                                 []
# 280                         [('Healthcare', '99.65%')]
# 281  [('Communication Services', '24.38%'), ('Techn...
#
#                                      top_ten_countries tradeable  \
# 0                                                   []      True
# 1    [('United Kingdom', '91.06%'), ('Egypt', '3.80...      True
# 2    [('United Kingdom', '100.42%'), ('Egypt', '2.7...      True
# 3    [('Taiwan', '25.94%'), ('Singapore', '19.01%')...      True
# 4    [('Netherlands', '3.53%'), ('Australia', '0.26...      True
# ..                                                 ...       ...
# 277                                                 []     False
# 278                                                 []      True
# 279                                                 []      True
# 280  [('United States', '73.66%'), ('United Kingdom...      True
# 281                     [('United Kingdom', '29.75%')]      True
#
#                                                   link
# 0    https://www.hl.co.uk/shares/shares-search-resu...
# 1    https://www.hl.co.uk/shares/shares-search-resu...
# 2    https://www.hl.co.uk/shares/shares-search-resu...
# 3    https://www.hl.co.uk/shares/shares-search-resu...
# 4    https://www.hl.co.uk/shares/shares-search-resu...
# ..                                                 ...
# 277  https://www.hl.co.uk/shares/shares-search-resu...
# 278  https://www.hl.co.uk/shares/shares-search-resu...
# 279  https://www.hl.co.uk/shares/shares-search-resu...
# 280  https://www.hl.co.uk/shares/shares-search-resu...
# 281  https://www.hl.co.uk/shares/shares-search-resu...
#
# [282 rows x 27 columns]

# %%
trusts_with_audit = pd.merge(trust_data_df, audit_df, on='symbol', how='inner')
trusts_with_audit.to_csv('../data/investment_trust_data_audit_241006.csv')
trusts_with_audit
# Out:
#      Unnamed: 0 symbol                                       name  \
# 0             0    3IN                      3i Infrastructure plc
# 1             1   AGVI  Aberforth Geared Value & Income Trust Plc
# 2             2    ASL      Aberforth Smaller Companies Trust plc
# 3             3   AAIF            Abrdn Asian Income Fund Limited
# 4             4   ADIG    Abrdn Diversified Income & Growth Trust
# ..          ...    ...                                        ...
# 276         277   WAFR                   Walls & Futures REIT plc
# 277         278    WHR                         Warehouse REIT plc
# 278         279   WKOF           Weiss Korea Opportunity Fund Ltd
# 279         280    WWH             Worldwide Healthcare Trust plc
# 280         281   WINV                  Worsley Investors Limited
#
#      estimate_nav  latest_actual_nav latest_actual_nav_date nav_premium  \
# 0          362.49             362.30          31 March 2024      -6.20%
# 1          100.83                NaN                    NaN     -16.10%
# 2         1691.09            1697.04         3 October 2024      -9.53%
# 3          255.36             255.02         2 October 2024     -13.46%
# 4           65.88              65.88         2 October 2024     -34.73%
# ..            ...                ...                    ...         ...
# 276          0.00               0.00                    NaN         NaN
# 277        124.65             124.50          31 March 2024     -30.77%
# 278        168.24             166.40         4 October 2024      -5.49%
# 279        385.95             384.26         2 October 2024      -9.83%
# 280         47.68              47.68           30 June 2024     -40.23%
#
#     average_12_month_nav_premium   nav_frequency     volume  ...  \
# 0                         -8.01%           Daily    515,157  ...
# 1                          0.00%           Daily    250,860  ...
# 2                        -10.80%           Daily    124,552  ...
# 3                        -12.73%           Daily    347,675  ...
# 4                        -30.30%           Daily    337,261  ...
# ..                           ...             ...        ...  ...
# 276                          NaN             NaN          0  ...
# 277                      -33.59%   Semi-Annually    573,998  ...
# 278                       -2.90%           Daily          0  ...
# 279                      -10.33%           Daily  1,345,796  ...
# 280                      -40.97%       Quarterly          0  ...
#
#              isin                                          objective  \
# 0    JE00BF5FX167  The Company aims to build a diversified portfo...
# 1    GB00BPJMQ253  To provide Ordinary Shareholders with high tot...
# 2    GB0000066554  To achieve a NAV total return (with dividends ...
# 3    GB00B0P6J834  To provide investors with a total return prima...
# 4    GB0001297562  To conduct an orderly realisation of its asset...
# ..            ...                                                ...
# 276           NaN                                                NaN
# 277  GB00BD2NCM38  To provide shareholders with an attractive lev...
# 278  GG00B933LL68  The investment objective is to provide shareho...
# 279  GB00BN455J50  In order to achieve a high level of capital gr...
# 280  GG00BHXH0C87  To provide shareholders with an attractive lev...
#
#                                       top_ten_holdings  \
# 0    [('Tcr', '17.32%'), ('Esvagt', '15.64%'), ('In...
# 1    [('Vesuvius plc Ordinary 10p', '4.03%'), ('Cen...
# 2    [('Wilmington plc Ordinary 5p', '3.43%'), ('Ju...
# 3    [('Taiwan Semiconductor Manufacturing Co Ltd',...
# 4    [('SL CAP INFRA EUR', '13.56%'), ('ABERDEEN ST...
# ..                                                 ...
# 276                                                 []
# 277               [('Investment Property', '153.19%')]
# 278                                                 []
# 279  [('Eli Lilly and Co', '10.08%'), ('Boston Scie...
# 280  [('Uci Curno', '46.91%'), ('Smiths News PLC', ...
#
#                                        top_ten_sectors  \
# 0                                                   []
# 1    [('Industrials', '24.38%'), ('Financial Servic...
# 2    [('Industrials', '28.13%'), ('Financial Servic...
# 3    [('Technology', '35.34%'), ('Financial Service...
# 4                                                   []
# ..                                                 ...
# 276                                                 []
# 277                                                 []
# 278                                                 []
# 279                         [('Healthcare', '99.65%')]
# 280  [('Communication Services', '24.38%'), ('Techn...
#
#                                      top_ten_countries  tradeable  \
# 0                                                   []       True
# 1    [('United Kingdom', '91.06%'), ('Egypt', '3.80...       True
# 2    [('United Kingdom', '100.42%'), ('Egypt', '2.7...       True
# 3    [('Taiwan', '25.94%'), ('Singapore', '19.01%')...       True
# 4    [('Netherlands', '3.53%'), ('Australia', '0.26...       True
# ..                                                 ...        ...
# 276                                                 []      False
# 277                                                 []       True
# 278                                                 []       True
# 279  [('United States', '73.66%'), ('United Kingdom...       True
# 280                     [('United Kingdom', '29.75%')]       True
#
#                                                   link  winding_down  \
# 0    https://www.hl.co.uk/shares/shares-search-resu...         False
# 1    https://www.hl.co.uk/shares/shares-search-resu...         False
# 2    https://www.hl.co.uk/shares/shares-search-resu...         False
# 3    https://www.hl.co.uk/shares/shares-search-resu...         False
# 4    https://www.hl.co.uk/shares/shares-search-resu...          True
# ..                                                 ...           ...
# 276  https://www.hl.co.uk/shares/shares-search-resu...         False
# 277  https://www.hl.co.uk/shares/shares-search-resu...         False
# 278  https://www.hl.co.uk/shares/shares-search-resu...         False
# 279  https://www.hl.co.uk/shares/shares-search-resu...         False
# 280  https://www.hl.co.uk/shares/shares-search-resu...         False
#
#     auditable                                         audit_link
# 0       False
# 1        True  https://www.aberforth.co.uk/trusts-and-funds/a...
# 2        True  https://www.aberforth.co.uk/trusts-and-funds/a...
# 3        True  https://www.asian-income.co.uk/en-gb/literatur...
# 4        True  https://www.abrdndiversified.co.uk/en-gb/liter...
# ..        ...                                                ...
# 276     False
# 277     False
# 278     False
# 279      True
# 280      True
#
# [281 rows x 30 columns]

# %%
from get_hl_trust_data import *
from investment_trust import InvestmentTrust


jema_trust = InvestmentTrust(symbol='JEMA', name='JPMorgan Russian', link='', tradeable=True, premium=0.0)
jema_data = get_dummy_symbol_data(jema_trust)
jema_data
# Out:
# TrustData(symbol='JEMA', name='JPMorgan Russian', estimate_nav=0, latest_actual_nav=0, latest_actual_nav_date='', nav_premium='', average_12_month_nav_premium='', nav_frequency='', volume=0, div_yld='', currency='', annual_mgmt_charge='', performance_fee=False, ongoing_charge='', total_assets_mils=0, gross_gearing='', market_cap_mils=0, structure='', domicile='', isin='', objective='', top_ten_holdings=[], top_ten_sectors=[], top_ten_countries=[], tradeable=True, link='')

# %%
jema_df = pd.DataFrame([jema_data.__dict__])
jema_df
# Out:
#   symbol              name  estimate_nav  latest_actual_nav  \
# 0   JEMA  JPMorgan Russian             0                  0
#
#   latest_actual_nav_date nav_premium average_12_month_nav_premium  \
# 0
#
#   nav_frequency  volume div_yld  ... market_cap_mils structure  domicile isin  \
# 0                     0          ...               0
#
#    objective top_ten_holdings  top_ten_sectors top_ten_countries tradeable  \
# 0                          []               []                []      True
#
#   link
# 0
#
# [1 rows x 26 columns]

# %%
df_with_audit = pd.merge(jema_df, audit_df, on='symbol', how='inner')
df_with_audit
# Out:
#   symbol              name  estimate_nav  latest_actual_nav  \
# 0   JEMA  JPMorgan Russian             0                  0
#
#   latest_actual_nav_date nav_premium average_12_month_nav_premium  \
# 0
#
#   nav_frequency  volume div_yld  ... isin objective  top_ten_holdings  \
# 0                     0          ...                               []
#
#   top_ten_sectors  top_ten_countries tradeable  link winding_down auditable  \
# 0              []                 []      True              False      True
#
#   audit_link
# 0
#
# [1 rows x 29 columns]
