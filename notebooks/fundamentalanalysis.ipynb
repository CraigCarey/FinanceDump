# %%
import fundamentalanalysis as fa

# %%
with open('/home/craigc/.keys/financialmodelingprep.txt', 'r') as file:
    api_key = file.read()

# %%
companies = fa.available_companies(api_key)
len(companies)
companies
# Out:
#                                            name      price  \
# symbol
# 4064.T      Nippon Carbide Industries Co., Inc.  1265.0000
# LEXTF               Lexston Life Sciences Corp.     0.0418
# CSRYX      Columbia Select Large Cap Value Fund    31.6300
# YXI               ProShares Short FTSE China 50    17.7500
# NWXQX      Nationwide Mid Cap Market Index Fund    16.1200
# ...                                         ...        ...
# TRUS.JK          PT Trust Finance Indonesia Tbk   372.0000
# BKY.L                  Berkeley Energia Limited    16.0000
# 600346.SS         Hengli Petrochemical Co.,Ltd.    16.4700
# 0224.HK            Pioneer Global Group Limited     0.7800
# MLTM.TA                        Malam - Team Ltd  7671.0000
#
#                                exchange exchangeShortName   type
# symbol
# 4064.T                            Tokyo               JPX  stock
# LEXTF                         Other OTC               PNK  stock
# ...

# %%
lse_companies = companies[(companies.exchangeShortName == 'LSE')]
print(f"num LSE companies: {len(lse_companies)}")
lse_companies
# Out:
# num LSE companies: 6335
#                                                      name       price  \
# symbol
# JRDM.L  JPMorgan ETFs (Ireland) ICAV - Global Emerging...   2008.0000
# IDVY.L                    iShares Euro Dividend UCITS ETF   1517.6400
# VJPU.L                      Vanguard FTSE Japan UCITS ETF     32.1975
# CH5.L         Amundi ETF MSCI Europe Healthcare UCITS ETF  30160.0000
# ITEP.L     HAN-GINS Tech Megatrend Equal Weight UCITS ETF    721.6780
# ...                                                   ...         ...
# MVI.L                      Marwyn Value Investors Limited     95.0000
# IAT.L                              Invesco Asia Trust plc    325.3600
# 0KD1.L                                      Tubacex, S.A.      1.9980
# DOCS.L                                    Dr. Martens plc    178.8000
# BKY.L                            Berkeley Energia Limited     16.0000
#
#                      exchange exchangeShortName   type
# symbol
# ...

# %%
lse_stocks = lse_companies[(lse_companies.type == 'stock')]
print(f"num LSE stocks: {len(lse_stocks)}")
lse_stocks
# Out:
# num LSE stocks: 3877
#                                                name     price  \
# symbol
# AIR3.L  Leverage Shares 3x Long Airbus (AIR.PA) ETC     3.542
# KINO.L                                   Kinovo plc    33.000
# HILS.L                    Hill & Smith Holdings PLC  1180.000
# OSI.L                      Osirium Technologies PLC     2.811
# SRT.L                        SRT Marine Systems plc    48.440
# ...                                             ...       ...
# IDEA.L                                  Ideagen plc   349.000
# MVI.L                Marwyn Value Investors Limited    95.000
# 0KD1.L                                Tubacex, S.A.     1.998
# DOCS.L                              Dr. Martens plc   178.800
# BKY.L                      Berkeley Energia Limited    16.000
#
#                      exchange exchangeShortName   type
# symbol
# AIR3.L  London Stock Exchange               LSE  stock
# KINO.L  London Stock Exchange               LSE  stock
# ...

# %%
# ticker = 'MSFT'
ticker = 'POLY.L'
profile = fa.profile(ticker, api_key)
profile
# Out:
#                                                                    0
# symbol                                                        POLY.L
# price                                                          241.1
# beta                                                        0.567959
# volAvg                                                        369750
# mktCap                                                  114191224742
# lastDiv                                                         52.0
# range                                                   92.02-1322.5
# changes                                                         -8.7
# companyName                              Polymetal International plc
# currency                                                         GBp
# cik                                                             None
# isin                                                    JE00B6T5S470
# cusip                                                           None
# ...

# %%
# No historic DCF for POLY
try:
    dcf_annually = fa.discounted_cash_flow(ticker, api_key, period="annual")
    print(dcf_annually.keys().tolist())
    dcf_annually
except:
    print(f"Couldn't get DCF for {ticker}")
# Out:
# Couldn't get DCF for POLY.L

# %%
balance_sheet_annually = fa.balance_sheet_statement(ticker, api_key, period="annual")
print(balance_sheet_annually.keys().tolist())
balance_sheet_annually
# Out:
# ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005']
#                                                                                       2021  \
# reportedCurrency                                                                       USD
# cik                                                                                   None
# fillingDate                                                                     2021-12-31
# acceptedDate                                                                    2021-12-31
# calendarYear                                                                          2021
# period                                                                                  FY
# cashAndCashEquivalents                                                           417000000
# shortTermInvestments                                                             5000000.0
# ...

# %%
income_statement_annually = fa.income_statement(ticker, api_key, period="annual")
print(income_statement_annually.keys().tolist())
income_statement_annually
# Out:
# ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005']
#                                                                                       2021  \
# reportedCurrency                                                                       USD
# cik                                                                                   None
# fillingDate                                                                     2021-12-31
# acceptedDate                                                                    2021-12-31
# calendarYear                                                                          2021
# period                                                                                  FY
# revenue                                                                         2890000000
# costOfRevenue                                                                   1307000000
# ...

# %%
cash_flow_statement_annually = fa.cash_flow_statement(ticker, api_key, period="annual")
print(cash_flow_statement_annually.keys().tolist())
cash_flow_statement_annually
# Out:
# ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011', '2010', '2009', '2008', '2007', '2006', '2005']
#                                                                                        2021  \
# reportedCurrency                                                                        USD
# cik                                                                                    None
# fillingDate                                                                      2021-12-31
# acceptedDate                                                                     2021-12-31
# calendarYear                                                                           2021
# period                                                                                   FY
# netIncome                                                                         904000000
# depreciationAndAmortization                                                       214000000
# ...

# %%
enterprise_value = fa.enterprise(ticker, api_key)
print(enterprise_value.keys().to_list())
enterprise_value
# Out:
# ['2021', '2020', '2019', '2018', '2017', '2016', '2015', '2014', '2013', '2012', '2011']
#                                        2021               2020           2019  \
# symbol                               POLY.L             POLY.L         POLY.L
# stockPrice                           1048.5             1581.0         1266.0
# numberOfShares                    471278987          471278987      469926157
# marketCapitalization         494136017869.5       745092078447   594926514762
# minusCashAndCashEquivalents       417000000          386000000      253000000
# addTotalDebt                     2100000000         1770000000     1764000000
# enterpriseValue              6624360178.695  8834920784.470001  7460265147.62
#
#                                             2018                 2017  \
# symbol                                    POLY.L               POLY.L
# stockPrice                            857.599976           825.799988
# ...

# %%
ratings = fa.rating(ticker, api_key)
print(ratings.keys().to_list())
ratings
# Out:
# ['rating', 'ratingScore', 'ratingRecommendation', 'ratingDetailsDCFScore', 'ratingDetailsDCFRecommendation', 'ratingDetailsROEScore', 'ratingDetailsROERecommendation', 'ratingDetailsROAScore', 'ratingDetailsROARecommendation', 'ratingDetailsDEScore', 'ratingDetailsDERecommendation', 'ratingDetailsPEScore', 'ratingDetailsPERecommendation', 'ratingDetailsPBScore', 'ratingDetailsPBRecommendation']
#            rating  ratingScore ratingRecommendation  ratingDetailsDCFScore  \
# date
# 2022-12-16     A+            5           Strong Buy                      5
# 2022-12-15     A+            5           Strong Buy                      5
# 2022-12-14     A+            5           Strong Buy                      5
# 2022-12-13     A+            5           Strong Buy                      5
# 2022-12-12     A+            5           Strong Buy                      5
# ...           ...          ...                  ...                    ...
# ...

# %%
quotes = fa.quote(ticker, api_key)
quotes
# Out:
#                                                  0
# symbol                                      POLY.L
# name                   Polymetal International plc
# price                                        241.1
# changesPercentage                          -3.4828
# change                                        -8.7
# dayLow                                         235
# dayHigh                                        251
# yearHigh                                    1322.5
# yearLow                                      92.02
# marketCap                             114191224742
# priceAvg50                                 228.258
# priceAvg200                               220.1726
# volume                                       69541
# avgVolume                                   369750
# exchange                                       LSE
# open                                           235
# previousClose                                249.8
# ...

# %%
key_metrics_annually = fa.key_metrics(ticker, api_key, period="annual")
key_metrics_annually
# Out:
#                                                   2021               2020  \
# period                                              FY                 FY
# revenuePerShare                               6.132249           6.079202
# netIncomePerShare                             1.918184           2.304368
# operatingCashFlowPerShare                     2.535653           2.529287
# freeCashFlowPerShare                          0.925142           1.292228
# cashPerShare                                  0.895436           0.823292
# bookValuePerShare                             4.674514           4.248015
# tangibleBookValuePerShare                     4.644807           3.318629
# shareholdersEquityPerShare                    4.674514           4.248015
# interestDebtPerShare                          4.596004           3.904269
# marketCap                               4941360178.695      7450920784.47
# enterpriseValue                         6624360178.695  8834920784.470001
# ...

# %%
stock_data = fa.stock_data(ticker, period="ytd", interval="1d")
len(stock_data)
stock_data
# Out:
#                   close         high          low   volume         open  \
# 2022-01-04  1282.500000  1303.500000  1271.000000  2032792  1296.500000
# 2022-01-05  1249.000000  1286.500000  1247.000000  1582238  1282.500000
# 2022-01-06  1200.500000  1237.500000  1198.469971  2275081  1229.000000
# 2022-01-07  1194.000000  1205.000000  1184.251953  1410725  1200.000000
# 2022-01-10  1190.000000  1213.996948  1184.000000  1809543  1205.000000
# ...                 ...          ...          ...      ...          ...
# 2022-12-13   244.000000   248.000000   235.000000   147106   235.100006
# 2022-12-14   251.000000   251.000000   240.100006   226326   248.699997
# 2022-12-15   247.399994   249.100006   239.000000   310992   249.100006
# 2022-12-16   249.800003   249.800003   237.500000   200975   245.899994
# 2022-12-19   241.100006   251.000000   235.000000    70541   235.000000
#
#                adjclose
# 2022-01-04  1026.884888
# 2022-01-05  1000.061707
# 2022-01-06   961.228271
# ...

# %%
stock_data_detailed = fa.stock_data_detailed(ticker, api_key, begin="2000-01-01", end="2022-12-01")
len(stock_data_detailed)
stock_data_detailed
# Out:
#              open     high       low  close    adjClose     volume  \
# 2022-12-01  244.0    247.5    233.67  240.0       240.0   143277.0
# 2022-11-30  240.0  243.136     234.0  236.0       236.0   611596.0
# 2022-11-29  243.4    245.0  235.0906  239.0       239.0   483023.0
# 2022-11-28  240.0    249.7   232.238  249.7       249.7   139738.0
# 2022-11-25  238.5   245.77     232.0  241.0       241.0   136900.0
# ...           ...      ...       ...    ...         ...        ...
# 2011-11-03  923.0    925.0     916.5  917.0  470.611359  2976084.0
# 2011-11-02  900.0    930.0     885.0  930.0  477.283142  3411198.0
# 2011-11-01  917.0    919.0     875.0  877.0   450.08313  1697902.0
# 2011-10-31  920.0    923.5     918.0  920.0  472.151062  5002744.0
# 2011-10-28  920.0    975.0     915.0  920.0  472.151062  9864658.0
#
#            unadjustedVolume     change changePercent       vwap  \
# 2022-12-01         143277.0       -4.0        -1.639     240.39
# ...

# %%
dividends = fa.stock_dividend(ticker, api_key, begin="2000-01-01", end="2022-12-01")
len(dividends)
dividends
# Out:
#                        label adjDividend dividend  recordDate paymentDate  \
# 2022-05-05        May 05, 22        52.0     52.0
# 2021-09-09  September 09, 21      32.587   32.587
# 2021-05-06        May 06, 21     63.3537  63.3537
# 2020-09-03  September 03, 20     30.9198  30.9198
# 2020-05-07        May 07, 20      34.397     0.42  2020-05-11  2020-05-29
# 2020-02-13   February 13, 20     15.3908      0.2  2020-02-14  2020-03-05
# 2019-09-05  September 05, 19     16.1696      0.2  2019-09-06  2019-09-27
# 2019-05-09        May 09, 19      23.974     0.31  2019-05-10  2019-05-24
# 2018-09-06  September 06, 18      13.068     0.17  2018-09-07  2018-09-28
# 2018-05-10        May 10, 18     22.2585      0.3  2018-05-11  2018-05-23
# 2017-09-07  September 07, 17     10.6037     0.14  2017-09-08  2017-09-29
# 2017-05-04        May 04, 17      13.973     0.18  2017-05-05  2017-05-26
# 2016-12-15   December 15, 16     12.1046     0.15  2016-12-16  2016-12-29
# ...

# %%
from urllib.request import urlopen
import certifi
import json
import pandas as pd

def get_jsonparsed_data(url):
    """
    Receive the content of ``url``, parse it as JSON and return the object.

    Parameters
    ----------
    url : str

    Returns
    -------
    dict
    """
    response = urlopen(url, cafile=certifi.where())
    data = response.read().decode("utf-8")
    return json.loads(data)

# %%
url = (f"https://financialmodelingprep.com/api/v3/discounted-cash-flow/{ticker}?apikey={api_key}")
print(get_jsonparsed_data(url))
df = pd.read_json(url)
df
# Out:
# /tmp/ipykernel_103581/1235619366.py:18: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# [{'symbol': 'POLY.L', 'date': '2022-12-19', 'dcf': 241.98482621017007, 'Stock Price': 241.1}]
#    symbol       date         dcf  Stock Price
# 0  POLY.L 2022-12-19  241.984826        241.1

# %%
url = (f"https://financialmodelingprep.com/api/v3/historical-discounted-cash-flow/{ticker}?apikey={api_key}")
print(get_jsonparsed_data(url))
df = pd.read_json(url)
df
# Out:
# /tmp/ipykernel_103581/1235619366.py:18: DeprecationWarning: cafile, capath and cadefault are deprecated, use a custom context instead.
#   response = urlopen(url, cafile=certifi.where())
# [{}]
# Empty DataFrame
# Columns: []
# Index: [0]
