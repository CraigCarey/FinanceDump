# %%
import pickle
from urllib.request import urlopen
import certifi
import json
import pandas as pd
from datetime import datetime
import json
import queue
import threading

import fundamentalanalysis as fa
import fa_mods as famods
import fa_utils

with open('/home/craigc/.keys/financialmodelingprep.txt', 'r') as file:
    api_key = file.read()

# %%
all_companies = fa.available_companies(api_key)
tradeable_companies = famods.tradable_companies(api_key)

display(len(all_companies))
display(len(tradeable_companies))
# Out:
# 70192
# 53942

# %%
exchanges = all_companies.groupby('exchangeShortName')['exchange'].agg('unique').reset_index().rename(columns={'exchangeShortName': 'short_name', 'unique': 'exchange'})

# %%
datestamp = datetime.now().strftime('%y%m%d')

with open(f'../data/all_symbols_{datestamp}.pkl', 'wb') as file:
    pickle.dump(all_companies, file)

with open(f'../data/all_tradable_symbols_{datestamp}.pkl', 'wb') as file:
    pickle.dump(tradeable_companies, file)

with open(f'../data/exchanges_{datestamp}.pkl', 'wb') as file:
    pickle.dump(exchanges, file)

# %%
lse_companies = all_companies[(all_companies.exchangeShortName == 'LSE')]
nyse_companies = all_companies[(all_companies.exchangeShortName == 'NYSE')]
nasdaq_companies = all_companies[(all_companies.exchangeShortName == 'NASDAQ')]

lse_stocks = lse_companies[(lse_companies.type == 'stock')].reset_index().drop(['exchange', 'exchangeShortName', 'type', 'price'], axis=1)
nyse_stocks = nyse_companies[(nyse_companies.type == 'stock')].reset_index().drop(['exchange', 'exchangeShortName', 'type', 'price'], axis=1)
nasdaq_stocks = nasdaq_companies[(nasdaq_companies.type == 'stock')].reset_index().drop(['exchange', 'exchangeShortName', 'type', 'price'], axis=1)

print(f"num LSE companies: {len(lse_companies)}")
print(f"num LSE stocks: {len(lse_stocks)}")
print()
print(f"num NYSE companies: {len(nyse_companies)}")
print(f"num NYSE stocks: {len(nyse_stocks)}")
print()
print(f"num NASDAQ companies: {len(nasdaq_companies)}")
print(f"num NASDAQ stocks: {len(nasdaq_stocks)}")
# Out:
# num LSE companies: 4829
# num LSE stocks: 3001
#
# num NYSE companies: 3614
# num NYSE stocks: 3083
#
# num NASDAQ companies: 6199
# num NASDAQ stocks: 5473

# %%
thread_lock = threading.Lock()

def get_exchange_data(exchange: str):
    datestamp = datetime.now().strftime('%y%m%d')
    exchange_companies = all_companies[(all_companies.exchangeShortName == exchange)]
    exchange_stocks = exchange_companies[(exchange_companies.type == 'stock')].reset_index().drop(['exchange', 'exchangeShortName', 'type', 'price'], axis=1)

    symbols = exchange_stocks.symbol.tolist()
    stock_data = {}
    failed = []
    num_stocks = len(symbols)
    cnt = 0

    symbol_queue = queue.Queue()
    [symbol_queue.put(s) for s in symbols]
    symbol_queue.qsize()

    def worker():
        nonlocal cnt
        nonlocal stock_data
        nonlocal failed
        while True:
            with thread_lock:
                cnt += 1
                symbol = symbol_queue.get()        
                print(f'{exchange} [{cnt}/{num_stocks}]: getting {symbol} - f[{len(failed)}], s[{len(stock_data)}]')

            if symbol in stock_data:
                print(f"Already have {symbol}, skipping")
                continue

            try:
                data = fa_utils.get_ticker_data(symbol, api_key)
                stock_data[symbol] = data
                print(f"{symbol} SUCCESS")
            except:
                print(f"{symbol} FAILED")
                failed.append(symbol)

            symbol_queue.task_done()

    for x in range(4):
        name = "Thread_" + str(x)
        t = threading.Thread(name=name,target=worker, daemon=True).start()

    symbol_queue.join()

    print(len(failed))
    print(len(stock_data))

    with open(f'../data/all_{exchange.lower()}_stock_data_{datestamp}.pkl', 'wb') as file:
        pickle.dump(stock_data, file)

    with open(f'../data/all_{exchange.lower()}_stock_data_{datestamp}_failed.pkl', 'wb') as file:
        pickle.dump(failed, file)

    return stock_data, failed

# %%
exchange = 'LSE'
data, failed = get_exchange_data(exchange)
# Out:
# LSE [1/3877]: getting MIRI.L - f[0], s[0]
# LSE [2/3877]: getting STAN.L - f[0], s[0]
# LSE [3/3877]: getting AIR3.L - f[0], s[0]
# LSE [4/3877]: getting ESO.L - f[0], s[0]
# AIR3.L SUCCESS
# LSE [5/3877]: getting WISE.L - f[0], s[1]
# MIRI.L SUCCESS
# LSE [6/3877]: getting EMUM.L - f[0], s[2]
# ESO.L SUCCESS
# LSE [7/3877]: getting COMF.L - f[0], s[3]
# STAN.L SUCCESS
# LSE [8/3877]: getting 72HN.L - f[0], s[4]
# WISE.L SUCCESS
# LSE [9/3877]: getting TCAP.L - f[0], s[5]
# EMUM.L SUCCESS
# LSE [10/3877]: getting DMTR.L - f[0], s[6]
# COMF.L SUCCESS
# LSE [11/3877]: getting 0QL5.L - f[0], s[7]
# 72HN.L SUCCESS
# LSE [12/3877]: getting WEIR.L - f[0], s[8]
# DMTR.L SUCCESS
# LSE [13/3877]: getting ASIA.L - f[0], s[9]
# 0QL5.L SUCCESS
# LSE [14/3877]: getting DVT.L - f[0], s[10]
# TCAP.L SUCCESS
# LSE [15/3877]: getting 5QQE.L - f[0], s[11]
# WEIR.L SUCCESS
# LSE [16/3877]: getting BPCR.L - f[0], s[12]
# 5QQE.L SUCCESS
# LSE [17/3877]: getting SFBE.L - f[0], s[13]
# ASIA.L SUCCESS
# LSE [18/3877]: getting KGF.L - f[0], s[14]
# DVT.L SUCCESS
# LSE [19/3877]: getting QLT.L - f[0], s[15]
# BPCR.L SUCCESS
# LSE [20/3877]: getting CCZ.L - f[0], s[16]
# SFBE.L SUCCESS
# LSE [21/3877]: getting 3STL.L - f[0], s[17]
# KGF.L SUCCESS
# LSE [22/3877]: getting WIL.L - f[0], s[18]
# CCZ.L SUCCESS
# LSE [23/3877]: getting GISG.L - f[0], s[19]
# 3STL.L SUCCESS
# LSE [24/3877]: getting PLT3.L - f[0], s[20]
# GISG.L SUCCESS
# LSE [25/3877]: getting AHT.L - f[0], s[21]
# WIL.L SUCCESS
# LSE [26/3877]: getting AUGM.L - f[0], s[22]
# PLT3.L SUCCESS
# LSE [27/3877]: getting SGLP.L - f[0], s[23]
# AUGM.L SUCCESS
# LSE [28/3877]: getting AVCT.L - f[0], s[24]
# AHT.L SUCCESS
# LSE [29/3877]: getting IUQD.L - f[0], s[25]
# SGLP.L SUCCESS
# LSE [30/3877]: getting 0ELV.L - f[0], s[26]
# IUQD.L SUCCESS
# LSE [31/3877]: getting 0KSA.L - f[0], s[27]
# 0ELV.L SUCCESS
# LSE [32/3877]: getting FLK.L - f[0], s[28]
# AVCT.L SUCCESS
# LSE [33/3877]: getting IBGY.L - f[0], s[29]
# 0KSA.L SUCCESS
# LSE [34/3877]: getting RMM.L - f[0], s[30]
# IBGY.L SUCCESS
# LSE [35/3877]: getting XLF3.L - f[0], s[31]
# FLK.L SUCCESS
# LSE [36/3877]: getting SJD.L - f[0], s[32]
# XLF3.L SUCCESS
# LSE [37/3877]: getting 3LRI.L - f[0], s[33]
# RMM.L SUCCESS
# LSE [38/3877]: getting MU2.L - f[0], s[34]
# SJD.L SUCCESS
# LSE [39/3877]: getting SKYY.L - f[0], s[35]
# QLT.L SUCCESS
# LSE [40/3877]: getting LQEE.L - f[0], s[36]
# 3LRI.L SUCCESS
# LSE [41/3877]: getting KAV.L - f[0], s[37]
# MU2.L SUCCESS
# LSE [42/3877]: getting BVIC.L - f[0], s[38]
# SKYY.L SUCCESS
# LSE [43/3877]: getting NSCI.L - f[0], s[39]
# LQEE.L SUCCESS
# LSE [44/3877]: getting PHAR.L - f[0], s[40]
# KAV.L SUCCESS
# LSE [45/3877]: getting CTL.L - f[0], s[41]
# NSCI.L SUCCESS
# LSE [46/3877]: getting HMBR.L - f[0], s[42]
# BVIC.L SUCCESS
# LSE [47/3877]: getting XTR.L - f[0], s[43]
# PHAR.L SUCCESS
# LSE [48/3877]: getting 0AAW.L - f[0], s[44]
# CTL.L SUCCESS
# LSE [49/3877]: getting XUFB.L - f[0], s[45]
# 0AAW.L SUCCESS
# LSE [50/3877]: getting SPYE.L - f[0], s[46]
# HMBR.L SUCCESS
# LSE [51/3877]: getting HTSC.L - f[0], s[47]
# XTR.L SUCCESS
# LSE [52/3877]: getting IGLN.L - f[0], s[48]
# XUFB.L SUCCESS
# LSE [53/3877]: getting 5SPY.L - f[0], s[49]
# SPYE.L SUCCESS
# LSE [54/3877]: getting ANX.L - f[0], s[50]
# IGLN.L SUCCESS
# LSE [55/3877]: getting NBMI.L - f[0], s[51]
# HTSC.L SUCCESS
# LSE [56/3877]: getting RISE.L - f[0], s[52]
# 5SPY.L SUCCESS
# LSE [57/3877]: getting LLOY.L - f[0], s[53]
# ANX.L SUCCESS
# LSE [58/3877]: getting SAZE.L - f[0], s[54]
# RISE.L SUCCESS
# LSE [59/3877]: getting 3LMS.L - f[0], s[55]
# NBMI.L SUCCESS
# LSE [60/3877]: getting CRH.L - f[0], s[56]
# LLOY.L SUCCESS
# LSE [61/3877]: getting VODS.L - f[0], s[57]
# SAZE.L SUCCESS
# LSE [62/3877]: getting DIA.L - f[0], s[58]
# 3LMS.L SUCCESS
# LSE [63/3877]: getting HIDR.L - f[0], s[59]
# CRH.L SUCCESS
# LSE [64/3877]: getting CLCO.L - f[0], s[60]
# VODS.L SUCCESS
# LSE [65/3877]: getting IGE.L - f[0], s[61]
# HIDR.L SUCCESS
# LSE [66/3877]: getting ISX5.L - f[0], s[62]
# DIA.L SUCCESS
# LSE [67/3877]: getting 0QOG.L - f[0], s[63]
# CLCO.L SUCCESS
# LSE [68/3877]: getting 0QKD.L - f[0], s[64]
# IGE.L SUCCESS
# LSE [69/3877]: getting AVST.L - f[0], s[65]
# 0QOG.L SUCCESS
# LSE [70/3877]: getting FAN.L - f[0], s[66]
# ISX5.L SUCCESS
# LSE [71/3877]: getting GFHG.L - f[0], s[67]
# AVST.L SUCCESS
# LSE [72/3877]: getting CORP.L - f[0], s[68]
# 0QKD.L SUCCESS
# LSE [73/3877]: getting CODE.L - f[0], s[69]
# GFHG.L SUCCESS
# LSE [74/3877]: getting SMDS.L - f[0], s[70]
# FAN.L SUCCESS
# LSE [75/3877]: getting AAS.L - f[0], s[71]
# CORP.L SUCCESS
# LSE [76/3877]: getting SSHE.L - f[0], s[72]
# CODE.L SUCCESS
# LSE [77/3877]: getting 0L5V.L - f[0], s[73]
# AAS.L SUCCESS
# LSE [78/3877]: getting FB1X.L - f[0], s[74]
# SMDS.L SUCCESS
# LSE [79/3877]: getting NTN.L - f[0], s[75]
# SSHE.L SUCCESS
# LSE [80/3877]: getting CEL.L - f[0], s[76]
# 0L5V.L SUCCESS
# LSE [81/3877]: getting TFIF.L - f[0], s[77]
# FB1X.L SUCCESS
# LSE [82/3877]: getting IBM.L - f[0], s[78]
# NTN.L SUCCESS
# LSE [83/3877]: getting MCHN.L - f[0], s[79]
# CEL.L SUCCESS
# LSE [84/3877]: getting PTOS.L - f[0], s[80]
# TFIF.L SUCCESS
# LSE [85/3877]: getting VSVS.L - f[0], s[81]
# MCHN.L SUCCESS
# LSE [86/3877]: getting MTEC.L - f[0], s[82]
# PTOS.L SUCCESS
# LSE [87/3877]: getting 2BAE.L - f[0], s[83]
# IBM.L SUCCESS
# LSE [88/3877]: getting CTO.L - f[0], s[84]
# VSVS.L SUCCESS
# LSE [89/3877]: getting SPLE.L - f[0], s[85]
# MTEC.L SUCCESS
# LSE [90/3877]: getting 0KBI.L - f[0], s[86]
# 2BAE.L SUCCESS
# LSE [91/3877]: getting LTG.L - f[0], s[87]
# CTO.L SUCCESS
# LSE [92/3877]: getting 0H14.L - f[0], s[88]
# 0KBI.L SUCCESS
# LSE [93/3877]: getting 0O84.L - f[0], s[89]
# LTG.L SUCCESS
# LSE [94/3877]: getting SGS.L - f[0], s[90]
# 0H14.L SUCCESS
# LSE [95/3877]: getting JD1S.L - f[0], s[91]
# 0O84.L SUCCESS
# LSE [96/3877]: getting COI1.L - f[0], s[92]
# SGS.L SUCCESS
# LSE [97/3877]: getting 0LJE.L - f[0], s[93]
# JD1S.L SUCCESS
# LSE [98/3877]: getting JHDA.L - f[0], s[94]
# COI1.L SUCCESS
# LSE [99/3877]: getting HSBA.L - f[0], s[95]
# 0LJE.L SUCCESS
# LSE [100/3877]: getting GBG.L - f[0], s[96]
# JHDA.L SUCCESS
# LSE [101/3877]: getting SARG.L - f[0], s[97]
# HSBA.L SUCCESS
# LSE [102/3877]: getting 0TZZ.L - f[0], s[98]
# GBG.L SUCCESS
# LSE [103/3877]: getting 3ADE.L - f[0], s[99]
# SARG.L SUCCESS
# LSE [104/3877]: getting TUNE.L - f[0], s[100]
# 0TZZ.L SUCCESS
# LSE [105/3877]: getting GCS.L - f[0], s[101]
# 3ADE.L SUCCESS
# LSE [106/3877]: getting ROK3.L - f[0], s[102]
# TUNE.L SUCCESS
# LSE [107/3877]: getting BABS.L - f[0], s[103]
# GCS.L SUCCESS
# LSE [108/3877]: getting 3LUS.L - f[0], s[104]
# ROK3.L SUCCESS
# LSE [109/3877]: getting 3MSF.L - f[0], s[105]
# BABS.L SUCCESS
# LSE [110/3877]: getting IXI.L - f[0], s[106]
# 3LUS.L SUCCESS
# LSE [111/3877]: getting 0IM1.L - f[0], s[107]
# 3MSF.L SUCCESS
# LSE [112/3877]: getting 1FB.L - f[0], s[108]
# 0IM1.L SUCCESS
# LSE [113/3877]: getting IUAA.L - f[0], s[109]
# IXI.L SUCCESS
# LSE [114/3877]: getting 0Y6X.L - f[0], s[110]
# 1FB.L SUCCESS
# LSE [115/3877]: getting 0HI3.L - f[0], s[111]
# IUAA.L SUCCESS
# LSE [116/3877]: getting INS.L - f[0], s[112]
# 0Y6X.L SUCCESS
# LSE [117/3877]: getting SYN.L - f[0], s[113]
# 0HI3.L SUCCESS
# LSE [118/3877]: getting 0A0C.L - f[0], s[114]
# SYN.L SUCCESS
# LSE [119/3877]: getting 0LE3.L - f[0], s[115]
# 0A0C.L SUCCESS
# LSE [120/3877]: getting IEM.L - f[0], s[116]
# INS.L SUCCESS
# LSE [121/3877]: getting 3TSL.L - f[0], s[117]
# 0LE3.L SUCCESS
# LSE [122/3877]: getting 3TYS.L - f[0], s[118]
# 3TSL.L SUCCESS
# LSE [123/3877]: getting 3UKL.L - f[0], s[119]
# IEM.L SUCCESS
# LSE [124/3877]: getting AOF.L - f[0], s[120]
# 3TYS.L SUCCESS
# LSE [125/3877]: getting 3ROE.L - f[0], s[121]
# 3UKL.L SUCCESS
# LSE [126/3877]: getting SENX.L - f[0], s[122]
# AOF.L SUCCESS
# LSE [127/3877]: getting 888.L - f[0], s[123]
# SPLE.L SUCCESS
# LSE [128/3877]: getting TSL1.L - f[0], s[124]
# 3ROE.L SUCCESS
# LSE [129/3877]: getting 0J1G.L - f[0], s[125]
# SENX.L SUCCESS
# LSE [130/3877]: getting SPED.L - f[0], s[126]
# 888.L SUCCESS
# LSE [131/3877]: getting 3LBA.L - f[0], s[127]
# TSL1.L SUCCESS
# LSE [132/3877]: getting AMD3.L - f[0], s[128]
# 0J1G.L SUCCESS
# LSE [133/3877]: getting 0IC7.L - f[0], s[129]
# SPED.L SUCCESS
# LSE [134/3877]: getting AGRO.L - f[0], s[130]
# AMD3.L SUCCESS
# LSE [135/3877]: getting 0QJV.L - f[0], s[131]
# 0IC7.L SUCCESS
# LSE [136/3877]: getting MUS.L - f[0], s[132]
# AGRO.L SUCCESS
# LSE [137/3877]: getting 3MRE.L - f[0], s[133]
# 0QJV.L SUCCESS
# LSE [138/3877]: getting SMSN.L - f[0], s[134]
# MUS.L SUCCESS
# LSE [139/3877]: getting 0LCX.L - f[0], s[135]
# SMSN.L SUCCESS
# LSE [140/3877]: getting RWS.L - f[0], s[136]
# 0LCX.L SUCCESS
# LSE [141/3877]: getting SNIO.L - f[0], s[137]
# SNIO.L SUCCESS
# LSE [142/3877]: getting 0KSX.L - f[0], s[138]
# 0KSX.L SUCCESS
# LSE [143/3877]: getting CRW.L - f[0], s[139]
# CRW.L SUCCESS
# LSE [144/3877]: getting 3LRD.L - f[0], s[140]
# 3LRD.L SUCCESS
# LSE [145/3877]: getting 0IQK.L - f[0], s[141]
# 3LBA.L SUCCESS
# LSE [146/3877]: getting 0KIZ.L - f[0], s[142]
# 0KIZ.L SUCCESS
# LSE [147/3877]: getting 0K6F.L - f[0], s[143]
# 3MRE.L SUCCESS
# LSE [148/3877]: getting 0L4F.L - f[0], s[144]
# 0K6F.L SUCCESS
# LSE [149/3877]: getting 0HR2.L - f[0], s[145]
# 0L4F.L SUCCESS
# LSE [150/3877]: getting MNG.L - f[0], s[146]
# RWS.L SUCCESS
# LSE [151/3877]: getting VISE.L - f[0], s[147]
# MNG.L SUCCESS
# LSE [152/3877]: getting 0JU0.L - f[0], s[148]
# 0JU0.L SUCCESS
# LSE [153/3877]: getting 0KTF.L - f[0], s[149]
# 0KTF.L SUCCESS
# LSE [154/3877]: getting CON3.L - f[0], s[150]
# CON3.L SUCCESS
# LSE [155/3877]: getting GPL.L - f[0], s[151]
# 0IQK.L SUCCESS
# LSE [156/3877]: getting ORCP.L - f[0], s[152]
# GPL.L SUCCESS
# LSE [157/3877]: getting IKA.L - f[0], s[153]
# ORCP.L SUCCESS
# LSE [158/3877]: getting AO.L - f[0], s[154]
# IKA.L SUCCESS
# LSE [159/3877]: getting 0M1O.L - f[0], s[155]
# AO.L SUCCESS
# LSE [160/3877]: getting 0KW4.L - f[0], s[156]
# 0M1O.L SUCCESS
# LSE [161/3877]: getting 0HEJ.L - f[0], s[157]
# 0KW4.L SUCCESS
# LSE [162/3877]: getting AGBP.L - f[0], s[158]
# 0HEJ.L SUCCESS
# LSE [163/3877]: getting GGP.L - f[0], s[159]
# AGBP.L SUCCESS
# LSE [164/3877]: getting 0IGA.L - f[0], s[160]
# GGP.L SUCCESS
# LSE [165/3877]: getting TPAL.L - f[0], s[161]
# 0IGA.L SUCCESS
# LSE [166/3877]: getting 3BID.L - f[0], s[162]
# TPAL.L SUCCESS
# LSE [167/3877]: getting 0OR2.L - f[0], s[163]
# 3BID.L SUCCESS
# LSE [168/3877]: getting 3XFE.L - f[0], s[164]
# 0OR2.L SUCCESS
# LSE [169/3877]: getting MXEU.L - f[0], s[165]
# 0HR2.L SUCCESS
# LSE [170/3877]: getting NAR.L - f[0], s[166]
# 3XFE.L SUCCESS
# LSE [171/3877]: getting GDX3.L - f[0], s[167]
# MXEU.L SUCCESS
# LSE [172/3877]: getting PLUG.L - f[0], s[168]
# VISE.L SUCCESS
# LSE [173/3877]: getting WRRN.L - f[0], s[169]
# GDX3.L SUCCESS
# LSE [174/3877]: getting 0HA5.L - f[0], s[170]
# NAR.L SUCCESS
# LSE [175/3877]: getting 0IJN.L - f[0], s[171]
# PLUG.L SUCCESS
# LSE [176/3877]: getting FLX.L - f[0], s[172]
# 0IJN.L SUCCESS
# LSE [177/3877]: getting SHSB.L - f[0], s[173]
# FLX.L SUCCESS
# LSE [178/3877]: getting 0JVD.L - f[0], s[174]
# SHSB.L SUCCESS
# LSE [179/3877]: getting 0URM.L - f[0], s[175]
# WRRN.L SUCCESS
# LSE [180/3877]: getting 0K4C.L - f[0], s[176]
# 0HA5.L SUCCESS
# LSE [181/3877]: getting SSME.L - f[0], s[177]
# 0K4C.L SUCCESS
# LSE [182/3877]: getting 0H6E.L - f[0], s[178]
# SSME.L SUCCESS
# LSE [183/3877]: getting 0KS2.L - f[0], s[179]
# 0H6E.L SUCCESS
# LSE [184/3877]: getting BSV.L - f[0], s[180]
# 0KS2.L SUCCESS
# LSE [185/3877]: getting 0J4X.L - f[0], s[181]
# BSV.L SUCCESS
# LSE [186/3877]: getting RMAP.L - f[0], s[182]
# 0J4X.L SUCCESS
# LSE [187/3877]: getting AXL.L - f[0], s[183]
# 0JVD.L SUCCESS
# LSE [188/3877]: getting 0J51.L - f[0], s[184]
# 0URM.L SUCCESS
# LSE [189/3877]: getting SHOS.L - f[0], s[185]
# 0J51.L SUCCESS
# LSE [190/3877]: getting 0KYY.L - f[0], s[186]
# SHOS.L SUCCESS
# LSE [191/3877]: getting 0JD3.L - f[0], s[187]
# 0KYY.L SUCCESS
# LSE [192/3877]: getting AGGU.L - f[0], s[188]
# 0JD3.L SUCCESS
# LSE [193/3877]: getting REDX.L - f[0], s[189]
# AGGU.L SUCCESS
# LSE [194/3877]: getting 0HYI.L - f[0], s[190]
# REDX.L SUCCESS
# LSE [195/3877]: getting 0K5R.L - f[0], s[191]
# 0K5R.L SUCCESS
# LSE [196/3877]: getting 0IR9.L - f[0], s[192]
# 0HYI.L SUCCESS
# LSE [197/3877]: getting 0NWC.L - f[0], s[193]
# 0IR9.L SUCCESS
# LSE [198/3877]: getting 0KJQ.L - f[0], s[194]
# 0NWC.L SUCCESS
# LSE [199/3877]: getting SUN.L - f[0], s[195]
# 0KJQ.L SUCCESS
# LSE [200/3877]: getting HMJP.L - f[0], s[196]
# RMAP.L SUCCESS
# LSE [201/3877]: getting 0FS8.L - f[0], s[197]
# HMJP.L SUCCESS
# LSE [202/3877]: getting LTHM.L - f[0], s[198]
# SUN.L SUCCESS
# LSE [203/3877]: getting 0HTQ.L - f[0], s[199]
# 0FS8.L SUCCESS
# LSE [204/3877]: getting RWI.L - f[0], s[200]
# 0HTQ.L SUCCESS
# LSE [205/3877]: getting 0JSY.L - f[0], s[201]
# LTHM.L SUCCESS
# LSE [206/3877]: getting 0GJS.L - f[0], s[202]
# 0JSY.L SUCCESS
# LSE [207/3877]: getting 0IWU.L - f[0], s[203]
# 0GJS.L SUCCESS
# LSE [208/3877]: getting 3NVD.L - f[0], s[204]
# AXL.L SUCCESS
# LSE [209/3877]: getting LWDB.L - f[0], s[205]
# RWI.L SUCCESS
# LSE [210/3877]: getting CNKS.L - f[0], s[206]
# LWDB.L SUCCESS
# LSE [211/3877]: getting TRSY.L - f[0], s[207]
# CNKS.L SUCCESS
# LSE [212/3877]: getting 0N4A.L - f[0], s[208]
# TRSY.L SUCCESS
# LSE [213/3877]: getting HWDN.L - f[0], s[209]
# 0N4A.L SUCCESS
# LSE [214/3877]: getting 0JDP.L - f[0], s[210]
# HWDN.L SUCCESS
# LSE [215/3877]: getting 0L7A.L - f[0], s[211]
# 0JDP.L SUCCESS
# LSE [216/3877]: getting 0ONY.L - f[0], s[212]
# 0L7A.L SUCCESS
# LSE [217/3877]: getting 0O2B.L - f[0], s[213]
# 0ONY.L SUCCESS
# LSE [218/3877]: getting 0IYQ.L - f[0], s[214]
# 0O2B.L SUCCESS
# LSE [219/3877]: getting 0RGI.L - f[0], s[215]
# 0RGI.L SUCCESS
# LSE [220/3877]: getting TSL3.L - f[0], s[216]
# TSL3.L SUCCESS
# LSE [221/3877]: getting BEM.L - f[0], s[217]
# 0IWU.L SUCCESS
# LSE [222/3877]: getting IGP.L - f[0], s[218]
# 3NVD.L SUCCESS
# LSE [223/3877]: getting GTE.L - f[0], s[219]
# BEM.L SUCCESS
# LSE [224/3877]: getting 0NFS.L - f[0], s[220]
# 0IYQ.L SUCCESS
# LSE [225/3877]: getting FANG.L - f[0], s[221]
# FANG.L SUCCESS
# LSE [226/3877]: getting 0HEC.L - f[0], s[222]
# IGP.L SUCCESS
# LSE [227/3877]: getting CNC.L - f[0], s[223]
# GTE.L SUCCESS
# LSE [228/3877]: getting SPTE.L - f[0], s[224]
# 0NFS.L SUCCESS
# LSE [229/3877]: getting NTEA.L - f[0], s[225]
# SPTE.L SUCCESS
# LSE [230/3877]: getting 0J50.L - f[0], s[226]
# CNC.L SUCCESS
# LSE [231/3877]: getting 0L35.L - f[0], s[227]
# NTEA.L SUCCESS
# LSE [232/3877]: getting ARO.L - f[0], s[228]
# 0J50.L SUCCESS
# LSE [233/3877]: getting MATD.L - f[0], s[229]
# 0L35.L SUCCESS
# LSE [234/3877]: getting MSF1.L - f[0], s[230]
# ARO.L SUCCESS
# LSE [235/3877]: getting PLTS.L - f[0], s[231]
# MSF1.L SUCCESS
# LSE [236/3877]: getting WSG.L - f[0], s[232]
# MATD.L SUCCESS
# LSE [237/3877]: getting ABNB.L - f[0], s[233]
# PLTS.L SUCCESS
# LSE [238/3877]: getting CHRT.L - f[0], s[234]
# ABNB.L SUCCESS
# LSE [239/3877]: getting 0A26.L - f[0], s[235]
# WSG.L SUCCESS
# LSE [240/3877]: getting 0ICI.L - f[0], s[236]
# CHRT.L SUCCESS
# LSE [241/3877]: getting 3BIE.L - f[0], s[237]
# 0HEC.L SUCCESS
# LSE [242/3877]: getting SE1.L - f[0], s[238]
# SE1.L SUCCESS
# LSE [243/3877]: getting FB3.L - f[0], s[239]
# FB3.L SUCCESS
# LSE [244/3877]: getting 0A4V.L - f[0], s[240]
# 0A4V.L SUCCESS
# LSE [245/3877]: getting FA.L - f[0], s[241]
# FA.L SUCCESS
# LSE [246/3877]: getting 0LHR.L - f[0], s[242]
# 0LHR.L SUCCESS
# LSE [247/3877]: getting 0L95.L - f[0], s[243]
# 0L95.L SUCCESS
# LSE [248/3877]: getting UKDV.L - f[0], s[244]
# 0ICI.L SUCCESS
# LSE [249/3877]: getting 0H9G.L - f[0], s[245]
# 0A26.L SUCCESS
# LSE [250/3877]: getting SAL.L - f[0], s[246]
# 3BIE.L SUCCESS
# LSE [251/3877]: getting 0HFN.L - f[0], s[247]
# UKDV.L SUCCESS
# LSE [252/3877]: getting MGNS.L - f[0], s[248]
# 0H9G.L SUCCESS
# LSE [253/3877]: getting 0KDI.L - f[0], s[249]
# SAL.L SUCCESS
# LSE [254/3877]: getting 0J9J.L - f[0], s[250]
# 0HFN.L SUCCESS
# LSE [255/3877]: getting 0I5O.L - f[0], s[251]
# MGNS.L SUCCESS
# LSE [256/3877]: getting 0HBH.L - f[0], s[252]
# 0KDI.L SUCCESS
# LSE [257/3877]: getting 3PLU.L - f[0], s[253]
# 0J9J.L SUCCESS
# LSE [258/3877]: getting XLE3.L - f[0], s[254]
# 0I5O.L SUCCESS
# LSE [259/3877]: getting 0LTI.L - f[0], s[255]
# 0HBH.L SUCCESS
# LSE [260/3877]: getting 3SVO.L - f[0], s[256]
# 3PLU.L SUCCESS
# LSE [261/3877]: getting HIGH.L - f[0], s[257]
# XLE3.L SUCCESS
# LSE [262/3877]: getting FRES.L - f[0], s[258]
# 0LTI.L SUCCESS
# LSE [263/3877]: getting BNZL.L - f[0], s[259]
# 3SVO.L SUCCESS
# LSE [264/3877]: getting 0HQW.L - f[0], s[260]
# HIGH.L SUCCESS
# LSE [265/3877]: getting 0JYW.L - f[0], s[261]
# BNZL.L SUCCESS
# LSE [266/3877]: getting CAM.L - f[0], s[262]
# 0HQW.L SUCCESS
# LSE [267/3877]: getting 0HLQ.L - f[0], s[263]
# 0HLQ.L SUCCESS
# LSE [268/3877]: getting SCTE.L - f[0], s[264]
# CAM.L SUCCESS
# LSE [269/3877]: getting HSBS.L - f[0], s[265]
# SCTE.L SUCCESS
# LSE [270/3877]: getting 79GL.L - f[0], s[266]
# HSBS.L SUCCESS
# LSE [271/3877]: getting UJO.L - f[0], s[267]
# 79GL.L SUCCESS
# LSE [272/3877]: getting 2TSE.L - f[0], s[268]
# UJO.L SUCCESS
# LSE [273/3877]: getting SBCS.L - f[0], s[269]
# 2TSE.L SUCCESS
# LSE [274/3877]: getting 0L6Z.L - f[0], s[270]
# SBCS.L SUCCESS
# LSE [275/3877]: getting BWRA.L - f[0], s[271]
# 0L6Z.L SUCCESS
# LSE [276/3877]: getting 0K9J.L - f[0], s[272]
# BWRA.L SUCCESS
# LSE [277/3877]: getting XLGS.L - f[0], s[273]
# FRES.L SUCCESS
# LSE [278/3877]: getting 3LDE.L - f[0], s[274]
# 0K9J.L SUCCESS
# LSE [279/3877]: getting MSF3.L - f[0], s[275]
# XLGS.L SUCCESS
# LSE [280/3877]: getting 0AH3.L - f[0], s[276]
# 0JYW.L SUCCESS
# LSE [281/3877]: getting SPLT.L - f[0], s[277]
# 3LDE.L SUCCESS
# LSE [282/3877]: getting RS1.L - f[0], s[278]
# MSF3.L SUCCESS
# LSE [283/3877]: getting 0I0B.L - f[0], s[279]
# 0AH3.L SUCCESS
# LSE [284/3877]: getting 0KFZ.L - f[0], s[280]
# SPLT.L SUCCESS
# LSE [285/3877]: getting SMSF.L - f[0], s[281]
# RS1.L SUCCESS
# LSE [286/3877]: getting 0DH7.L - f[0], s[282]
# 0I0B.L SUCCESS
# LSE [287/3877]: getting HICL.L - f[0], s[283]
# 0KFZ.L SUCCESS
# LSE [288/3877]: getting 0IL6.L - f[0], s[284]
# SMSF.L SUCCESS
# LSE [289/3877]: getting 0KGS.L - f[0], s[285]
# 0DH7.L SUCCESS
# LSE [290/3877]: getting IBGZ.L - f[0], s[286]
# HICL.L SUCCESS
# LSE [291/3877]: getting 0F29.L - f[0], s[287]
# 0IL6.L SUCCESS
# LSE [292/3877]: getting 0KBK.L - f[0], s[288]
# 0KGS.L SUCCESS
# LSE [293/3877]: getting 3HSE.L - f[0], s[289]
# IBGZ.L SUCCESS
# LSE [294/3877]: getting 0IJW.L - f[0], s[290]
# 0F29.L SUCCESS
# LSE [295/3877]: getting 0HQP.L - f[0], s[291]
# 0KBK.L SUCCESS
# LSE [296/3877]: getting 0JDM.L - f[0], s[292]
# 3HSE.L SUCCESS
# LSE [297/3877]: getting 0LI9.L - f[0], s[293]
# 0IJW.L SUCCESS
# LSE [298/3877]: getting 3LDO.L - f[0], s[294]
# 0HQP.L SUCCESS
# LSE [299/3877]: getting 0HW9.L - f[0], s[295]
# 0JDM.L SUCCESS
# LSE [300/3877]: getting 0QLU.L - f[0], s[296]
# 0HW9.L SUCCESS
# LSE [301/3877]: getting SKMD.L - f[0], s[297]
# SKMD.L SUCCESS
# LSE [302/3877]: getting 0K3S.L - f[0], s[298]
# 0K3S.L SUCCESS
# LSE [303/3877]: getting 0L8B.L - f[0], s[299]
# 0L8B.L SUCCESS
# LSE [304/3877]: getting 0LEF.L - f[0], s[300]
# 0LEF.L SUCCESS
# LSE [305/3877]: getting 0R09.L - f[0], s[301]
# 0R09.L SUCCESS
# LSE [306/3877]: getting 0JQQ.L - f[0], s[302]
# 0JQQ.L SUCCESS
# LSE [307/3877]: getting 0JSI.L - f[0], s[303]
# 0JSI.L SUCCESS
# LSE [308/3877]: getting TSM3.L - f[0], s[304]
# TSM3.L SUCCESS
# LSE [309/3877]: getting 0F2S.L - f[0], s[305]
# 0F2S.L SUCCESS
# LSE [310/3877]: getting 0L2T.L - f[0], s[306]
# 0LI9.L SUCCESS
# LSE [311/3877]: getting 0G5B.L - f[0], s[307]
# 0L2T.L SUCCESS
# LSE [312/3877]: getting 0JBU.L - f[0], s[308]
# 3LDO.L SUCCESS
# LSE [313/3877]: getting 3ZM.L - f[0], s[309]
# 0QLU.L SUCCESS
# LSE [314/3877]: getting 0HRZ.L - f[0], s[310]
# 0G5B.L SUCCESS
# LSE [315/3877]: getting 0MKP.L - f[0], s[311]
# 3ZM.L SUCCESS
# LSE [316/3877]: getting 0L3H.L - f[0], s[312]
# 0JBU.L SUCCESS
# LSE [317/3877]: getting AAF.L - f[0], s[313]
# 0HRZ.L SUCCESS
# LSE [318/3877]: getting 0K2F.L - f[0], s[314]
# 0MKP.L SUCCESS
# LSE [319/3877]: getting 0IFK.L - f[0], s[315]
# 0L3H.L SUCCESS
# LSE [320/3877]: getting 0IKK.L - f[0], s[316]
# AAF.L SUCCESS
# LSE [321/3877]: getting HSBK.L - f[0], s[317]
# 0K2F.L SUCCESS
# LSE [322/3877]: getting PYPS.L - f[0], s[318]
# 0IFK.L SUCCESS
# LSE [323/3877]: getting 0R1C.L - f[0], s[319]
# 0IKK.L SUCCESS
# LSE [324/3877]: getting 0IBG.L - f[0], s[320]
# HSBK.L SUCCESS
# LSE [325/3877]: getting SSLN.L - f[0], s[321]
# PYPS.L SUCCESS
# LSE [326/3877]: getting CBKD.L - f[0], s[322]
# 0R1C.L SUCCESS
# LSE [327/3877]: getting 0LVK.L - f[0], s[323]
# 0IBG.L SUCCESS
# LSE [328/3877]: getting FERG.L - f[0], s[324]
# SSLN.L SUCCESS
# LSE [329/3877]: getting 0J5H.L - f[0], s[325]
# CBKD.L SUCCESS
# LSE [330/3877]: getting 2GS.L - f[0], s[326]
# 0LVK.L SUCCESS
# LSE [331/3877]: getting SNR.L - f[0], s[327]
# 0J5H.L SUCCESS
# LSE [332/3877]: getting 0Y8Z.L - f[0], s[328]
# FERG.L SUCCESS
# LSE [333/3877]: getting GS2E.L - f[0], s[329]
# 2GS.L SUCCESS
# LSE [334/3877]: getting SGLS.L - f[0], s[330]
# SNR.L SUCCESS
# LSE [335/3877]: getting 0K19.L - f[0], s[331]
# 0Y8Z.L SUCCESS
# LSE [336/3877]: getting 0M6I.L - f[0], s[332]
# GS2E.L SUCCESS
# LSE [337/3877]: getting 0IPY.L - f[0], s[333]
# SGLS.L SUCCESS
# LSE [338/3877]: getting 0JPH.L - f[0], s[334]
# 0K19.L SUCCESS
# LSE [339/3877]: getting 0LSL.L - f[0], s[335]
# 0M6I.L SUCCESS
# LSE [340/3877]: getting 0K4T.L - f[0], s[336]
# 0IPY.L SUCCESS
# LSE [341/3877]: getting 0MT8.L - f[0], s[337]
# 0JPH.L SUCCESS
# LSE [342/3877]: getting JEL.L - f[0], s[338]
# 0LSL.L SUCCESS
# LSE [343/3877]: getting UC90.L - f[0], s[339]
# 0K4T.L SUCCESS
# LSE [344/3877]: getting 0IIW.L - f[0], s[340]
# 0MT8.L SUCCESS
# LSE [345/3877]: getting CTYA.L - f[0], s[341]
# JEL.L SUCCESS
# LSE [346/3877]: getting 0GMG.L - f[0], s[342]
# UC90.L SUCCESS
# LSE [347/3877]: getting 0J3K.L - f[0], s[343]
# 0IIW.L SUCCESS
# LSE [348/3877]: getting 0K34.L - f[0], s[344]
# CTYA.L SUCCESS
# LSE [349/3877]: getting 0A1S.L - f[0], s[345]
# 0GMG.L SUCCESS
# LSE [350/3877]: getting HLN.L - f[0], s[346]
# 0J3K.L SUCCESS
# LSE [351/3877]: getting FTAD.L - f[0], s[347]
# 0K34.L SUCCESS
# LSE [352/3877]: getting VRS.L - f[0], s[348]
# 0A1S.L SUCCESS
# LSE [353/3877]: getting ROKS.L - f[0], s[349]
# HLN.L SUCCESS
# LSE [354/3877]: getting 1AMZ.L - f[0], s[350]
# FTAD.L SUCCESS
# LSE [355/3877]: getting 0HP1.L - f[0], s[351]
# VRS.L SUCCESS
# LSE [356/3877]: getting 0IXY.L - f[0], s[352]
# ROKS.L SUCCESS
# LSE [357/3877]: getting RIFS.L - f[0], s[353]
# 1AMZ.L SUCCESS
# LSE [358/3877]: getting GTLY.L - f[0], s[354]
# 0HP1.L SUCCESS
# LSE [359/3877]: getting MTO.L - f[0], s[355]
# 0IXY.L SUCCESS
# LSE [360/3877]: getting 0KE0.L - f[0], s[356]
# RIFS.L SUCCESS
# LSE [361/3877]: getting SNX.L - f[0], s[357]
# GTLY.L SUCCESS
# LSE [362/3877]: getting 0HYR.L - f[0], s[358]
# 0KE0.L SUCCESS
# LSE [363/3877]: getting 0OPA.L - f[0], s[359]
# MTO.L SUCCESS
# LSE [364/3877]: getting 0KFH.L - f[0], s[360]
# SNX.L SUCCESS
# LSE [365/3877]: getting IFSD.L - f[0], s[361]
# 0HYR.L SUCCESS
# LSE [366/3877]: getting 0K45.L - f[0], s[362]
# 0OPA.L SUCCESS
# LSE [367/3877]: getting 0KB7.L - f[0], s[363]
# 0KFH.L SUCCESS
# LSE [368/3877]: getting SMU.L - f[0], s[364]
# IFSD.L SUCCESS
# LSE [369/3877]: getting TLW.L - f[0], s[365]
# 0K45.L SUCCESS
# LSE [370/3877]: getting ARW3.L - f[0], s[366]
# ARW3.L FAILED
# LSE [371/3877]: getting BRNB.L - f[1], s[366]
# 0KB7.L SUCCESS
# LSE [372/3877]: getting 0KAN.L - f[1], s[367]
# SMU.L SUCCESS
# LSE [373/3877]: getting 0O2W.L - f[1], s[368]
# BRNB.L SUCCESS
# LSE [374/3877]: getting 0J3N.L - f[1], s[369]
# TLW.L SUCCESS
# LSE [375/3877]: getting 3BAC.L - f[1], s[370]
# 0KAN.L SUCCESS
# LSE [376/3877]: getting 0HGV.L - f[1], s[371]
# 0O2W.L SUCCESS
# LSE [377/3877]: getting 0J5Q.L - f[1], s[372]
# 0J3N.L SUCCESS
# LSE [378/3877]: getting CAPD.L - f[1], s[373]
# 3BAC.L SUCCESS
# LSE [379/3877]: getting 0IJV.L - f[1], s[374]
# 0HGV.L SUCCESS
# LSE [380/3877]: getting 0JVV.L - f[1], s[375]
# 0J5Q.L SUCCESS
# LSE [381/3877]: getting RKW.L - f[1], s[376]
# 0IJV.L SUCCESS
# LSE [382/3877]: getting 3AIR.L - f[1], s[377]
# 0JVV.L SUCCESS
# LSE [383/3877]: getting 0JMU.L - f[1], s[378]
# CAPD.L SUCCESS
# LSE [384/3877]: getting VLG.L - f[1], s[379]
# RKW.L SUCCESS
# LSE [385/3877]: getting 3ZME.L - f[1], s[380]
# 3AIR.L SUCCESS
# LSE [386/3877]: getting 0L9G.L - f[1], s[381]
# 3ZME.L SUCCESS
# LSE [387/3877]: getting 0HPW.L - f[1], s[382]
# 0JMU.L SUCCESS
# LSE [388/3877]: getting 0HR4.L - f[1], s[383]
# VLG.L SUCCESS
# LSE [389/3877]: getting 0J4G.L - f[1], s[384]
# 0HPW.L SUCCESS
# LSE [390/3877]: getting 0K87.L - f[1], s[385]
# 0K87.L SUCCESS
# LSE [391/3877]: getting 0JZ2.L - f[1], s[386]
# 0JZ2.L SUCCESS
# LSE [392/3877]: getting 0L3C.L - f[1], s[387]
# 0L3C.L SUCCESS
# LSE [393/3877]: getting MSFS.L - f[1], s[388]
# MSFS.L SUCCESS
# LSE [394/3877]: getting 0EWR.L - f[1], s[389]
# 0HR4.L SUCCESS
# LSE [395/3877]: getting 0HWG.L - f[1], s[390]
# 0L9G.L SUCCESS
# LSE [396/3877]: getting 0J3H.L - f[1], s[391]
# 0EWR.L SUCCESS
# LSE [397/3877]: getting 0KEZ.L - f[1], s[392]
# 0J4G.L SUCCESS
# LSE [398/3877]: getting GEC.L - f[1], s[393]
# 0HWG.L SUCCESS
# LSE [399/3877]: getting 0NQJ.L - f[1], s[394]
# 0KEZ.L SUCCESS
# LSE [400/3877]: getting ITRK.L - f[1], s[395]
# GEC.L SUCCESS
# LSE [401/3877]: getting 0LFS.L - f[1], s[396]
# 0NQJ.L SUCCESS
# LSE [402/3877]: getting 0QZY.L - f[1], s[397]
# ITRK.L SUCCESS
# LSE [403/3877]: getting 0KUV.L - f[1], s[398]
# 0J3H.L SUCCESS
# LSE [404/3877]: getting SPRE.L - f[1], s[399]
# SPRE.L SUCCESS
# LSE [405/3877]: getting PFP.L - f[1], s[400]
# 0LFS.L SUCCESS
# LSE [406/3877]: getting BAB2.L - f[1], s[401]
# 0QZY.L SUCCESS
# LSE [407/3877]: getting SPE.L - f[1], s[402]
# PFP.L SUCCESS
# LSE [408/3877]: getting MCON.L - f[1], s[403]
# BAB2.L SUCCESS
# LSE [409/3877]: getting JPHG.L - f[1], s[404]
# MCON.L SUCCESS
# LSE [410/3877]: getting STSE.L - f[1], s[405]
# JPHG.L SUCCESS
# LSE [411/3877]: getting 0NDP.L - f[1], s[406]
# STSE.L SUCCESS
# LSE [412/3877]: getting 0EIE.L - f[1], s[407]
# 0NDP.L SUCCESS
# LSE [413/3877]: getting BA.L - f[1], s[408]
# 0EIE.L SUCCESS
# LSE [414/3877]: getting 0LC6.L - f[1], s[409]
# BA.L SUCCESS
# LSE [415/3877]: getting 0K79.L - f[1], s[410]
# 0LC6.L SUCCESS
# LSE [416/3877]: getting JWNG.L - f[1], s[411]
# 0K79.L SUCCESS
# LSE [417/3877]: getting SGZ.L - f[1], s[412]
# SGZ.L SUCCESS
# LSE [418/3877]: getting 0CIJ.L - f[1], s[413]
# 0CIJ.L SUCCESS
# LSE [419/3877]: getting SHEL.L - f[1], s[414]
# SHEL.L SUCCESS
# LSE [420/3877]: getting 0JYA.L - f[1], s[415]
# 0JYA.L SUCCESS
# LSE [421/3877]: getting 0KAK.L - f[1], s[416]
# 0KAK.L SUCCESS
# LSE [422/3877]: getting 0JTQ.L - f[1], s[417]
# 0KUV.L SUCCESS
# LSE [423/3877]: getting 0E1L.L - f[1], s[418]
# 0JTQ.L SUCCESS
# LSE [424/3877]: getting 0QLM.L - f[1], s[419]
# 0E1L.L SUCCESS
# LSE [425/3877]: getting SDIS.L - f[1], s[420]
# SPE.L SUCCESS
# LSE [426/3877]: getting PGH.L - f[1], s[421]
# 0QLM.L SUCCESS
# LSE [427/3877]: getting 0Y5F.L - f[1], s[422]
# SDIS.L SUCCESS
# LSE [428/3877]: getting PNN.L - f[1], s[423]
# 0Y5F.L SUCCESS
# LSE [429/3877]: getting ARC.L - f[1], s[424]
# PGH.L SUCCESS
# LSE [430/3877]: getting 0KSJ.L - f[1], s[425]
# 0KSJ.L SUCCESS
# LSE [431/3877]: getting 0QYU.L - f[1], s[426]
# PNN.L SUCCESS
# LSE [432/3877]: getting ZHEH.L - f[1], s[427]
# ARC.L SUCCESS
# LSE [433/3877]: getting 0KRX.L - f[1], s[428]
# 0QYU.L SUCCESS
# LSE [434/3877]: getting 0LC3.L - f[1], s[429]
# 0KRX.L SUCCESS
# LSE [435/3877]: getting 0JDB.L - f[1], s[430]
# ZHEH.L SUCCESS
# LSE [436/3877]: getting 0KF5.L - f[1], s[431]
# JWNG.L SUCCESS
# LSE [437/3877]: getting 0LHO.L - f[1], s[432]
# 0LC3.L SUCCESS
# LSE [438/3877]: getting 0IBD.L - f[1], s[433]
# 0JDB.L SUCCESS
# LSE [439/3877]: getting 0R2P.L - f[1], s[434]
# 0KF5.L SUCCESS
# LSE [440/3877]: getting 0QQK.L - f[1], s[435]
# 0IBD.L SUCCESS
# LSE [441/3877]: getting 0QLL.L - f[1], s[436]
# 0R2P.L SUCCESS
# LSE [442/3877]: getting SMWH.L - f[1], s[437]
# 0QQK.L SUCCESS
# LSE [443/3877]: getting 0N0B.L - f[1], s[438]
# 0QLL.L SUCCESS
# LSE [444/3877]: getting PLGS.L - f[1], s[439]
# 0N0B.L SUCCESS
# LSE [445/3877]: getting 0A52.L - f[1], s[440]
# SMWH.L SUCCESS
# LSE [446/3877]: getting 0KTW.L - f[1], s[441]
# PLGS.L SUCCESS
# LSE [447/3877]: getting 0NZ1.L - f[1], s[442]
# 0A52.L SUCCESS
# LSE [448/3877]: getting 0HEM.L - f[1], s[443]
# 0KTW.L SUCCESS
# LSE [449/3877]: getting 0R43.L - f[1], s[444]
# 0HEM.L SUCCESS
# LSE [450/3877]: getting 0M3F.L - f[1], s[445]
# 0NZ1.L SUCCESS
# LSE [451/3877]: getting 3PYE.L - f[1], s[446]
# 0R43.L SUCCESS
# LSE [452/3877]: getting GOOG.L - f[1], s[447]
# 0M3F.L SUCCESS
# LSE [453/3877]: getting ROR.L - f[1], s[448]
# 3PYE.L SUCCESS
# LSE [454/3877]: getting VIXL.L - f[1], s[449]
# GOOG.L SUCCESS
# LSE [455/3877]: getting QQ3S.L - f[1], s[450]
# ROR.L SUCCESS
# LSE [456/3877]: getting 0R2S.L - f[1], s[451]
# QQ3S.L SUCCESS
# LSE [457/3877]: getting AFM.L - f[1], s[452]
# 0R2S.L SUCCESS
# LSE [458/3877]: getting ELLA.L - f[1], s[453]
# VIXL.L SUCCESS
# LSE [459/3877]: getting 0ROQ.L - f[1], s[454]
# AFM.L SUCCESS
# LSE [460/3877]: getting 0QNQ.L - f[1], s[455]
# 0LHO.L SUCCESS
# LSE [461/3877]: getting 0HUR.L - f[1], s[456]
# 0ROQ.L SUCCESS
# LSE [462/3877]: getting 0QKJ.L - f[1], s[457]
# ELLA.L SUCCESS
# LSE [463/3877]: getting WTID.L - f[1], s[458]
# 0QNQ.L SUCCESS
# LSE [464/3877]: getting GLB.L - f[1], s[459]
# 0HUR.L SUCCESS
# LSE [465/3877]: getting SCRM.L - f[1], s[460]
# WTID.L SUCCESS
# LSE [466/3877]: getting 0I5P.L - f[1], s[461]
# 0QKJ.L SUCCESS
# LSE [467/3877]: getting 0HJI.L - f[1], s[462]
# SCRM.L SUCCESS
# LSE [468/3877]: getting 3FB.L - f[1], s[463]
# GLB.L SUCCESS
# LSE [469/3877]: getting 0QWE.L - f[1], s[464]
# 0I5P.L SUCCESS
# LSE [470/3877]: getting 0R86.L - f[1], s[465]
# 3FB.L SUCCESS
# LSE [471/3877]: getting 3LBC.L - f[1], s[466]
# 3LBC.L SUCCESS
# LSE [472/3877]: getting SSLV.L - f[1], s[467]
# SSLV.L SUCCESS
# LSE [473/3877]: getting 0QLQ.L - f[1], s[468]
# 0QLQ.L SUCCESS
# LSE [474/3877]: getting 0K0J.L - f[1], s[469]
# 0K0J.L SUCCESS
# LSE [475/3877]: getting SUK1.L - f[1], s[470]
# SUK1.L SUCCESS
# LSE [476/3877]: getting 2MCL.L - f[1], s[471]
# 0HJI.L SUCCESS
# LSE [477/3877]: getting IEAA.L - f[1], s[472]
# 0QWE.L SUCCESS
# LSE [478/3877]: getting 3BLR.L - f[1], s[473]
# 2MCL.L SUCCESS
# LSE [479/3877]: getting 0A18.L - f[1], s[474]
# IEAA.L SUCCESS
# LSE [480/3877]: getting KRPZ.L - f[1], s[475]
# 0R86.L SUCCESS
# LSE [481/3877]: getting MRNS.L - f[1], s[476]
# 3BLR.L SUCCESS
# LSE [482/3877]: getting 0QP6.L - f[1], s[477]
# 0A18.L SUCCESS
# LSE [483/3877]: getting 0UKH.L - f[1], s[478]
# MRNS.L SUCCESS
# LSE [484/3877]: getting JCGI.L - f[1], s[479]
# KRPZ.L SUCCESS
# LSE [485/3877]: getting 3SFG.L - f[1], s[480]
# 0QP6.L SUCCESS
# LSE [486/3877]: getting 0RD1.L - f[1], s[481]
# 0UKH.L SUCCESS
# LSE [487/3877]: getting 0FM2.L - f[1], s[482]
# 3SFG.L SUCCESS
# LSE [488/3877]: getting AMZS.L - f[1], s[483]
# JCGI.L SUCCESS
# LSE [489/3877]: getting ENET.L - f[1], s[484]
# 0RD1.L SUCCESS
# LSE [490/3877]: getting 0UGP.L - f[1], s[485]
# 0FM2.L SUCCESS
# LSE [491/3877]: getting SPAL.L - f[1], s[486]
# AMZS.L SUCCESS
# LSE [492/3877]: getting SGGD.L - f[1], s[487]
# ENET.L SUCCESS
# LSE [493/3877]: getting 0RU6.L - f[1], s[488]
# SPAL.L SUCCESS
# LSE [494/3877]: getting 0QR1.L - f[1], s[489]
# SGGD.L SUCCESS
# LSE [495/3877]: getting SZM.L - f[1], s[490]
# 0RU6.L SUCCESS
# LSE [496/3877]: getting CRM3.L - f[1], s[491]
# 0QR1.L SUCCESS
# LSE [497/3877]: getting 0QK1.L - f[1], s[492]
# SZM.L SUCCESS
# LSE [498/3877]: getting 0OCD.L - f[1], s[493]
# CRM3.L SUCCESS
# LSE [499/3877]: getting 0K9K.L - f[1], s[494]
# 0QK1.L SUCCESS
# LSE [500/3877]: getting 0GOX.L - f[1], s[495]
# 0OCD.L SUCCESS
# LSE [501/3877]: getting FDBK.L - f[1], s[496]
# 0K9K.L SUCCESS
# LSE [502/3877]: getting 0V5H.L - f[1], s[497]
# 0GOX.L SUCCESS
# LSE [503/3877]: getting 0QYN.L - f[1], s[498]
# 0V5H.L SUCCESS
# LSE [504/3877]: getting 3SIP.L - f[1], s[499]
# FDBK.L SUCCESS
# LSE [505/3877]: getting 0RTK.L - f[1], s[500]
# 0QYN.L SUCCESS
# LSE [506/3877]: getting 3DIE.L - f[1], s[501]
# 3SIP.L SUCCESS
# LSE [507/3877]: getting 0KNY.L - f[1], s[502]
# 0RTK.L SUCCESS
# LSE [508/3877]: getting FBS.L - f[1], s[503]
# 3DIE.L SUCCESS
# LSE [509/3877]: getting HHPD.L - f[1], s[504]
# 0KNY.L SUCCESS
# LSE [510/3877]: getting 0YG8.L - f[1], s[505]
# 0UGP.L SUCCESS
# LSE [511/3877]: getting 0RUJ.L - f[1], s[506]
# FBS.L SUCCESS
# LSE [512/3877]: getting INFG.L - f[1], s[507]
# HHPD.L SUCCESS
# LSE [513/3877]: getting 0R2M.L - f[1], s[508]
# 0YG8.L SUCCESS
# LSE [514/3877]: getting IDS.L - f[1], s[509]
# 0RUJ.L SUCCESS
# LSE [515/3877]: getting 0I0N.L - f[1], s[510]
# INFG.L SUCCESS
# LSE [516/3877]: getting 3EUL.L - f[1], s[511]
# 0R2M.L SUCCESS
# LSE [517/3877]: getting 0R08.L - f[1], s[512]
# 0I0N.L SUCCESS
# LSE [518/3877]: getting 0QY8.L - f[1], s[513]
# IDS.L SUCCESS
# LSE [519/3877]: getting GFTU.L - f[1], s[514]
# 3EUL.L SUCCESS
# LSE [520/3877]: getting NXT.L - f[1], s[515]
# 0QY8.L SUCCESS
# LSE [521/3877]: getting 0QZH.L - f[1], s[516]
# 0QZH.L SUCCESS
# LSE [522/3877]: getting 2MSF.L - f[1], s[517]
# 2MSF.L SUCCESS
# LSE [523/3877]: getting 1TSL.L - f[1], s[518]
# 0R08.L SUCCESS
# LSE [524/3877]: getting 0YY7.L - f[1], s[519]
# GFTU.L SUCCESS
# LSE [525/3877]: getting 0QZM.L - f[1], s[520]
# NXT.L SUCCESS
# LSE [526/3877]: getting BNC.L - f[1], s[521]
# 0YY7.L SUCCESS
# LSE [527/3877]: getting 0M1U.L - f[1], s[522]
# 0QZM.L FAILED
# LSE [528/3877]: getting 0R16.L - f[2], s[522]
# 0M1U.L SUCCESS
# LSE [529/3877]: getting 0QYR.L - f[2], s[523]
# 0R16.L SUCCESS
# LSE [530/3877]: getting ZAM.L - f[2], s[524]
# BNC.L SUCCESS
# LSE [531/3877]: getting 0NEB.L - f[2], s[525]
# 0QYR.L SUCCESS
# LSE [532/3877]: getting 0E5H.L - f[2], s[526]
# 0NEB.L SUCCESS
# LSE [533/3877]: getting 0R1B.L - f[2], s[527]
# 1TSL.L SUCCESS
# LSE [534/3877]: getting 0ID1.L - f[2], s[528]
# ZAM.L SUCCESS
# LSE [535/3877]: getting 0R2Y.L - f[2], s[529]
# 0E5H.L SUCCESS
# LSE [536/3877]: getting 0R3Q.L - f[2], s[530]
# 0R1B.L SUCCESS
# LSE [537/3877]: getting 0VFA.L - f[2], s[531]
# 0ID1.L SUCCESS
# LSE [538/3877]: getting 0QZ3.L - f[2], s[532]
# 0R2Y.L SUCCESS
# LSE [539/3877]: getting 0R3D.L - f[2], s[533]
# 0R3Q.L SUCCESS
# LSE [540/3877]: getting 0UAI.L - f[2], s[534]
# 0QZ3.L SUCCESS
# LSE [541/3877]: getting 0VDK.L - f[2], s[535]
# 0VFA.L SUCCESS0R3D.L SUCCESS
# LSE [542/3877]: getting APTD.L - f[2], s[537]
#
# LSE [543/3877]: getting 0QMI.L - f[2], s[537]
# 0UAI.L SUCCESS
# LSE [544/3877]: getting 0Y9S.L - f[2], s[538]
# 0VDK.L SUCCESS
# LSE [545/3877]: getting 0QNH.L - f[2], s[539]
# 0Y9S.L SUCCESS
# LSE [546/3877]: getting HFEL.L - f[2], s[540]
# APTD.L SUCCESS
# LSE [547/3877]: getting LOAD.L - f[2], s[541]
# 0QNH.L SUCCESS
# LSE [548/3877]: getting UPR.L - f[2], s[542]
# HFEL.L SUCCESS
# LSE [549/3877]: getting 3UKS.L - f[2], s[543]
# LOAD.L SUCCESS
# LSE [550/3877]: getting TCUS.L - f[2], s[544]
# UPR.L SUCCESS
# LSE [551/3877]: getting 0QRA.L - f[2], s[545]
# 3UKS.L SUCCESS
# LSE [552/3877]: getting MSF2.L - f[2], s[546]
# TCUS.L SUCCESS
# LSE [553/3877]: getting DWHA.L - f[2], s[547]
# 0QRA.L SUCCESS
# LSE [554/3877]: getting AIR.L - f[2], s[548]
# MSF2.L SUCCESS
# LSE [555/3877]: getting 0JZT.L - f[2], s[549]
# DWHA.L SUCCESS
# LSE [556/3877]: getting CALL.L - f[2], s[550]
# AIR.L SUCCESS
# LSE [557/3877]: getting 3BAB.L - f[2], s[551]
# 0JZT.L SUCCESS
# LSE [558/3877]: getting RGO.L - f[2], s[552]
# CALL.L SUCCESS
# LSE [559/3877]: getting KMR.L - f[2], s[553]
# RGO.L SUCCESS
# LSE [560/3877]: getting 0QNN.L - f[2], s[554]
# 0QMI.L SUCCESS
# LSE [561/3877]: getting AMYT.L - f[2], s[555]
# KMR.L SUCCESS
# LSE [562/3877]: getting CIHL.L - f[2], s[556]
# 0QNN.L SUCCESS
# LSE [563/3877]: getting SROE.L - f[2], s[557]
# AMYT.L SUCCESS
# LSE [564/3877]: getting HDD.L - f[2], s[558]
# HDD.L FAILED
# LSE [565/3877]: getting CLG.L - f[3], s[558]
# CIHL.L SUCCESS
# LSE [566/3877]: getting AGK.L - f[3], s[559]
# SROE.L SUCCESS
# LSE [567/3877]: getting DFIB.L - f[3], s[560]
# CLG.L SUCCESS
# LSE [568/3877]: getting DCD.L - f[3], s[561]
# AGK.L SUCCESS
# LSE [569/3877]: getting MBO.L - f[3], s[562]
# DFIB.L SUCCESS
# LSE [570/3877]: getting SCIT.L - f[3], s[563]
# DCD.L SUCCESS
# LSE [571/3877]: getting 3BCE.L - f[3], s[564]
# SCIT.L SUCCESS
# LSE [572/3877]: getting 0Y4Q.L - f[3], s[565]
# MBO.L SUCCESS
# LSE [573/3877]: getting ARDN.L - f[3], s[566]
# 3BCE.L SUCCESS
# LSE [574/3877]: getting HOC.L - f[3], s[567]
# 0Y4Q.L SUCCESS
# LSE [575/3877]: getting 0HCT.L - f[3], s[568]
# ARDN.L SUCCESS
# LSE [576/3877]: getting ULVR.L - f[3], s[569]
# HOC.L SUCCESS
# LSE [577/3877]: getting 0MJH.L - f[3], s[570]
# 0HCT.L SUCCESS
# LSE [578/3877]: getting 0W9J.L - f[3], s[571]
# 0MJH.L SUCCESS
# LSE [579/3877]: getting MMX.L - f[3], s[572]
# ULVR.L SUCCESS
# LSE [580/3877]: getting MRW.L - f[3], s[573]
# 0W9J.L SUCCESS
# LSE [581/3877]: getting VCBC.L - f[3], s[574]
# MRW.L SUCCESS
# LSE [582/3877]: getting FCCN.L - f[3], s[575]
# FCCN.L SUCCESS
# LSE [583/3877]: getting 0Y5E.L - f[3], s[576]
# 0Y5E.L SUCCESS
# LSE [584/3877]: getting XSG.L - f[3], s[577]
# 3BAB.L SUCCESS
# LSE [585/3877]: getting 0KCS.L - f[3], s[578]
# XSG.L SUCCESS
# LSE [586/3877]: getting 0AH7.L - f[3], s[579]
# 0KCS.L SUCCESS
# LSE [587/3877]: getting MVIR.L - f[3], s[580]
# 0AH7.L SUCCESS
# LSE [588/3877]: getting 0IRE.L - f[3], s[581]
# MVIR.L SUCCESS
# LSE [589/3877]: getting 0XI7.L - f[3], s[582]
# MMX.L SUCCESS
# LSE [590/3877]: getting 0HYE.L - f[3], s[583]
# 0HYE.L SUCCESS
# LSE [591/3877]: getting 0TPE.L - f[3], s[584]
# 0TPE.L SUCCESS
# LSE [592/3877]: getting 0UVX.L - f[3], s[585]
# 0UVX.L SUCCESS
# LSE [593/3877]: getting CITS.L - f[3], s[586]
# 0XI7.L SUCCESS
# LSE [594/3877]: getting FLTA.L - f[3], s[587]
# CITS.L SUCCESS
# LSE [595/3877]: getting 3SRI.L - f[3], s[588]
# FLTA.L SUCCESS
# LSE [596/3877]: getting APLS.L - f[3], s[589]
# APLS.L SUCCESS
# LSE [597/3877]: getting 0I6Q.L - f[3], s[590]
# 0IRE.L SUCCESS
# LSE [598/3877]: getting 0R2I.L - f[3], s[591]
# 0I6Q.L SUCCESS
# LSE [599/3877]: getting 0RJD.L - f[3], s[592]
# 0R2I.L SUCCESS
# LSE [600/3877]: getting 0JQ2.L - f[3], s[593]
# 0RJD.L SUCCESS
# LSE [601/3877]: getting 0YU1.L - f[3], s[594]
# 0JQ2.L SUCCESS
# LSE [602/3877]: getting 0HG3.L - f[3], s[595]
# 0YU1.L SUCCESS
# LSE [603/3877]: getting 0FNZ.L - f[3], s[596]
# 0HG3.L SUCCESS
# LSE [604/3877]: getting 0QZZ.L - f[3], s[597]
# 0FNZ.L SUCCESS
# LSE [605/3877]: getting XPF.L - f[3], s[598]
# 0QZZ.L SUCCESS
# LSE [606/3877]: getting 3BAL.L - f[3], s[599]
# XPF.L SUCCESS
# LSE [607/3877]: getting HYLD.L - f[3], s[600]
# 3BAL.L SUCCESS
# LSE [608/3877]: getting BT.A.L - f[3], s[601]
# 3SRI.L SUCCESS
# LSE [609/3877]: getting 0RKL.L - f[3], s[602]
# 0RKL.L SUCCESS
# LSE [610/3877]: getting PRP.L - f[3], s[603]
# PRP.L SUCCESS
# LSE [611/3877]: getting SBAE.L - f[3], s[604]
# SBAE.L SUCCESS
# LSE [612/3877]: getting MNO.L - f[3], s[605]
# MNO.L SUCCESS
# LSE [613/3877]: getting 0U96.L - f[3], s[606]
# 0U96.L SUCCESS
# LSE [614/3877]: getting 2BRK.L - f[3], s[607]
# 2BRK.L SUCCESS
# LSE [615/3877]: getting AAP3.L - f[3], s[608]
# VCBC.L SUCCESS
# LSE [616/3877]: getting 0V50.L - f[3], s[609]
# HYLD.L SUCCESS
# LSE [617/3877]: getting SPDM.L - f[3], s[610]
# BT.A.L SUCCESS
# LSE [618/3877]: getting 3TWT.L - f[3], s[611]
# 0V50.L SUCCESS
# LSE [619/3877]: getting 3PYP.L - f[3], s[612]
# AAP3.L SUCCESS
# LSE [620/3877]: getting RYA.L - f[3], s[613]
# SPDM.L SUCCESS
# LSE [621/3877]: getting FEML.L - f[3], s[614]
# 3TWT.L SUCCESS
# LSE [622/3877]: getting NUC.L - f[3], s[615]
# FEML.L SUCCESS
# LSE [623/3877]: getting 1PAS.L - f[3], s[616]
# 3PYP.L SUCCESS
# LSE [624/3877]: getting TWT3.L - f[3], s[617]
# NUC.L SUCCESS
# LSE [625/3877]: getting 0R40.L - f[3], s[618]
# RYA.L SUCCESS
# LSE [626/3877]: getting 3GOO.L - f[3], s[619]
# TWT3.L SUCCESS
# LSE [627/3877]: getting VGOV.L - f[3], s[620]
# 1PAS.L SUCCESS
# LSE [628/3877]: getting RMS.L - f[3], s[621]
# 0R40.L SUCCESS
# LSE [629/3877]: getting TYT.L - f[3], s[622]
# 3GOO.L SUCCESS
# LSE [630/3877]: getting PRM.L - f[3], s[623]
# RMS.L SUCCESS
# LSE [631/3877]: getting BWSA.L - f[3], s[624]
# VGOV.L SUCCESS
# LSE [632/3877]: getting CO3S.L - f[3], s[625]
# PRM.L SUCCESS
# LSE [633/3877]: getting RAV.L - f[3], s[626]
# TYT.L SUCCESS
# LSE [634/3877]: getting RDSA.L - f[3], s[627]
# CO3S.L SUCCESS
# LSE [635/3877]: getting 0QQI.L - f[3], s[628]
# BWSA.L SUCCESS
# LSE [636/3877]: getting PDZ.L - f[3], s[629]
# RAV.L SUCCESS
# LSE [637/3877]: getting GEM.L - f[3], s[630]
# 0QQI.L SUCCESS
# LSE [638/3877]: getting 3ARE.L - f[3], s[631]
# RDSA.L SUCCESS
# LSE [639/3877]: getting AMPS.L - f[3], s[632]
# PDZ.L SUCCESS
# LSE [640/3877]: getting SIM.L - f[3], s[633]
# SIM.L SUCCESS
# LSE [641/3877]: getting 0QQR.L - f[3], s[634]
# 0QQR.L SUCCESS
# LSE [642/3877]: getting PPIX.L - f[3], s[635]
# PPIX.L SUCCESS
# LSE [643/3877]: getting TSL2.L - f[3], s[636]
# TSL2.L SUCCESS
# LSE [644/3877]: getting GENI.L - f[3], s[637]
# GENI.L SUCCESS
# LSE [645/3877]: getting 0RH8.L - f[3], s[638]
# 3ARE.L SUCCESS
# LSE [646/3877]: getting 0QYH.L - f[3], s[639]
# 0RH8.L SUCCESS
# LSE [647/3877]: getting RIV.L - f[3], s[640]
# GEM.L SUCCESS
# LSE [648/3877]: getting AGGG.L - f[3], s[641]
# AMPS.L SUCCESS
# LSE [649/3877]: getting KWS.L - f[3], s[642]
# 0QYH.L SUCCESS
# LSE [650/3877]: getting PRES.L - f[3], s[643]
# RIV.L SUCCESS
# LSE [651/3877]: getting IDTL.L - f[3], s[644]
# AGGG.L SUCCESS
# LSE [652/3877]: getting EUDV.L - f[3], s[645]
# KWS.L SUCCESS
# LSE [653/3877]: getting 0JZ1.L - f[3], s[646]
# IDTL.L SUCCESS
# LSE [654/3877]: getting SLN.L - f[3], s[647]
# EUDV.L SUCCESS
# LSE [655/3877]: getting 0OOJ.L - f[3], s[648]
# PRES.L SUCCESS
# LSE [656/3877]: getting 3JDE.L - f[3], s[649]
# 0JZ1.L SUCCESS
# LSE [657/3877]: getting 3HCL.L - f[3], s[650]
# 0OOJ.L SUCCESS
# LSE [658/3877]: getting SUMO.L - f[3], s[651]
# 3JDE.L SUCCESS
# LSE [659/3877]: getting DPH.L - f[3], s[652]
# SLN.L SUCCESS
# LSE [660/3877]: getting DIS3.L - f[3], s[653]
# 3HCL.L SUCCESS
# LSE [661/3877]: getting STU.L - f[3], s[654]
# SUMO.L SUCCESS
# LSE [662/3877]: getting VHVE.L - f[3], s[655]
# DIS3.L SUCCESS
# LSE [663/3877]: getting 0HMI.L - f[3], s[656]
# DPH.L SUCCESS
# LSE [664/3877]: getting 0Q0C.L - f[3], s[657]
# VHVE.L SUCCESS
# LSE [665/3877]: getting 0QZ1.L - f[3], s[658]
# 0Q0C.L SUCCESS
# LSE [666/3877]: getting UNG.L - f[3], s[659]
# 0QZ1.L SUCCESS
# LSE [667/3877]: getting 0HYA.L - f[3], s[660]
# 0HYA.L SUCCESS
# LSE [668/3877]: getting BIRG.L - f[3], s[661]
# UNG.L SUCCESS
# LSE [669/3877]: getting VRE.L - f[3], s[662]
# BIRG.L SUCCESS
# LSE [670/3877]: getting TCM.L - f[3], s[663]
# VRE.L SUCCESS
# LSE [671/3877]: getting AQX.L - f[3], s[664]
# TCM.L SUCCESS
# LSE [672/3877]: getting IMMO.L - f[3], s[665]
# AQX.L SUCCESS
# LSE [673/3877]: getting 0RPS.L - f[3], s[666]
# IMMO.L SUCCESS
# LSE [674/3877]: getting 0QO9.L - f[3], s[667]
# 0RPS.L SUCCESS
# LSE [675/3877]: getting TCN.L - f[3], s[668]
# STU.L SUCCESS
# LSE [676/3877]: getting TUNG.L - f[3], s[669]
# 0HMI.L SUCCESS
# LSE [677/3877]: getting CRC.L - f[3], s[670]
# TUNG.L SUCCESS
# LSE [678/3877]: getting UDG.L - f[3], s[671]
# CRC.L SUCCESS
# LSE [679/3877]: getting ULS.L - f[3], s[672]
# ULS.L SUCCESS
# LSE [680/3877]: getting SXLU.L - f[3], s[673]
# UDG.L SUCCESS
# LSE [681/3877]: getting SRWE.L - f[3], s[674]
# SXLU.L SUCCESS
# LSE [682/3877]: getting 0QIH.L - f[3], s[675]
# SRWE.L SUCCESS
# LSE [683/3877]: getting 0A8K.L - f[3], s[676]
# 0QIH.L SUCCESS
# LSE [684/3877]: getting SQ3.L - f[3], s[677]
# 0A8K.L SUCCESS
# LSE [685/3877]: getting FEQD.L - f[3], s[678]
# SQ3.L SUCCESS
# LSE [686/3877]: getting GSK.L - f[3], s[679]
# FEQD.L SUCCESS
# LSE [687/3877]: getting 0R00.L - f[3], s[680]
# 0R00.L SUCCESS
# LSE [688/3877]: getting VTC.L - f[3], s[681]
# GSK.L SUCCESS
# LSE [689/3877]: getting ZOE.L - f[3], s[682]
# 0QO9.L SUCCESS
# LSE [690/3877]: getting 0QZO.L - f[3], s[683]
# TCN.L SUCCESS
# LSE [691/3877]: getting 0REZ.L - f[3], s[684]
# VTC.L SUCCESS
# LSE [692/3877]: getting 0QM5.L - f[3], s[685]
# ZOE.L SUCCESS
# LSE [693/3877]: getting ZOL.L - f[3], s[686]
# 0QZO.L SUCCESS
# LSE [694/3877]: getting 0R13.L - f[3], s[687]
# 0REZ.L SUCCESS
# LSE [695/3877]: getting 0R15.L - f[3], s[688]
# 0QM5.L SUCCESS
# LSE [696/3877]: getting AJG.L - f[3], s[689]
# 0R13.L SUCCESS
# LSE [697/3877]: getting 0I4Q.L - f[3], s[690]
# 0R15.L SUCCESS
# LSE [698/3877]: getting 0I0T.L - f[3], s[691]
# 0I0T.L SUCCESS
# LSE [699/3877]: getting 3ICE.L - f[3], s[692]
# 3ICE.L SUCCESS
# LSE [700/3877]: getting ARW.L - f[3], s[693]
# ZOL.L SUCCESS
# LSE [701/3877]: getting 0RKK.L - f[3], s[694]
# AJG.L SUCCESS
# LSE [702/3877]: getting 2MUE.L - f[3], s[695]
# 0I4Q.L SUCCESS
# LSE [703/3877]: getting ARE.L - f[3], s[696]
# 0RKK.L SUCCESS
# LSE [704/3877]: getting UC04.L - f[3], s[697]
# ARE.L SUCCESS
# LSE [705/3877]: getting 3SLL.L - f[3], s[698]
# 2MUE.L SUCCESS
# LSE [706/3877]: getting 0QOT.L - f[3], s[699]
# UC04.L SUCCESS
# LSE [707/3877]: getting 0KH6.L - f[3], s[700]
# 0KH6.L SUCCESS
# LSE [708/3877]: getting 2UKL.L - f[3], s[701]
# 0QOT.L SUCCESS
# LSE [709/3877]: getting BCN.L - f[3], s[702]
# 3SLL.L SUCCESS
# LSE [710/3877]: getting 0QQ4.L - f[3], s[703]
# ARW.L SUCCESS
# LSE [711/3877]: getting 0RG7.L - f[3], s[704]
# 0QQ4.L SUCCESS
# LSE [712/3877]: getting 0JQ4.L - f[3], s[705]
# 2UKL.L SUCCESS
# LSE [713/3877]: getting 0QQ6.L - f[3], s[706]
# BCN.L SUCCESS
# LSE [714/3877]: getting BHGU.L - f[3], s[707]
# 0RG7.L SUCCESS
# LSE [715/3877]: getting ROSN.L - f[3], s[708]
# 0QQ6.L SUCCESS
# LSE [716/3877]: getting GOO3.L - f[3], s[709]
# 0JQ4.L SUCCESS
# LSE [717/3877]: getting BWO.L - f[3], s[710]
# BHGU.L SUCCESS
# LSE [718/3877]: getting 0MFI.L - f[3], s[711]
# ROSN.L SUCCESS
# LSE [719/3877]: getting 0R8F.L - f[3], s[712]
# GOO3.L SUCCESS
# LSE [720/3877]: getting BA47.L - f[3], s[713]
# 0MFI.L SUCCESS
# LSE [721/3877]: getting ECM.L - f[3], s[714]
# BWO.L SUCCESS
# LSE [722/3877]: getting 0QAU.L - f[3], s[715]
# 0R8F.L SUCCESS
# LSE [723/3877]: getting 0R19.L - f[3], s[716]
# BA47.L SUCCESS
# LSE [724/3877]: getting IQAI.L - f[3], s[717]
# 0QAU.L SUCCESS
# LSE [725/3877]: getting DRIP.L - f[3], s[718]
# ECM.L SUCCESS
# LSE [726/3877]: getting 0SYQ.L - f[3], s[719]
# 0R19.L SUCCESS
# LSE [727/3877]: getting ELTA.L - f[3], s[720]
# DRIP.L SUCCESS
# LSE [728/3877]: getting 0JZM.L - f[3], s[721]
# 0SYQ.L SUCCESS
# LSE [729/3877]: getting 0AAJ.L - f[3], s[722]
# IQAI.L SUCCESS
# LSE [730/3877]: getting 0R4W.L - f[3], s[723]
# 0JZM.L SUCCESS
# LSE [731/3877]: getting 0FSN.L - f[3], s[724]
# ELTA.L SUCCESS
# LSE [732/3877]: getting JEGI.L - f[3], s[725]
# 0AAJ.L SUCCESS
# LSE [733/3877]: getting 0PMJ.L - f[3], s[726]
# 0R4W.L SUCCESS
# LSE [734/3877]: getting 3CON.L - f[3], s[727]
# 0FSN.L SUCCESS
# LSE [735/3877]: getting 0VL8.L - f[3], s[728]
# JEGI.L SUCCESS
# LSE [736/3877]: getting 0QKL.L - f[3], s[729]
# 0PMJ.L SUCCESS
# LSE [737/3877]: getting 0Z1Q.L - f[3], s[730]
# 3CON.L SUCCESS
# LSE [738/3877]: getting CIP.L - f[3], s[731]
# 0VL8.L SUCCESS
# LSE [739/3877]: getting 0QLD.L - f[3], s[732]
# 0QKL.L SUCCESS
# LSE [740/3877]: getting 0HR3.L - f[3], s[733]
# 0Z1Q.L SUCCESS
# LSE [741/3877]: getting OMU.L - f[3], s[734]
# CIP.L SUCCESS
# LSE [742/3877]: getting ESC.L - f[3], s[735]
# 0QLD.L SUCCESS
# LSE [743/3877]: getting EQN.L - f[3], s[736]
# 0HR3.L SUCCESS
# LSE [744/3877]: getting BME.L - f[3], s[737]
# ESC.L SUCCESS
# LSE [745/3877]: getting CAY.L - f[3], s[738]
# OMU.L SUCCESS
# LSE [746/3877]: getting ISXF.L - f[3], s[739]
# EQN.L SUCCESS
# LSE [747/3877]: getting 0RHU.L - f[3], s[740]
# CAY.L SUCCESS
# LSE [748/3877]: getting 3OIL.L - f[3], s[741]
# BME.L SUCCESS
# LSE [749/3877]: getting 0T6G.L - f[3], s[742]
# ISXF.L SUCCESS
# LSE [750/3877]: getting WPP.L - f[3], s[743]
# 0RHU.L SUCCESS
# LSE [751/3877]: getting 0ISM.L - f[3], s[744]
# 3OIL.L SUCCESS
# LSE [752/3877]: getting HOYE.L - f[3], s[745]
# 0T6G.L SUCCESS
# LSE [753/3877]: getting 0RH1.L - f[3], s[746]
# 0ISM.L SUCCESS
# LSE [754/3877]: getting FLO.L - f[3], s[747]
# WPP.L SUCCESS
# LSE [755/3877]: getting GHS.L - f[3], s[748]
# HOYE.L SUCCESS
# LSE [756/3877]: getting 0UKI.L - f[3], s[749]
# GHS.L SUCCESS
# LSE [757/3877]: getting 0RH3.L - f[3], s[750]
# 0RH1.L SUCCESS
# LSE [758/3877]: getting SXLI.L - f[3], s[751]
# FLO.L SUCCESS
# LSE [759/3877]: getting 0Z4I.L - f[3], s[752]
# 0UKI.L SUCCESS
# LSE [760/3877]: getting BAES.L - f[3], s[753]
# SXLI.L SUCCESS
# LSE [761/3877]: getting DISS.L - f[3], s[754]
# 0Z4I.L SUCCESS
# LSE [762/3877]: getting 0QQN.L - f[3], s[755]
# BAES.L SUCCESS
# LSE [763/3877]: getting 0VBE.L - f[3], s[756]
# DISS.L SUCCESS
# LSE [764/3877]: getting NMCN.L - f[3], s[757]
# 0RH3.L SUCCESS
# LSE [765/3877]: getting OOUT.L - f[3], s[758]
# 0QQN.L SUCCESS
# LSE [766/3877]: getting SBA.L - f[3], s[759]
# SBA.L SUCCESS
# LSE [767/3877]: getting GTC.L - f[3], s[760]
# GTC.L SUCCESS
# LSE [768/3877]: getting CTEC.L - f[3], s[761]
# CTEC.L SUCCESS
# LSE [769/3877]: getting 0R88.L - f[3], s[762]
# 0R88.L SUCCESS
# LSE [770/3877]: getting 0RFX.L - f[3], s[763]
# 0RFX.L SUCCESS
# LSE [771/3877]: getting 1MCS.L - f[3], s[764]
# 1MCS.L SUCCESS
# LSE [772/3877]: getting SNFL.L - f[3], s[765]
# 0VBE.L SUCCESS
# LSE [773/3877]: getting LEK.L - f[3], s[766]
# OOUT.L SUCCESS
# LSE [774/3877]: getting NSH.L - f[3], s[767]
# NMCN.L SUCCESS
# LSE [775/3877]: getting 3DEL.L - f[3], s[768]
# LEK.L SUCCESS
# LSE [776/3877]: getting 1PDD.L - f[3], s[769]
# 3DEL.L SUCCESS
# LSE [777/3877]: getting 0KXO.L - f[3], s[770]
# SNFL.L SUCCESS
# LSE [778/3877]: getting SHYG.L - f[3], s[771]
# 1PDD.L SUCCESS
# LSE [779/3877]: getting TWTS.L - f[3], s[772]
# 0KXO.L SUCCESS
# LSE [780/3877]: getting IMB.L - f[3], s[773]
# SHYG.L SUCCESS
# LSE [781/3877]: getting BIRD.L - f[3], s[774]
# TWTS.L SUCCESS
# LSE [782/3877]: getting 92IP.L - f[3], s[775]
# BIRD.L SUCCESS
# LSE [783/3877]: getting 0HYP.L - f[3], s[776]
# IMB.L SUCCESS
# LSE [784/3877]: getting 0H9N.L - f[3], s[777]
# 92IP.L SUCCESS
# LSE [785/3877]: getting 0Y5C.L - f[3], s[778]
# 0HYP.L SUCCESS
# LSE [786/3877]: getting JLP.L - f[3], s[779]
# 0H9N.L SUCCESS
# LSE [787/3877]: getting 0GP7.L - f[3], s[780]
# 0Y5C.L SUCCESS
# LSE [788/3877]: getting 0Q19.L - f[3], s[781]
# NSH.L SUCCESS
# LSE [789/3877]: getting 3UBE.L - f[3], s[782]
# 3UBE.L SUCCESS
# LSE [790/3877]: getting SPTO.L - f[3], s[783]
# SPTO.L SUCCESS
# LSE [791/3877]: getting IPLT.L - f[3], s[784]
# IPLT.L SUCCESS
# LSE [792/3877]: getting GNS.L - f[3], s[785]
# 0GP7.L SUCCESS
# LSE [793/3877]: getting SAMZ.L - f[3], s[786]
# 0Q19.L SUCCESS
# LSE [794/3877]: getting BEG.L - f[3], s[787]
# JLP.L SUCCESS
# LSE [795/3877]: getting 0XWD.L - f[3], s[788]
# GNS.L SUCCESS
# LSE [796/3877]: getting SUSS.L - f[3], s[789]
# SAMZ.L SUCCESS
# ...
# LSE [3621/3877]: getting JPEC.L - f[6], s[3611]
# GCP.L SUCCESS
# LSE [3622/3877]: getting I3E.L - f[6], s[3612]
# YOU.L SUCCESS
# LSE [3623/3877]: getting TMO.L - f[6], s[3613]
# JPEC.L SUCCESS
# LSE [3624/3877]: getting HSV.L - f[6], s[3614]
# HSV.L SUCCESS
# LSE [3625/3877]: getting GLR.L - f[6], s[3615]
# GLR.L SUCCESS
# LSE [3626/3877]: getting CRWN.L - f[6], s[3616]
# CRWN.L SUCCESS
# LSE [3627/3877]: getting OTMP.L - f[6], s[3617]
# OTMP.L SUCCESS
# LSE [3628/3877]: getting LSAA.L - f[6], s[3618]
# LSAA.L SUCCESS
# LSE [3629/3877]: getting FUL.L - f[6], s[3619]
# FUL.L SUCCESS
# LSE [3630/3877]: getting MAW.L - f[6], s[3620]
# MAW.L SUCCESS
# LSE [3631/3877]: getting MIG5.L - f[6], s[3621]
# MIG5.L SUCCESS
# LSE [3632/3877]: getting PTR.L - f[6], s[3622]
# CAR.L SUCCESS
# LSE [3633/3877]: getting CEPS.L - f[6], s[3623]
# PTR.L SUCCESS
# LSE [3634/3877]: getting KDR.L - f[6], s[3624]
# I3E.L SUCCESS
# LSE [3635/3877]: getting ZAIM.L - f[6], s[3625]
# TMO.L SUCCESS
# LSE [3636/3877]: getting OSEC.L - f[6], s[3626]
# KDR.L SUCCESS
# LSE [3637/3877]: getting CFYN.L - f[6], s[3627]
# CEPS.L SUCCESS
# LSE [3638/3877]: getting 0RP0.L - f[6], s[3628]
# OSEC.L SUCCESS
# LSE [3639/3877]: getting KAT.L - f[6], s[3629]
# 0RP0.L SUCCESS
# LSE [3640/3877]: getting FINS.L - f[6], s[3630]
# KAT.L SUCCESS
# LSE [3641/3877]: getting KMK.L - f[6], s[3631]
# CFYN.L SUCCESS
# LSE [3642/3877]: getting RBW.L - f[6], s[3632]
# FINS.L SUCCESS
# LSE [3643/3877]: getting DBOX.L - f[6], s[3633]
# KMK.L SUCCESS
# LSE [3644/3877]: getting RCN.L - f[6], s[3634]
# RBW.L SUCCESS
# LSE [3645/3877]: getting GCM.L - f[6], s[3635]
# DBOX.L SUCCESS
# LSE [3646/3877]: getting HOTC.L - f[6], s[3636]
# RCN.L SUCCESS
# LSE [3647/3877]: getting HEMO.L - f[6], s[3637]
# GCM.L SUCCESS
# LSE [3648/3877]: getting PIRI.L - f[6], s[3638]
# HEMO.L SUCCESS
# LSE [3649/3877]: getting 0QZ7.L - f[6], s[3639]
# HOTC.L SUCCESS
# LSE [3650/3877]: getting 0R6H.L - f[6], s[3640]
# PIRI.L SUCCESS
# LSE [3651/3877]: getting EMH.L - f[6], s[3641]
# 0QZ7.L SUCCESS
# LSE [3652/3877]: getting EMIS.L - f[6], s[3642]
# 0R6H.L SUCCESS
# LSE [3653/3877]: getting 0S9E.L - f[6], s[3643]
# EMH.L SUCCESS
# LSE [3654/3877]: getting BAY.L - f[6], s[3644]
# 0S9E.L SUCCESS
# LSE [3655/3877]: getting SFE.L - f[6], s[3645]
# EMIS.L SUCCESS
# LSE [3656/3877]: getting PMP.L - f[6], s[3646]
# BAY.L SUCCESS
# LSE [3657/3877]: getting TEEC.L - f[6], s[3647]
# SFE.L SUCCESS
# LSE [3658/3877]: getting 0I4X.L - f[6], s[3648]
# PMP.L SUCCESS
# LSE [3659/3877]: getting 0XL5.L - f[6], s[3649]
# TEEC.L SUCCESS
# LSE [3660/3877]: getting COM.L - f[6], s[3650]
# 0I4X.L SUCCESS
# LSE [3661/3877]: getting POLY.L - f[6], s[3651]
# 0XL5.L SUCCESS
# LSE [3662/3877]: getting LUCE.L - f[6], s[3652]
# COM.L SUCCESS
# LSE [3663/3877]: getting TRN.L - f[6], s[3653]
# POLY.L SUCCESS
# LSE [3664/3877]: getting PYX.L - f[6], s[3654]
# LUCE.L SUCCESS
# LSE [3665/3877]: getting GELN.L - f[6], s[3655]
# TRN.L SUCCESS
# LSE [3666/3877]: getting MHC.L - f[6], s[3656]
# GELN.L SUCCESS
# LSE [3667/3877]: getting 0O33.L - f[6], s[3657]
# MHC.L SUCCESS
# LSE [3668/3877]: getting 0QZS.L - f[6], s[3658]
# PYX.L SUCCESS
# LSE [3669/3877]: getting KGP.L - f[6], s[3659]
# 0O33.L SUCCESS
# LSE [3670/3877]: getting TIDE.L - f[6], s[3660]
# 0QZS.L SUCCESS
# LSE [3671/3877]: getting APTA.L - f[6], s[3661]
# KGP.L SUCCESS
# LSE [3672/3877]: getting WCAT.L - f[6], s[3662]
# APTA.L SUCCESS
# LSE [3673/3877]: getting CCR.L - f[6], s[3663]
# TIDE.L SUCCESS
# LSE [3674/3877]: getting NCCL.L - f[6], s[3664]
# WCAT.L SUCCESS
# LSE [3675/3877]: getting VIC.L - f[6], s[3665]
# NCCL.L SUCCESS
# LSE [3676/3877]: getting MILA.L - f[6], s[3666]
# CCR.L SUCCESS
# LSE [3677/3877]: getting CORA.L - f[6], s[3667]
# VIC.L SUCCESS
# LSE [3678/3877]: getting DPP.L - f[6], s[3668]
# MILA.L SUCCESS
# LSE [3679/3877]: getting LME.L - f[6], s[3669]
# CORA.L SUCCESS
# LSE [3680/3877]: getting TUI.L - f[6], s[3670]
# DPP.L SUCCESS
# LSE [3681/3877]: getting 0QPU.L - f[6], s[3671]
# TUI.L SUCCESS
# LSE [3682/3877]: getting 0VGM.L - f[6], s[3672]
# 0QPU.L SUCCESS
# LSE [3683/3877]: getting BVX.L - f[6], s[3673]
# LME.L SUCCESS
# LSE [3684/3877]: getting IPF.L - f[6], s[3674]
# 0VGM.L SUCCESS
# LSE [3685/3877]: getting 0SAY.L - f[6], s[3675]
# ZAIM.L SUCCESS
# LSE [3686/3877]: getting 0RQB.L - f[6], s[3676]
# 0SAY.L SUCCESS
# LSE [3687/3877]: getting BMT.L - f[6], s[3677]
# BMT.L SUCCESS
# LSE [3688/3877]: getting PLUS.L - f[6], s[3678]
# PLUS.L SUCCESS
# LSE [3689/3877]: getting PGOO.L - f[6], s[3679]
# PGOO.L SUCCESS
# LSE [3690/3877]: getting BDEV.L - f[6], s[3680]
# BDEV.L SUCCESS
# LSE [3691/3877]: getting SSTY.L - f[6], s[3681]
# SSTY.L SUCCESS
# LSE [3692/3877]: getting OBI.L - f[6], s[3682]
# OBI.L SUCCESS
# LSE [3693/3877]: getting BLV.L - f[6], s[3683]
# BLV.L SUCCESS
# LSE [3694/3877]: getting EGY.L - f[6], s[3684]
# EGY.L SUCCESS
# LSE [3695/3877]: getting NTOG.L - f[6], s[3685]
# BVX.L SUCCESS
# LSE [3696/3877]: getting DNL.L - f[6], s[3686]
# 0RQB.L SUCCESS
# LSE [3697/3877]: getting HUW.L - f[6], s[3687]
# IPF.L SUCCESS
# LSE [3698/3877]: getting SMJ.L - f[6], s[3688]
# DNL.L SUCCESS
# LSE [3699/3877]: getting HPA1.L - f[6], s[3689]
# NTOG.L SUCCESS
# LSE [3700/3877]: getting RGD.L - f[6], s[3690]
# HPA1.L SUCCESS
# LSE [3701/3877]: getting RHM.L - f[6], s[3691]
# SMJ.L SUCCESS
# LSE [3702/3877]: getting FORT.L - f[6], s[3692]
# RGD.L SUCCESS
# LSE [3703/3877]: getting IMM.L - f[6], s[3693]
# FORT.L SUCCESS
# LSE [3704/3877]: getting WINE.L - f[6], s[3694]
# IMM.L SUCCESS
# LSE [3705/3877]: getting RCOI.L - f[6], s[3695]
# RCOI.L SUCCESS
# LSE [3706/3877]: getting PVN.L - f[6], s[3696]
# WINE.L SUCCESS
# LSE [3707/3877]: getting 0QMR.L - f[6], s[3697]
# PVN.L SUCCESS
# LSE [3708/3877]: getting 0P2J.L - f[6], s[3698]
# 0QMR.L SUCCESS
# LSE [3709/3877]: getting GYG.L - f[6], s[3699]
# 0P2J.L SUCCESS
# LSE [3710/3877]: getting BRH.L - f[6], s[3700]
# GYG.L SUCCESS
# LSE [3711/3877]: getting IES.L - f[6], s[3701]
# IES.L SUCCESS
# LSE [3712/3877]: getting HVPE.L - f[6], s[3702]
# HUW.L SUCCESS
# LSE [3713/3877]: getting ITIM.L - f[6], s[3703]
# BRH.L SUCCESS
# LSE [3714/3877]: getting LST.L - f[6], s[3704]
# RHM.L SUCCESS
# LSE [3715/3877]: getting GSF.L - f[6], s[3705]
# HVPE.L SUCCESS
# LSE [3716/3877]: getting INSP.L - f[6], s[3706]
# ITIM.L SUCCESS
# LSE [3717/3877]: getting PAGE.L - f[6], s[3707]
# LST.L SUCCESS
# LSE [3718/3877]: getting DNA2.L - f[6], s[3708]
# INSP.L SUCCESS
# LSE [3719/3877]: getting RAT.L - f[6], s[3709]
# PAGE.L SUCCESS
# LSE [3720/3877]: getting BATS.L - f[6], s[3710]
# RAT.L SUCCESS
# LSE [3721/3877]: getting D467.L - f[6], s[3711]
# BATS.L SUCCESS
# LSE [3722/3877]: getting PHNX.L - f[6], s[3712]
# D467.L SUCCESS
# LSE [3723/3877]: getting OCDO.L - f[6], s[3713]
# PHNX.L SUCCESS
# LSE [3724/3877]: getting ASHM.L - f[6], s[3714]
# OCDO.L SUCCESS
# LSE [3725/3877]: getting SCIR.L - f[6], s[3715]
# ASHM.L SUCCESS
# LSE [3726/3877]: getting JHD.L - f[6], s[3716]
# SCIR.L SUCCESS
# LSE [3727/3877]: getting UBG.L - f[6], s[3717]
# JHD.L SUCCESS
# LSE [3728/3877]: getting IDE.L - f[6], s[3718]
# UBG.L SUCCESS
# LSE [3729/3877]: getting TTE.L - f[6], s[3719]
# DNA2.L SUCCESS
# LSE [3730/3877]: getting 0QPR.L - f[6], s[3720]
# IDE.L SUCCESS
# LSE [3731/3877]: getting SCRF.L - f[6], s[3721]
# 0QPR.L SUCCESS
# LSE [3732/3877]: getting NWOR.L - f[6], s[3722]
# TTE.L SUCCESS
# LSE [3733/3877]: getting ADA.L - f[6], s[3723]
# SCRF.L SUCCESS
# LSE [3734/3877]: getting USF.L - f[6], s[3724]
# NWOR.L SUCCESS
# LSE [3735/3877]: getting KOO.L - f[6], s[3725]
# ADA.L SUCCESS
# LSE [3736/3877]: getting GSP.L - f[6], s[3726]
# USF.L SUCCESS
# LSE [3737/3877]: getting DFS.L - f[6], s[3727]
# KOO.L SUCCESS
# LSE [3738/3877]: getting AWE.L - f[6], s[3728]
# GSP.L SUCCESS
# LSE [3739/3877]: getting TAVI.L - f[6], s[3729]
# DFS.L SUCCESS
# LSE [3740/3877]: getting SAA.L - f[6], s[3730]
# AWE.L SUCCESS
# LSE [3741/3877]: getting BIG.L - f[6], s[3731]
# BIG.L SUCCESS
# LSE [3742/3877]: getting HSW.L - f[6], s[3732]
# TAVI.L SUCCESS
# LSE [3743/3877]: getting ESKN.L - f[6], s[3733]
# SAA.L SUCCESS
# LSE [3744/3877]: getting 0R1D.L - f[6], s[3734]
# GSF.L SUCCESS
# LSE [3745/3877]: getting IIP.L - f[6], s[3735]
# HSW.L SUCCESS
# LSE [3746/3877]: getting 0QSS.L - f[6], s[3736]
# ESKN.L SUCCESS
# LSE [3747/3877]: getting TPOB.L - f[6], s[3737]
# 0R1D.L SUCCESS
# LSE [3748/3877]: getting CNS.L - f[6], s[3738]
# IIP.L SUCCESS
# LSE [3749/3877]: getting PPHC.L - f[6], s[3739]
# 0QSS.L SUCCESS
# LSE [3750/3877]: getting VTAS.L - f[6], s[3740]
# TPOB.L SUCCESS
# LSE [3751/3877]: getting GCL.L - f[6], s[3741]
# CNS.L SUCCESS
# LSE [3752/3877]: getting SQZ.L - f[6], s[3742]
# PPHC.L SUCCESS
# LSE [3753/3877]: getting CHRY.L - f[6], s[3743]
# VTAS.L SUCCESS
# LSE [3754/3877]: getting GMS.L - f[6], s[3744]
# GCL.L SUCCESS
# LSE [3755/3877]: getting BOE.L - f[6], s[3745]
# CHRY.L SUCCESS
# LSE [3756/3877]: getting PAT.L - f[6], s[3746]
# SQZ.L SUCCESS
# LSE [3757/3877]: getting HZM.L - f[6], s[3747]
# GMS.L SUCCESS
# LSE [3758/3877]: getting SDI.L - f[6], s[3748]
# PAT.L SUCCESS
# LSE [3759/3877]: getting PREM.L - f[6], s[3749]
# HZM.L SUCCESS
# LSE [3760/3877]: getting HDT.L - f[6], s[3750]
# SDI.L SUCCESS
# LSE [3761/3877]: getting LIV.L - f[6], s[3751]
# PREM.L SUCCESS
# LSE [3762/3877]: getting PGHZ.L - f[6], s[3752]
# LIV.L SUCCESS
# LSE [3763/3877]: getting PRIM.L - f[6], s[3753]
# HDT.L SUCCESS
# LSE [3764/3877]: getting BMV.L - f[6], s[3754]
# BMV.L SUCCESS
# LSE [3765/3877]: getting SLP.L - f[6], s[3755]
# PRIM.L SUCCESS
# LSE [3766/3877]: getting TAN.L - f[6], s[3756]
# BOE.L SUCCESS
# LSE [3767/3877]: getting FOXT.L - f[6], s[3757]
# FOXT.L SUCCESS
# LSE [3768/3877]: getting MPO.L - f[6], s[3758]
# PGHZ.L SUCCESS
# LSE [3769/3877]: getting CHH.L - f[6], s[3759]
# SLP.L SUCCESS
# LSE [3770/3877]: getting 0QN2.L - f[6], s[3760]
# TAN.L SUCCESS
# LSE [3771/3877]: getting BOTB.L - f[6], s[3761]
# 0QN2.L SUCCESS
# LSE [3772/3877]: getting GRP.L - f[6], s[3762]
# BOTB.L SUCCESS
# LSE [3773/3877]: getting NEX.L - f[6], s[3763]
# GRP.L SUCCESS
# LSE [3774/3877]: getting PDL.L - f[6], s[3764]
# NEX.L SUCCESS
# LSE [3775/3877]: getting TM17.L - f[6], s[3765]
# PDL.L SUCCESS
# LSE [3776/3877]: getting ATOM.L - f[6], s[3766]
# TM17.L SUCCESS
# LSE [3777/3877]: getting 0O0E.L - f[6], s[3767]
# ATOM.L SUCCESS
# LSE [3778/3877]: getting SGE.L - f[6], s[3768]
# MPO.L SUCCESS
# LSE [3779/3877]: getting ALAI.L - f[6], s[3769]
# 0O0E.L SUCCESS
# LSE [3780/3877]: getting ASLI.L - f[6], s[3770]
# ALAI.L SUCCESS
# LSE [3781/3877]: getting JDW.L - f[6], s[3771]
# CHH.L SUCCESS
# LSE [3782/3877]: getting MTR.L - f[6], s[3772]
# SGE.L SUCCESS
# LSE [3783/3877]: getting SNT.L - f[6], s[3773]
# ASLI.L SUCCESS
# LSE [3784/3877]: getting 0DTK.L - f[6], s[3774]
# JDW.L SUCCESS
# LSE [3785/3877]: getting SEED.L - f[6], s[3775]
# MTR.L SUCCESS
# LSE [3786/3877]: getting URU.L - f[6], s[3776]
# 0DTK.L SUCCESS
# LSE [3787/3877]: getting IRON.L - f[6], s[3777]
# SNT.L SUCCESS
# LSE [3788/3877]: getting TFGS.L - f[6], s[3778]
# SEED.L SUCCESS
# LSE [3789/3877]: getting CTG.L - f[6], s[3779]
# TFGS.L SUCCESS
# LSE [3790/3877]: getting B90.L - f[6], s[3780]
# URU.L SUCCESS
# LSE [3791/3877]: getting MPAC.L - f[6], s[3781]
# IRON.L SUCCESS
# LSE [3792/3877]: getting 0QI9.L - f[6], s[3782]
# 0QI9.L SUCCESS
# LSE [3793/3877]: getting CORO.L - f[6], s[3783]
# CTG.L SUCCESS
# LSE [3794/3877]: getting ADV.L - f[6], s[3784]
# CORO.L SUCCESS
# LSE [3795/3877]: getting JAN.L - f[6], s[3785]
# ADV.L SUCCESS
# LSE [3796/3877]: getting TM1.L - f[6], s[3786]
# JAN.L SUCCESS
# LSE [3797/3877]: getting SYNC.L - f[6], s[3787]
# TM1.L SUCCESS
# LSE [3798/3877]: getting MSLH.L - f[6], s[3788]
# SYNC.L SUCCESS
# LSE [3799/3877]: getting HMI.L - f[6], s[3789]
# MSLH.L SUCCESS
# LSE [3800/3877]: getting 0QQZ.L - f[6], s[3790]
# HMI.L SUCCESS
# LSE [3801/3877]: getting SAV.L - f[6], s[3791]
# 0QQZ.L SUCCESS
# LSE [3802/3877]: getting 0EE0.L - f[6], s[3792]
# SAV.L SUCCESS
# LSE [3803/3877]: getting GCG.L - f[6], s[3793]
# 0EE0.L SUCCESS
# LSE [3804/3877]: getting SIV.L - f[6], s[3794]
# GCG.L SUCCESS
# LSE [3805/3877]: getting EJFI.L - f[6], s[3795]
# EJFI.L SUCCESS
# LSE [3806/3877]: getting MCLS.L - f[6], s[3796]
# MCLS.L SUCCESS
# LSE [3807/3877]: getting BVXP.L - f[6], s[3797]
# BVXP.L SUCCESS
# LSE [3808/3877]: getting MAV4.L - f[6], s[3798]
# MAV4.L SUCCESS
# LSE [3809/3877]: getting MIG.L - f[6], s[3799]
# B90.L SUCCESS
# LSE [3810/3877]: getting MXC.L - f[6], s[3800]
# MPAC.L SUCCESS
# LSE [3811/3877]: getting JIM.L - f[6], s[3801]
# MIG.L SUCCESS
# LSE [3812/3877]: getting CMRS.L - f[6], s[3802]
# MXC.L SUCCESS
# LSE [3813/3877]: getting DCI.L - f[6], s[3803]
# SIV.L SUCCESS
# LSE [3814/3877]: getting MER.L - f[6], s[3804]
# JIM.L SUCCESS
# LSE [3815/3877]: getting ADF.L - f[6], s[3805]
# CMRS.L SUCCESS
# LSE [3816/3877]: getting MCL.L - f[6], s[3806]
# DCI.L SUCCESS
# LSE [3817/3877]: getting GWI.L - f[6], s[3807]
# MER.L SUCCESS
# LSE [3818/3877]: getting ATYM.L - f[6], s[3808]
# ADF.L SUCCESS
# LSE [3819/3877]: getting ASLR.L - f[6], s[3809]
# MCL.L SUCCESS
# LSE [3820/3877]: getting EME.L - f[6], s[3810]
# GWI.L SUCCESS
# LSE [3821/3877]: getting FRAN.L - f[6], s[3811]
# ATYM.L SUCCESS
# LSE [3822/3877]: getting ONT.L - f[6], s[3812]
# EME.L SUCCESS
# LSE [3823/3877]: getting SVT.L - f[6], s[3813]
# FRAN.L SUCCESS
# LSE [3824/3877]: getting 0QYK.L - f[6], s[3814]
# ONT.L SUCCESS
# LSE [3825/3877]: getting ICP.L - f[6], s[3815]
# 0QYK.L SUCCESS
# LSE [3826/3877]: getting SMD.L - f[6], s[3816]
# SVT.L SUCCESS
# LSE [3827/3877]: getting KRS.L - f[6], s[3817]
# ICP.L SUCCESS
# LSE [3828/3877]: getting DISH.L - f[6], s[3818]
# SMD.L SUCCESS
# LSE [3829/3877]: getting APAX.L - f[6], s[3819]
# KRS.L SUCCESS
# LSE [3830/3877]: getting AAU.L - f[6], s[3820]
# DISH.L SUCCESS
# LSE [3831/3877]: getting 0QM6.L - f[6], s[3821]
# APAX.L SUCCESS
# LSE [3832/3877]: getting SJG.L - f[6], s[3822]
# AAU.L SUCCESS
# LSE [3833/3877]: getting 0R6V.L - f[6], s[3823]
# 0QM6.L SUCCESS
# LSE [3834/3877]: getting QTX.L - f[6], s[3824]
# 0R6V.L SUCCESS
# LSE [3835/3877]: getting CBX.L - f[6], s[3825]
# CBX.L SUCCESS
# LSE [3836/3877]: getting 0Z1W.L - f[6], s[3826]
# 0Z1W.L SUCCESS
# LSE [3837/3877]: getting MKA.L - f[6], s[3827]
# MKA.L SUCCESS
# LSE [3838/3877]: getting CGEO.L - f[6], s[3828]
# SJG.L SUCCESS
# LSE [3839/3877]: getting GSCU.L - f[6], s[3829]
# QTX.L SUCCESS
# LSE [3840/3877]: getting BHMU.L - f[6], s[3830]
# GSCU.L SUCCESS
# LSE [3841/3877]: getting AVAP.L - f[6], s[3831]
# ASLR.L SUCCESS
# LSE [3842/3877]: getting FTF.L - f[6], s[3832]
# BHMU.L SUCCESS
# LSE [3843/3877]: getting 0HVD.L - f[6], s[3833]
# AVAP.L SUCCESS
# LSE [3844/3877]: getting EVE.L - f[6], s[3834]
# FTF.L SUCCESS
# LSE [3845/3877]: getting 0HKM.L - f[6], s[3835]
# 0HVD.L SUCCESS
# LSE [3846/3877]: getting DSCV.L - f[6], s[3836]
# EVE.L SUCCESS
# LSE [3847/3877]: getting GNC.L - f[6], s[3837]
# 0HKM.L SUCCESS
# LSE [3848/3877]: getting ROC.L - f[6], s[3838]
# DSCV.L SUCCESS
# LSE [3849/3877]: getting EBOX.L - f[6], s[3839]
# GNC.L SUCCESS
# LSE [3850/3877]: getting 0UAN.L - f[6], s[3840]
# ROC.L SUCCESS
# LSE [3851/3877]: getting 0RT6.L - f[6], s[3841]
# EBOX.L SUCCESS
# LSE [3852/3877]: getting GSEO.L - f[6], s[3842]
# 0UAN.L SUCCESS
# LSE [3853/3877]: getting 0HH6.L - f[6], s[3843]
# 0RT6.L SUCCESS
# LSE [3854/3877]: getting CKT.L - f[6], s[3844]
# GSEO.L SUCCESS
# LSE [3855/3877]: getting 0MRM.L - f[6], s[3845]
# 0HH6.L SUCCESS
# LSE [3856/3877]: getting MAST.L - f[6], s[3846]
# CKT.L SUCCESS
# LSE [3857/3877]: getting BHMG.L - f[6], s[3847]
# 0MRM.L SUCCESS
# LSE [3858/3877]: getting SNWS.L - f[6], s[3848]
# MAST.L SUCCESS
# LSE [3859/3877]: getting ASTO.L - f[6], s[3849]
# BHMG.L SUCCESS
# LSE [3860/3877]: getting MEX.L - f[6], s[3850]
# SNWS.L SUCCESS
# LSE [3861/3877]: getting 0R0G.L - f[6], s[3851]
# ASTO.L SUCCESS
# LSE [3862/3877]: getting RNWH.L - f[6], s[3852]
# MEX.L SUCCESS
# LSE [3863/3877]: getting ALTN.L - f[6], s[3853]
# 0R0G.L SUCCESS
# LSE [3864/3877]: getting PTEC.L - f[6], s[3854]
# RNWH.L SUCCESS
# LSE [3865/3877]: getting GDP.L - f[6], s[3855]
# ALTN.L SUCCESS
# LSE [3866/3877]: getting CNG.L - f[6], s[3856]
# PTEC.L SUCCESS
# LSE [3867/3877]: getting 0QN1.L - f[6], s[3857]
# CGEO.L SUCCESS
# LSE [3868/3877]: getting CRN.L - f[6], s[3858]
# GDP.L SUCCESS
# LSE [3869/3877]: getting CCPA.L - f[6], s[3859]
# CRN.L SUCCESS
# LSE [3870/3877]: getting WCW.L - f[6], s[3860]
# 0QN1.L SUCCESS
# LSE [3871/3877]: getting STVG.L - f[6], s[3861]
# CNG.L SUCCESS
# LSE [3872/3877]: getting DATA.L - f[6], s[3862]
# CCPA.L SUCCESS
# LSE [3873/3877]: getting IDEA.L - f[6], s[3863]
# DATA.L SUCCESS
# LSE [3874/3877]: getting MVI.L - f[6], s[3864]
# STVG.L SUCCESS
# LSE [3875/3877]: getting 0KD1.L - f[6], s[3865]
# IDEA.L SUCCESS
# LSE [3876/3877]: getting DOCS.L - f[6], s[3866]
# MVI.L SUCCESS
# LSE [3877/3877]: getting BKY.L - f[6], s[3867]
# 0KD1.L SUCCESS
# DOCS.L SUCCESS
# BKY.L SUCCESS
# WCW.L SUCCESS
# 6
# 3871

# %%
exchange = 'NASDAQ'
nasdaq_data, nasdaq_failed = get_exchange_data(exchange)
# Out:
# NYSE [1/3083]: getting KMI - f[0], s[0]
# NYSE [2/3083]: getting GE - f[0], s[0]
# NYSE [3/3083]: getting BAC - f[0], s[0]
# NYSE [4/3083]: getting HPQ - f[0], s[0]
# KMI SUCCESS
# NYSE [5/3083]: getting CX - f[0], s[1]
# BAC SUCCESS
# NYSE [6/3083]: getting F - f[0], s[2]
# HPQ SUCCESS
# NYSE [7/3083]: getting SNAP - f[0], s[3]
# GE SUCCESS
# NYSE [8/3083]: getting WFC - f[0], s[4]
# CX SUCCESS
# NYSE [9/3083]: getting AIG - f[0], s[5]
# SNAP SUCCESS
# NYSE [10/3083]: getting T - f[0], s[6]
# F SUCCESS
# NYSE [11/3083]: getting C - f[0], s[7]
# WFC SUCCESS
# NYSE [12/3083]: getting VALE - f[0], s[8]
# AIG SUCCESS
# NYSE [13/3083]: getting MS - f[0], s[9]
# T SUCCESS
# NYSE [14/3083]: getting JPM - f[0], s[10]
# VALE SUCCESS
# NYSE [15/3083]: getting ORCL - f[0], s[11]
# C SUCCESS
# NYSE [16/3083]: getting NKE - f[0], s[12]
# JPM SUCCESS
# NYSE [17/3083]: getting PG - f[0], s[13]
# MS SUCCESS
# NYSE [18/3083]: getting BBD - f[0], s[14]
# NKE SUCCESS
# NYSE [19/3083]: getting PFE - f[0], s[15]
# ORCL SUCCESS
# NYSE [20/3083]: getting NOK - f[0], s[16]
# BBD SUCCESS
# NYSE [21/3083]: getting TWTR - f[0], s[17]
# PG SUCCESS
# NYSE [22/3083]: getting XOM - f[0], s[18]
# NOK SUCCESS
# NYSE [23/3083]: getting VIPS - f[0], s[19]
# PFE SUCCESS
# NYSE [24/3083]: getting AXP - f[0], s[20]
# XOM SUCCESS
# NYSE [25/3083]: getting BMY - f[0], s[21]
# BMY SUCCESS
# NYSE [26/3083]: getting V - f[0], s[22]
# V SUCCESS
# NYSE [27/3083]: getting KEY - f[0], s[23]
# KEY SUCCESS
# NYSE [28/3083]: getting RF - f[0], s[24]
# RF SUCCESS
# NYSE [29/3083]: getting KR - f[0], s[25]
# TWTR SUCCESS
# NYSE [30/3083]: getting HAL - f[0], s[26]
# AXP SUCCESS
# NYSE [31/3083]: getting BABA - f[0], s[27]
# VIPS SUCCESS
# NYSE [32/3083]: getting MRO - f[0], s[28]
# BABA SUCCESS
# NYSE [33/3083]: getting GM - f[0], s[29]
# GM SUCCESS
# NYSE [34/3083]: getting FCX - f[0], s[30]
# FCX SUCCESS
# NYSE [35/3083]: getting CRM - f[0], s[31]
# CRM SUCCESS
# NYSE [36/3083]: getting SQ - f[0], s[32]
# SQ SUCCESS
# NYSE [37/3083]: getting NUE - f[0], s[33]
# NUE SUCCESS
# NYSE [38/3083]: getting SWN - f[0], s[34]
# HAL SUCCESS
# NYSE [39/3083]: getting LOW - f[0], s[35]
# KR SUCCESS
# NYSE [40/3083]: getting RAD - f[0], s[36]
# MRO SUCCESS
# NYSE [41/3083]: getting SLB - f[0], s[37]
# LOW SUCCESS
# NYSE [42/3083]: getting ABBV - f[0], s[38]
# RAD SUCCESS
# NYSE [43/3083]: getting GIS - f[0], s[39]
# SLB SUCCESS
# NYSE [44/3083]: getting VZ - f[0], s[40]
# ABBV SUCCESS
# NYSE [45/3083]: getting X - f[0], s[41]
# SWN SUCCESS
# NYSE [46/3083]: getting DVN - f[0], s[42]
# GIS SUCCESS
# NYSE [47/3083]: getting IBN - f[0], s[43]
# VZ SUCCESS
# NYSE [48/3083]: getting MPC - f[0], s[44]
# X SUCCESS
# NYSE [49/3083]: getting PM - f[0], s[45]
# IBN SUCCESS
# NYSE [50/3083]: getting MSCI - f[0], s[46]
# DVN SUCCESS
# NYSE [51/3083]: getting RDN - f[0], s[47]
# MPC SUCCESS
# NYSE [52/3083]: getting KO - f[0], s[48]
# PM SUCCESS
# NYSE [53/3083]: getting COP - f[0], s[49]
# MSCI SUCCESS
# NYSE [54/3083]: getting DIS - f[0], s[50]
# RDN SUCCESS
# NYSE [55/3083]: getting LEN - f[0], s[51]
# KO SUCCESS
# NYSE [56/3083]: getting CVX - f[0], s[52]
# COP SUCCESS
# NYSE [57/3083]: getting AUY - f[0], s[53]
# DIS SUCCESS
# NYSE [58/3083]: getting WMT - f[0], s[54]
# LEN SUCCESS
# NYSE [59/3083]: getting CLF - f[0], s[55]
# CVX SUCCESS
# NYSE [60/3083]: getting MRK - f[0], s[56]
# AUY SUCCESS
# NYSE [61/3083]: getting MGM - f[0], s[57]
# WMT SUCCESS
# NYSE [62/3083]: getting GFI - f[0], s[58]
# CLF SUCCESS
# NYSE [63/3083]: getting KGC - f[0], s[59]
# MRK SUCCESS
# NYSE [64/3083]: getting SCHW - f[0], s[60]
# GFI SUCCESS
# NYSE [65/3083]: getting NBR - f[0], s[61]
# MGM SUCCESS
# NYSE [66/3083]: getting JNJ - f[0], s[62]
# KGC SUCCESS
# NYSE [67/3083]: getting BSX - f[0], s[63]
# SCHW SUCCESS
# NYSE [68/3083]: getting ITUB - f[0], s[64]
# NBR SUCCESS
# NYSE [69/3083]: getting BK - f[0], s[65]
# JNJ SUCCESS
# NYSE [70/3083]: getting HMY - f[0], s[66]
# BSX SUCCESS
# NYSE [71/3083]: getting HOME - f[0], s[67]
# HMY SUCCESS
# NYSE [72/3083]: getting KOS - f[0], s[68]
# HOME SUCCESS
# NYSE [73/3083]: getting DAL - f[0], s[69]
# KOS SUCCESS
# NYSE [74/3083]: getting INFY - f[0], s[70]
# DAL SUCCESS
# NYSE [75/3083]: getting CCL - f[0], s[71]
# ITUB SUCCESS
# NYSE [76/3083]: getting MFGP - f[0], s[72]
# INFY SUCCESS
# NYSE [77/3083]: getting PBR - f[0], s[73]
# BK SUCCESS
# NYSE [78/3083]: getting LPI - f[0], s[74]
# CCL SUCCESS
# NYSE [79/3083]: getting ABT - f[0], s[75]
# PBR SUCCESS
# NYSE [80/3083]: getting USB - f[0], s[76]
# LPI SUCCESS
# NYSE [81/3083]: getting BA - f[0], s[77]
# USB SUCCESS
# NYSE [82/3083]: getting GGB - f[0], s[78]
# BA SUCCESS
# NYSE [83/3083]: getting DB - f[0], s[79]
# GGB SUCCESS
# NYSE [84/3083]: getting KNX - f[0], s[80]
# DB SUCCESS
# NYSE [85/3083]: getting KBH - f[0], s[81]
# KNX SUCCESS
# NYSE [86/3083]: getting PGR - f[0], s[82]
# KBH SUCCESS
# NYSE [87/3083]: getting MO - f[0], s[83]
# PGR SUCCESS
# NYSE [88/3083]: getting MDT - f[0], s[84]
# MO SUCCESS
# NYSE [89/3083]: getting RIG - f[0], s[85]
# MDT SUCCESS
# NYSE [90/3083]: getting BCS - f[0], s[86]
# RIG SUCCESS
# NYSE [91/3083]: getting EOG - f[0], s[87]
# BCS SUCCESS
# NYSE [92/3083]: getting HPE - f[0], s[88]
# EOG SUCCESS
# NYSE [93/3083]: getting OKE - f[0], s[89]
# HPE SUCCESS
# NYSE [94/3083]: getting CVS - f[0], s[90]
# MFGP SUCCESS
# NYSE [95/3083]: getting HES - f[0], s[91]
# OKE SUCCESS
# NYSE [96/3083]: getting GDDY - f[0], s[92]
# CVS SUCCESS
# NYSE [97/3083]: getting BX - f[0], s[93]
# GDDY SUCCESS
# NYSE [98/3083]: getting NLSN - f[0], s[94]
# HES SUCCESS
# NYSE [99/3083]: getting TS - f[0], s[95]
# BX SUCCESS
# NYSE [100/3083]: getting BOX - f[0], s[96]
# ABT SUCCESS
# NYSE [101/3083]: getting OXY - f[0], s[97]
# NLSN SUCCESS
# NYSE [102/3083]: getting CVE - f[0], s[98]
# TS SUCCESS
# NYSE [103/3083]: getting SYF - f[0], s[99]
# BOX SUCCESS
# NYSE [104/3083]: getting MTG - f[0], s[100]
# OXY SUCCESS
# NYSE [105/3083]: getting LUV - f[0], s[101]
# CVE SUCCESS
# NYSE [106/3083]: getting FTI - f[0], s[102]
# SYF SUCCESS
# NYSE [107/3083]: getting AA - f[0], s[103]
# MTG SUCCESS
# NYSE [108/3083]: getting ABEV - f[0], s[104]
# LUV SUCCESS
# NYSE [109/3083]: getting TAL - f[0], s[105]
# FTI SUCCESS
# NYSE [110/3083]: getting UNH - f[0], s[106]
# AA SUCCESS
# NYSE [111/3083]: getting GES - f[0], s[107]
# ABEV SUCCESS
# NYSE [112/3083]: getting CNC - f[0], s[108]
# TAL SUCCESS
# NYSE [113/3083]: getting CLDR - f[0], s[109]
# UNH SUCCESS
# NYSE [114/3083]: getting RES - f[0], s[110]
# GES SUCCESS
# NYSE [115/3083]: getting CI - f[0], s[111]
# CLDR SUCCESS
# NYSE [116/3083]: getting WMB - f[0], s[112]
# CNC SUCCESS
# NYSE [117/3083]: getting HBI - f[0], s[113]
# CI SUCCESS
# NYSE [118/3083]: getting XL - f[0], s[114]
# RES SUCCESS
# NYSE [119/3083]: getting D - f[0], s[115]
# WMB SUCCESS
# NYSE [120/3083]: getting CHS - f[0], s[116]
# HBI SUCCESS
# NYSE [121/3083]: getting CFG - f[0], s[117]
# XL SUCCESS
# NYSE [122/3083]: getting SU - f[0], s[118]
# CFG SUCCESS
# NYSE [123/3083]: getting MMM - f[0], s[119]
# D SUCCESS
# NYSE [124/3083]: getting JBL - f[0], s[120]
# CHS SUCCESS
# NYSE [125/3083]: getting ACN - f[0], s[121]
# SU SUCCESS
# NYSE [126/3083]: getting NTR - f[0], s[122]
# JBL SUCCESS
# NYSE [127/3083]: getting BRFS - f[0], s[123]
# MMM SUCCESS
# NYSE [128/3083]: getting LVS - f[0], s[124]
# ACN SUCCESS
# NYSE [129/3083]: getting EGO - f[0], s[125]
# NTR SUCCESS
# NYSE [130/3083]: getting TEVA - f[0], s[126]
# LVS SUCCESS
# NYSE [131/3083]: getting VLO - f[0], s[127]
# BRFS SUCCESS
# NYSE [132/3083]: getting IMAX - f[0], s[128]
# EGO SUCCESS
# NYSE [133/3083]: getting FNB - f[0], s[129]
# TEVA SUCCESS
# NYSE [134/3083]: getting HD - f[0], s[130]
# VLO SUCCESS
# NYSE [135/3083]: getting AR - f[0], s[131]
# IMAX SUCCESS
# NYSE [136/3083]: getting ARNC - f[0], s[132]
# FNB SUCCESS
# NYSE [137/3083]: getting VOYA - f[0], s[133]
# HD SUCCESS
# NYSE [138/3083]: getting SM - f[0], s[134]
# ARNC SUCCESS
# NYSE [139/3083]: getting DHI - f[0], s[135]
# AR SUCCESS
# NYSE [140/3083]: getting HRB - f[0], s[136]
# VOYA SUCCESS
# NYSE [141/3083]: getting BTU - f[0], s[137]
# SM SUCCESS
# NYSE [142/3083]: getting IPG - f[0], s[138]
# DHI SUCCESS
# NYSE [143/3083]: getting DE - f[0], s[139]
# BTU SUCCESS
# NYSE [144/3083]: getting COG - f[0], s[140]
# HRB SUCCESS
# NYSE [145/3083]: getting IBM - f[0], s[141]
# IPG SUCCESS
# NYSE [146/3083]: getting NYT - f[0], s[142]
# COG SUCCESS
# NYSE [147/3083]: getting OLN - f[0], s[143]
# DE SUCCESS
# NYSE [148/3083]: getting JCI - f[0], s[144]
# IBM SUCCESS
# NYSE [149/3083]: getting VST - f[0], s[145]
# VST SUCCESS
# NYSE [150/3083]: getting EPD - f[0], s[146]
# NYT SUCCESS
# NYSE [151/3083]: getting KMB - f[0], s[147]
# OLN SUCCESS
# NYSE [152/3083]: getting IT - f[0], s[148]
# JCI SUCCESS
# NYSE [153/3083]: getting CAT - f[0], s[149]
# EPD SUCCESS
# NYSE [154/3083]: getting AU - f[0], s[150]
# IT SUCCESS
# NYSE [155/3083]: getting KKR - f[0], s[151]
# KMB SUCCESS
# NYSE [156/3083]: getting CMC - f[0], s[152]
# CAT SUCCESS
# NYSE [157/3083]: getting NRG - f[0], s[153]
# AU SUCCESS
# NYSE [158/3083]: getting CPB - f[0], s[154]
# KKR SUCCESS
# NYSE [159/3083]: getting ATHM - f[0], s[155]
# NRG SUCCESS
# NYSE [160/3083]: getting WRB - f[0], s[156]
# CMC SUCCESS
# NYSE [161/3083]: getting TGT - f[0], s[157]
# ATHM SUCCESS
# NYSE [162/3083]: getting TV - f[0], s[158]
# CPB SUCCESS
# NYSE [163/3083]: getting GLW - f[0], s[159]
# WRB SUCCESS
# NYSE [164/3083]: getting MAS - f[0], s[160]
# TGT SUCCESS
# NYSE [165/3083]: getting DOV - f[0], s[161]
# MAS SUCCESS
# NYSE [166/3083]: getting HRL - f[0], s[162]
# TV SUCCESS
# NYSE [167/3083]: getting TECK - f[0], s[163]
# DOV SUCCESS
# NYSE [168/3083]: getting AES - f[0], s[164]
# TECK SUCCESS
# NYSE [169/3083]: getting PPL - f[0], s[165]
# AES SUCCESS
# NYSE [170/3083]: getting SEE - f[0], s[166]
# PPL SUCCESS
# NYSE [171/3083]: getting FRC - f[0], s[167]
# FRC SUCCESS
# NYSE [172/3083]: getting K - f[0], s[168]
# K SUCCESS
# NYSE [173/3083]: getting M - f[0], s[169]
# SEE SUCCESS
# NYSE [174/3083]: getting TSM - f[0], s[170]
# M SUCCESS
# NYSE [175/3083]: getting STL - f[0], s[171]
# TSM SUCCESS
# NYSE [176/3083]: getting NYCB - f[0], s[172]
# STL SUCCESS
# NYSE [177/3083]: getting TRQ - f[0], s[173]
# GLW SUCCESS
# NYSE [178/3083]: getting BAH - f[0], s[174]
# NYCB SUCCESS
# NYSE [179/3083]: getting MET - f[0], s[175]
# BAH SUCCESS
# NYSE [180/3083]: getting AFL - f[0], s[176]
# TRQ SUCCESS
# NYSE [181/3083]: getting TPR - f[0], s[177]
# HRL SUCCESS
# NYSE [182/3083]: getting WPM - f[0], s[178]
# MET SUCCESS
# NYSE [183/3083]: getting WLL - f[0], s[179]
# AFL SUCCESS
# NYSE [184/3083]: getting PCG - f[0], s[180]
# WLL SUCCESS
# NYSE [185/3083]: getting CLR - f[0], s[181]
# WPM SUCCESS
# NYSE [186/3083]: getting HL - f[0], s[182]
# PCG SUCCESS
# NYSE [187/3083]: getting UAA - f[0], s[183]
# HL SUCCESS
# NYSE [188/3083]: getting CAG - f[0], s[184]
# UAA SUCCESS
# NYSE [189/3083]: getting SO - f[0], s[185]
# CAG SUCCESS
# NYSE [190/3083]: getting GKOS - f[0], s[186]
# SO SUCCESS
# NYSE [191/3083]: getting ZTO - f[0], s[187]
# GKOS SUCCESS
# NYSE [192/3083]: getting GS - f[0], s[188]
# ZTO SUCCESS
# NYSE [193/3083]: getting ADT - f[0], s[189]
# ADT SUCCESS
# NYSE [194/3083]: getting EMR - f[0], s[190]
# GS SUCCESS
# NYSE [195/3083]: getting CNP - f[0], s[191]
# CLR SUCCESS
# NYSE [196/3083]: getting COTY - f[0], s[192]
# EMR SUCCESS
# NYSE [197/3083]: getting MA - f[0], s[193]
# CNP SUCCESS
# NYSE [198/3083]: getting AWI - f[0], s[194]
# COTY SUCCESS
# NYSE [199/3083]: getting BBVA - f[0], s[195]
# MA SUCCESS
# NYSE [200/3083]: getting AER - f[0], s[196]
# AWI SUCCESS
# NYSE [201/3083]: getting GTN - f[0], s[197]
# BBVA SUCCESS
# NYSE [202/3083]: getting CDE - f[0], s[198]
# AER SUCCESS
# NYSE [203/3083]: getting NCR - f[0], s[199]
# CDE SUCCESS
# NYSE [204/3083]: getting PSTG - f[0], s[200]
# NCR SUCCESS
# NYSE [205/3083]: getting SJM - f[0], s[201]
# PSTG SUCCESS
# NYSE [206/3083]: getting ETN - f[0], s[202]
# SJM SUCCESS
# NYSE [207/3083]: getting DUK - f[0], s[203]
# ETN SUCCESS
# NYSE [208/3083]: getting CL - f[0], s[204]
# DUK SUCCESS
# NYSE [209/3083]: getting KAR - f[0], s[205]
# CL SUCCESS
# NYSE [210/3083]: getting NEE - f[0], s[206]
# KAR SUCCESS
# NYSE [211/3083]: getting PXD - f[0], s[207]
# PXD SUCCESS
# NYSE [212/3083]: getting ADM - f[0], s[208]
# ADM SUCCESS
# NYSE [213/3083]: getting VMW - f[0], s[209]
# VMW SUCCESS
# NYSE [214/3083]: getting DKS - f[0], s[210]
# TPR FAILED
# NYSE [215/3083]: getting WTI - f[1], s[210]
# DKS SUCCESS
# NYSE [216/3083]: getting CE - f[1], s[211]
# CE SUCCESS
# NYSE [217/3083]: getting HUN - f[1], s[212]
# HUN SUCCESS
# NYSE [218/3083]: getting CSTM - f[1], s[213]
# GTN SUCCESS
# NYSE [219/3083]: getting GPK - f[1], s[214]
# NEE SUCCESS
# NYSE [220/3083]: getting TJX - f[1], s[215]
# WTI SUCCESS
# NYSE [221/3083]: getting KSS - f[1], s[216]
# GPK SUCCESS
# NYSE [222/3083]: getting XEC - f[1], s[217]
# KSS SUCCESS
# NYSE [223/3083]: getting DRI - f[1], s[218]
# TJX SUCCESS
# NYSE [224/3083]: getting ATI - f[1], s[219]
# XEC SUCCESS
# NYSE [225/3083]: getting IAG - f[1], s[220]
# ATI SUCCESS
# NYSE [226/3083]: getting VFC - f[1], s[221]
# IAG SUCCESS
# NYSE [227/3083]: getting ICE - f[1], s[222]
# CSTM SUCCESS
# NYSE [228/3083]: getting BLL - f[1], s[223]
# ICE SUCCESS
# NYSE [229/3083]: getting IVZ - f[1], s[224]
# BLL SUCCESS
# NYSE [230/3083]: getting DG - f[1], s[225]
# IVZ SUCCESS
# NYSE [231/3083]: getting SID - f[1], s[226]
# DG SUCCESS
# NYSE [232/3083]: getting SLCA - f[1], s[227]
# SID SUCCESS
# NYSE [233/3083]: getting SGU - f[1], s[228]
# SLCA SUCCESS
# NYSE [234/3083]: getting TOL - f[1], s[229]
# DRI SUCCESS
# NYSE [235/3083]: getting BCO - f[1], s[230]
# SGU SUCCESS
# NYSE [236/3083]: getting BKD - f[1], s[231]
# TOL SUCCESS
# NYSE [237/3083]: getting TAP - f[1], s[232]
# BKD SUCCESS
# NYSE [238/3083]: getting UNP - f[1], s[233]
# BCO SUCCESS
# NYSE [239/3083]: getting BDX - f[1], s[234]
# TAP SUCCESS
# NYSE [240/3083]: getting GME - f[1], s[235]
# UNP SUCCESS
# NYSE [241/3083]: getting MX - f[1], s[236]
# BDX SUCCESS
# NYSE [242/3083]: getting LB - f[1], s[237]
# GME SUCCESS
# NYSE [243/3083]: getting NCLH - f[1], s[238]
# LB SUCCESS
# NYSE [244/3083]: getting NOV - f[1], s[239]
# NCLH SUCCESS
# NYSE [245/3083]: getting LMT - f[1], s[240]
# NOV SUCCESS
# NYSE [246/3083]: getting MTZ - f[1], s[241]
# LMT SUCCESS
# NYSE [247/3083]: getting GPS - f[1], s[242]
# MTZ SUCCESS
# NYSE [248/3083]: getting SYY - f[1], s[243]
# VFC SUCCESS
# NYSE [249/3083]: getting FTV - f[1], s[244]
# GPS SUCCESS
# NYSE [250/3083]: getting BKI - f[1], s[245]
# FTV SUCCESS
# NYSE [251/3083]: getting EIX - f[1], s[246]
# SYY SUCCESS
# NYSE [252/3083]: getting CPE - f[1], s[247]
# BKI SUCCESS
# NYSE [253/3083]: getting CF - f[1], s[248]
# EIX SUCCESS
# NYSE [254/3083]: getting PNC - f[1], s[249]
# CPE SUCCESS
# NYSE [255/3083]: getting WIT - f[1], s[250]
# CF SUCCESS
# NYSE [256/3083]: getting LYB - f[1], s[251]
# PNC SUCCESS
# NYSE [257/3083]: getting MGA - f[1], s[252]
# LYB SUCCESS
# NYSE [258/3083]: getting AEO - f[1], s[253]
# WIT SUCCESS
# NYSE [259/3083]: getting BP - f[1], s[254]
# MX SUCCESS
# NYSE [260/3083]: getting VVV - f[1], s[255]
# MGA SUCCESS
# NYSE [261/3083]: getting UPS - f[1], s[256]
# AEO SUCCESS
# NYSE [262/3083]: getting MUR - f[1], s[257]
# BP SUCCESS
# NYSE [263/3083]: getting VMC - f[1], s[258]
# VVV SUCCESS
# NYSE [264/3083]: getting NOMD - f[1], s[259]
# UPS SUCCESS
# NYSE [265/3083]: getting ANTM - f[1], s[260]
# VMC SUCCESS
# NYSE [266/3083]: getting GD - f[1], s[261]
# MUR SUCCESS
# NYSE [267/3083]: getting FNF - f[1], s[262]
# ANTM SUCCESS
# NYSE [268/3083]: getting CHD - f[1], s[263]
# FNF SUCCESS
# NYSE [269/3083]: getting IP - f[1], s[264]
# NOMD SUCCESS
# NYSE [270/3083]: getting SE - f[1], s[265]
# SE SUCCESS
# NYSE [271/3083]: getting CC - f[1], s[266]
# CC SUCCESS
# NYSE [272/3083]: getting DAN - f[1], s[267]
# GD SUCCESS
# NYSE [273/3083]: getting ZBH - f[1], s[268]
# DAN SUCCESS
# NYSE [274/3083]: getting LPX - f[1], s[269]
# CHD SUCCESS
# NYSE [275/3083]: getting BBY - f[1], s[270]
# IP SUCCESS
# NYSE [276/3083]: getting BG - f[1], s[271]
# ZBH SUCCESS
# NYSE [277/3083]: getting LC - f[1], s[272]
# LPX SUCCESS
# NYSE [278/3083]: getting PWR - f[1], s[273]
# LC SUCCESS
# NYSE [279/3083]: getting NEM - f[1], s[274]
# BG SUCCESS
# NYSE [280/3083]: getting BEN - f[1], s[275]
# BBY SUCCESS
# NYSE [281/3083]: getting SHLX - f[1], s[276]
# PWR SUCCESS
# NYSE [282/3083]: getting PBH - f[1], s[277]
# SHLX SUCCESS
# NYSE [283/3083]: getting SBH - f[1], s[278]
# NEM SUCCESS
# NYSE [284/3083]: getting NI - f[1], s[279]
# BEN SUCCESS
# NYSE [285/3083]: getting LLY - f[1], s[280]
# PBH SUCCESS
# NYSE [286/3083]: getting STNG - f[1], s[281]
# SBH SUCCESS
# NYSE [287/3083]: getting FHN - f[1], s[282]
# NI SUCCESS
# NYSE [288/3083]: getting HLX - f[1], s[283]
# STNG SUCCESS
# NYSE [289/3083]: getting RSG - f[1], s[284]
# LLY SUCCESS
# NYSE [290/3083]: getting BIG - f[1], s[285]
# FHN SUCCESS
# NYSE [291/3083]: getting CYH - f[1], s[286]
# HLX SUCCESS
# NYSE [292/3083]: getting PAYC - f[1], s[287]
# RSG SUCCESS
# NYSE [293/3083]: getting GCP - f[1], s[288]
# BIG SUCCESS
# NYSE [294/3083]: getting YUM - f[1], s[289]
# PAYC SUCCESS
# NYSE [295/3083]: getting STZ - f[1], s[290]
# CYH SUCCESS
# NYSE [296/3083]: getting LYG - f[1], s[291]
# LYG SUCCESS
# NYSE [297/3083]: getting USFD - f[1], s[292]
# STZ SUCCESS
# NYSE [298/3083]: getting THC - f[1], s[293]
# USFD SUCCESS
# NYSE [299/3083]: getting ALLY - f[1], s[294]
# THC SUCCESS
# NYSE [300/3083]: getting EVR - f[1], s[295]
# ALLY SUCCESS
# NYSE [301/3083]: getting CMS - f[1], s[296]
# EVR SUCCESS
# NYSE [302/3083]: getting RIO - f[1], s[297]
# CMS SUCCESS
# NYSE [303/3083]: getting KMT - f[1], s[298]
# RIO SUCCESS
# NYSE [304/3083]: getting AMR - f[1], s[299]
# AMR SUCCESS
# NYSE [305/3083]: getting HP - f[1], s[300]
# KMT SUCCESS
# NYSE [306/3083]: getting FLR - f[1], s[301]
# FLR SUCCESS
# NYSE [307/3083]: getting JHG - f[1], s[302]
# JHG SUCCESS
# NYSE [308/3083]: getting FDX - f[1], s[303]
# GCP SUCCESS
# NYSE [309/3083]: getting EMN - f[1], s[304]
# YUM SUCCESS
# NYSE [310/3083]: getting WU - f[1], s[305]
# EMN SUCCESS
# NYSE [311/3083]: getting BAX - f[1], s[306]
# HP SUCCESS
# NYSE [312/3083]: getting CARS - f[1], s[307]
# WU SUCCESS
# NYSE [313/3083]: getting TEL - f[1], s[308]
# BAX SUCCESS
# NYSE [314/3083]: getting MLM - f[1], s[309]
# CARS SUCCESS
# NYSE [315/3083]: getting GWW - f[1], s[310]
# TEL SUCCESS
# NYSE [316/3083]: getting PBF - f[1], s[311]
# MLM SUCCESS
# NYSE [317/3083]: getting BW - f[1], s[312]
# PBF SUCCESS
# NYSE [318/3083]: getting CMI - f[1], s[313]
# GWW SUCCESS
# NYSE [319/3083]: getting CNQ - f[1], s[314]
# FDX SUCCESS
# NYSE [320/3083]: getting HCA - f[1], s[315]
# BW SUCCESS
# NYSE [321/3083]: getting SAN - f[1], s[316]
# CNQ SUCCESS
# NYSE [322/3083]: getting CNHI - f[1], s[317]
# CMI SUCCESS
# NYSE [323/3083]: getting CNX - f[1], s[318]
# HCA SUCCESS
# NYSE [324/3083]: getting INFO - f[1], s[319]
# SAN SUCCESS
# NYSE [325/3083]: getting ES - f[1], s[320]
# CNHI SUCCESS
# NYSE [326/3083]: getting ARMK - f[1], s[321]
# CNX SUCCESS
# NYSE [327/3083]: getting OII - f[1], s[322]
# INFO SUCCESS
# NYSE [328/3083]: getting NOW - f[1], s[323]
# NOW SUCCESS
# NYSE [329/3083]: getting APTV - f[1], s[324]
# APTV SUCCESS
# NYSE [330/3083]: getting HOMB - f[1], s[325]
# HOMB SUCCESS
# NYSE [331/3083]: getting QD - f[1], s[326]
# ES SUCCESS
# NYSE [332/3083]: getting NSC - f[1], s[327]
# ARMK SUCCESS
# NYSE [333/3083]: getting PSX - f[1], s[328]
# OII SUCCESS
# NYSE [334/3083]: getting PNW - f[1], s[329]
# PSX SUCCESS
# NYSE [335/3083]: getting FOE - f[1], s[330]
# NSC SUCCESS
# NYSE [336/3083]: getting A - f[1], s[331]
# PNW SUCCESS
# NYSE [337/3083]: getting MOS - f[1], s[332]
# FOE SUCCESS
# NYSE [338/3083]: getting LPL - f[1], s[333]
# A SUCCESS
# NYSE [339/3083]: getting SKX - f[1], s[334]
# MOS SUCCESS
# NYSE [340/3083]: getting PHM - f[1], s[335]
# LPL SUCCESS
# NYSE [341/3083]: getting MT - f[1], s[336]
# SKX SUCCESS
# NYSE [342/3083]: getting CAAP - f[1], s[337]
# PHM SUCCESS
# NYSE [343/3083]: getting RRC - f[1], s[338]
# CAAP SUCCESS
# NYSE [344/3083]: getting FL - f[1], s[339]
# MT SUCCESS
# NYSE [345/3083]: getting AGO - f[1], s[340]
# AGO SUCCESS
# NYSE [346/3083]: getting CCJ - f[1], s[341]
# RRC SUCCESS
# NYSE [347/3083]: getting AXTA - f[1], s[342]
# FL SUCCESS
# NYSE [348/3083]: getting AEM - f[1], s[343]
# AXTA SUCCESS
# NYSE [349/3083]: getting BB - f[1], s[344]
# CCJ SUCCESS
# NYSE [350/3083]: getting CB - f[1], s[345]
# AEM SUCCESS
# NYSE [351/3083]: getting PRU - f[1], s[346]
# BB SUCCESS
# NYSE [352/3083]: getting PVG - f[1], s[347]
# PRU SUCCESS
# NYSE [353/3083]: getting AVYA - f[1], s[348]
# CB SUCCESS
# NYSE [354/3083]: getting SC - f[1], s[349]
# AVYA SUCCESS
# NYSE [355/3083]: getting ANF - f[1], s[350]
# QD SUCCESS
# NYSE [356/3083]: getting HIG - f[1], s[351]
# ANF SUCCESS
# NYSE [357/3083]: getting ITW - f[1], s[352]
# ITW SUCCESS
# NYSE [358/3083]: getting YELP - f[1], s[353]
# YELP SUCCESS
# NYSE [359/3083]: getting MTOR - f[1], s[354]
# PVG SUCCESS
# NYSE [360/3083]: getting EVC - f[1], s[355]
# MTOR SUCCESS
# NYSE [361/3083]: getting POST - f[1], s[356]
# SC SUCCESS
# NYSE [362/3083]: getting EL - f[1], s[357]
# POST SUCCESS
# NYSE [363/3083]: getting ING - f[1], s[358]
# EVC SUCCESS
# NYSE [364/3083]: getting UBS - f[1], s[359]
# HIG SUCCESS
# NYSE [365/3083]: getting VSH - f[1], s[360]
# EL SUCCESS
# NYSE [366/3083]: getting TWLO - f[1], s[361]
# ING SUCCESS
# NYSE [367/3083]: getting RLGY - f[1], s[362]
# TWLO SUCCESS
# NYSE [368/3083]: getting CNO - f[1], s[363]
# UBS SUCCESS
# NYSE [369/3083]: getting JNPR - f[1], s[364]
# VSH SUCCESS
# NYSE [370/3083]: getting FEDU - f[1], s[365]
# RLGY SUCCESS
# NYSE [371/3083]: getting AUD - f[1], s[366]
# CNO SUCCESS
# NYSE [372/3083]: getting BANC - f[1], s[367]
# FEDU SUCCESS
# NYSE [373/3083]: getting OMF - f[1], s[368]
# JNPR SUCCESS
# NYSE [374/3083]: getting LW - f[1], s[369]
# AUD SUCCESS
# NYSE [375/3083]: getting FE - f[1], s[370]
# LW SUCCESS
# NYSE [376/3083]: getting NOC - f[1], s[371]
# OMF SUCCESS
# NYSE [377/3083]: getting ASH - f[1], s[372]
# BANC SUCCESS
# NYSE [378/3083]: getting FET - f[1], s[373]
# FE SUCCESS
# NYSE [379/3083]: getting TPH - f[1], s[374]
# FET SUCCESS
# NYSE [380/3083]: getting AMX - f[1], s[375]
# NOC SUCCESS
# NYSE [381/3083]: getting FLO - f[1], s[376]
# ASH SUCCESS
# NYSE [382/3083]: getting COF - f[1], s[377]
# TPH SUCCESS
# NYSE [383/3083]: getting FLT - f[1], s[378]
# AMX SUCCESS
# NYSE [384/3083]: getting IGT - f[1], s[379]
# COF SUCCESS
# NYSE [385/3083]: getting RXN - f[1], s[380]
# RXN SUCCESS
# NYSE [386/3083]: getting OSK - f[1], s[381]
# OSK SUCCESS
# NYSE [387/3083]: getting DHR - f[1], s[382]
# DHR SUCCESS
# NYSE [388/3083]: getting AMN - f[1], s[383]
# AMN SUCCESS
# NYSE [389/3083]: getting RCL - f[1], s[384]
# RCL SUCCESS
# NYSE [390/3083]: getting W - f[1], s[385]
# W SUCCESS
# NYSE [391/3083]: getting IR - f[1], s[386]
# IR SUCCESS
# NYSE [392/3083]: getting PEG - f[1], s[387]
# FLO SUCCESS
# NYSE [393/3083]: getting FBP - f[1], s[388]
# PEG SUCCESS
# NYSE [394/3083]: getting WEC - f[1], s[389]
# FLT SUCCESS
# NYSE [395/3083]: getting MDC - f[1], s[390]
# WEC SUCCESS
# NYSE [396/3083]: getting TISI - f[1], s[391]
# TISI SUCCESS
# NYSE [397/3083]: getting YUMC - f[1], s[392]
# YUMC SUCCESS
# NYSE [398/3083]: getting ALV - f[1], s[393]
# ALV SUCCESS
# NYSE [399/3083]: getting BHP - f[1], s[394]
# IGT SUCCESS
# NYSE [400/3083]: getting BYD - f[1], s[395]
# FBP SUCCESS
# NYSE [401/3083]: getting WGO - f[1], s[396]
# MDC SUCCESS
# NYSE [402/3083]: getting KSU - f[1], s[397]
# BYD SUCCESS
# NYSE [403/3083]: getting PUMP - f[1], s[398]
# WGO SUCCESS
# NYSE [404/3083]: getting NOG - f[1], s[399]
# PUMP SUCCESS
# NYSE [405/3083]: getting FBHS - f[1], s[400]
# KSU SUCCESS
# NYSE [406/3083]: getting TXT - f[1], s[401]
# NOG SUCCESS
# NYSE [407/3083]: getting AGI - f[1], s[402]
# FBHS SUCCESS
# NYSE [408/3083]: getting ED - f[1], s[403]
# TXT SUCCESS
# NYSE [409/3083]: getting DBD - f[1], s[404]
# AGI SUCCESS
# NYSE [410/3083]: getting CBT - f[1], s[405]
# ED SUCCESS
# NYSE [411/3083]: getting ABB - f[1], s[406]
# DBD SUCCESS
# NYSE [412/3083]: getting CP - f[1], s[407]
# BHP SUCCESS
# NYSE [413/3083]: getting PNR - f[1], s[408]
# ABB SUCCESS
# NYSE [414/3083]: getting PKI - f[1], s[409]
# CBT SUCCESS
# NYSE [415/3083]: getting ASB - f[1], s[410]
# CP SUCCESS
# NYSE [416/3083]: getting UHS - f[1], s[411]
# PNR SUCCESS
# NYSE [417/3083]: getting ENB - f[1], s[412]
# ASB SUCCESS
# NYSE [418/3083]: getting TDC - f[1], s[413]
# PKI SUCCESS
# NYSE [419/3083]: getting AG - f[1], s[414]
# UHS SUCCESS
# NYSE [420/3083]: getting NAT - f[1], s[415]
# TDC SUCCESS
# NYSE [421/3083]: getting TRP - f[1], s[416]
# AG SUCCESS
# NYSE [422/3083]: getting RH - f[1], s[417]
# ENB SUCCESS
# NYSE [423/3083]: getting CBRE - f[1], s[418]
# NAT SUCCESS
# NYSE [424/3083]: getting HGV - f[1], s[419]
# TRP SUCCESS
# NYSE [425/3083]: getting AEG - f[1], s[420]
# RH SUCCESS
# NYSE [426/3083]: getting BTI - f[1], s[421]
# CBRE SUCCESS
# NYSE [427/3083]: getting NVS - f[1], s[422]
# HGV SUCCESS
# NYSE [428/3083]: getting QSR - f[1], s[423]
# BTI SUCCESS
# NYSE [429/3083]: getting LDOS - f[1], s[424]
# AEG SUCCESS
# NYSE [430/3083]: getting ETH - f[1], s[425]
# NVS SUCCESS
# NYSE [431/3083]: getting AEE - f[1], s[426]
# ETH SUCCESS
# NYSE [432/3083]: getting HCC - f[1], s[427]
# LDOS SUCCESS
# NYSE [433/3083]: getting MBT - f[1], s[428]
# AEE SUCCESS
# NYSE [434/3083]: getting TMO - f[1], s[429]
# HCC SUCCESS
# NYSE [435/3083]: getting STT - f[1], s[430]
# MBT SUCCESS
# NYSE [436/3083]: getting HLF - f[1], s[431]
# TMO SUCCESS
# NYSE [437/3083]: getting WRK - f[1], s[432]
# STT SUCCESS
# NYSE [438/3083]: getting BR - f[1], s[433]
# HLF SUCCESS
# NYSE [439/3083]: getting MCD - f[1], s[434]
# WRK SUCCESS
# NYSE [440/3083]: getting PRO - f[1], s[435]
# BR SUCCESS
# NYSE [441/3083]: getting AXL - f[1], s[436]
# MCD SUCCESS
# NYSE [442/3083]: getting SUN - f[1], s[437]
# AXL SUCCESS
# NYSE [443/3083]: getting ZEN - f[1], s[438]
# SUN SUCCESS
# NYSE [444/3083]: getting ATEN - f[1], s[439]
# ATEN SUCCESS
# NYSE [445/3083]: getting CRC - f[1], s[440]
# ZEN SUCCESS
# NYSE [446/3083]: getting ATUS - f[1], s[441]
# ATUS SUCCESS
# NYSE [447/3083]: getting SIG - f[1], s[442]
# CRC SUCCESS
# NYSE [448/3083]: getting BDC - f[1], s[443]
# SIG SUCCESS
# NYSE [449/3083]: getting XPO - f[1], s[444]
# PRO SUCCESS
# NYSE [450/3083]: getting APO - f[1], s[445]
# XPO SUCCESS
# NYSE [451/3083]: getting CRI - f[1], s[446]
# QSR SUCCESS
# NYSE [452/3083]: getting AGCO - f[1], s[447]
# CRI SUCCESS
# NYSE [453/3083]: getting MMC - f[1], s[448]
# AGCO SUCCESS
# NYSE [454/3083]: getting GNW - f[1], s[449]
# MMC SUCCESS
# NYSE [455/3083]: getting TMHC - f[1], s[450]
# GNW SUCCESS
# NYSE [456/3083]: getting URI - f[1], s[451]
# TMHC SUCCESS
# NYSE [457/3083]: getting MCO - f[1], s[452]
# URI SUCCESS
# NYSE [458/3083]: getting PAGS - f[1], s[453]
# PAGS SUCCESS
# NYSE [459/3083]: getting L - f[1], s[454]
# MCO SUCCESS
# NYSE [460/3083]: getting MBI - f[1], s[455]
# L SUCCESS
# NYSE [461/3083]: getting PDS - f[1], s[456]
# MBI SUCCESS
# NYSE [462/3083]: getting BCC - f[1], s[457]
# BCC SUCCESS
# NYSE [463/3083]: getting PRTY - f[1], s[458]
# PDS SUCCESS
# NYSE [464/3083]: getting OGE - f[1], s[459]
# OGE SUCCESS
# NYSE [465/3083]: getting QGEN - f[1], s[460]
# BDC SUCCESS
# NYSE [466/3083]: getting EAT - f[1], s[461]
# QGEN SUCCESS
# NYSE [467/3083]: getting DXC - f[1], s[462]
# EAT SUCCESS
# NYSE [468/3083]: getting KBR - f[1], s[463]
# APO SUCCESS
# NYSE [469/3083]: getting STM - f[1], s[464]
# PRTY SUCCESS
# NYSE [470/3083]: getting AQUA - f[1], s[465]
# AQUA SUCCESS
# NYSE [471/3083]: getting EQT - f[1], s[466]
# EQT SUCCESS
# NYSE [472/3083]: getting SRE - f[1], s[467]
# DXC SUCCESS
# NYSE [473/3083]: getting SAVE - f[1], s[468]
# KBR SUCCESS
# NYSE [474/3083]: getting NPTN - f[1], s[469]
# SRE SUCCESS
# NYSE [475/3083]: getting SQM - f[1], s[470]
# STM SUCCESS
# NYSE [476/3083]: getting SXT - f[1], s[471]
# SAVE SUCCESS
# NYSE [477/3083]: getting OMC - f[1], s[472]
# NPTN SUCCESS
# NYSE [478/3083]: getting CVA - f[1], s[473]
# SQM SUCCESS
# NYSE [479/3083]: getting FMC - f[1], s[474]
# SXT SUCCESS
# NYSE [480/3083]: getting KN - f[1], s[475]
# OMC SUCCESS
# NYSE [481/3083]: getting KW - f[1], s[476]
# CVA SUCCESS
# NYSE [482/3083]: getting SCS - f[1], s[477]
# FMC SUCCESS
# NYSE [483/3083]: getting CXW - f[1], s[478]
# KN SUCCESS
# NYSE [484/3083]: getting DFS - f[1], s[479]
# KW SUCCESS
# NYSE [485/3083]: getting PH - f[1], s[480]
# SCS SUCCESS
# NYSE [486/3083]: getting USA - f[1], s[481]
# DFS SUCCESS
# NYSE [487/3083]: getting CIEN - f[1], s[482]
# CXW SUCCESS
# NYSE [488/3083]: getting OIS - f[1], s[483]
# USA SUCCESS
# NYSE [489/3083]: getting SCCO - f[1], s[484]
# PH SUCCESS
# NYSE [490/3083]: getting YEXT - f[1], s[485]
# CIEN SUCCESS
# NYSE [491/3083]: getting REVG - f[1], s[486]
# OIS SUCCESS
# NYSE [492/3083]: getting ALLE - f[1], s[487]
# YEXT SUCCESS
# NYSE [493/3083]: getting MHK - f[1], s[488]
# SCCO SUCCESS
# NYSE [494/3083]: getting GRA - f[1], s[489]
# REVG SUCCESS
# NYSE [495/3083]: getting VNTR - f[1], s[490]
# ALLE SUCCESS
# NYSE [496/3083]: getting SUM - f[1], s[491]
# MHK SUCCESS
# NYSE [497/3083]: getting ERJ - f[1], s[492]
# GRA SUCCESS
# NYSE [498/3083]: getting UNM - f[1], s[493]
# VNTR SUCCESS
# NYSE [499/3083]: getting NJR - f[1], s[494]
# SUM SUCCESS
# NYSE [500/3083]: getting AOS - f[1], s[495]
# ERJ SUCCESS
# NYSE [501/3083]: getting DGX - f[1], s[496]
# UNM SUCCESS
# NYSE [502/3083]: getting FIS - f[1], s[497]
# NJR SUCCESS
# NYSE [503/3083]: getting TRN - f[1], s[498]
# AOS SUCCESS
# NYSE [504/3083]: getting SPGI - f[1], s[499]
# FIS SUCCESS
# NYSE [505/3083]: getting AN - f[1], s[500]
# AN SUCCESS
# NYSE [506/3083]: getting MCK - f[1], s[501]
# MCK SUCCESS
# NYSE [507/3083]: getting MUX - f[1], s[502]
# TRN SUCCESS
# NYSE [508/3083]: getting IEX - f[1], s[503]
# MUX SUCCESS
# NYSE [509/3083]: getting TROX - f[1], s[504]
# TROX SUCCESS
# NYSE [510/3083]: getting OEC - f[1], s[505]
# OEC SUCCESS
# NYSE [511/3083]: getting ATH - f[1], s[506]
# SPGI SUCCESS
# NYSE [512/3083]: getting ABC - f[1], s[507]
# DGX SUCCESS
# NYSE [513/3083]: getting EFX - f[1], s[508]
# ABC SUCCESS
# NYSE [514/3083]: getting DPZ - f[1], s[509]
# ATH SUCCESS
# NYSE [515/3083]: getting ENLC - f[1], s[510]
# DPZ SUCCESS
# NYSE [516/3083]: getting TTM - f[1], s[511]
# ENLC SUCCESS
# NYSE [517/3083]: getting MPLX - f[1], s[512]
# EFX SUCCESS
# NYSE [518/3083]: getting EC - f[1], s[513]
# TTM SUCCESS
# NYSE [519/3083]: getting SIX - f[1], s[514]
# MPLX SUCCESS
# NYSE [520/3083]: getting VEEV - f[1], s[515]
# EC SUCCESS
# NYSE [521/3083]: getting NVO - f[1], s[516]
# VEEV SUCCESS
# NYSE [522/3083]: getting SWK - f[1], s[517]
# SIX SUCCESS
# NYSE [523/3083]: getting SNDR - f[1], s[518]
# NVO SUCCESS
# NYSE [524/3083]: getting EW - f[1], s[519]
# SNDR SUCCESS
# NYSE [525/3083]: getting ROK - f[1], s[520]
# IEX SUCCESS
# NYSE [526/3083]: getting ALL - f[1], s[521]
# SWK SUCCESS
# NYSE [527/3083]: getting APRN - f[1], s[522]
# EW SUCCESS
# NYSE [528/3083]: getting MFC - f[1], s[523]
# APRN SUCCESS
# NYSE [529/3083]: getting ZTS - f[1], s[524]
# ROK SUCCESS
# NYSE [530/3083]: getting BUD - f[1], s[525]
# ALL SUCCESS
# NYSE [531/3083]: getting UA - f[1], s[526]
# MFC SUCCESS
# NYSE [532/3083]: getting AROC - f[1], s[527]
# ZTS SUCCESS
# NYSE [533/3083]: getting THO - f[1], s[528]
# BUD SUCCESS
# NYSE [534/3083]: getting KT - f[1], s[529]
# UA SUCCESS
# NYSE [535/3083]: getting TGNA - f[1], s[530]
# AROC SUCCESS
# NYSE [536/3083]: getting CHGG - f[1], s[531]
# KT SUCCESS
# NYSE [537/3083]: getting WM - f[1], s[532]
# THO SUCCESS
# NYSE [538/3083]: getting ASX - f[1], s[533]
# TGNA SUCCESS
# NYSE [539/3083]: getting ALB - f[1], s[534]
# CHGG SUCCESS
# NYSE [540/3083]: getting RHI - f[1], s[535]
# ASX SUCCESS
# NYSE [541/3083]: getting HLT - f[1], s[536]
# WM SUCCESS
# NYSE [542/3083]: getting DNOW - f[1], s[537]
# ALB SUCCESS
# NYSE [543/3083]: getting OC - f[1], s[538]
# RHI SUCCESS
# NYSE [544/3083]: getting AGRO - f[1], s[539]
# HLT SUCCESS
# NYSE [545/3083]: getting AL - f[1], s[540]
# DNOW SUCCESS
# NYSE [546/3083]: getting EVH - f[1], s[541]
# AGRO SUCCESS
# NYSE [547/3083]: getting UIS - f[1], s[542]
# OC SUCCESS
# NYSE [548/3083]: getting JELD - f[1], s[543]
# AL SUCCESS
# NYSE [549/3083]: getting TDG - f[1], s[544]
# EVH SUCCESS
# NYSE [550/3083]: getting RY - f[1], s[545]
# JELD SUCCESS
# NYSE [551/3083]: getting SYK - f[1], s[546]
# TDG SUCCESS
# NYSE [552/3083]: getting TRV - f[1], s[547]
# RY SUCCESS
# NYSE [553/3083]: getting CSL - f[1], s[548]
# CSL SUCCESS
# NYSE [554/3083]: getting GWRE - f[1], s[549]
# GWRE SUCCESS
# NYSE [555/3083]: getting ANET - f[1], s[550]
# ANET SUCCESS
# NYSE [556/3083]: getting WSM - f[1], s[551]
# UIS SUCCESS
# NYSE [557/3083]: getting EXP - f[1], s[552]
# WSM SUCCESS
# NYSE [558/3083]: getting BWA - f[1], s[553]
# SYK SUCCESS
# NYSE [559/3083]: getting SWCH - f[1], s[554]
# TRV SUCCESS
# NYSE [560/3083]: getting ADS - f[1], s[555]
# EXP SUCCESS
# NYSE [561/3083]: getting DRQ - f[1], s[556]
# SWCH SUCCESS
# NYSE [562/3083]: getting AXS - f[1], s[557]
# BWA SUCCESS
# NYSE [563/3083]: getting MTDR - f[1], s[558]
# ADS SUCCESS
# NYSE [564/3083]: getting CAJ - f[1], s[559]
# DRQ SUCCESS
# NYSE [565/3083]: getting CNI - f[1], s[560]
# AXS SUCCESS
# NYSE [566/3083]: getting CAL - f[1], s[561]
# MTDR SUCCESS
# NYSE [567/3083]: getting SAP - f[1], s[562]
# CAJ SUCCESS
# NYSE [568/3083]: getting ESNT - f[1], s[563]
# CNI SUCCESS
# NYSE [569/3083]: getting OI - f[1], s[564]
# SAP SUCCESS
# NYSE [570/3083]: getting MDU - f[1], s[565]
# CAL SUCCESS
# NYSE [571/3083]: getting PSXP - f[1], s[566]
# ESNT SUCCESS
# NYSE [572/3083]: getting CWH - f[1], s[567]
# OI SUCCESS
# NYSE [573/3083]: getting DECK - f[1], s[568]
# PSXP SUCCESS
# NYSE [574/3083]: getting SMFG - f[1], s[569]
# CWH SUCCESS
# NYSE [575/3083]: getting LAZ - f[1], s[570]
# MDU SUCCESS
# NYSE [576/3083]: getting NEXA - f[1], s[571]
# NEXA SUCCESS
# NYSE [577/3083]: getting PLNT - f[1], s[572]
# SMFG SUCCESS
# NYSE [578/3083]: getting CAH - f[1], s[573]
# DECK SUCCESS
# NYSE [579/3083]: getting AYI - f[1], s[574]
# LAZ SUCCESS
# NYSE [580/3083]: getting DVA - f[1], s[575]
# PLNT SUCCESS
# NYSE [581/3083]: getting WCN - f[1], s[576]
# AYI SUCCESS
# NYSE [582/3083]: getting MYOV - f[1], s[577]
# CAH SUCCESS
# NYSE [583/3083]: getting ABM - f[1], s[578]
# DVA SUCCESS
# NYSE [584/3083]: getting NGL - f[1], s[579]
# WCN SUCCESS
# NYSE [585/3083]: getting ARCO - f[1], s[580]
# MYOV SUCCESS
# NYSE [586/3083]: getting LNC - f[1], s[581]
# NGL SUCCESS
# NYSE [587/3083]: getting NGG - f[1], s[582]
# ABM SUCCESS
# NYSE [588/3083]: getting GTES - f[1], s[583]
# ARCO SUCCESS
# NYSE [589/3083]: getting CMA - f[1], s[584]
# LNC SUCCESS
# NYSE [590/3083]: getting ALK - f[1], s[585]
# GTES SUCCESS
# NYSE [591/3083]: getting HUM - f[1], s[586]
# NGG SUCCESS
# NYSE [592/3083]: getting TEX - f[1], s[587]
# CMA SUCCESS
# NYSE [593/3083]: getting SAND - f[1], s[588]
# ALK SUCCESS
# NYSE [594/3083]: getting JWN - f[1], s[589]
# HUM SUCCESS
# NYSE [595/3083]: getting HFC - f[1], s[590]
# TEX SUCCESS
# NYSE [596/3083]: getting PQG - f[1], s[591]
# SAND SUCCESS
# NYSE [597/3083]: getting EDU - f[1], s[592]
# PQG SUCCESS
# NYSE [598/3083]: getting LBRT - f[1], s[593]
# JWN SUCCESS
# NYSE [599/3083]: getting TSN - f[1], s[594]
# HFC SUCCESS
# NYSE [600/3083]: getting HSBC - f[1], s[595]
# EDU SUCCESS
# NYSE [601/3083]: getting OMI - f[1], s[596]
# LBRT SUCCESS
# NYSE [602/3083]: getting MMP - f[1], s[597]
# HSBC SUCCESS
# NYSE [603/3083]: getting HDB - f[1], s[598]
# TSN SUCCESS
# NYSE [604/3083]: getting TSE - f[1], s[599]
# OMI SUCCESS
# NYSE [605/3083]: getting WAL - f[1], s[600]
# MMP SUCCESS
# NYSE [606/3083]: getting SBS - f[1], s[601]
# HDB SUCCESS
# NYSE [607/3083]: getting TRGP - f[1], s[602]
# TSE SUCCESS
# NYSE [608/3083]: getting LYV - f[1], s[603]
# SBS SUCCESS
# NYSE [609/3083]: getting ECL - f[1], s[604]
# WAL SUCCESS
# NYSE [610/3083]: getting ELY - f[1], s[605]
# TRGP SUCCESS
# NYSE [611/3083]: getting ARES - f[1], s[606]
# LYV SUCCESS
# NYSE [612/3083]: getting DDD - f[1], s[607]
# ARES SUCCESS
# NYSE [613/3083]: getting MKC - f[1], s[608]
# ELY SUCCESS
# NYSE [614/3083]: getting BSBR - f[1], s[609]
# ECL SUCCESS
# NYSE [615/3083]: getting RMD - f[1], s[610]
# DDD SUCCESS
# NYSE [616/3083]: getting BKU - f[1], s[611]
# BSBR SUCCESS
# NYSE [617/3083]: getting H - f[1], s[612]
# MKC SUCCESS
# NYSE [618/3083]: getting EXPR - f[1], s[613]
# RMD SUCCESS
# NYSE [619/3083]: getting CVEO - f[1], s[614]
# BKU SUCCESS
# NYSE [620/3083]: getting TDOC - f[1], s[615]
# H SUCCESS
# NYSE [621/3083]: getting TRU - f[1], s[616]
# TDOC SUCCESS
# NYSE [622/3083]: getting SOGO - f[1], s[617]
# TRU SUCCESS
# NYSE [623/3083]: getting XYL - f[1], s[618]
# SOGO SUCCESS
# NYSE [624/3083]: getting SFUN - f[1], s[619]
# XYL SUCCESS
# NYSE [625/3083]: getting DY - f[1], s[620]
# SFUN SUCCESS
# NYSE [626/3083]: getting SONY - f[1], s[621]
# CVEO SUCCESS
# NYSE [627/3083]: getting AEL - f[1], s[622]
# EXPR SUCCESS
# NYSE [628/3083]: getting WES - f[1], s[623]
# DY SUCCESS
# NYSE [629/3083]: getting QUAD - f[1], s[624]
# SONY SUCCESS
# NYSE [630/3083]: getting VSTO - f[1], s[625]
# WES SUCCESS
# NYSE [631/3083]: getting PPG - f[1], s[626]
# QUAD SUCCESS
# NYSE [632/3083]: getting ORI - f[1], s[627]
# VSTO SUCCESS
# NYSE [633/3083]: getting TPC - f[1], s[628]
# PPG SUCCESS
# NYSE [634/3083]: getting MC - f[1], s[629]
# ORI SUCCESS
# NYSE [635/3083]: getting DDS - f[1], s[630]
# MC SUCCESS
# NYSE [636/3083]: getting TMST - f[1], s[631]
# TPC SUCCESS
# NYSE [637/3083]: getting CIG - f[1], s[632]
# TMST SUCCESS
# NYSE [638/3083]: getting CUK - f[1], s[633]
# DDS SUCCESS
# NYSE [639/3083]: getting MSI - f[1], s[634]
# CIG SUCCESS
# NYSE [640/3083]: getting FNV - f[1], s[635]
# CUK SUCCESS
# NYSE [641/3083]: getting KMX - f[1], s[636]
# FNV SUCCESS
# NYSE [642/3083]: getting LFC - f[1], s[637]
# MSI SUCCESS
# NYSE [643/3083]: getting LH - f[1], s[638]
# AEL SUCCESS
# NYSE [644/3083]: getting NBHC - f[1], s[639]
# LFC SUCCESS
# NYSE [645/3083]: getting FND - f[1], s[640]
# KMX SUCCESS
# NYSE [646/3083]: getting MOH - f[1], s[641]
# LH SUCCESS
# NYSE [647/3083]: getting FUL - f[1], s[642]
# NBHC SUCCESS
# NYSE [648/3083]: getting MRC - f[1], s[643]
# FND SUCCESS
# NYSE [649/3083]: getting CPG - f[1], s[644]
# MOH SUCCESS
# NYSE [650/3083]: getting WHR - f[1], s[645]
# MRC SUCCESS
# NYSE [651/3083]: getting HSY - f[1], s[646]
# FUL SUCCESS
# NYSE [652/3083]: getting SEAS - f[1], s[647]
# CPG SUCCESS
# NYSE [653/3083]: getting COO - f[1], s[648]
# HSY SUCCESS
# NYSE [654/3083]: getting JT - f[1], s[649]
# COO SUCCESS
# NYSE [655/3083]: getting SHOP - f[1], s[650]
# SHOP SUCCESS
# NYSE [656/3083]: getting MWA - f[1], s[651]
# MWA SUCCESS
# NYSE [657/3083]: getting GWB - f[1], s[652]
# GWB SUCCESS
# NYSE [658/3083]: getting BOOT - f[1], s[653]
# BOOT SUCCESS
# NYSE [659/3083]: getting TKR - f[1], s[654]
# WHR SUCCESS
# NYSE [660/3083]: getting RL - f[1], s[655]
# SEAS SUCCESS
# NYSE [661/3083]: getting TD - f[1], s[656]
# TKR SUCCESS
# NYSE [662/3083]: getting BRO - f[1], s[657]
# RL SUCCESS
# NYSE [663/3083]: getting ALSN - f[1], s[658]
# TD SUCCESS
# NYSE [664/3083]: getting FAF - f[1], s[659]
# JT SUCCESS
# NYSE [665/3083]: getting G - f[1], s[660]
# ALSN SUCCESS
# NYSE [666/3083]: getting CFX - f[1], s[661]
# FAF SUCCESS
# NYSE [667/3083]: getting GPC - f[1], s[662]
# G SUCCESS
# NYSE [668/3083]: getting ELP - f[1], s[663]
# BRO SUCCESS
# NYSE [669/3083]: getting KMPR - f[1], s[664]
# CFX SUCCESS
# NYSE [670/3083]: getting BGS - f[1], s[665]
# ELP SUCCESS
# NYSE [671/3083]: getting CRS - f[1], s[666]
# GPC SUCCESS
# NYSE [672/3083]: getting AMC - f[1], s[667]
# KMPR SUCCESS
# NYSE [673/3083]: getting BVN - f[1], s[668]
# BGS SUCCESS
# NYSE [674/3083]: getting EXK - f[1], s[669]
# AMC SUCCESS
# NYSE [675/3083]: getting BLK - f[1], s[670]
# CRS SUCCESS
# NYSE [676/3083]: getting POR - f[1], s[671]
# BLK SUCCESS
# NYSE [677/3083]: getting BBL - f[1], s[672]
# POR SUCCESS
# NYSE [678/3083]: getting GCI - f[1], s[673]
# BBL SUCCESS
# NYSE [679/3083]: getting HOG - f[1], s[674]
# GCI SUCCESS
# NYSE [680/3083]: getting UNVR - f[1], s[675]
# UNVR SUCCESS
# NYSE [681/3083]: getting TUP - f[1], s[676]
# HOG SUCCESS
# NYSE [682/3083]: getting FSM - f[1], s[677]
# FSM SUCCESS
# NYSE [683/3083]: getting XIN - f[1], s[678]
# TUP SUCCESS
# NYSE [684/3083]: getting ADNT - f[1], s[679]
# ADNT SUCCESS
# NYSE [685/3083]: getting HAE - f[1], s[680]
# HAE SUCCESS
# NYSE [686/3083]: getting DLX - f[1], s[681]
# DLX SUCCESS
# NYSE [687/3083]: getting GEO - f[1], s[682]
# GEO SUCCESS
# NYSE [688/3083]: getting AAP - f[1], s[683]
# BVN SUCCESS
# NYSE [689/3083]: getting AON - f[1], s[684]
# XIN SUCCESS
# NYSE [690/3083]: getting SKM - f[1], s[685]
# EXK SUCCESS
# NYSE [691/3083]: getting MAN - f[1], s[686]
# AAP SUCCESS
# NYSE [692/3083]: getting TNET - f[1], s[687]
# SKM SUCCESS
# NYSE [693/3083]: getting LZB - f[1], s[688]
# AON SUCCESS
# NYSE [694/3083]: getting FTSI - f[1], s[689]
# MAN SUCCESS
# NYSE [695/3083]: getting BXS - f[1], s[690]
# TNET SUCCESS
# NYSE [696/3083]: getting TRI - f[1], s[691]
# FTSI SUCCESS
# NYSE [697/3083]: getting JQC - f[1], s[692]
# LZB SUCCESS
# NYSE [698/3083]: getting GMS - f[1], s[693]
# JQC SUCCESS
# NYSE [699/3083]: getting PBI - f[1], s[694]
# TRI SUCCESS
# NYSE [700/3083]: getting RJF - f[1], s[695]
# GMS SUCCESS
# NYSE [701/3083]: getting TTC - f[1], s[696]
# RJF SUCCESS
# NYSE [702/3083]: getting SHW - f[1], s[697]
# PBI SUCCESS
# NYSE [703/3083]: getting AMP - f[1], s[698]
# TTC SUCCESS
# NYSE [704/3083]: getting WSO - f[1], s[699]
# AMP SUCCESS
# NYSE [705/3083]: getting ATO - f[1], s[700]
# SHW SUCCESS
# NYSE [706/3083]: getting WAB - f[1], s[701]
# WSO SUCCESS
# NYSE [707/3083]: getting PFGC - f[1], s[702]
# ATO SUCCESS
# NYSE [708/3083]: getting MUSA - f[1], s[703]
# WAB SUCCESS
# NYSE [709/3083]: getting DK - f[1], s[704]
# PFGC SUCCESS
# NYSE [710/3083]: getting CM - f[1], s[705]
# MUSA SUCCESS
# NYSE [711/3083]: getting SWX - f[1], s[706]
# DK SUCCESS
# NYSE [712/3083]: getting MTW - f[1], s[707]
# CM SUCCESS
# NYSE [713/3083]: getting IRS - f[1], s[708]
# SWX SUCCESS
# NYSE [714/3083]: getting MIC - f[1], s[709]
# MTW SUCCESS
# NYSE [715/3083]: getting CNK - f[1], s[710]
# IRS SUCCESS
# NYSE [716/3083]: getting OCN - f[1], s[711]
# MIC SUCCESS
# NYSE [717/3083]: getting ENS - f[1], s[712]
# CNK SUCCESS
# NYSE [718/3083]: getting TFX - f[1], s[713]
# BXS SUCCESS
# NYSE [719/3083]: getting UFS - f[1], s[714]
# UFS SUCCESS
# NYSE [720/3083]: getting MTN - f[1], s[715]
# MTN SUCCESS
# NYSE [721/3083]: getting SPR - f[1], s[716]
# OCN SUCCESS
# NYSE [722/3083]: getting HBM - f[1], s[717]
# ENS SUCCESS
# NYSE [723/3083]: getting EVRI - f[1], s[718]
# SPR SUCCESS
# NYSE [724/3083]: getting LCI - f[1], s[719]
# TFX SUCCESS
# NYSE [725/3083]: getting PII - f[1], s[720]
# HBM SUCCESS
# NYSE [726/3083]: getting SF - f[1], s[721]
# EVRI SUCCESS
# NYSE [727/3083]: getting DCP - f[1], s[722]
# LCI SUCCESS
# NYSE [728/3083]: getting VEDL - f[1], s[723]
# PII SUCCESS
# NYSE [729/3083]: getting WBS - f[1], s[724]
# SF SUCCESS
# NYSE [730/3083]: getting WST - f[1], s[725]
# VEDL SUCCESS
# NYSE [731/3083]: getting SCI - f[1], s[726]
# WBS SUCCESS
# NYSE [732/3083]: getting BERY - f[1], s[727]
# WST SUCCESS
# NYSE [733/3083]: getting ENIA - f[1], s[728]
# SCI SUCCESS
# NYSE [734/3083]: getting SPNT - f[1], s[729]
# BERY SUCCESS
# NYSE [735/3083]: getting CCK - f[1], s[730]
# ENIA SUCCESS
# NYSE [736/3083]: getting WNC - f[1], s[731]
# SPNT SUCCESS
# NYSE [737/3083]: getting ETR - f[1], s[732]
# CCK SUCCESS
# NYSE [738/3083]: getting FLS - f[1], s[733]
# WNC SUCCESS
# NYSE [739/3083]: getting WBT - f[1], s[734]
# WBT SUCCESS
# NYSE [740/3083]: getting CRH - f[1], s[735]
# FLS SUCCESS
# NYSE [741/3083]: getting GHL - f[1], s[736]
# CRH SUCCESS
# NYSE [742/3083]: getting IPI - f[1], s[737]
# GHL SUCCESS
# NYSE [743/3083]: getting BLDR - f[1], s[738]
# IPI SUCCESS
# NYSE [744/3083]: getting CPS - f[1], s[739]
# BLDR SUCCESS
# NYSE [745/3083]: getting APH - f[1], s[740]
# DCP SUCCESS
# NYSE [746/3083]: getting TK - f[1], s[741]
# CPS SUCCESS
# NYSE [747/3083]: getting RS - f[1], s[742]
# APH SUCCESS
# NYSE [748/3083]: getting HEI - f[1], s[743]
# TK SUCCESS
# NYSE [749/3083]: getting CFR - f[1], s[744]
# RS SUCCESS
# NYSE [750/3083]: getting YPF - f[1], s[745]
# HEI SUCCESS
# NYSE [751/3083]: getting CMG - f[1], s[746]
# CFR SUCCESS
# NYSE [752/3083]: getting RPM - f[1], s[747]
# YPF SUCCESS
# NYSE [753/3083]: getting BNS - f[1], s[748]
# CMG SUCCESS
# NYSE [754/3083]: getting BWXT - f[1], s[749]
# BNS SUCCESS
# NYSE [755/3083]: getting WOW - f[1], s[750]
# RPM SUCCESS
# NYSE [756/3083]: getting PRMW - f[1], s[751]
# ETR SUCCESS
# NYSE [757/3083]: getting WOR - f[1], s[752]
# WOW SUCCESS
# NYSE [758/3083]: getting HUBS - f[1], s[753]
# PRMW SUCCESS
# NYSE [759/3083]: getting QUOT - f[1], s[754]
# WOR SUCCESS
# NYSE [760/3083]: getting NS - f[1], s[755]
# HUBS SUCCESS
# NYSE [761/3083]: getting FMX - f[1], s[756]
# QUOT SUCCESS
# NYSE [762/3083]: getting PKG - f[1], s[757]
# NS SUCCESS
# NYSE [763/3083]: getting NAV - f[1], s[758]
# FMX SUCCESS
# NYSE [764/3083]: getting CLX - f[1], s[759]
# PKG SUCCESS
# NYSE [765/3083]: getting VGR - f[1], s[760]
# NAV SUCCESS
# NYSE [766/3083]: getting HII - f[1], s[761]
# CLX SUCCESS
# NYSE [767/3083]: getting PRGO - f[1], s[762]
# VGR SUCCESS
# NYSE [768/3083]: getting MSA - f[1], s[763]
# HII SUCCESS
# NYSE [769/3083]: getting SQNS - f[1], s[764]
# PRGO SUCCESS
# NYSE [770/3083]: getting ACM - f[1], s[765]
# SQNS SUCCESS
# NYSE [771/3083]: getting HLI - f[1], s[766]
# ACM SUCCESS
# NYSE [772/3083]: getting CMP - f[1], s[767]
# HLI SUCCESS
# NYSE [773/3083]: getting SPB - f[1], s[768]
# CMP SUCCESS
# NYSE [774/3083]: getting IFF - f[1], s[769]
# SPB SUCCESS
# NYSE [775/3083]: getting RYI - f[1], s[770]
# IFF SUCCESS
# NYSE [776/3083]: getting IQV - f[1], s[771]
# RYI SUCCESS
# NYSE [777/3083]: getting WNS - f[1], s[772]
# IQV SUCCESS
# NYSE [778/3083]: getting VIV - f[1], s[773]
# BWXT SUCCESS
# NYSE [779/3083]: getting FCF - f[1], s[774]
# WNS SUCCESS
# NYSE [780/3083]: getting SNP - f[1], s[775]
# MSA SUCCESS
# NYSE [781/3083]: getting TTI - f[1], s[776]
# VIV SUCCESS
# NYSE [782/3083]: getting THS - f[1], s[777]
# SNP SUCCESS
# NYSE [783/3083]: getting RRD - f[1], s[778]
# FCF SUCCESS
# NYSE [784/3083]: getting TBI - f[1], s[779]
# THS SUCCESS
# NYSE [785/3083]: getting BHE - f[1], s[780]
# TTI SUCCESS
# NYSE [786/3083]: getting BCE - f[1], s[781]
# RRD SUCCESS
# NYSE [787/3083]: getting ENIC - f[1], s[782]
# TBI SUCCESS
# NYSE [788/3083]: getting SPXC - f[1], s[783]
# ENIC SUCCESS
# NYSE [789/3083]: getting ARCH - f[1], s[784]
# BCE SUCCESS
# NYSE [790/3083]: getting AM - f[1], s[785]
# BHE SUCCESS
# NYSE [791/3083]: getting TGI - f[1], s[786]
# SPXC SUCCESS
# NYSE [792/3083]: getting AWK - f[1], s[787]
# AM SUCCESS
# NYSE [793/3083]: getting R - f[1], s[788]
# ARCH SUCCESS
# NYSE [794/3083]: getting EXG - f[1], s[789]
# TGI SUCCESS
# NYSE [795/3083]: getting BKH - f[1], s[790]
# AWK SUCCESS
# NYSE [796/3083]: getting AVD - f[1], s[791]
# EXG SUCCESS
# NYSE [797/3083]: getting CMCM - f[1], s[792]
# CMCM SUCCESS
# NYSE [798/3083]: getting GPN - f[1], s[793]
# AVD SUCCESS
# NYSE [799/3083]: getting HE - f[1], s[794]
# GPN SUCCESS
# NYSE [800/3083]: getting SJI - f[1], s[795]
# HE SUCCESS
# NYSE [801/3083]: getting UGI - f[1], s[796]
# SJI SUCCESS
# NYSE [802/3083]: getting CBD - f[1], s[797]
# UGI SUCCESS
# NYSE [803/3083]: getting SMG - f[1], s[798]
# CBD SUCCESS
# NYSE [804/3083]: getting WAT - f[1], s[799]
# SMG SUCCESS
# NYSE [805/3083]: getting FLOW - f[1], s[800]
# R SUCCESS
# NYSE [806/3083]: getting CWT - f[1], s[801]
# BKH SUCCESS
# NYSE [807/3083]: getting MTB - f[1], s[802]
# WAT SUCCESS
# NYSE [808/3083]: getting CRL - f[1], s[803]
# FLOW SUCCESS
# NYSE [809/3083]: getting FDS - f[1], s[804]
# CWT SUCCESS
# NYSE [810/3083]: getting JLL - f[1], s[805]
# MTB SUCCESS
# NYSE [811/3083]: getting HSC - f[1], s[806]
# CRL SUCCESS
# NYSE [812/3083]: getting SAIL - f[1], s[807]
# FDS SUCCESS
# NYSE [813/3083]: getting PNM - f[1], s[808]
# JLL SUCCESS
# NYSE [814/3083]: getting AVY - f[1], s[809]
# SAIL SUCCESS
# NYSE [815/3083]: getting WMS - f[1], s[810]
# HSC SUCCESS
# NYSE [816/3083]: getting DHT - f[1], s[811]
# PNM SUCCESS
# NYSE [817/3083]: getting AVA - f[1], s[812]
# WMS SUCCESS
# NYSE [818/3083]: getting WLK - f[1], s[813]
# AVY SUCCESS
# NYSE [819/3083]: getting NTB - f[1], s[814]
# DHT SUCCESS
# NYSE [820/3083]: getting STE - f[1], s[815]
# AVA SUCCESS
# NYSE [821/3083]: getting DCI - f[1], s[816]
# NTB SUCCESS
# NYSE [822/3083]: getting FTAI - f[1], s[817]
# WLK SUCCESS
# NYSE [823/3083]: getting AIZ - f[1], s[818]
# STE SUCCESS
# NYSE [824/3083]: getting BURL - f[1], s[819]
# FTAI SUCCESS
# NYSE [825/3083]: getting LEG - f[1], s[820]
# AIZ SUCCESS
# NYSE [826/3083]: getting AAN - f[1], s[821]
# DCI SUCCESS
# NYSE [827/3083]: getting SOI - f[1], s[822]
# BURL SUCCESS
# NYSE [828/3083]: getting PRA - f[1], s[823]
# LEG SUCCESS
# NYSE [829/3083]: getting INT - f[1], s[824]
# AAN SUCCESS
# NYSE [830/3083]: getting LPG - f[1], s[825]
# SOI SUCCESS
# NYSE [831/3083]: getting BAP - f[1], s[826]
# PRA SUCCESS
# NYSE [832/3083]: getting BC - f[1], s[827]
# BAP SUCCESS
# NYSE [833/3083]: getting SNN - f[1], s[828]
# LPG SUCCESS
# NYSE [834/3083]: getting CUBI - f[1], s[829]
# INT SUCCESS
# NYSE [835/3083]: getting CADE - f[1], s[830]
# BC SUCCESS
# NYSE [836/3083]: getting AJRD - f[1], s[831]
# SNN SUCCESS
# NYSE [837/3083]: getting APAM - f[1], s[832]
# CUBI SUCCESS
# NYSE [838/3083]: getting ST - f[1], s[833]
# CADE SUCCESS
# NYSE [839/3083]: getting MLI - f[1], s[834]
# APAM SUCCESS
# NYSE [840/3083]: getting ROG - f[1], s[835]
# ST SUCCESS
# NYSE [841/3083]: getting UMC - f[1], s[836]
# AJRD SUCCESS
# NYSE [842/3083]: getting KEYS - f[1], s[837]
# MLI SUCCESS
# NYSE [843/3083]: getting HRC - f[1], s[838]
# KEYS SUCCESS
# NYSE [844/3083]: getting ASC - f[1], s[839]
# UMC SUCCESS
# NYSE [845/3083]: getting STC - f[1], s[840]
# HRC SUCCESS
# NYSE [846/3083]: getting LII - f[1], s[841]
# STC SUCCESS
# NYSE [847/3083]: getting OSG - f[1], s[842]
# LII SUCCESS
# NYSE [848/3083]: getting GOOS - f[1], s[843]
# OSG SUCCESS
# NYSE [849/3083]: getting BMO - f[1], s[844]
# GOOS SUCCESS
# NYSE [850/3083]: getting EPAM - f[1], s[845]
# BMO SUCCESS
# NYSE [851/3083]: getting PVH - f[1], s[846]
# EPAM SUCCESS
# NYSE [852/3083]: getting MTD - f[1], s[847]
# MTD SUCCESS
# NYSE [853/3083]: getting EGHT - f[1], s[848]
# EGHT SUCCESS
# NYSE [854/3083]: getting INGR - f[1], s[849]
# INGR SUCCESS
# NYSE [855/3083]: getting AWR - f[1], s[850]
# AWR SUCCESS
# NYSE [856/3083]: getting WLKP - f[1], s[851]
# ROG SUCCESS
# NYSE [857/3083]: getting BFAM - f[1], s[852]
# WLKP SUCCESS
# NYSE [858/3083]: getting TEN - f[1], s[853]
# ASC SUCCESS
# NYSE [859/3083]: getting SUP - f[1], s[854]
# BFAM SUCCESS
# NYSE [860/3083]: getting LL - f[1], s[855]
# TEN SUCCESS
# ...
# NYSE [2847/3083]: getting GOGN - f[2], s[2841]
# FRC-PH SUCCESS
# NYSE [2848/3083]: getting DINO - f[2], s[2842]
# FRC-PK SUCCESS
# NYSE [2849/3083]: getting BALL - f[2], s[2843]
# MS-PO SUCCESS
# NYSE [2850/3083]: getting BLCO - f[2], s[2844]
# GOGN SUCCESS
# NYSE [2851/3083]: getting GEHI - f[2], s[2845]
# BLCO SUCCESS
# NYSE [2852/3083]: getting NIC - f[2], s[2846]
# GEHI SUCCESS
# NYSE [2853/3083]: getting ODV - f[2], s[2847]
# DINO SUCCESS
# NYSE [2854/3083]: getting GBTG - f[2], s[2848]
# BALL SUCCESS
# NYSE [2855/3083]: getting EMWP - f[2], s[2849]
# NIC SUCCESS
# NYSE [2856/3083]: getting STR - f[2], s[2850]
# ODV SUCCESS
# NYSE [2857/3083]: getting SMR - f[2], s[2851]
# EMWP SUCCESS
# NYSE [2858/3083]: getting GROV - f[2], s[2852]
# GBTG SUCCESS
# NYSE [2859/3083]: getting EHAB - f[2], s[2853]
# GROV SUCCESS
# NYSE [2860/3083]: getting AIU - f[2], s[2854]
# EHAB SUCCESS
# NYSE [2861/3083]: getting HOUS - f[2], s[2855]
# STR SUCCESS
# NYSE [2862/3083]: getting PGRU - f[2], s[2856]
# AIU SUCCESS
# NYSE [2863/3083]: getting WDS - f[2], s[2857]
# HOUS SUCCESS
# NYSE [2864/3083]: getting ELV - f[2], s[2858]
# PGRU SUCCESS
# NYSE [2865/3083]: getting EVEX - f[2], s[2859]
# WDS SUCCESS
# NYSE [2866/3083]: getting GSK - f[2], s[2860]
# EVEX SUCCESS
# NYSE [2867/3083]: getting HLN - f[2], s[2861]
# ELV SUCCESS
# NYSE [2868/3083]: getting MAIA - f[2], s[2862]
# HLN SUCCESS
# NYSE [2869/3083]: getting GETY - f[2], s[2863]
# GSK SUCCESS
# NYSE [2870/3083]: getting HKD - f[2], s[2864]
# MAIA SUCCESS
# NYSE [2871/3083]: getting STRY - f[2], s[2865]
# GETY SUCCESS
# NYSE [2872/3083]: getting APE - f[2], s[2866]
# HKD SUCCESS
# NYSE [2873/3083]: getting QBTS - f[2], s[2867]
# STRY SUCCESS
# NYSE [2874/3083]: getting PR - f[2], s[2868]
# QBTS SUCCESS
# NYSE [2875/3083]: getting MODG - f[2], s[2869]
# SMR SUCCESS
# NYSE [2876/3083]: getting CRBG - f[2], s[2870]
# CRBG SUCCESS
# NYSE [2877/3083]: getting AMPX - f[2], s[2871]
# AMPX SUCCESS
# NYSE [2878/3083]: getting BHVN - f[2], s[2872]
# BHVN SUCCESS
# NYSE [2879/3083]: getting AXAC - f[2], s[2873]
# AXAC SUCCESS
# NYSE [2880/3083]: getting BBUC - f[2], s[2874]
# APE SUCCESS
# NYSE [2881/3083]: getting BYN - f[2], s[2875]
# BBUC SUCCESS
# NYSE [2882/3083]: getting DMA - f[2], s[2876]
# PR SUCCESS
# NYSE [2883/3083]: getting DO - f[2], s[2877]
# BYN SUCCESS
# NYSE [2884/3083]: getting EICA - f[2], s[2878]
# DMA SUCCESS
# NYSE [2885/3083]: getting GAQ - f[2], s[2879]
# DO SUCCESS
# NYSE [2886/3083]: getting GUG - f[2], s[2880]
# MODG SUCCESS
# NYSE [2887/3083]: getting HMA - f[2], s[2881]
# EICA SUCCESS
# NYSE [2888/3083]: getting ICNC - f[2], s[2882]
# GAQ SUCCESS
# NYSE [2889/3083]: getting LCW - f[2], s[2883]
# GUG SUCCESS
# NYSE [2890/3083]: getting LVWR - f[2], s[2884]
# HMA SUCCESS
# NYSE [2891/3083]: getting MBSC - f[2], s[2885]
# ICNC SUCCESS
# NYSE [2892/3083]: getting MEGI - f[2], s[2886]
# LCW SUCCESS
# NYSE [2893/3083]: getting NMAI - f[2], s[2887]
# LVWR SUCCESS
# NYSE [2894/3083]: getting NOTE - f[2], s[2888]
# MBSC SUCCESS
# NYSE [2895/3083]: getting NPFD - f[2], s[2889]
# MEGI SUCCESS
# NYSE [2896/3083]: getting PAXS - f[2], s[2890]
# NMAI SUCCESS
# NYSE [2897/3083]: getting PGSS - f[2], s[2891]
# NOTE SUCCESS
# NYSE [2898/3083]: getting RBCP - f[2], s[2892]
# NPFD SUCCESS
# NYSE [2899/3083]: getting RBT - f[2], s[2893]
# PAXS SUCCESS
# NYSE [2900/3083]: getting RLTY - f[2], s[2894]
# PGSS SUCCESS
# NYSE [2901/3083]: getting RMMZ - f[2], s[2895]
# RBT SUCCESS
# NYSE [2902/3083]: getting AAC-UN - f[2], s[2896]
# RBCP SUCCESS
# NYSE [2903/3083]: getting AAQC - f[2], s[2897]
# RLTY SUCCESS
# NYSE [2904/3083]: getting AAQC-UN - f[2], s[2898]
# RMMZ SUCCESS
# NYSE [2905/3083]: getting ACDI-UN - f[2], s[2899]
# AAC-UN SUCCESS
# NYSE [2906/3083]: getting ACRO-UN - f[2], s[2900]
# AAQC SUCCESS
# NYSE [2907/3083]: getting SKE - f[2], s[2901]
# AAQC-UN SUCCESS
# NYSE [2908/3083]: getting TFPM - f[2], s[2902]
# ACDI-UN SUCCESS
# NYSE [2909/3083]: getting TGR - f[2], s[2903]
# ACRO-UN SUCCESS
# NYSE [2910/3083]: getting AGAC - f[2], s[2904]
# TGR SUCCESS
# NYSE [2911/3083]: getting AGAC-UN - f[2], s[2905]
# TFPM SUCCESS
# NYSE [2912/3083]: getting AMPI-UN - f[2], s[2906]
# SKE SUCCESS
# NYSE [2913/3083]: getting ANAC-UN - f[2], s[2907]
# AGAC SUCCESS
# NYSE [2914/3083]: getting APCA-UN - f[2], s[2908]
# AGAC-UN SUCCESS
# NYSE [2915/3083]: getting APN-UN - f[2], s[2909]
# AMPI-UN SUCCESS
# NYSE [2916/3083]: getting ASAQ-UN - f[2], s[2910]
# ANAC-UN SUCCESS
# NYSE [2917/3083]: getting ATAQ - f[2], s[2911]
# APCA-UN SUCCESS
# NYSE [2918/3083]: getting ATEK-UN - f[2], s[2912]
# APN-UN SUCCESS
# NYSE [2919/3083]: getting AVAN-UN - f[2], s[2913]
# ASAQ-UN SUCCESS
# NYSE [2920/3083]: getting BACA-UN - f[2], s[2914]
# ATAQ SUCCESS
# NYSE [2921/3083]: getting BFAC-UN - f[2], s[2915]
# ATEK-UN SUCCESS
# NYSE [2922/3083]: getting BGSX-UN - f[2], s[2916]
# AVAN-UN SUCCESS
# NYSE [2923/3083]: getting BITE - f[2], s[2917]
# BACA-UN SUCCESS
# NYSE [2924/3083]: getting BITE-UN - f[2], s[2918]
# BFAC-UN SUCCESS
# NYSE [2925/3083]: getting BLUA - f[2], s[2919]
# BGSX-UN SUCCESS
# NYSE [2926/3083]: getting BLUA-UN - f[2], s[2920]
# BITE-UN SUCCESS
# NYSE [2927/3083]: getting BMAC-UN - f[2], s[2921]
# BLUA SUCCESS
# NYSE [2928/3083]: getting BOAS - f[2], s[2922]
# BOAS SUCCESS
# NYSE [2929/3083]: getting BOAS-UN - f[2], s[2923]
# BMAC-UN SUCCESS
# NYSE [2930/3083]: getting BYN-UN - f[2], s[2924]
# BOAS-UN SUCCESS
# NYSE [2931/3083]: getting CCVI - f[2], s[2925]
# BYN-UN SUCCESS
# NYSE [2932/3083]: getting CCVI-UN - f[2], s[2926]
# CCVI SUCCESS
# NYSE [2933/3083]: getting CLAA-UN - f[2], s[2927]
# CLAA-UN SUCCESS
# NYSE [2934/3083]: getting CLBR-UN - f[2], s[2928]
# CLBR-UN SUCCESS
# NYSE [2935/3083]: getting CNDA-UN - f[2], s[2929]
# CNDA-UN SUCCESS
# NYSE [2936/3083]: getting CNDB-UN - f[2], s[2930]
# CNDB-UN SUCCESS
# NYSE [2937/3083]: getting CORS-UN - f[2], s[2931]
# CORS-UN SUCCESS
# NYSE [2938/3083]: getting CPTK - f[2], s[2932]
# CPTK SUCCESS
# NYSE [2939/3083]: getting CPTK-UN - f[2], s[2933]
# BITE SUCCESS
# NYSE [2940/3083]: getting CPUH-UN - f[2], s[2934]
# BLUA-UN SUCCESS
# NYSE [2941/3083]: getting CSTA - f[2], s[2935]
# CPUH-UN SUCCESS
# NYSE [2942/3083]: getting CSTA-UN - f[2], s[2936]
# CSTA SUCCESS
# NYSE [2943/3083]: getting CVII-UN - f[2], s[2937]
# CSTA-UN SUCCESS
# NYSE [2944/3083]: getting CXAC-UN - f[2], s[2938]
# CVII-UN SUCCESS
# NYSE [2945/3083]: getting DMYS-UN - f[2], s[2939]
# CXAC-UN SUCCESS
# NYSE [2946/3083]: getting DNZ - f[2], s[2940]
# CCVI-UN SUCCESS
# NYSE [2947/3083]: getting DNZ-UN - f[2], s[2941]
# DMYS-UN SUCCESS
# NYSE [2948/3083]: getting DSAQ-UN - f[2], s[2942]
# DNZ SUCCESS
# NYSE [2949/3083]: getting EOCW-UN - f[2], s[2943]
# DNZ-UN SUCCESS
# NYSE [2950/3083]: getting ESM - f[2], s[2944]
# DSAQ-UN SUCCESS
# NYSE [2951/3083]: getting EVE-UN - f[2], s[2945]
# EOCW-UN SUCCESS
# NYSE [2952/3083]: getting FACA - f[2], s[2946]
# ESM SUCCESS
# NYSE [2953/3083]: getting FACA-UN - f[2], s[2947]
# EVE-UN SUCCESS
# NYSE [2954/3083]: getting FACT - f[2], s[2948]
# FACA SUCCESS
# NYSE [2955/3083]: getting FACT-UN - f[2], s[2949]
# FACA-UN SUCCESS
# NYSE [2956/3083]: getting FCAX - f[2], s[2950]
# FACT SUCCESS
# NYSE [2957/3083]: getting FCAX-UN - f[2], s[2951]
# FACT-UN SUCCESS
# NYSE [2958/3083]: getting FHN-PB - f[2], s[2952]
# FCAX SUCCESS
# NYSE [2959/3083]: getting FHN-PC - f[2], s[2953]
# FCAX-UN SUCCESS
# NYSE [2960/3083]: getting FLME - f[2], s[2954]
# FHN-PB SUCCESS
# NYSE [2961/3083]: getting FLME-UN - f[2], s[2955]
# FHN-PC SUCCESS
# NYSE [2962/3083]: getting FLYA-UN - f[2], s[2956]
# FLME SUCCESS
# NYSE [2963/3083]: getting FRXB - f[2], s[2957]
# CPTK-UN SUCCESS
# NYSE [2964/3083]: getting FRXB-UN - f[2], s[2958]
# FRXB-UN SUCCESS
# NYSE [2965/3083]: getting FSNB-UN - f[2], s[2959]
# FSNB-UN SUCCESS
# NYSE [2966/3083]: getting FTEV-UN - f[2], s[2960]
# FTEV-UN SUCCESS
# NYSE [2967/3083]: getting FVIV - f[2], s[2961]
# FVIV SUCCESS
# NYSE [2968/3083]: getting FVIV-UN - f[2], s[2962]
# FVIV-UN SUCCESS
# NYSE [2969/3083]: getting FZT - f[2], s[2963]
# FLME-UN SUCCESS
# NYSE [2970/3083]: getting FZT-UN - f[2], s[2964]
# FLYA-UN SUCCESS
# NYSE [2971/3083]: getting GAPA - f[2], s[2965]
# FRXB SUCCESS
# NYSE [2972/3083]: getting GAPA-UN - f[2], s[2966]
# FZT-UN SUCCESS
# NYSE [2973/3083]: getting GFOR-UN - f[2], s[2967]
# GAPA SUCCESS
# NYSE [2974/3083]: getting GIA-UN - f[2], s[2968]
# GAPA-UN SUCCESS
# NYSE [2975/3083]: getting GOGN-UN - f[2], s[2969]
# GFOR-UN SUCCESS
# NYSE [2976/3083]: getting GRBK-PA - f[2], s[2970]
# GIA-UN SUCCESS
# NYSE [2977/3083]: getting GSQB-UN - f[2], s[2971]
# GOGN-UN SUCCESS
# NYSE [2978/3083]: getting GSQD - f[2], s[2972]
# GSQB-UN SUCCESS
# NYSE [2979/3083]: getting GSQD-UN - f[2], s[2973]
# GRBK-PA SUCCESS
# NYSE [2980/3083]: getting HHLA - f[2], s[2974]
# GSQD SUCCESS
# NYSE [2981/3083]: getting HHLA-UN - f[2], s[2975]
# HHLA SUCCESS
# NYSE [2982/3083]: getting HTAQ-UN - f[2], s[2976]
# HTAQ-UN SUCCESS
# NYSE [2983/3083]: getting HUGS - f[2], s[2977]
# HUGS SUCCESS
# NYSE [2984/3083]: getting HUGS-UN - f[2], s[2978]
# HUGS-UN SUCCESS
# NYSE [2985/3083]: getting IBER - f[2], s[2979]
# IBER SUCCESS
# NYSE [2986/3083]: getting IBER-UN - f[2], s[2980]
# IBER-UN SUCCESS
# NYSE [2987/3083]: getting ICNC-UN - f[2], s[2981]
# ICNC-UN SUCCESS
# NYSE [2988/3083]: getting IFIN-UN - f[2], s[2982]
# FZT SUCCESS
# NYSE [2989/3083]: getting INAQ-UN - f[2], s[2983]
# IFIN-UN SUCCESS
# NYSE [2990/3083]: getting IPOF-UN - f[2], s[2984]
# INAQ-UN SUCCESS
# NYSE [2991/3083]: getting IPVA - f[2], s[2985]
# IPOF-UN SUCCESS
# NYSE [2992/3083]: getting IPVA-UN - f[2], s[2986]
# IPVA SUCCESS
# NYSE [2993/3083]: getting IPVF - f[2], s[2987]
# IPVA-UN SUCCESS
# NYSE [2994/3083]: getting IPVF-UN - f[2], s[2988]
# GSQD-UN SUCCESS
# NYSE [2995/3083]: getting IRRX-UN - f[2], s[2989]
# HHLA-UN SUCCESS
# NYSE [2996/3083]: getting JATT-UN - f[2], s[2990]
# IRRX-UN SUCCESS
# NYSE [2997/3083]: getting JUN-UN - f[2], s[2991]
# JATT-UN SUCCESS
# NYSE [2998/3083]: getting JWSM-UN - f[2], s[2992]
# JUN-UN SUCCESS
# NYSE [2999/3083]: getting KAHC-UN - f[2], s[2993]
# JWSM-UN SUCCESS
# NYSE [3000/3083]: getting KCGI-UN - f[2], s[2994]
# KAHC-UN SUCCESS
# NYSE [3001/3083]: getting LGV - f[2], s[2995]
# KCGI-UN SUCCESS
# NYSE [3002/3083]: getting LGV-UN - f[2], s[2996]
# LGV SUCCESS
# NYSE [3003/3083]: getting LOCC-UN - f[2], s[2997]
# LGV-UN SUCCESS
# NYSE [3004/3083]: getting LOKM - f[2], s[2998]
# IPVF SUCCESS
# NYSE [3005/3083]: getting LOKM-UN - f[2], s[2999]
# IPVF-UN SUCCESS
# NYSE [3006/3083]: getting MACC-UN - f[2], s[3000]
# LOKM-UN SUCCESS
# NYSE [3007/3083]: getting MATV - f[2], s[3001]
# MATV SUCCESS
# NYSE [3008/3083]: getting MBAC - f[2], s[3002]
# MBAC SUCCESS
# NYSE [3009/3083]: getting MBAC-UN - f[2], s[3003]
# MBAC-UN SUCCESS
# NYSE [3010/3083]: getting MBSC-UN - f[2], s[3004]
# MBSC-UN SUCCESS
# NYSE [3011/3083]: getting MNTN-UN - f[2], s[3005]
# LOKM SUCCESS
# NYSE [3012/3083]: getting MTAL-UN - f[2], s[3006]
# MTAL-UN SUCCESS
# NYSE [3013/3083]: getting MTVC-UN - f[2], s[3007]
# MTVC-UN SUCCESS
# NYSE [3014/3083]: getting NFNT-UN - f[2], s[3008]
# MNTN-UN SUCCESS
# NYSE [3015/3083]: getting NFYS-UN - f[2], s[3009]
# MACC-UN SUCCESS
# NYSE [3016/3083]: getting NGC - f[2], s[3010]
# NFYS-UN SUCCESS
# NYSE [3017/3083]: getting OSI - f[2], s[3011]
# NGC SUCCESS
# NYSE [3018/3083]: getting OSI-UN - f[2], s[3012]
# OSI SUCCESS
# NYSE [3019/3083]: getting PDOT - f[2], s[3013]
# OSI-UN SUCCESS
# NYSE [3020/3083]: getting PDOT-UN - f[2], s[3014]
# PDOT SUCCESS
# NYSE [3021/3083]: getting PGSS-UN - f[2], s[3015]
# PDOT-UN SUCCESS
# NYSE [3022/3083]: getting PHYT-UN - f[2], s[3016]
# PGSS-UN SUCCESS
# NYSE [3023/3083]: getting POND - f[2], s[3017]
# PHYT-UN SUCCESS
# NYSE [3024/3083]: getting POND-UN - f[2], s[3018]
# POND SUCCESS
# NYSE [3025/3083]: getting PORT-UN - f[2], s[3019]
# POND-UN SUCCESS
# NYSE [3026/3083]: getting PRBM-UN - f[2], s[3020]
# LOCC-UN SUCCESS
# NYSE [3027/3083]: getting PRPC - f[2], s[3021]
# PORT-UN SUCCESS
# NYSE [3028/3083]: getting PRPC-UN - f[2], s[3022]
# PRBM-UN SUCCESS
# NYSE [3029/3083]: getting PSPC-UN - f[2], s[3023]
# PRPC SUCCESS
# NYSE [3030/3083]: getting PV-UN - f[2], s[3024]
# PRPC-UN SUCCESS
# NYSE [3031/3083]: getting RJAC-UN - f[2], s[3025]
# PSPC-UN SUCCESS
# NYSE [3032/3083]: getting RKTA - f[2], s[3026]
# PV-UN SUCCESS
# NYSE [3033/3083]: getting RONI-UN - f[2], s[3027]
# RJAC-UN SUCCESS
# NYSE [3034/3083]: getting ROSS - f[2], s[3028]
# RKTA SUCCESS
# NYSE [3035/3083]: getting ROSS-UN - f[2], s[3029]
# RONI-UN SUCCESS
# NYSE [3036/3083]: getting RRAC-UN - f[2], s[3030]
# ROSS SUCCESS
# NYSE [3037/3083]: getting SBII - f[2], s[3031]
# NFNT-UN SUCCESS
# NYSE [3038/3083]: getting SBII-UN - f[2], s[3032]
# ROSS-UN SUCCESS
# NYSE [3039/3083]: getting SCUA-UN - f[2], s[3033]
# RRAC-UN SUCCESS
# NYSE [3040/3083]: getting SDRL - f[2], s[3034]
# SBII SUCCESS
# NYSE [3041/3083]: getting SEDA-UN - f[2], s[3035]
# SBII-UN SUCCESS
# NYSE [3042/3083]: getting SHAP-UN - f[2], s[3036]
# SCUA-UN SUCCESS
# NYSE [3043/3083]: getting SLAC - f[2], s[3037]
# SDRL SUCCESS
# NYSE [3044/3083]: getting SLAC-UN - f[2], s[3038]
# SEDA-UN SUCCESS
# NYSE [3045/3083]: getting SPGS - f[2], s[3039]
# SHAP-UN SUCCESS
# NYSE [3046/3083]: getting SPGS-UN - f[2], s[3040]
# SLAC SUCCESS
# NYSE [3047/3083]: getting STET-UN - f[2], s[3041]
# SLAC-UN SUCCESS
# NYSE [3048/3083]: getting STRE - f[2], s[3042]
# SPGS SUCCESS
# NYSE [3049/3083]: getting STRE-UN - f[2], s[3043]
# SPGS-UN SUCCESS
# NYSE [3050/3083]: getting SUAC-UN - f[2], s[3044]
# STET-UN SUCCESS
# NYSE [3051/3083]: getting TGR-UN - f[2], s[3045]
# STRE SUCCESS
# NYSE [3052/3083]: getting TLGA - f[2], s[3046]
# STRE-UN SUCCESS
# NYSE [3053/3083]: getting TLGA-UN - f[2], s[3047]
# SUAC-UN SUCCESS
# NYSE [3054/3083]: getting TRAQ-UN - f[2], s[3048]
# TGR-UN SUCCESS
# NYSE [3055/3083]: getting TRCA-UN - f[2], s[3049]
# TLGA-UN SUCCESS
# NYSE [3056/3083]: getting TRIS-UN - f[2], s[3050]
# TRAQ-UN SUCCESS
# NYSE [3057/3083]: getting TSPQ - f[2], s[3051]
# TRCA-UN SUCCESS
# NYSE [3058/3083]: getting TSPQ-UN - f[2], s[3052]
# TLGA SUCCESS
# NYSE [3059/3083]: getting TWNI - f[2], s[3053]
# TRIS-UN SUCCESS
# NYSE [3060/3083]: getting TWNI-UN - f[2], s[3054]
# TSPQ-UN SUCCESS
# NYSE [3061/3083]: getting TWOA - f[2], s[3055]
# TSPQ SUCCESS
# NYSE [3062/3083]: getting VCXB-UN - f[2], s[3056]
# VCXB-UN SUCCESS
# NYSE [3063/3083]: getting VVX - f[2], s[3057]
# VVX SUCCESS
# NYSE [3064/3083]: getting WEL-UN - f[2], s[3058]
# WEL-UN SUCCESS
# NYSE [3065/3083]: getting WNNR-UN - f[2], s[3059]
# WNNR-UN SUCCESS
# NYSE [3066/3083]: getting WPCA - f[2], s[3060]
# WPCA SUCCESS
# NYSE [3067/3083]: getting WPCA-UN - f[2], s[3061]
# WPCA-UN SUCCESS
# NYSE [3068/3083]: getting WPCB - f[2], s[3062]
# WPCB SUCCESS
# NYSE [3069/3083]: getting WPCB-UN - f[2], s[3063]
# TWNI-UN SUCCESS
# NYSE [3070/3083]: getting WQGA-UN - f[2], s[3064]
# TWNI SUCCESS
# NYSE [3071/3083]: getting RBC - f[2], s[3065]
# WQGA-UN SUCCESS
# NYSE [3072/3083]: getting RTO - f[2], s[3066]
# TWOA SUCCESS
# NYSE [3073/3083]: getting GRND - f[2], s[3067]
# GRND SUCCESS
# NYSE [3074/3083]: getting RXO - f[2], s[3068]
# RBC SUCCESS
# NYSE [3075/3083]: getting WT - f[2], s[3069]
# RTO SUCCESS
# NYSE [3076/3083]: getting BAM - f[2], s[3070]
# WT SUCCESS
# NYSE [3077/3083]: getting DIP - f[2], s[3071]
# BAM SUCCESS
# NYSE [3078/3083]: getting BN - f[2], s[3072]
# RXO SUCCESS
# NYSE [3079/3083]: getting BNRE - f[2], s[3073]
# DIP SUCCESS
# NYSE [3080/3083]: getting FBIN - f[2], s[3074]
# FBIN FAILED
# NYSE [3081/3083]: getting LANV - f[3], s[3074]
# BN SUCCESS
# NYSE [3082/3083]: getting MBC - f[3], s[3075]
# BNRE SUCCESS
# NYSE [3083/3083]: getting MRDB - f[3], s[3076]
# LANV SUCCESS
# MBC SUCCESS
# MRDB SUCCESS
# WPCB-UN SUCCESS
# 3
# 3080
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 5
#       2 nyse_data, nyse_failed = get_exchange_data(exchange)
#       4 exchange = 'NASDAQ'
# ----> 5 nasdaq_data, nasdaq_failed = get_exchange_data(exchange)
#       7 exchange = 'AMEX'
#       8 amex_data, amex_failed = get_exchange_data(exchange)
#
# Cell In[6], line 46, in get_exchange_data(exchange)
#      43     name = "Thread_" + str(x)
#      44     t = threading.Thread(name=name,target=worker, daemon=True).start()
# ---> 46 symbol_queue.join()
#      48 print(len(failed))
#      49 print(len(stock_data))
#
# File /usr/lib/python3.10/queue.py:90, in Queue.join(self)
#      88 with self.all_tasks_done:
#      89     while self.unfinished_tasks:
# ---> 90         self.all_tasks_done.wait()
#
# File /usr/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
exchange = 'NASDAQ'
nasdaq_data, nasdaq_failed = get_exchange_data(exchange)

# %%
with open(f'../data/all_{exchange.lower()}_stock_data_{datestamp}.pkl', 'rb') as file:
    stock_data_2 = pickle.load(file)

print(len(stock_data_2))
display(stock_data_2)
