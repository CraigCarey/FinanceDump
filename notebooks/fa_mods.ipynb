# %%
from urllib.request import urlopen
from urllib.error import HTTPError
import json
import pandas as pd

from fa_mods import (
    income_statement_growth,
    balance_sheet_statement_growth,
    cash_flow_statement_growth,
    discounted_cash_flow,
    advanced_discounted_cash_flow,
    advanced_levered_discounted_cash_flow,
    score,
    owner_earnings,
    enterprise_values
)

with open('/home/craigc/.keys/financialmodelingprep.txt', 'r') as file:
    api_key = file.read()

ticker = "POLY.L"

# %%
# inc_stmt = income_statement(ticker, api_key)
# display(inc_stmt)

# inc_stmt_growth = income_statement_growth(ticker, api_key)
# display(inc_stmt_growth)

# bal_sht_stmt_growth = balance_sheet_statement_growth(ticker, api_key)
# display(bal_sht_stmt_growth)

# csh_flw_stmt_growth = cash_flow_statement_growth(ticker, api_key)
# display(csh_flw_stmt_growth)

# dis_csh_flow = discounted_cash_flow(ticker, api_key)
# display(dis_csh_flow)

# adv_dis_csh_flow = advanced_discounted_cash_flow(ticker, api_key)
# display(adv_dis_csh_flow)

# adv_lev_dis_csh_flow = advanced_levered_discounted_cash_flow(ticker, api_key)
# display(adv_lev_dis_csh_flow)

# scr = score(ticker, api_key)
# display(scr)

# own_earns = owner_earnings(ticker, api_key)
# display(own_earns)

# ent_val = enterprise_values(ticker, api_key)
# display(ent_val)
# Out:
#                                        2021               2020           2019  \
# date                             2021-12-31         2020-12-31     2019-12-31
# stockPrice                           1048.5               1581           1266
# numberOfShares                    471278987          471278987      469926157
# marketCapitalization         494136017869.5       745092078447   594926514762
# minusCashAndCashEquivalents       417000000          386000000      253000000
# addTotalDebt                     2100000000         1770000000     1764000000
# enterpriseValue              6624360178.695  8834920784.470001  7460265147.62
#
#                                             2018                 2017  \
# date                                  2018-12-31           2017-12-31
# stockPrice                            857.599976           825.799988
# numberOfShares                         449016966            429880907
# ...
