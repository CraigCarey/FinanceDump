# %%
import yfinance as yf
import pickle

file = open('all_ftse_221210.pkl', 'rb')

tickers_dict = pickle.load(file)

# %%
ticker = tickers_dict['IMB.L']
income_statement = ticker.financials
# Out:
# {'zip': 'BS3 2LL',
#  'sector': 'Consumer Defensive',
#  'fullTimeEmployees': 30300,
# ...
