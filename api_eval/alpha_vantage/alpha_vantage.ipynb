# %%
from alpha_vantage.fundamentaldata import FundamentalData
from alpha_vantage.timeseries import TimeSeries
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 from alpha_vantage.fundamentaldata import FundamentalData
#       2 from alpha_vantage.timeseries import TimeSeries
#
# ModuleNotFoundError: No module named 'alpha_vantage'

# %%
fd = FundamentalData(key='')
ts = TimeSeries(key='')

ts.get_symbol_search(['imb'])
# Out:
# (    1. symbol                                            2. name      3. type  \
#  0        IMBI                        iMedia Brands Inc - Class A       Equity
#  1     IMB.LON                                Imperial Brands PLC       Equity
#  2       IMBAX     VOYA LIMITED MATURITY BOND PORTFOLIO CLASS ADV  Mutual Fund
#  3       IMBBF                                Imperial Brands Plc       Equity
#  4       IMBBY                                Imperial Brands Plc       Equity
#  5       IMBIL                                  iMedia Brands Inc       Equity
#  6       IMBIX           DELAWARE IVY MUNICIPAL BOND FUND CLASS I  Mutual Fund
#  7    IMBA.LON    iShares US Mortgage Backed Securities UCITS Acc          ETF
#  8    IMBE.AMS  iShares US Mortgage Backed Securities UCITS ET...          ETF
#  9  IMBB11.SAO                 Etf Bradesco Ima-B Fundo De Indice          ETF
#
#            4. region 5. marketOpen 6. marketClose 7. timezone 8. currency  \
# ...

# %%
inc_stm = fd.get_income_statement_annual('IMB.LON')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 inc_stm = fd.get_income_statement_annual('IMB.LON')
#
# File ~/personal_workspace/fintech/fintech-venv/lib/python3.10/site-packages/alpha_vantage/alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
#     220     if 'json' in self.output_format.lower() or 'pandas' \
#     221             in self.output_format.lower():
#     222         if data_key is not None:
#
# File ~/personal_workspace/fintech/fintech-venv/lib/python3.10/site-packages/alpha_vantage/alphavantage.py:160, in AlphaVantage._call_api_on_func.<locals>._call_wrapper(self, *args, **kwargs)
#     158 else:
# ...

# %%
display(inc_stm[0])
# Out:
#   fiscalDateEnding reportedCurrency   grossProfit  totalRevenue costOfRevenue  \
# 0       2022-06-30              USD  135620000000  196109000000   93355000000
# 1       2021-06-30              USD  115856000000  165936000000   79977000000
# 2       2020-06-30              USD   96937000000  140503000000   73159000000
# 3       2019-06-30              USD   82933000000  123495000000   67908000000
# 4       2018-06-30              USD   72007000000  107222000000   62776000000
#
#   costofGoodsAndServicesSold operatingIncome sellingGeneralAndAdministrative  \
# 0                62650000000     83383000000                     27725000000
# 1                52232000000     69916000000                     25224000000
# 2                46078000000     52959000000                     24709000000
# 3                42910000000     42959000000                     23098000000
# 4                38353000000     35058000000                     22223000000
#
# ...
