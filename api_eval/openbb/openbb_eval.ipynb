# %%
from openbb_terminal.sdk import openbb

# %%
openbb.stocks.th.open()
# Out:
#                                   name short_name
# FRA           Frankfurt Stock Exchange          F
# STU                    Börse Stuttgart         SG
# ENX                           Euronext         NX
# HAM                    Hamburger Börse         HM
# MUN                      Börse München         MU
# DUS                   Börse Düsseldorf         DU
# PAR                     Euronext Paris         PA
# GER               Deutsche Börse Xetra         DE
# IOB              London Stock Exchange         IL
# LSE              London Stock Exchange          L
# MEX          Bolsa Mexicana de Valores         MX
# HAN            Börsen Hamburg-Hannover         HA
# FKA           Frankfurt Stock Exchange          F
# TLO                     Borsa Italiana         TI
# VIE                       Wiener Börse         VI
# OSL                          Oslo Børs         OL
# STO            Nasdaq Nordic Stockholm         ST
# MCE                    Bolsa de Madrid         MC
# MIL                     Borsa Italiana         MI
# NYQ            New York Stock Exchange       NYSE
# VAN               TSX Venture Exchange          V
# SAO                  A Bolsa do Brasil         SA
# ISE                    Euronext Dublin         IR
# AMS                 Euronext Amsterdam         AS
# PNK                  OTC Markets Group        OTC
# AQS                     Aquis Exchange         AQ
# TOR             Toronto Stock Exchange         TO
# NGM                           NasdaqGM      NASGM
# NCM                             Nasdaq      NASDQ
# NMS                           NasdaqGS      NASGS
# EBS                 SIX Swiss Exchange         SW
# ASE                      NYSE American       AMEX
# BUE       Bolsas y Mercados Argentinos         BA
# SGO                  Bolsa de Santiago         SN
# CNQ  Canadian Securities Exchange: CSE         CN
# CCS        Bolsa de Valores de Caracas         CR
# BRU                  Euronext Brussels         BR
# NEO                       NEO Exchange         NE
# NYS                                NYS        NYS
# NAS                             NASDAQ        NAS
# LIS                    Euronext Lisbon         LS
# PCX                          NYSE Arca       ARCA
# SAT               Nasdaq OMX Stockholm         ST

# %%
openbb.stocks.th.exchange('LSE')
# Out:
#                                                                      LSE
# name                                               London Stock Exchange
# short_name                                                             L
# website                https://www.londonstockexchange.com/trade/equi...
# market_open                                                     08:00:00
# market_close                                                    16:30:00
# lunchbreak_start                                                    None
# lunchbreak_end                                                      None
# opening_auction_start                                           07:50:00
# opening_auction_end                                             08:00:00
# closing_auction_start                                           16:30:00
# closing_auction_end                                             16:35:00
# timezone                                                   Europe/London
# flag                                                                  🇬🇧
# open                                                                True

# %%
# ?openbb.economy.events
# Out:
# Signature:
# openbb.economy.events(
#     countries: Union[List[str], str] = '',
#     start_date: Union[str, NoneType] = None,
#     end_date: Union[str, NoneType] = None,
# ) -> pandas.core.frame.DataFrame
# Call signature: openbb.economy.events(*args: Any, **kwargs: Any) -> Any
# Type:           Operation
# String form:    <openbb_terminal.core.library.operation.Operation object at 0x7fe83777eac0>
# File:           ~/personal_workspace/FinTech/api_eval/openbb/openbb-venv/lib/python3.8/site-packages/openbb_terminal/core/library/operation.py
# Docstring:
# Get economic calendar for countries between specified dates
#
# Parameters
# ----------
# countries : [List[str],str]
#     List of countries to include in calendar.  Empty returns all
# start_date : Optional[str]
#     Start date for calendar
# end_date : Optional[str]
#     End date for calendar
#
# Returns
# -------
# pd.DataFrame
#     Economic calendar
#
# Examples
# --------
# Get todays economic calendar for the United States
# >>> from openbb_terminal.sdk import openbb
# >>> calendar = openbb.economy.events("united_states")
#
# To get multiple countries for a given date, pass the same start and end date as well as
# a list of countries
# >>> calendars = openbb.economy.events(["united_states", "canada"], start_date="2022-11-18", end_date="2022-11-18")

# %%
economic_calendar = openbb.economy.events(countries=['United Kingdom', 'United States'])
economic_calendar
# Out:
#    Time (GMT)         Country                                           Event  \
# 0       02:00  United Kingdom                                Car Registration
# 1       02:00  United Kingdom                                Car Registration
# 2       02:00  United Kingdom                                    Core CPI MoM
# 3       02:00  United Kingdom                                        Core CPI
# 4       02:00  United Kingdom                                        Core RPI
# 5       02:00  United Kingdom                                        Core RPI
# 6       02:00  United Kingdom                                             CPI
# 7       02:00  United Kingdom                                             CPI
# 8       02:00  United Kingdom                                      CPI, n.s.a
# 9       02:00  United Kingdom                                             RPI
# 10      02:00  United Kingdom                                             RPI
# 11      04:00   United States                              IEA Monthly Report
# 12      04:30  United Kingdom                               House Price Index
# 13      04:30  United Kingdom                       Housing Equity Withdrawal
# 14      07:00   United States                       MBA 30-Year Mortgage Rate
# 15      07:00   United States                       MBA Mortgage Applications
# 16      07:00   United States                              MBA Purchase Index
# 17      07:00   United States                           Mortgage Market Index
# 18      07:00   United States                        Mortgage Refinance Index
# 19      08:30   United States                                        Core PPI
# 20      08:30   United States                                        Core PPI
# 21      08:30   United States                               Core Retail Sales
# 22      08:30   United States                                             PPI
# 23      08:30   United States                   PPI ex. Food/Energy/Transport
# 24      08:30   United States                   PPI ex. Food/Energy/Transport
# 25      08:30   United States                                             PPI
# 26      08:30   United States                                  Retail Control
# 27      08:30   United States                                    Retail Sales
# 28      08:30   United States                                    Retail Sales
# 29      08:30   United States                       Retail Sales Ex Gas/Autos
# 30      08:55   United States                                         Redbook
# 31      09:00   United States                       FOMC Member Bostic Speaks
# 32      09:15   United States                       Capacity Utilization Rate
# 33      09:15   United States                           Industrial Production
# 34      09:15   United States                           Industrial Production
# 35      09:15   United States                        Manufacturing Production
# 36      09:30   United States                      FOMC Member Bullard Speaks
# 37      10:00   United States                            Business Inventories
# 38      10:00   United States                       NAHB Housing Market Index
# 39      10:00   United States                      Retail Inventories Ex Auto
# 40      13:00   United States                            20-Year Bond Auction
# 41      13:00   United States                       FOMC Member George Speaks
# 42      14:00   United States                                      Beige Book
# 43      14:00   United States                       FOMC Member Harker Speaks
# 44      16:00   United States                      US Foreign Buying, T-bonds
# 45      16:00   United States                        Overall Net Capital Flow
# 46      16:00   United States                  TIC Net Long-Term Transactions
# 47      16:00   United States  TIC Net Long-Term Transactions including Swaps
# 48      16:30   United States                      API Weekly Crude Oil Stock
# 49      18:00   United States                                Fed Logan Speaks
# 50      19:01  United Kingdom                        RICS House Price Balance
#
#      Actual Consensus Previous        Date
# 0    -10.1%         -     6.4%  2023-01-19
# 1     18.3%         -    23.5%  2023-01-19
# 2      0.5%      0.4%     0.3%  2023-01-19
# 3      6.3%      6.2%     6.3%  2023-01-19
# 4     12.9%         -    13.5%  2023-01-19
# 5      0.5%         -     0.5%  2023-01-19
# 6      0.4%      0.4%     0.4%  2023-01-19
# 7     10.5%     10.5%    10.7%  2023-01-19
# 8    127.20         -   126.70  2023-01-19
# 9      0.6%      0.7%     0.6%  2023-01-19
# 10    13.4%     13.6%    14.0%  2023-01-19
# 11        -         -        -  2023-01-19
# 12    10.3%     10.4%    12.6%  2023-01-19
# 13    -5.8B     -7.9B    -5.1B  2023-01-19
# 14    6.23%         -    6.42%  2023-01-19
# 15    27.9%         -     1.2%  2023-01-19
# 16    198.7         -    159.4  2023-01-19
# 17    238.7         -    186.7  2023-01-19
# 18    438.3         -    326.7  2023-01-19
# 19     0.1%      0.1%     0.2%  2023-01-19
# 20     5.5%      5.7%     6.2%  2023-01-19
# 21    -1.1%     -0.4%    -0.6%  2023-01-19
# 22     6.2%      6.8%     7.3%  2023-01-19
# 23     4.6%         -     4.9%  2023-01-19
# 24     0.1%         -     0.3%  2023-01-19
# 25    -0.5%     -0.1%     0.2%  2023-01-19
# 26    -0.7%     -0.3%    -0.2%  2023-01-19
# 27    -1.1%     -0.8%    -1.0%  2023-01-19
# 28    6.02%         -    6.01%  2023-01-19
# 29    -0.7%         -    -0.5%  2023-01-19
# 30     5.0%         -     5.3%  2023-01-19
# 31        -         -        -  2023-01-19
# 32    78.8%     79.6%    79.4%  2023-01-19
# 33    1.65%         -    2.18%  2023-01-19
# 34    -0.7%     -0.1%    -0.6%  2023-01-19
# 35    -1.3%     -0.3%    -1.1%  2023-01-19
# 36        -         -        -  2023-01-19
# 37     0.4%      0.4%     0.2%  2023-01-19
# 38       35        31       31  2023-01-19
# 39    -0.3%         -    -0.6%  2023-01-19
# 40   3.678%         -   3.935%  2023-01-19
# 41        -         -        -  2023-01-19
# 42        -         -        -  2023-01-19
# 43        -         -        -  2023-01-19
# 44   54.20B         -   61.90B  2023-01-19
# 45  213.10B         -  179.30B  2023-01-19
# 46   171.5B     92.7B    67.8B  2023-01-19
# 47  165.20B         -   50.80B  2023-01-19
# 48   7.615M   -1.750M  14.865M  2023-01-19
# 49        -         -        -  2023-01-19
# 50     -42%      -30%     -26%  2023-01-19

# %%
symbols = openbb.etf.holdings('DIA')
symbols
# Out:
#                                                                    Name  \
# Symbol
# UNH                                     UnitedHealth Group Incorporated
# GS                                        The Goldman Sachs Group, Inc.
# HD                                                 The Home Depot, Inc.
# DGELN 2.375 05.20.26 EMTN                               McDonald's Corp
# AMGN                                                         Amgen Inc.
# CAT                                                    Caterpillar Inc.
# MSFT                                              Microsoft Corporation
# V                                                             Visa Inc.
# HON                                        Honeywell International Inc.
# BA                                                   The Boeing Company
# TRV                                       The Travelers Companies, Inc.
# CVX                                                 Chevron Corporation
# JNJ                                                   Johnson & Johnson
# AXP                                            American Express Company
# PG                                         The Procter & Gamble Company
# CRM                                                    Salesforce, Inc.
# IBM                         International Business Machines Corporation
# WMT                                                        Walmart Inc.
# JPM                                                JPMorgan Chase & Co.
# AAPL                                                         Apple Inc.
# NKE                                                          NIKE, Inc.
# MMM                                                          3M Company
# GALPNA 1.375 09.19.23 EMTN                               Merck & Co Inc
# DIS                                             The Walt Disney Company
# KO                                                The Coca-Cola Company
# DOW                                                            Dow Inc.
# CSCO                                                Cisco Systems, Inc.
# TSCOLN 2.5 07.01.24 EMTN                     Verizon Communications Inc
# WBA                                      Walgreens Boots Alliance, Inc.
# INTC                                                  Intel Corporation
# N/A                                                           Us Dollar
#
#                            % Of Etf    Shares
# Symbol
# UNH                           9.42%   5813808
# GS                            6.80%   5813808
# HD                            6.36%   5813808
# DGELN 2.375 05.20.26 EMTN     5.33%   5813808
# AMGN                          5.23%   5813808
# CAT                           4.98%   5813808
# MSFT                          4.67%   5813808
# V                             4.33%   5813808
# HON                           4.12%   5813808
# BA                            4.11%   5813808
# TRV                           3.59%   5813808
# CVX                           3.51%   5813808
# JNJ                           3.35%   5813808
# AXP                           2.99%   5813808
# PG                            2.92%   5813808
# CRM                           2.88%   5813808
# IBM                           2.82%   5813808
# WMT                           2.81%   5813808
# JPM                           2.74%   5813808
# AAPL                          2.64%   5813808
# NKE                           2.49%   5813808
# MMM                           2.46%   5813808
# GALPNA 1.375 09.19.23 EMTN    2.15%   5813808
# DIS                           1.94%   5813808
# KO                            1.20%   5813808
# DOW                           1.12%   5813808
# CSCO                          0.93%   5813808
# TSCOLN 2.5 07.01.24 EMTN      0.79%   5813808
# WBA                           0.71%   5813808
# INTC                          0.58%   5813808
# N/A                           0.04%  13246264

# %%
openbb.stocks.ca.screener(similar = ['AAPL', 'NFLX', 'META', 'AMZN', 'MSFT', 'GOOGL', 'DIS', 'TSLA'], data_type = 'valuation')
# Out:
#   Ticker    Market Cap    P/E  Fwd P/E   PEG   P/S    P/B    P/C   P/FCF  \
# 0   AAPL  2.129390e+12  22.16    20.07  2.54  5.40  42.79  44.08   22.04
# 1   AMZN  9.455600e+11  88.06    59.70  3.39  1.88   7.08  16.12     NaN
# 2    DIS  1.813500e+11  56.66    18.64  2.40  2.19   1.90  15.61  169.97
# 3  GOOGL  1.171390e+12  18.44    17.67  2.06  4.15   4.68  10.08   18.73
# 4   META  3.481200e+11  12.69    16.84   NaN  2.95   2.87   8.33   13.23
# 5   MSFT  1.752550e+12  25.41    21.13  1.97  8.63  10.13  16.34   39.13
# 6   NFLX  1.440500e+11  30.77    31.17  5.98  4.58   7.07  23.56  200.90
# 7   TSLA  4.105100e+11  39.67    26.68  1.14  5.48  10.16  19.45   25.62
#
#    EPS this Y  EPS next Y  EPS past 5Y  EPS next 5Y  Sales past 5Y   Price  \
# 0       0.089      0.0910        0.216       0.0873          0.115  134.21
# 1       0.549      0.7380        0.676       0.2600          0.281   93.82
# 2       0.578      0.2868       -0.210       0.2361          0.085   97.38
# 3       0.914      0.0963        0.321       0.0895          0.233   92.18
# 4       0.364     -0.1301        0.316          NaN          0.337  134.62
# 5       0.198      0.1673        0.243       0.1288          0.155  231.75
# 6       0.813      0.0099        0.905       0.0515          0.275  321.80
# 7       6.692      0.1951        0.486       0.3482          0.504  126.97
#
#    Change      Volume
# 0 -0.0074  14413465.0
# 1 -0.0172  19053552.0
# 2 -0.0168   2301967.0
# 3  0.0116   7067862.0
# 4  0.0121   6846813.0
# 5 -0.0172   6562163.0
# 6 -0.0139   2935996.0
# 7 -0.0141  53267119.0

# %%
symbols = openbb.etf.holdings('DIA')
dia_symbols = list(symbols.index.drop(['N/A']))
dia_valuation = openbb.stocks.ca.screener(similar = dia_symbols, data_type = 'valuation')
dia_valuation = dia_valuation.sort_values(by = ['Price'], ascending = False).convert_dtypes()

dia_valuation.head(5)
# Out:
#    Ticker      Market Cap    P/E  Fwd P/E   PEG   P/S     P/B     P/C   P/FCF  \
# 23    UNH  450520000000.0  23.33    16.82  1.66  1.43    5.96    11.6   30.42
# 10     GS  116930000000.0    9.3     9.64  <NA>   1.9    1.13    0.41    2.71
# 11     HD  328560000000.0  19.51    19.16  3.94  2.09  254.87  133.45  127.15
# 1    AMGN  140650000000.0  21.18    14.23  3.39  5.34   38.71   12.25   28.99
# 4     CAT  129840000000.0  18.47    16.55   1.2  2.29    8.51   20.46   47.53
#
#     EPS this Y  EPS next Y  EPS past 5Y  EPS next 5Y  Sales past 5Y   Price  \
# 23       0.128      0.1348        0.201       0.1406          0.092  484.85
# 10       1.403       0.108        0.296      -0.1022          0.113  348.66
# 11       0.301      0.0142        0.192       0.0495          0.098   314.5
# 1       -0.165      0.0518        0.001       0.0625          0.025   261.2
# 4        1.212       0.099        1.535       0.1535          0.058  246.52
#
#     Change   Volume
# 23  0.0181  1278014
# 10 -0.0012   696449
# 11 -0.0284   935312
# 1   -0.012   419343
# 4  -0.0249  1103371

# %%
# %matplotlib inline

spy_daily = openbb.stocks.load(
        symbol = 'SPY',
        start_date = '1993-11-01',
        monthly = True)

openbb.stocks.candle(
    data = spy_daily,
    asset_type = 'SPY - Monthly Chart from November, 1993',
    symbol = ''
)
# Out:
# Loading Monthly data for SPY with starting period 1993-11-01.

# %%
openbb.stocks.candle('JEMA.L', start_date='2022-01-01')
# Out:
# Loading Daily data for JEMA.L with starting period 2022-01-04.

# %%
openbb.ta.donchian_chart(
    data = openbb.stocks.load('POLY.L', interval = 15),
    symbol = 'POLY 15 Minute Data'
)
# Out:
# Loading Intraday 15min data for POLY.L with starting period 2022-11-21.

# %%
openbb.futures.curve_chart('GC')

# %%
openbb.stocks.disc.ulc()
# Out:
#    Symbol                                  Name  Price (Intraday)  Change  \
# 0       F                    Ford Motor Company           12.1100 -0.3000
# 1    ITUB            Itaú Unibanco Holding S.A.            4.9799 -0.1301
# 2     FCX                 Freeport-McMoRan Inc.           43.3800 -0.5400
# 3     PBR  Petróleo Brasileiro S.A. - Petrobras           11.0900  0.1100
# 4    VALE                             Vale S.A.           18.0000 -0.0500
# 5    GOLD              Barrick Gold Corporation           18.7000  0.3300
# 6     MRO              Marathon Oil Corporation           26.7600 -0.1200
# 7     OXY      Occidental Petroleum Corporation           64.4000 -0.0200
# 8     NLY       Annaly Capital Management, Inc.           22.4700 -0.1000
# 9     CLF                 Cleveland-Cliffs Inc.           20.3900 -0.3500
# 10     GM                General Motors Company           35.3800 -1.0600
# 11     MU               Micron Technology, Inc.           55.9300 -0.5800
# 12   HBAN    Huntington Bancshares Incorporated           13.8900 -0.1800
# 13    GGB                           Gerdau S.A.            6.4500 -0.0100
# 14    UMC   United Microelectronics Corporation            7.5100 -0.0700
# 15    KMI                   Kinder Morgan, Inc.           18.6800  0.3200
# 16     ET                    Energy Transfer LP           12.4800 -0.0300
# 17    DAL                 Delta Air Lines, Inc.           37.6100 -0.7700
# 18    HST           Host Hotels & Resorts, Inc.           17.0100 -0.1300
# 19    DVN              Devon Energy Corporation           62.6600  0.0400
# 20    CVE                   Cenovus Energy Inc.           18.4700 -0.0600
# 21    APA                       APA Corporation           43.8600 -0.2000
# 22     KR                        The Kroger Co.           44.2100 -1.0500
# 23   MRNA                         Moderna, Inc.          193.6400 -3.3800
# 24  PBR-A  Petróleo Brasileiro S.A. - Petrobras            9.7400  0.0900
#
#    % Change   Volume Avg Vol (3 month) Market Cap  PE Ratio (TTM)
# 0    -2.38%  16.705M           54.071M    48.708B            5.41
# 1    -2.55%   9.862M           43.392M    48.231B            8.74
# 2    -1.24%   5.551M            14.04M    61.997B           16.43
# 3    +0.96%   5.097M           36.955M    72.297B            2.14
# 4    -0.30%       4M           35.183M    83.423B            4.63
# 5    +1.77%   6.484M           20.026M    33.274B           17.48
# 6    -0.44%   2.578M           11.004M    16.944B            5.14
# 7    -0.03%   2.942M           13.002M    58.534B            5.34
# 8    -0.47%   1.252M            7.121M    10.511B            2.99
# 9    -1.69%   3.351M           13.753M    10.507B            4.07
# 10   -2.90%   3.565M           13.332M    50.271B            6.02
# 11   -1.03%   3.567M           16.194M     61.03B           10.13
# 12   -1.31%   8.078M           15.734M    20.032B           10.68
# 13   -0.08%   2.104M           13.683M    11.026B            4.14
# 14   -0.99%   1.575M            9.263M    18.737B            7.15
# 15   +1.77%   4.512M           15.344M    41.999B           16.83
# 16   -0.28%   4.073M           14.911M     38.62B            9.31
# 17   -2.01%   6.191M            9.863M    24.115B          289.31
# 18   -0.76%   1.196M            6.912M    12.338B           14.66
# 19   +0.06%   1.818M            9.561M    40.961B            6.58
# 20   -0.32%   2.597M            6.497M    35.466B            9.52
# 21   -0.45%   1.456M            6.423M    14.102B            4.15
# 22   -2.33%    1.27M            5.059M    31.643B           13.90
# 23   -1.72%   1.364M            5.406M    74.393B            6.80
# 24   +0.88%   1.842M           15.474M    66.425B            1.87
