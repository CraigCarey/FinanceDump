# %%
import json
import time

from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import undetected_chromedriver as uc
from bs4 import BeautifulSoup

chrome_options = Options()
chrome_options.add_argument("--headless=new")
chrome_options.add_argument("--disable-gpu")
chrome_options.add_argument("--window-size=1920,1080")

# %%
# driver = webdriver.Chrome(
#     service=Service(ChromeDriverManager().install()),
#     options=chrome_options,
# )

driver = uc.Chrome()
driver.get("https://www.lse.co.uk/profiles/peoplepower1/?page=1")

# %%
BASE_URL = "https://www.lse.co.uk/profiles/peoplepower1/?page={}"

MAX_PAGES = 50
OUTPUT_FILE = "peoplepower1_posts.json"

page = 1

url = BASE_URL.format(page)
print(f"Scraping page {page}")

driver.get(url)
time.sleep(3)  # allow JS to render

soup = BeautifulSoup(driver.page_source, "html.parser")
# Out:
# Scraping page 1

# %%
# save the html to a file for inspection
with open("peoplepower1_page1.html", "w", encoding="utf-8") as f:
    f.write(soup.prettify())
