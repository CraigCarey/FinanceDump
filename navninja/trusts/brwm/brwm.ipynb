# %%
import sys
import os

# Add the sibling directory to Python's search path
sibling_dir = os.path.abspath("../../utils")
sys.path.append(sibling_dir)

from data_utils import download_file, calculate_md5, lines_to_df, check_df_types

pdf_url = "https://www.blackrock.com/uk/literature/policies/bwmt-portfolio-disclosure.pdf"
save_location = "bwmt-portfolio-disclosure.pdf"

download_file(pdf_url, save_location)

md5_checksum = calculate_md5(save_location)
print(f"MD5 Checksum: {md5_checksum}")
# Out:
# File downloaded successfully and saved to bwmt-portfolio-disclosure.pdf
# MD5 Checksum: 265ebb9f7b2012434df1408763efcbfd

# %%
# frig the pdf into a text file manually
with open("brwm_raw.txt", "r") as file:
    lines = file.readlines()  # Reads all lines into a list
print(lines)

lines = lines[7:-2]
lines = [line.strip() for line in lines]
lines
# Out:
# ['BlackRock World Mining Trust plc\n', 'As at 30 June 2024\n', 'Portfolio Holdings\n', 'Security\n', 'Market Value\n', '(bid) % of\n', 'Number Security Holdings £ Portfolio\n', 'B4T3BW6 Glencore 21,852,325 98,575,838 8.2%\n', '6144690 BHP 3,211,088 72,405,556 6.0%\n', '9315284 BHP Brazil Royalty 12,000,000 19,935,132 1.7%\n', '0144403 BHP 58,636 1,326,932 0.1%\n', '0718875 Rio Tinto 1,442,689 75,019,828 6.2%\n', '0161M94V3 Rio Tinto Plc P/Opt 19/07/24 (300) (332,640) 0.0%\n', 'B1XZS82 Anglo American 2,707,836 67,750,057 5.6%\n', '01HM7D1S4 Anglo American Plc C/Opt 19/07/24 (600) (492,000) 0.0%\n', '2352118 Freeport-McMoran 1,586,354 60,989,482 5.0%\n', '01LYCQ5C5 Freeport-McMoran IncP/Opt 19/07/24 (3,000) (407,009) 0.0%\n', '2636607 Newmont 1,737,380 57,491,184 4.8%\n', '9346193 Vale 6,387,658 31,295,326 2.6%\n', '2857334 Vale 2,757,301 24,342,599 2.0%\n', '01NGZRYH1 Vale S.A. C/Opt 19/07/24 (13,000) (164,544) 0.0%\n', '2009823 Agnico Eagle Mines 1,001,112 51,567,613 4.3%\n', '287932
# ...

# %%
df = lines_to_df(lines)
check_df_types(df)
df
# Out:
# /home/craigc/personal_workspace/FinanceDump/navninja/utils/data_utils.py:74: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, entry_df], ignore_index=True)
#       SEDOL                                   Name     Holding       Value  \
# 0   B4T3BW6                               Glencore  21852325.0  98575838.0
# 1   6144690                                    BHP   3211088.0  72405556.0
# 2   9315284                     BHP Brazil Royalty  12000000.0  19935132.0
# 3   0144403                                    BHP     58636.0   1326932.0
# 4   0718875                              Rio Tinto   1442689.0  75019828.0
# ..      ...                                    ...         ...         ...
# ...

# %%
total_weight = df['Weight'].sum()
print("Total Weight:", total_weight)
# Out:
# Total Weight: 1.0

# %%
df.to_csv("brwm.csv", index=False)
