# %%
import sys
import os

# Add the sibling directory to Python's search path
sibling_dir = os.path.abspath("../../utils")
sys.path.append(sibling_dir)

from data_utils import download_pdf, calculate_md5, lines_to_df, check_df_types

pdf_url = "https://www.blackrock.com/uk/literature/policies/brlait-portfolio-disclosure.pdf"
save_location = "brlait-portfolio-disclosure.pdf"

download_pdf(pdf_url, save_location)

md5_checksum = calculate_md5(save_location)
print(f"MD5 Checksum: {md5_checksum}")
# Out:
# PDF downloaded successfully and saved to brlait-portfolio-disclosure.pdf
# MD5 Checksum: 6e4dccc2ce219331200523ddcfa50f91

# %%
# frig the pdf into a text file manually (removing sum lines)
with open("brla_raw.txt", "r") as file:
    lines = file.readlines()  # Reads all lines into a list
print(lines)

lines = lines[5:-2]
lines = [line.strip() for line in lines]
lines
# Out:
# ['BlackRock Latin American Investment Trust Plc\n', 'As at 31 October 2024\n', 'Portfolio Holdings\n', 'Market Value / % of\n', 'Sedol Security Holdings Gross Exposure ($) Portfolio\n', '2857334 Vale - ADS 1,051,322 11,238,632 7.5%\n', '2196286 Vale S.A. 171,218 1,835,003 1.2%\n', '2616580 Petrobrás - ADR 535,629 7,198,854 4.8%\n', '2683410 Petrobrás - preference shares ADR 279,029 3,448,798 2.3%\n', '2684532 Petrobrás 264,216 1,638,586 1.1%\n', '2421041 Grupo Financiero Banorte 1,273,956 8,825,363 5.9%\n', 'B00FSK0 Banco Bradesco - ADR 1,974,846 4,838,373 3.2%\n', 'B00FM53 Banco Bradesco - Preference Shares 1,238,048 3,073,334 2.1%\n', 'BW1YVH8 Walmart de México y Centroamérica 2,752,864 7,547,151 5.0%\n', 'BG36ZK1 B3 3,397,874 6,233,721 4.1%\n', 'BF4J7N9 Hapvida Participacoes 9,513,854 5,785,151 3.8%\n', 'BK4Y052 XP 301,639 5,260,584 3.5%\n', 'BYXZ2W5 Rumo 1,530,150 5,257,562 3.5%\n', "BNDQ8P6 Rede D'or Sao Luiz 935,503 4,744,788 3.2%\n", '2393388 PINFRA 516,309 4,492,576 3.0%\n', '2643674 Grupo México 806,277 4,207,640 2.8%\n', 'B671GT8 Fibra Uno Administracion - REIT 3,372,218 3,874,446 2.6%\n', '2581332 MAG Silver Corp 181,439 3,045,754 2.0%\n', 'B01CJZ2 MAG Silver Corp 46,862 800,403 0.6%\n', '2849739 Itaú Unibanco – ADR 635,505 3,838,450 2.5%\n', 'BRJPLM3 Azza Consultancy Services Ltd 521,559 3,713,873 2.5%\n', 'BYM4063 Becle Sab De 2,661,984 3,500,860 2.3%\n', 'B1YW5V4 EZTEC 1,424,620 3,435,580 2.3%\n', 'BN6NP19 Nu Holdings Ltd 223,968 3,375,198 2.2%\n', 'B07C796 Alpargatas S.A. 2,646,707 3,273,667 2.2%\n', 'B0YFC60 Grupo Aeroportuario del Pacifico - ADS 18,562 3,230,902 2.1%\n', '2771122 Sociedad Química Y Minera - ADR 80,992 3,110,903 2.1%\n', '2491914 Kimberly-Clark 2,022,597 2,897,210 1.9%\n', 'B0CGYD6 Lojas Renner 894,971 2,871,021 1.9%\n', 'BMZ9R04 Sendas Distribuidora 1,972,032 2,548,186 1.7%\n', 'BGKG6M3 StoneCo Ltd 229,295 2,542,881 1.7%\n', 'BNZKZY4 Seatrium 1,596,200 2,280,440 1.5%\n', '2488671 Cemex - ADR 395,044 2,062,130 1.4%\n', 'BYZ6D56 IRB Brasil Resseguros 269,552 2,016,258 1.3%\n', '2196189 Cia Cervecerias Unidas 212,664 1,176,981 0.8%\n', '2217596 Cia Cervecerias Unidas - ADR 77,280 838,488 0.5%\n', 'BJLSQZ2 Vamos 1,842,233 1,998,572 1.3%\n', '2246039 FEMSA - ADR 17,897 1,734,040 1.2%\n', 'BP40HF4 Globant 7,954 1,668,272 1.1%\n', '2840970 CCR 699,228 1,479,689 1.0%\n', '2189855 Cyrela Brazil Realty 384,335 1,442,731 1.0%\n', '2406457 Cemex Sab de CV 2,675,906 1,402,326 0.9%\n', 'B56XQT8 Energisa 87,100 649,254 0.4%\n', 'Total Investments 150,434,631 100.0%\n', 'NM1224U-4074928-2/2']
# ['2857334 Vale - ADS 1,051,322 11,238,632 7.5%',
#  '2196286 Vale S.A. 171,218 1,835,003 1.2%',
#  '2616580 Petrobrás - ADR 535,629 7,198,854 4.8%',
#  '2683410 Petrobrás - preference shares ADR 279,029 3,448,798 2.3%',
#  '2684532 Petrobrás 264,216 1,638,586 1.1%',
#  '2421041 Grupo Financiero Banorte 1,273,956 8,825,363 5.9%',
#  'B00FSK0 Banco Bradesco - ADR 1,974,846 4,838,373 3.2%',
#  'B00FM53 Banco Bradesco - Preference Shares 1,238,048 3,073,334 2.1%',
#  'BW1YVH8 Walmart de México y Centroamérica 2,752,864 7,547,151 5.0%',
#  'BG36ZK1 B3 3,397,874 6,233,721 4.1%',
#  'BF4J7N9 Hapvida Participacoes 9,513,854 5,785,151 3.8%',
#  'BK4Y052 XP 301,639 5,260,584 3.5%',
#  'BYXZ2W5 Rumo 1,530,150 5,257,562 3.5%',
#  "BNDQ8P6 Rede D'or Sao Luiz 935,503 4,744,788 3.2%",
#  '2393388 PINFRA 516,309 4,492,576 3.0%',
#  '2643674 Grupo México 806,277 4,207,640 2.8%',
#  'B671GT8 Fibra Uno Administracion - REIT 3,372,218 3,874,446 2.6%',
#  '2581332 MAG Silver Corp 181,439 3,045,754 2.0%',
#  'B01CJZ2 MAG Silver Corp 46,862 800,403 0.6%',
#  '2849739 Itaú Unibanco – ADR 635,505 3,838,450 2.5%',
#  'BRJPLM3 Azza Consultancy Services Ltd 521,559 3,713,873 2.5%',
#  'BYM4063 Becle Sab De 2,661,984 3,500,860 2.3%',
#  'B1YW5V4 EZTEC 1,424,620 3,435,580 2.3%',
#  'BN6NP19 Nu Holdings Ltd 223,968 3,375,198 2.2%',
#  'B07C796 Alpargatas S.A. 2,646,707 3,273,667 2.2%',
#  'B0YFC60 Grupo Aeroportuario del Pacifico - ADS 18,562 3,230,902 2.1%',
#  '2771122 Sociedad Química Y Minera - ADR 80,992 3,110,903 2.1%',
#  '2491914 Kimberly-Clark 2,022,597 2,897,210 1.9%',
#  'B0CGYD6 Lojas Renner 894,971 2,871,021 1.9%',
#  'BMZ9R04 Sendas Distribuidora 1,972,032 2,548,186 1.7%',
#  'BGKG6M3 StoneCo Ltd 229,295 2,542,881 1.7%',
#  'BNZKZY4 Seatrium 1,596,200 2,280,440 1.5%',
#  '2488671 Cemex - ADR 395,044 2,062,130 1.4%',
#  'BYZ6D56 IRB Brasil Resseguros 269,552 2,016,258 1.3%',
#  '2196189 Cia Cervecerias Unidas 212,664 1,176,981 0.8%',
#  '2217596 Cia Cervecerias Unidas - ADR 77,280 838,488 0.5%',
#  'BJLSQZ2 Vamos 1,842,233 1,998,572 1.3%',
#  '2246039 FEMSA - ADR 17,897 1,734,040 1.2%',
#  'BP40HF4 Globant 7,954 1,668,272 1.1%',
#  '2840970 CCR 699,228 1,479,689 1.0%',
#  '2189855 Cyrela Brazil Realty 384,335 1,442,731 1.0%',
#  '2406457 Cemex Sab de CV 2,675,906 1,402,326 0.9%',
#  'B56XQT8 Energisa 87,100 649,254 0.4%']

# %%
df = lines_to_df(lines)
check_df_types(df)
df
# Out:
# /home/craigc/personal_workspace/FinanceDump/navninja/utils/data_utils.py:74: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   df = pd.concat([df, entry_df], ignore_index=True)
#       SEDOL                                    Name    Holding       Value  \
# 0   2857334                              Vale - ADS  1051322.0  11238632.0
# 1   2196286                               Vale S.A.   171218.0   1835003.0
# 2   2616580                         Petrobrás - ADR   535629.0   7198854.0
# 3   2683410       Petrobrás - preference shares ADR   279029.0   3448798.0
# 4   2684532                               Petrobrás   264216.0   1638586.0
# 5   2421041                Grupo Financiero Banorte  1273956.0   8825363.0
# 6   B00FSK0                    Banco Bradesco - ADR  1974846.0   4838373.0
# 7   B00FM53      Banco Bradesco - Preference Shares  1238048.0   3073334.0
# 8   BW1YVH8       Walmart de México y Centroamérica  2752864.0   7547151.0
# 9   BG36ZK1                                      B3  3397874.0   6233721.0
# 10  BF4J7N9                   Hapvida Participacoes  9513854.0   5785151.0
# 11  BK4Y052                                      XP   301639.0   5260584.0
# 12  BYXZ2W5                                    Rumo  1530150.0   5257562.0
# 13  BNDQ8P6                      Rede D'or Sao Luiz   935503.0   4744788.0
# 14  2393388                                  PINFRA   516309.0   4492576.0
# 15  2643674                            Grupo México   806277.0   4207640.0
# 16  B671GT8         Fibra Uno Administracion - REIT  3372218.0   3874446.0
# 17  2581332                         MAG Silver Corp   181439.0   3045754.0
# 18  B01CJZ2                         MAG Silver Corp    46862.0    800403.0
# 19  2849739                     Itaú Unibanco – ADR   635505.0   3838450.0
# 20  BRJPLM3           Azza Consultancy Services Ltd   521559.0   3713873.0
# 21  BYM4063                            Becle Sab De  2661984.0   3500860.0
# 22  B1YW5V4                                   EZTEC  1424620.0   3435580.0
# 23  BN6NP19                         Nu Holdings Ltd   223968.0   3375198.0
# 24  B07C796                         Alpargatas S.A.  2646707.0   3273667.0
# 25  B0YFC60  Grupo Aeroportuario del Pacifico - ADS    18562.0   3230902.0
# 26  2771122         Sociedad Química Y Minera - ADR    80992.0   3110903.0
# 27  2491914                          Kimberly-Clark  2022597.0   2897210.0
# 28  B0CGYD6                            Lojas Renner   894971.0   2871021.0
# 29  BMZ9R04                    Sendas Distribuidora  1972032.0   2548186.0
# 30  BGKG6M3                             StoneCo Ltd   229295.0   2542881.0
# 31  BNZKZY4                                Seatrium  1596200.0   2280440.0
# 32  2488671                             Cemex - ADR   395044.0   2062130.0
# 33  BYZ6D56                   IRB Brasil Resseguros   269552.0   2016258.0
# 34  2196189                  Cia Cervecerias Unidas   212664.0   1176981.0
# 35  2217596            Cia Cervecerias Unidas - ADR    77280.0    838488.0
# 36  BJLSQZ2                                   Vamos  1842233.0   1998572.0
# 37  2246039                             FEMSA - ADR    17897.0   1734040.0
# 38  BP40HF4                                 Globant     7954.0   1668272.0
# 39  2840970                                     CCR   699228.0   1479689.0
# 40  2189855                    Cyrela Brazil Realty   384335.0   1442731.0
# 41  2406457                         Cemex Sab de CV  2675906.0   1402326.0
# 42  B56XQT8                                Energisa    87100.0    649254.0
#
#     Weight
# 0    0.075
# 1    0.012
# 2    0.048
# 3    0.023
# 4    0.011
# 5    0.059
# 6    0.032
# 7    0.021
# 8    0.050
# 9    0.041
# 10   0.038
# 11   0.035
# 12   0.035
# 13   0.032
# 14   0.030
# 15   0.028
# 16   0.026
# 17   0.020
# 18   0.006
# 19   0.025
# 20   0.025
# 21   0.023
# 22   0.023
# 23   0.022
# 24   0.022
# 25   0.021
# 26   0.021
# 27   0.019
# 28   0.019
# 29   0.017
# 30   0.017
# 31   0.015
# 32   0.014
# 33   0.013
# 34   0.008
# 35   0.005
# 36   0.013
# 37   0.012
# 38   0.011
# 39   0.010
# 40   0.010
# 41   0.009
# 42   0.004

# %%
total_weight = df['Weight'].sum()
print("Total Weight:", total_weight)
# Out:
# Total Weight: 1.0

# %%
df.to_csv("brla.csv", index=False)
