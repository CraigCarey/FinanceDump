# %% [markdown]
# # Hypothesis testing

# %%
import pandas as pd
import numpy as np
from scipy.stats import norm
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# import microsoft.csv, and add a new feature - logreturn
ms = pd.read_csv('data/microsoft.csv')
ms['logReturn'] = np.log(ms['Close'].shift(-1)) - np.log(ms['Close'])

# %%
plt.title("Close prices of MSFT 2007-2018", size=30)
ms['Close'].plot(figsize=(20, 8))
# Out:
# <AxesSubplot: title={'center': 'Close prices of MSFT 2007-2018'}>

# %%
# Log return goes up and down during the period
plt.title("Log return of MSFT 2007-2018", size=30)
ms['logReturn'].plot(figsize=(20, 8))
plt.axhline(0, color='red')
plt.show()

# %%
plt.title("Histogram of daily return of MSFT 2007-2018", size=30)
ms.loc[:, 'logReturn'].dropna().hist(bins=100)
# Out:
# <AxesSubplot: title={'center': 'Histogram of daily return of MSFT 2007-2018'}>

# %% [markdown]
# ## Steps involved in testing a claim by hypothesis testing

# %% [markdown]
# ### Step 1: Set hypothesis

# %% [markdown]
# $H_0 : \mu = 0$
# $H_a : \mu \neq 0$
#
# H0 is the __null hypothesis__, and means the average daily return is 0
#
# H1 is the __alternative hypothesis__, and means the average stock return is not equal to 0

# %% [markdown]
# ### Step 2: Calculate test statistic

# %%
sample_mean = ms['logReturn'].mean()
sample_std = ms['logReturn'].std(ddof=1)
n = ms['logReturn'].shape[0]

# if sample size n is large enough, we can use z-distribution, instead of t-distribtuion
# mu = 0 under the null hypothesis
zhat = (sample_mean - 0)/(sample_std/n**0.5)
print(zhat)
# Out:
# 1.614147714000367

# %% [markdown]
# ### Step 3: Set decision criteria

# %%
# confidence level
alpha = 0.05

zleft = norm.ppf(alpha/2, 0, 1)
zright = -zleft  # z-distribution is symmetric 
print(zleft, zright)
# Out:
# -1.9599639845400545 1.9599639845400545

# %% [markdown]
# ### Step 4:  Make decision - shall we reject H0?

# %%
print(f'At significant level of {alpha}, shall we reject: {zhat > zright or zhat < zleft}')
# Out:
# At significant level of 0.05, shall we reject: False

# %% [markdown]
# ## Try one tail test by yourself !

# %% [markdown]
# $H_0 : \mu \leq 0$
# $H_a : \mu > 0$

# %%
# step 2
sample_mean = ms['logReturn'].mean()
sample_std = ms['logReturn'].std(ddof=1)
n = ms['logReturn'].shape[0]

# if sample size n is large enough, we can use z-distribution, instead of t-distribtuion
# mu = 0 under the null hypothesis
zhat = (sample_mean - 0)/(sample_std/n**0.5)
print(zhat)
# Out:
# None

# %% [markdown]
# ** Expected output: ** 1.6141477140003675

# %%
# step 3
alpha = 0.05

zright = norm.ppf(1-alpha, 0, 1)
print(zright)
# Out:
# 1.64485362695

# %% [markdown]
# ** Expected output: ** 1.64485362695

# %%
# step 4
print('At significant level of {}, shall we reject: {}'.format(alpha, zhat>zright))
# Out:
# At significant level of 0.05, shall we reject: False

# %% [markdown]
# ** Expected output: ** At significant level of 0.05, shall we reject: False

# %% [markdown]
# # An alternative method: p-value

# %%
# step 3 (p-value)
p = 1 - norm.cdf(zhat, 0, 1)
print(p)
# Out:
# 0.053247694997

# %%
# step 4
print('At significant level of {}, shall we reject: {}'.format(alpha, p < alpha))
# Out:
# At significant level of 0.05, shall we reject: False
