# %%
from jema import (
    get_latest_holdings,
    get_symbols_and_exchanges,
    append_symbols_and_exchanges,
    get_local_prices,
    get_fx_rates,
    apply_rates,
    create_jema_json,
    read_jema_json,
)
# Out:
# /home/craigc/personal_workspace/jema-st
# 0

# %%
latest_holdings = get_latest_holdings()
display(latest_holdings.head())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 latest_holdings = get_latest_holdings()
#       2 display(latest_holdings.head())
#
# File ~/personal_workspace/FinanceDump/jema/jema.py:95, in get_latest_holdings(local_filename)
#      94 def get_latest_holdings(local_filename=xlsx_filename):
# ---> 95     month_sheet = latest_holdings_sheet0_name()
#      96     month_data = pd.read_excel(
#      97         local_filename, sheet_name=month_sheet, skiprows=9, usecols=range(5)
#      98     )
#      99     month_data.drop(["% of Fund"], axis=1, inplace=True)
#
# File ~/personal_workspace/FinanceDump/jema/jema.py:44, in latest_holdings_sheet0_name()
#      43 def latest_holdings_sheet0_name():
# ---> 44     xls = pd.ExcelFile(xlsx_filename)
#      45     return xls.sheet_names[0]
#
# File ~/personal_workspace/FinanceDump/jema/jema-venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:1550, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1548     ext = "xls"
#    1549 else:
# -> 1550     ext = inspect_excel_format(
#    1551         content_or_path=path_or_buffer, storage_options=storage_options
#    1552     )
#    1553     if ext is None:
#    1554         raise ValueError(
#    1555             "Excel file format cannot be determined, you must specify "
#    1556             "an engine manually."
#    1557         )
#
# File ~/personal_workspace/FinanceDump/jema/jema-venv/lib/python3.12/site-packages/pandas/io/excel/_base.py:1402, in inspect_excel_format(content_or_path, storage_options)
#    1399 if isinstance(content_or_path, bytes):
#    1400     content_or_path = BytesIO(content_or_path)
# -> 1402 with get_handle(
#    1403     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1404 ) as handle:
#    1405     stream = handle.handle
#    1406     stream.seek(0)
#
# File ~/personal_workspace/FinanceDump/jema/jema-venv/lib/python3.12/site-packages/pandas/io/common.py:882, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#    (...)    878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
# --> 882         handle = open(handle, ioargs.mode)
#     883     handles.append(handle)
#     885 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: 'jpm-emerging-europe-middle-east-afria-disclosure.xlsx'

# %%
symbols_and_exchanges = get_symbols_and_exchanges()
display(symbols_and_exchanges.head())
# Out:
#                                             Issuer Security No.     Symbol  \
# 0                                   ABSA GROUP LTD      BFX05H3        ABG
# 1                   ABU DHABI COMMERCIAL BANK PJSC      6545464       ADCB
# 2                      ABU DHABI ISLAMIC BANK PJSC      6001728       ADIB
# 3  ABU DHABI NATIONAL OIL CO FOR DISTRIBUTION PJSC      BYVGM64  ADNOCDIST
# 4                                  ADES HOLDING CO      BR56KM3       2382
#
#   Exchange Currency  Conv Rate
# 0      JSE      ZAC          1
# 1      ADX      AED          1
# 2      ADX      AED          1
# 3      ADX      AED          1
# 4  TADAWUL      SAR          1

# %%
latest_holdings_with_symbols = append_symbols_and_exchanges(latest_holdings)
display(latest_holdings_with_symbols.head())
# Out:
#                                 Security Description Security No.   Symbol  \
# 0                                     ABSA GROUP LTD      BFX05H3      ABG
# 1     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728     ADIB
# 2                 ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3     2382
# 3  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983      BRBN103  ADNOCLS
# 4                  AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9     1120
#
#   Exchange Currency  Conv Rate Holding  Market Value
# 0      JSE      ZAC          1   44158     375877.04
# 1      ADX      AED          1  117334     515464.70
# 2  TADAWUL      SAR          1  108419     371655.55
# 3      ADX      AED          1  420883     500624.93
# 4  TADAWUL      SAR          1   54131    1161252.36

# %%
# loop until failures is empty
while True:
    failures = get_local_prices(latest_holdings_with_symbols)
    if not failures:
        break

display(failures)
display(latest_holdings_with_symbols.head())
# Out:
# Processing: JSE:ABG
# Processing: ADX:ADIB
# Processing: TADAWUL:2382
# Processing: ADX:ADNOCLS
# Processing: TADAWUL:1120
# Processing: ADX:ALDAR
# Processing: TADAWUL:4200
# Processing: TADAWUL:2081
# Processing: OTC:APHBF
# Processing: NYSE:AU
# Processing: TADAWUL:1080
# Processing: TADAWUL:4321
# Processing: ATHEX:AIA
# Processing: GETTEX:318
# Processing: LSE:0Q3J
# Processing: GPW:CCC
# Processing: DFM:DIB
# Processing: TADAWUL:7203
# Processing: DFM:EMAARDEV
# Processing: DFM:EMAAR
# Processing: DFM:DU
# Processing: LSIN:0RCP
# Processing: JSE:FSR
# Processing: RUS:SIBN
# Processing: RUS:GAZP
# Processing: RUS:GAZP
# Processing: LSE:0QQ8
# Processing: LSE:0LV3
# Processing: LSIN:HSBK
# Processing: LSE:0J39
# Processing: LSIN:0EXG
# Processing: FX_IDC:GBPGBP
# Processing: NASDAQ:KSPI
# Processing: LSIN:0O8D
# Processing: LSIN:0Q3Y
# Processing: OTC:KUMBF
# Processing: TADAWUL:1830
# Processing: GPW:LPP
# Processing: RUS:LKOH
# Processing: RUS:LKOH
# Processing: RUS:MGNT
# Processing: RUS:MDMG
# Processing: LSE:MTLN
# Processing: RUS:GMKN
# Processing: LSIN:KAP
# Processing: JSE:NPN
# Processing: LSIN:0RCR
# Processing: KSE:NBK
# Processing: JSE:NED
# Processing: LSE:55VX
# Processing: RUS:NVTK
# Processing: RUS:NVTK
# Processing: RUS:NLMK
# Processing: ATHEX:OPTIMA
# Processing: DFM:PARKIN
# Processing: LSIN:0RTY
# Processing: RUS:PLZL
# Processing: GPW:PZU
# Processing: QSE:QGTS
# Processing: QSE:QNBK
# Processing: TADAWUL:1010
# Processing: TADAWUL:4142
# Processing: RUS:ROSN
# Processing: RUS:ROSN
# Processing: RUS:RTKM
# Processing: JSE:SLM
# Processing: ATHEX:SAR
# Processing: JSE:SOL
# Processing: TADAWUL:1060
# Processing: TADAWUL:4031
# Processing: TADAWUL:2270
# Processing: RUS:SBER
# Processing: RUS:SBER
# Processing: RUS:CHMF
# Processing: JSE:SHP
# Processing: JSE:SSW
# Processing: RUS:AFKS
# Processing: JSE:SBK
# Processing: RUS:TATN
# Processing: RUS:TATNP
# Processing: RUS:TCSG
# Processing: DFM:TECOM
# Processing: TADAWUL:1180
# Processing: BIST:TUPRS
# Processing: BIST:THYAO
# Processing: BIST:RAYSG
# Processing: TADAWUL:4003
# Processing: TADAWUL:4260
# Processing: JSE:VAL
# Processing: RUS:VTBR
# Processing: JSE:WBC
# Processing: RUS:X5
# []
#                                 Security Description Security No.   Symbol  \
# 0                                     ABSA GROUP LTD      BFX05H3      ABG
# 1     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728     ADIB
# 2                 ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3     2382
# 3  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983      BRBN103  ADNOCLS
# 4                  AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9     1120
#
#   Exchange Currency  Conv Rate Holding  Market Value    SP LC
# 0      JSE      ZAC          1   44158     375877.04  22702.0
# 1      ADX      AED          1  117334     515464.70     20.5
# 2  TADAWUL      SAR          1  108419     371655.55    17.32
# 3      ADX      AED          1  420883     500624.93     5.85
# 4  TADAWUL      SAR          1   54131    1161252.36    97.95

# %%
fx_rates = get_fx_rates(latest_holdings_with_symbols)
display(fx_rates)
# Out:
# {'ZAC': 0.0004412,
#  'AED': 0.20413,
#  'SAR': 0.1982,
#  'USD': 0.75125,
#  'EUR': 0.87378,
#  'PLN': 0.20643,
#  'RUB': 0.009647,
#  'CHF': 0.9325,
#  'GBP': 1.0,
#  'KWF': 0.002426,
#  'QAR': 0.20593,
#  'TRY': 0.01724}

# %%
apply_rates(latest_holdings_with_symbols, fx_rates)
display(latest_holdings_with_symbols.head())
latest_holdings_with_symbols.to_csv("jema_holdings.csv", index=False)
# Out:
#                                 Security Description Security No.   Symbol  \
# 0                                     ABSA GROUP LTD      BFX05H3      ABG
# 1     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728     ADIB
# 2                 ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3     2382
# 3  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983      BRBN103  ADNOCLS
# 4                  AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9     1120
#
#   Exchange Currency  Conv Rate Holding  Market Value    SP LC     SP GBP  \
# 0      JSE      ZAC          1   44158     375877.04  22702.0  10.016122
# 1      ADX      AED          1  117334     515464.70     20.5   4.184665
# 2  TADAWUL      SAR          1  108419     371655.55    17.32   3.432824
# 3      ADX      AED          1  420883     500624.93     5.85   1.194160
# 4  TADAWUL      SAR          1   54131    1161252.36    97.95  19.413690
#
#     Holding GBP
# 0  4.422919e+05
# 1  4.910035e+05
# 2  3.721833e+05
# 3  5.026019e+05
# 4  1.050882e+06

# %%
create_jema_json(latest_holdings_with_symbols, fx_rates)

jd = read_jema_json()
display(jd)
display(jd['total_nav_gbp'])
# Out:
# 224,038,509
# 5.54 GBP per share
# JEMA price: 2.30 GBP
# S Account Divs: 55,168,298
# S account divs per share: 1.36
# Total NAV: 6.90
# Total Russian Holding: 198,364,516
# Total Non-Russian Holding: 25,673,993
# Total holdings: 224,038,509
# {'total_holding_gbp': 224038509,
#  'equity_nav_gbp': 5.540022477744807,
#  'jema_price': 2.3,
#  's_account_divs_now_gbp': 55168298,
#  's_account_divs_per_share': 1.3642012363996043,
#  'total_nav_gbp': 6.904223714144411,
#  'total_holding_rus': 198364516,
#  'total_holding_non': 25673993,
#  'data_timestamp': '2025-12-10T10:44:41.705786'}
# 6.904223714144411

# %%
# copy the files to streamlit folder
import shutil
streamlit_dir = "/home/craigc/personal_workspace/jema-st/"
shutil.copy("jema_holdings.csv", f"{streamlit_dir}jema_holdings.csv")
shutil.copy("jema_data.json", f"{streamlit_dir}jema_data.json")
# Out:
# '/home/craigc/personal_workspace/jema-st/jema_data.json'

# %%
# cd into streamlit folder and git add, commit, push
import os
script_dir = "/home/craigc/personal_workspace/FinanceDump/jema"
os.chdir(streamlit_dir)
os.system("git add jema_holdings.csv jema_data.json")
os.system('git commit -m "Update JEMA data"')
os.system("git push")
os.chdir(script_dir)
# Out:
# On branch main
# Your branch is ahead of 'origin/main' by 1 commit.
#   (use "git push" to publish your local commits)
#
# nothing to commit, working tree clean
# To github.com-dyler:jema-st/jema-st.git
#    74dff2e..a71ea27  main -> main
# 0
