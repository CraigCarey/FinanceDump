# %%
import shutil
import os
from datetime import datetime

from jema import (
    get_latest_holdings,
    get_jema_holdings_xlsx,
    get_symbols_and_exchanges,
    append_symbols_and_exchanges,
    get_local_prices,
    get_fx_rates,
    apply_rates,
    create_jema_json,
    read_jema_json,
)
official_nav = float(input())
# Out:
# you are using nologin method, data you access may be limited

# %%
get_jema_holdings_xlsx()
latest_holdings = get_latest_holdings()
display(latest_holdings.head())
# Out:
#   Holding                            Security Description  Market Value  \
# 0   37303                                  ABSA GROUP LTD     472905.14
# 1   62573  ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1     323157.90
# 2   83169              ADES HOLDING CO COMMON STOCK SAR 1     295707.01
# 3   56152               AL RAJHI BANK COMMON STOCK SAR 10    1124621.69
# 4  259343        ALDAR PROPERTIES PJSC COMMON STOCK AED 1     567264.89
#
#   Security No.
# 0      BFX05H3
# 1      6001728
# 2      BR56KM3
# 3      B12LZH9
# 4      B0LX3Y2

# %%
symbols_and_exchanges = get_symbols_and_exchanges()
display(symbols_and_exchanges.head())
# Out:
#                                             Issuer Security No.     Symbol  \
# 0                                   ABSA GROUP LTD      BFX05H3        ABG
# 1                   ABU DHABI COMMERCIAL BANK PJSC      6545464       ADCB
# 2                      ABU DHABI ISLAMIC BANK PJSC      6001728       ADIB
# 3  ABU DHABI NATIONAL OIL CO FOR DISTRIBUTION PJSC      BYVGM64  ADNOCDIST
# 4                                  ADES HOLDING CO      BR56KM3       2382
#
#   Exchange Currency  Conv Rate
# 0      JSE      ZAC          1
# 1      ADX      AED          1
# 2      ADX      AED          1
# 3      ADX      AED          1
# 4  TADAWUL      SAR          1

# %%
latest_holdings_with_symbols = append_symbols_and_exchanges(latest_holdings)
display(latest_holdings_with_symbols.head())
# Out:
#                              Security Description Security No. Symbol  \
# 0                                  ABSA GROUP LTD      BFX05H3    ABG
# 1  ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728   ADIB
# 2              ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3   2382
# 3               AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9   1120
# 4        ALDAR PROPERTIES PJSC COMMON STOCK AED 1      B0LX3Y2  ALDAR
#
#   Exchange Currency  Conv Rate Holding  Market Value
# 0      JSE      ZAC          1   37303     472905.14
# 1      ADX      AED          1   62573     323157.90
# 2  TADAWUL      SAR          1   83169     295707.01
# 3  TADAWUL      SAR          1   56152    1124621.69
# 4      ADX      AED          1  259343     567264.89

# %%
# Get new additions - ones with no symbol
new_additions = latest_holdings_with_symbols[latest_holdings_with_symbols['Symbol'] == '']
display(new_additions)
# Out:
# Empty DataFrame
# Columns: [Security Description, Security No., Symbol, Exchange, Currency, Conv Rate, Holding, Market Value]
# Index: []

# %%
# loop until failures is empty
while True:
    failures = get_local_prices(latest_holdings_with_symbols)
    if not failures:
        break

# failures = get_local_prices(latest_holdings_with_symbols)

display(failures)
display(latest_holdings_with_symbols.head())
# Out:
# Processing: JSE:ABG
# Processing: ADX:ADIB
# Processing: TADAWUL:2382
# Processing: TADAWUL:1120
# Processing: ADX:ALDAR
# Processing: TADAWUL:4200
# Processing: TADAWUL:2081
# Processing: OTC:APHBF
# Processing: NYSE:AU
# Processing: TADAWUL:4321
# Processing: ATHEX:AIA
# Processing: LSIN:0DP9
# Processing: GETTEX:318
# Processing: LSE:0Q3J
# Processing: JSE:DSY
# Processing: DFM:DIB
# Processing: TADAWUL:1303
# Processing: TADAWUL:7203
# Processing: DFM:EMAARDEV
# Processing: DFM:EMAAR
# Processing: DFM:DU
# Processing: DFM:EMIRATESNBD
# Processing: TADAWUL:7020
# Processing: ATHEX:EUROB
# Processing: JSE:FSR
# Processing: RUS:SIBN
# Processing: RUS:GAZP
# Processing: RUS:GAZP
# Processing: LSE:0QQ8
# Processing: LSE:0LV3
# Processing: LSIN:HSBK
# Processing: LSE:0J39
# Processing: LSE:0S2J
# Processing: FX_IDC:GBPGBP
# Processing: JSE:JSE
# Processing: NASDAQ:KSPI
# Processing: LSIN:0O8D
# Processing: LSIN:0HLK
# Processing: LSIN:0Q3Y
# Processing: OTC:KUMBF
# Processing: RUS:LKOH
# Processing: RUS:LKOH
# Processing: RUS:MGNT
# Processing: LSE:0NUG
# Processing: RUS:MDMG
# Processing: LSE:MTLN
# Processing: RUS:GMKN
# Processing: LSIN:0RGC
# Processing: OTC:MTNOF
# Processing: LSIN:KAP
# Processing: JSE:NPN
# Processing: LSIN:0RCR
# Processing: JSE:NED
# Processing: JSE:NPH
# Processing: LSE:55VX
# Processing: RUS:NVTK
# Processing: RUS:NVTK
# Processing: RUS:NLMK
# Processing: ATHEX:OPTIMA
# Processing: BET:OTP
# Processing: DFM:PARKIN
# Processing: ATHEX:TPEIR
# Processing: RUS:PLZL
# Processing: GPW:PZU
# Processing: QSE:QNBK
# Processing: TADAWUL:1010
# Processing: TADAWUL:4142
# Processing: RUS:ROSN
# Processing: RUS:ROSN
# Processing: RUS:RTKM
# Processing: JSE:SLM
# Processing: ATHEX:SAR
# Processing: JSE:SOL
# Processing: TADAWUL:1060
# Processing: TADAWUL:4031
# Processing: TADAWUL:7010
# Processing: RUS:SBER
# Processing: RUS:SBER
# Processing: RUS:CHMF
# Processing: JSE:SHP
# Processing: JSE:SSW
# Processing: RUS:AFKS
# Processing: JSE:SBK
# Processing: RUS:TATN
# Processing: RUS:TATNP
# Processing: RUS:TCSG
# Processing: DFM:TECOM
# Processing: TADAWUL:1180
# Processing: JSE:TBS
# Processing: BIST:RAYSG
# Processing: TADAWUL:4003
# Processing: JSE:VAL
# Processing: RUS:VTBR
# Processing: JSE:WBC
# Processing: RUS:X5
# []
#                              Security Description Security No. Symbol  \
# 0                                  ABSA GROUP LTD      BFX05H3    ABG
# 1  ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728   ADIB
# 2              ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3   2382
# 3               AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9   1120
# 4        ALDAR PROPERTIES PJSC COMMON STOCK AED 1      B0LX3Y2  ALDAR
#
#   Exchange Currency  Conv Rate Holding  Market Value    SP LC
# 0      JSE      ZAC          1   37303     472905.14  24932.0
# 1      ADX      AED          1   62573     323157.90    23.52
# 2  TADAWUL      SAR          1   83169     295707.01    19.01
# 3  TADAWUL      SAR          1   56152    1124621.69    109.3
# 4      ADX      AED          1  259343     567264.89     8.49

# %%
fx_rates = get_fx_rates(latest_holdings_with_symbols)
display(fx_rates)
# Out:
# {'ZAC': 0.00045025,
#  'AED': 0.20068,
#  'SAR': 0.1949,
#  'USD': 0.738646,
#  'EUR': 0.86994,
#  'RON': 0.170853,
#  'PLN': 0.20506,
#  'RUB': 0.00964,
#  'CHF': 0.942566,
#  'GBP': 1.0,
#  'HUF': 0.002378,
#  'CZK': 0.035687,
#  'QAR': 0.20197,
#  'TRY': 0.016461}

# %%
apply_rates(latest_holdings_with_symbols, fx_rates)
display(latest_holdings_with_symbols.head())
latest_holdings_with_symbols.to_csv("jema_holdings.csv", index=False)
# Out:
#                              Security Description Security No. Symbol  \
# 0                                  ABSA GROUP LTD      BFX05H3    ABG
# 1  ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728   ADIB
# 2              ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3   2382
# 3               AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9   1120
# 4        ALDAR PROPERTIES PJSC COMMON STOCK AED 1      B0LX3Y2  ALDAR
#
#   Exchange Currency  Conv Rate Holding  Market Value    SP LC     SP GBP  \
# 0      JSE      ZAC          1   37303     472905.14  24932.0  11.225633
# 1      ADX      AED          1   62573     323157.90    23.52   4.719994
# 2  TADAWUL      SAR          1   83169     295707.01    19.01   3.705049
# 3  TADAWUL      SAR          1   56152    1124621.69    109.3  21.302570
# 4      ADX      AED          1  259343     567264.89     8.49   1.703773
#
#     Holding GBP
# 0  4.187498e+05
# 1  2.953442e+05
# 2  3.081452e+05
# 3  1.196182e+06
# 4  4.418617e+05

# %%
create_jema_json(latest_holdings_with_symbols, fx_rates, official_nav)

jd = read_jema_json()
display(jd)
display(jd['total_nav_gbp'])
# Out:
# {'total_holding_gbp': 226120124,
#  'equity_nav_gbp': 5.591496636993076,
#  'jema_price': 2.6008,
#  's_account_divs_now_gbp': 57092899,
#  's_account_divs_per_share': 1.4117927546983184,
#  'total_nav_gbp': 7.0032893916913945,
#  'total_holding_rus': 200207433,
#  'total_holding_non': 25912691,
#  'data_timestamp': '2026-04-16T10:50:08.227678',
#  'official_nav': 69.5,
#  'adjusted_nav': 69.02760961918892,
#  'official_pd': 2.7421582733812953,
#  'equity_pd_total': -0.5348651409725921,
#  'actual_pd_total': -0.6286316537075345}
# 7.0032893916913945

# %%
# copy the files to streamlit folderand git add, commit, push
script_dir = "/home/craigc/personal_workspace/FinanceDump/jema"
streamlit_dir = "/home/craigc/personal_workspace/jema-st/"

# cd into streamlit folder and git add, commit, push
os.chdir(streamlit_dir)
os.system("git fetch && git reset --hard @{u}")

shutil.copy(f"{script_dir}/jema_holdings.csv", f"{streamlit_dir}jema_holdings.csv")
shutil.copy(f"{script_dir}/jema_data.json", f"{streamlit_dir}jema_data.json")

os.system("git add jema_holdings.csv jema_data.json")

commit_message = f"Update JEMA data - {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}"
os.system(f'git commit -m "{commit_message}"')
os.system("git push")
os.chdir(script_dir)
# Out:
# HEAD is now at b2b90e2 Update JEMA data - 2026-04-15 12:40:29
# [main c214352] Update JEMA data - 2026-04-16 10:50:09
#  2 files changed, 110 insertions(+), 110 deletions(-)
#  rewrite jema_data.json (99%)
# To github.com-dyler:/jema-st/jema-st
#    b2b90e2..c214352  main -> main
