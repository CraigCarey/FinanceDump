# %%
from jema import (
    get_latest_holdings,
    get_symbols_and_exchanges,
    append_symbols_and_exchanges,
    get_local_prices,
    get_fx_rates,
    apply_rates,
    create_jema_json,
    read_jema_json,
)
# Out:
# you are using nologin method, data you access may be limited

# %%
latest_holdings = get_latest_holdings()
display(latest_holdings.head())
# Out:
#   Holding                               Security Description  Market Value  \
# 0   43170                                     ABSA GROUP LTD     463321.32
# 1  114708     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1     481565.01
# 2  105992                 ADES HOLDING CO COMMON STOCK SAR 1     366401.49
# 3  411462  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983     491398.93
# 4   52919                  AL RAJHI BANK COMMON STOCK SAR 10    1021664.37
#
#   Security No.
# 0      BFX05H3
# 1      6001728
# 2      BR56KM3
# 3      BRBN103
# 4      B12LZH9

# %%
symbols_and_exchanges = get_symbols_and_exchanges()
display(symbols_and_exchanges.head())
# Out:
#                                             Issuer Security No.     Symbol  \
# 0                                   ABSA GROUP LTD      BFX05H3        ABG
# 1                   ABU DHABI COMMERCIAL BANK PJSC      6545464       ADCB
# 2                      ABU DHABI ISLAMIC BANK PJSC      6001728       ADIB
# 3  ABU DHABI NATIONAL OIL CO FOR DISTRIBUTION PJSC      BYVGM64  ADNOCDIST
# 4                                  ADES HOLDING CO      BR56KM3       2382
#
#   Exchange Currency  Conv Rate
# 0      JSE      ZAC          1
# 1      ADX      AED          1
# 2      ADX      AED          1
# 3      ADX      AED          1
# 4  TADAWUL      SAR          1

# %%
latest_holdings_with_symbols = append_symbols_and_exchanges(latest_holdings)
display(latest_holdings_with_symbols.head())
# Out:
#                                 Security Description Security No.   Symbol  \
# 0                                     ABSA GROUP LTD      BFX05H3      ABG
# 1     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728     ADIB
# 2                 ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3     2382
# 3  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983      BRBN103  ADNOCLS
# 4                  AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9     1120
#
#   Exchange Currency  Conv Rate Holding  Market Value
# 0      JSE      ZAC          1   43170     463321.32
# 1      ADX      AED          1  114708     481565.01
# 2  TADAWUL      SAR          1  105992     366401.49
# 3      ADX      AED          1  411462     491398.93
# 4  TADAWUL      SAR          1   52919    1021664.37

# %%
# loop until failures is empty
while True:
    failures = get_local_prices(latest_holdings_with_symbols)
    if not failures:
        break

display(failures)
display(latest_holdings_with_symbols.head())
# Out:
# Processing: JSE:ABG
# Processing: ADX:ADIB
# Processing: TADAWUL:2382
# Processing: ADX:ADNOCLS
# Processing: TADAWUL:1120
# Processing: ADX:ALDAR
# Processing: TADAWUL:4200
# Processing: TADAWUL:2081
# Processing: OTC:APHBF
# Processing: NYSE:AU
# Processing: TADAWUL:1080
# Processing: TADAWUL:4321
# Processing: ATHEX:AIA
# Processing: LSIN:0DP9
# Processing: GETTEX:318
# Processing: LSE:0Q3J
# Processing: JSE:DSY
# Processing: DFM:DIB
# Processing: TADAWUL:7203
# Processing: DFM:EMAARDEV
# Processing: DFM:EMAAR
# Processing: DFM:DU
# Processing: TADAWUL:7020
# Processing: ATHEX:EUROB
# Processing: JSE:FSR
# Processing: RUS:SIBN
# Processing: RUS:GAZP
# Processing: RUS:GAZP
# Processing: LSE:0QQ8
# Processing: LSE:0LV3
# Processing: LSIN:HSBK
# Processing: LSE:0J39
# Processing: FX_IDC:GBPGBP
# Processing: JSE:JSE
# Processing: NASDAQ:KSPI
# Processing: LSIN:0O8D
# Processing: LSIN:0HLK
# Processing: LSIN:0Q3Y
# Processing: OTC:KUMBF
# Processing: RUS:LKOH
# Processing: RUS:LKOH
# Processing: RUS:MGNT
# Processing: RUS:MDMG
# Processing: LSE:MTLN
# Processing: RUS:GMKN
# Processing: LSIN:0RGC
# Processing: LSIN:KAP
# Processing: JSE:NPN
# Processing: LSIN:0RCR
# Processing: KSE:NBK
# Processing: JSE:NED
# Processing: LSE:55VX
# Processing: RUS:NVTK
# Processing: RUS:NVTK
# Processing: RUS:NLMK
# Processing: ATHEX:OPTIMA
# Processing: DFM:PARKIN
# Processing: ATHEX:TPEIR
# Processing: RUS:PLZL
# Processing: GPW:PZU
# Processing: QSE:QGTS
# Processing: QSE:QNBK
# Processing: TADAWUL:1010
# Processing: TADAWUL:4142
# Processing: RUS:ROSN
# Processing: RUS:ROSN
# Processing: RUS:RTKM
# Processing: JSE:SLM
# Processing: ATHEX:SAR
# Processing: JSE:SOL
# Processing: TADAWUL:1060
# Processing: TADAWUL:4031
# Processing: RUS:SBER
# Processing: RUS:SBER
# Processing: RUS:CHMF
# Processing: JSE:SHP
# Processing: JSE:SSW
# Processing: RUS:AFKS
# Processing: JSE:SBK
# Processing: RUS:TATN
# Processing: RUS:TATNP
# Processing: RUS:TCSG
# Processing: DFM:TECOM
# Processing: TADAWUL:1180
# Processing: BIST:TUPRS
# Processing: BIST:THYAO
# Processing: BIST:RAYSG
# Processing: TADAWUL:4003
# Processing: TADAWUL:4260
# Processing: JSE:VAL
# Processing: RUS:VTBR
# Processing: JSE:WBC
# Processing: RUS:X5
# []
#                                 Security Description Security No.   Symbol  \
# 0                                     ABSA GROUP LTD      BFX05H3      ABG
# 1     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728     ADIB
# 2                 ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3     2382
# 3  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983      BRBN103  ADNOCLS
# 4                  AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9     1120
#
#   Exchange Currency  Conv Rate Holding  Market Value    SP LC
# 0      JSE      ZAC          1   43170     463321.32  24287.0
# 1      ADX      AED          1  114708     481565.01    22.92
# 2  TADAWUL      SAR          1  105992     366401.49     17.4
# 3      ADX      AED          1  411462     491398.93      5.7
# 4  TADAWUL      SAR          1   52919    1021664.37    102.7

# %%
fx_rates = get_fx_rates(latest_holdings_with_symbols)
display(fx_rates)
# Out:
# {'ZAC': 0.0004564,
#  'AED': 0.20253,
#  'SAR': 0.1968,
#  'USD': 0.74519,
#  'EUR': 0.87423,
#  'RON': 0.17139,
#  'PLN': 0.20641,
#  'RUB': 0.009617,
#  'CHF': 0.9425,
#  'GBP': 1.0,
#  'CZK': 0.03585,
#  'KWF': 0.002406,
#  'QAR': 0.20433,
#  'TRY': 0.01682}

# %%
apply_rates(latest_holdings_with_symbols, fx_rates)
display(latest_holdings_with_symbols.head())
latest_holdings_with_symbols.to_csv("jema_holdings.csv", index=False)
# Out:
#                                 Security Description Security No.   Symbol  \
# 0                                     ABSA GROUP LTD      BFX05H3      ABG
# 1     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1      6001728     ADIB
# 2                 ADES HOLDING CO COMMON STOCK SAR 1      BR56KM3     2382
# 3  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983      BRBN103  ADNOCLS
# 4                  AL RAJHI BANK COMMON STOCK SAR 10      B12LZH9     1120
#
#   Exchange Currency  Conv Rate Holding  Market Value    SP LC     SP GBP  \
# 0      JSE      ZAC          1   43170     463321.32  24287.0  11.084587
# 1      ADX      AED          1  114708     481565.01    22.92   4.641988
# 2  TADAWUL      SAR          1  105992     366401.49     17.4   3.424320
# 3      ADX      AED          1  411462     491398.93      5.7   1.154421
# 4  TADAWUL      SAR          1   52919    1021664.37    102.7  20.211360
#
#     Holding GBP
# 0  4.785216e+05
# 1  5.324731e+05
# 2  3.629505e+05
# 3  4.750004e+05
# 4  1.069565e+06

# %%
create_jema_json(latest_holdings_with_symbols, fx_rates)

jd = read_jema_json()
display(jd)
display(jd['total_nav_gbp'])
# Out:
# {'total_holding_gbp': 225897626,
#  'equity_nav_gbp': 5.585994708209693,
#  'jema_price': 2.36775,
#  's_account_divs_now_gbp': 54996737,
#  's_account_divs_per_share': 1.3599588773491593,
#  'total_nav_gbp': 6.945953585558852,
#  'total_holding_rus': 199616262,
#  'total_holding_non': 26281364,
#  'data_timestamp': '2026-01-21T13:38:04.476161',
#  'declared_nav': 65.9,
#  'official_pd': 2.5929438543247345,
#  'equity_pd_total': -0.5761274180012852,
#  'actual_pd_total': -0.6591180792047435}
# 6.945953585558852

# %%
# copy the files to streamlit folder
import shutil
streamlit_dir = "/home/craigc/personal_workspace/jema-st/"
shutil.copy("jema_holdings.csv", f"{streamlit_dir}jema_holdings.csv")
shutil.copy("jema_data.json", f"{streamlit_dir}jema_data.json")
# Out:
# '/home/craigc/personal_workspace/jema-st/jema_data.json'

# %%
# cd into streamlit folder and git add, commit, push
import os
script_dir = "/home/craigc/personal_workspace/FinanceDump/jema"
os.chdir(streamlit_dir)
os.system("git pull")
os.system("git add jema_holdings.csv jema_data.json")
os.system('git commit -m "Update JEMA data"')
os.system("git push")
os.chdir(script_dir)
# Out:
# Already up-to-date.
# [main 9bac0b0] Update JEMA data
#  2 files changed, 110 insertions(+), 109 deletions(-)
#  rewrite jema_data.json (99%)
#  rewrite jema_holdings.csv (66%)
# To github.com-dyler:/jema-st/jema-st
#    2a9753a..9bac0b0  main -> main
