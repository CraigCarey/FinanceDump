# %%
import requests

import pandas as pd

import time

print(pd.__version__)

pd.set_option("display.max_columns", None)
pd.set_option("display.max_rows", None)
# pd.set_option('future.no_silent_downcasting', True)
# Out:
# 2.3.3

# %%
# URL of the file to be downloaded
local_filename = 'jpm-emerging-europe-middle-east-afria-disclosure.xlsx'
url = f'https://am.jpmorgan.com/content/dam/jpm-am-aem/emea/gb/en/supplemental/full-portfolio-listing/{local_filename}'

# Send a HTTP GET request to the URL
with requests.get(url, stream=True) as response:
    response.raise_for_status()  # Check for HTTP errors

    # Open a local file with write-binary mode
    with open(local_filename, 'wb') as file:
        for chunk in response.iter_content(chunk_size=8192):
            file.write(chunk)

print(f'File downloaded: {local_filename}')
# Out:
# File downloaded: jpm-emerging-europe-middle-east-afria-disclosure.xlsx

# %%
pc_col = "% of Fund"
market_val_col = "Market Value"
desc_col = 'Security Description'
figi_col = 'FIGI'
isin_col = 'ISIN'
sedol_col = 'SEDOL'
security_col = 'Security No.'
figi_name_col = 'FIGI Name'
figi_ticker_col = 'FIGI Ticker'
figi_exchange_col = 'FIGI Exchange Code'
figi_type_col = 'FIGI Security Type'
figi_market_sector_col = 'FIGI Market Sector'

latest_data = pd.read_excel(local_filename, sheet_name='Jan 2026', skiprows=9, usecols=range(5))
latest_data.drop([pc_col, market_val_col], axis=1, inplace=True)
latest_data.dropna(inplace=True)
latest_data[figi_col] = ''
latest_data[isin_col] = ''
latest_data[isin_col] = ''
latest_data[figi_name_col] = ''
latest_data[figi_ticker_col] = ''
latest_data[figi_exchange_col] = ''
latest_data[figi_type_col] = ''
latest_data[figi_market_sector_col] = ''
latest_data = latest_data.rename(columns={security_col: sedol_col})

display(latest_data.sort_values(by=desc_col))
# Out:
#       Holding                               Security Description    SEDOL  \
# 23      37303                                     ABSA GROUP LTD  BFX05H3
# 42      62573     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1  6001728
# 38      83169                 ADES HOLDING CO COMMON STOCK SAR 1  BR56KM3
# 19     411462  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983  BRBN103
# 1       52919                  AL RAJHI BANK COMMON STOCK SAR 10  B12LZH9
# 13     278047           ALDAR PROPERTIES PJSC COMMON STOCK AED 1  B0LX3Y2
# 77       6921  ALDREES PETROLEUM AND TRANSPORT SERVICES CO CO...  B128FF8
# 62       8582  ALKHORAYEF WATER & POWER TECHNOLOGIES CO COMMO...  BN33QN1
# 48      83221                 ALPHA BANK SA COMMON STOCK EUR 0.3  BTJZ707
# 53       3669                          ANGLOGOLD ASHANTI PLC ZAR  BRXH266
# 81      30202             ARAB NATIONAL BANK COMMON STOCK SAR 10  B12LZK2
# 36      84990             ARABIAN CENTRES CO COMMON STOCK SAR 10  BKBF694
# 63      20939  ATHENS INTERNATIONAL AIRPORT SA COMMON STOCK E...  BPYS8N3
# 64      36498           BANCA TRANSILVANIA SA COMMON STOCK RON 1  5393307
# 31      42976   BANK OF CYPRUS HOLDINGS PLC COMMON STOCK EUR 0.1  BN2BZT5
# 24        536              BENEFIT SYSTEMS SA COMMON STOCK PLN 1  B4XY9X2
# 51      24432                 DISCOVERY LTD COMMON STOCK ZAR 0.1  6177878
# 32     180593         DUBAI ISLAMIC BANK PJSC COMMON STOCK AED 1  6283452
# 70      68742      ELECTRICAL INDUSTRIES CO COMMON STOCK SAR 0.5  BSMSY94
# 68       1219                         ELM CO COMMON STOCK SAR 10  BNYDSH8
# 34      97455          EMAAR DEVELOPMENT PJSC COMMON STOCK AED 1  BDG1977
# 10     196579           EMAAR PROPERTIES PJSC COMMON STOCK AED 1  B01RM25
# 56     115911  EMIRATES INTEGRATED TELECOMMUNICATIONS CO PJSC...  B13TMN7
# 29      27826             ETIHAD ETISALAT CO COMMON STOCK SAR 10  B12LR51
# 33      93766                  EUROBANK SA COMMON STOCK EUR 0.22  BW9DW63
# 8      145007                   FIRSTRAND LTD COMMON STOCK ZAR 1  6606996
# 98     577525                            FIX PRICE GROUP LTD GDR  X84CF24
# 89    1265335                 GAZPROM NEFT PJSC COMMON STOCK RUB  X84D1F6
# 60    5365084                                   GAZPROM PJSC ADR  X84C976
# 59    8860909                      GAZPROM PJSC COMMON STOCK RUB  X8C529A
# 2       26569                GOLD FIELDS LTD COMMON STOCK ZAR 50  6280215
# 52       1210                 GRUPA KETY SA COMMON STOCK PLN 2.5  5216385
# 9       25227       HALYK SAVINGS BANK OF KAZAKHSTAN JSC GDR USD  B1KDG41
# 18      27699     HARMONY GOLD MINING CO LTD COMMON STOCK ZAR 50  6410562
# 25      28699    IMPALA PLATINUM HOLDINGS LTD COMMON STOCK ZAR 0  B1FFT76
# 101   1011.54                  JPM USD LIQUIDITY LVNAV X (DIST.)  7253766
# 47      43588                                            JSE LTD  B12W5L6
# 20       8223           KASPI.KZ JSC - ADR (SPONSORED) LEVEL III  BJY21K1
# 6       10004           KGHM POLSKA MIEDZ SA COMMON STOCK PLN 10  5263251
# 26       2055              KRKA DD NOVO MESTO COMMON STOCK EUR 1  5157235
# 40       3037                         KRUK SA COMMON STOCK PLN 1  B4PTLY0
# 39      18739           KUMBA IRON ORE LTD COMMON STOCK ZAR 0.01  B1G4262
# 45     262047                       LUKOIL PJSC COMMON STOCK RUB  X84D1F5
# 44     362649             LUKOIL PJSC COMMON STOCK RUB 0.025 RUB  X84C974
# 88     180877                  MAGNIT PJSC COMMON STOCK RUB 0.01  X8C505A
# 96     432517           MD MEDICAL GROUP INVESTMENTS PLC GDR USD  X8C6397
# 30       9516      METLEN ENERGY & METALS PLC COMMON STOCK EUR 1  BTQGS77
# 82    7119200         MMC NORILSK NICKEL PJSC COMMON STOCK RUB 1  X84C977
# 72      23477           MONETA MONEY BANK AS COMMON STOCK CZK 20  BD3CQ16
# 11       9743                        NAC KAZATOMPROM JSC GDR USD  BGXQL36
# 5       16183                     NASPERS LTD COMMON STOCK ZAR 2  BV2FFX7
# 27      31425      NATIONAL BANK OF GREECE SA COMMON STOCK EUR 1  BG087C6
# 17     206580  NATIONAL BANK OF KUWAIT SAKP COMMON STOCK KWD 100  6889526
# 21      35976             NEDBANK GROUP LTD COMMON STOCK ZAR 100  6628008
# 50      15071     NORTHAM PLATINUM HOLDINGS LTD COMMON STOCK ZAR  BMZ1NS0
# 15      14767                  NOVA LJUBLJANSKA BANKA DD GDR EUR  BGRPD22
# 74    1268490                  NOVATEK PJSC COMMON STOCK RUB 0.1  X84C972
# 75     103572                  NOVATEK PJSC COMMON STOCK RUB 0.1  X84C970
# 87    3657350            NOVOLIPETSK STEEL PJSC COMMON STOCK RUB  X84C97E
# 22      57840               OPTIMA BANK SA COMMON STOCK EUR 3.45  BL571C1
# 58     178126               PARKIN CO PJSC COMMON STOCK AED 0.02  BRRGQF6
# 41      41300              PIRAEUS BANK SA COMMON STOCK EUR 0.93  BVLKBV3
# 95     297730                       POLYUS PJSC COMMON STOCK RUB  X84D1F8
# 35      22525  POWSZECHNY ZAKLAD UBEZPIECZEN SA COMMON STOCK ...  B63DG21
# 54     257026      QATAR GAS TRANSPORT CO LTD COMMON STOCK QAR 1  B0MLBC9
# 4      185253        QATAR NATIONAL BANK QPSC COMMON STOCK QAR 1  6148197
# 43      54728                     RIYAD BANK COMMON STOCK SAR 10  B12LZW4
# 57       8636         RIYADH CABLES GROUP CO COMMON STOCK SAR 10  BNBPXW7
# 84    1677948               ROSNEFT OIL CO PJSC COMMON STOCK RUB  X84D1F9
# 83    2041744          ROSNEFT OIL CO PJSC COMMON STOCK RUB 0.01  X84C971
# 93    6156103                   ROSTELECOM PJSC COMMON STOCK RUB  X84C978
# 37      69192                      SANLAM LTD COMMON STOCK ZAR 1  B0L6750
# 49      24341                                SARANTIS SA EUR1.53  7124958
# 16      90498                       SASOL LTD COMMON STOCK ZAR 0  6777450
# 69      26440               SAUDI AWWAL BANK COMMON STOCK SAR 10  B12LSY7
# 80      20014       SAUDI GROUND SERVICES CO COMMON STOCK SAR 10  BYYTJ69
# 66    2355925                            SBERBANK OF RUSSIA PJSC  X8C6398
# 65   14455036           SBERBANK OF RUSSIA PJSC PREFERENCE RUB 3  X8C6155
# 102    552780                              SEVERSTAL PAO GDR USD  X84C975
# 28      33424       SHOPRITE HOLDINGS LTD COMMON STOCK ZAR 113.4  6801575
# 14     141197            SIBANYE STILLWATER LTD COMMON STOCK ZAR  BL0L913
# 97   12313057                SISTEMA PJSFC COMMON STOCK RUB 0.09  X84D1F7
# 7       45628        STANDARD BANK GROUP LTD COMMON STOCK ZAR 10  B030GJ7
# 90     730066                      TATNEFT PJSC COMMON STOCK RUB  X84C973
# 91     571359                      TATNEFT PJSC PREFERENCE RUB 1  X8C6150
# 99      75226                          TCS GROUP HOLDING PLC GDR  X8C4FD3
# 73     228871              TECOM GROUP PJSC COMMON STOCK AED 0.1  BLDC8Q1
# 3       97150                            THE SAUDI NATIONAL BANK  BSHYYN1
# 71      11872               TIGER BRANDS LTD COMMON STOCK ZAR 10  B0J4PP2
# 78     737944              TURKIYE SIGORTA AS COMMON STOCK TRY 1  B03MTD8
# 55      14337             UNITED ELECTRONICS CO COMMON STOCK SAR  B4P2SD7
# 86       6420  UNITED INTERNATIONAL TRANSPORTATION CO COMMON ...  B2493D0
# 12       7775          VALTERRA PLATINUM LTD COMMON STOCK ZAR 10  6761000
# 94    4246654                VTB BANK PJSC COMMON STOCK RUB 0.01  X8C6392
# 79      72103          WE BUY CARS HOLDINGS LTD COMMON STOCK ZAR  BSB8C80
# 100    275182                       X 5 RETAIL GROUP NV-REGS GDR  X8C4FD9
#
#     FIGI ISIN FIGI Name FIGI Ticker FIGI Exchange Code FIGI Security Type  \
# 23
# 42
# 38
# 19
# 1
# 13
# 77
# 62
# 48
# 53
# 81
# 36
# 63
# 64
# 31
# 24
# 51
# 32
# 70
# 68
# 34
# 10
# 56
# 29
# 33
# 8
# 98
# 89
# 60
# 59
# 2
# 52
# 9
# 18
# 25
# 101
# 47
# 20
# 6
# 26
# 40
# 39
# 45
# 44
# 88
# 96
# 30
# 82
# 72
# 11
# 5
# 27
# 17
# 21
# 50
# 15
# 74
# 75
# 87
# 22
# 58
# 41
# 95
# 35
# 54
# 4
# 43
# 57
# 84
# 83
# 93
# 37
# 49
# 16
# 69
# 80
# 66
# 65
# 102
# 28
# 14
# 97
# 7
# 90
# 91
# 99
# 73
# 3
# 71
# 78
# 55
# 86
# 12
# 94
# 79
# 100
#
#     FIGI Market Sector
# 23
# 42
# 38
# 19
# 1
# 13
# 77
# 62
# 48
# 53
# 81
# 36
# 63
# 64
# 31
# 24
# 51
# 32
# 70
# 68
# 34
# 10
# 56
# 29
# 33
# 8
# 98
# 89
# 60
# 59
# 2
# 52
# 9
# 18
# 25
# 101
# 47
# 20
# 6
# 26
# 40
# 39
# 45
# 44
# 88
# 96
# 30
# 82
# 72
# 11
# 5
# 27
# 17
# 21
# 50
# 15
# 74
# 75
# 87
# 22
# 58
# 41
# 95
# 35
# 54
# 4
# 43
# 57
# 84
# 83
# 93
# 37
# 49
# 16
# 69
# 80
# 66
# 65
# 102
# 28
# 14
# 97
# 7
# 90
# 91
# 99
# 73
# 3
# 71
# 78
# 55
# 86
# 12
# 94
# 79
# 100

# %%
def read_api_key(file_path):
    try:
        with open(file_path, 'r') as file:
            api_key = file.read().strip()
            return api_key
    except FileNotFoundError:
        print(f"Error: The file '{file_path}' does not exist.")
        return None
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

api_key_file = "/home/craigc/.keys/openfigi"
api_key = read_api_key(api_key_file)

if api_key:
    print("API Key read successfully.")
else:
    print("Failed to read the API Key.")
# Out:
# API Key read successfully.

# %%
def query_openfigi_by_sedol(api_key, sedol):
    url = "https://api.openfigi.com/v3/mapping"
    headers = {
        'Content-Type': 'application/json',
        'X-OPENFIGI-APIKEY': api_key
    }
    payload = [
        {
            "idType": "ID_SEDOL",
            "idValue": sedol
        }
    ]
    try:
        response = requests.post(url, json=payload, headers=headers)
        response.raise_for_status()
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None
    
sedol = "BFX05H3"

result = query_openfigi_by_sedol(api_key, sedol)
if result:
    print(result)
# Out:
# [{'data': [{'figi': 'BBG000BF9DG8', 'name': 'ABSA GROUP LTD', 'ticker': 'ABG', 'exchCode': 'SJ', 'compositeFIGI': 'BBG000BF9C25', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001S7JF34', 'securityType2': 'Common Stock', 'securityDescription': 'ABG'}]}]

# %%
def query_openfigi_by_isin(api_key, isin):
    url = "https://api.openfigi.com/v3/mapping"
    headers = {
        'Content-Type': 'application/json',
        'X-OPENFIGI-APIKEY': api_key
    }
    payload = [
        {
            "idType": "ID_ISIN",
            "idValue": isin
        }
    ]
    try:
        response = requests.post(url, json=payload, headers=headers)
        response.raise_for_status()
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        print(f"An error occurred: {e}")
        return None

isin = "RU000A0JNAA8"

result = query_openfigi_by_isin(api_key, isin)
if result:
    print(result)
# Out:
# [{'data': [{'figi': 'BBG000C2KNG1', 'name': 'POLYUS PJSC', 'ticker': 'PLZL', 'exchCode': 'RU', 'compositeFIGI': 'BBG000C2KNG1', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL'}, {'figi': 'BBG000C2KNM4', 'name': 'POLYUS PJSC', 'ticker': 'PLZL', 'exchCode': 'RR', 'compositeFIGI': 'BBG000C2KNG1', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL'}, {'figi': 'BBG000R607Y3', 'name': 'POLYUS PJSC', 'ticker': 'PLZL', 'exchCode': 'RM', 'compositeFIGI': 'BBG000R607Y3', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL'}, {'figi': 'BBG000R60844', 'name': 'POLYUS PJSC', 'ticker': 'PLZL', 'exchCode': 'RX', 'compositeFIGI': 'BBG000R607Y3', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL'}, {'figi': 'BBG000R608V4', 'name': 'POLYUS PJSC', 'ticker': 'PLZL', 'exchCode': 'RN', 'compositeFIGI': 'BBG000R607Y3', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL'}, {'figi': 'BBG000R609J6', 'name': 'POLYUS PJSC', 'ticker': 'PLZL', 'exchCode': 'RP', 'compositeFIGI': 'BBG000R607Y3', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL'}, {'figi': 'BBG00JSB9SW7', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'EO', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9SZ4', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XH', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9T19', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XF', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9T37', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XE', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9T46', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XJ', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9T55', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XL', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9T64', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XG', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9T73', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XO', 'compositeFIGI': 'BBG00JSB9SW7', 'securityType': 'Common Stock', 'marketSector': 'Equity', 'shareClassFIGI': 'BBG001SDNL24', 'securityType2': 'Common Stock', 'securityDescription': 'PLZL1USD'}, {'figi': 'BBG00JSB9TD6', 'name': 'POLYUS PJSC', 'ticker': 'PLZL1USD', 'exchCode': 'XA', ' ...

# %%
# For some reason JPM have fucked up the SEDOLS from Oct 2024 onwards
sedol_map = {
    "X84C974": "B59SNS8",
    "X84D1F5": "B59SNS8",
    "X8C529A": "4364928",
    "X84C976": "4364928",
    "X8C6155": "4767981",
    "X8C6398": "4767981",
    "X84C972": "B59HPK1",
    "X84C970": "B59HPK1",
    "X84C977": "B5B1TX2",
    "X84C971": "B59SS16",
    "X84D1F9": "B59SS16",
    "X84C97E": "B59FPC7",
    "X8C505A": "B59GLW2",
    "X84D1F6": "B59L417",
    "X84C973": "B5B1TJ8",
    "X8C6150": "B5B1TJ8",
    "X84C978": "2150259",
    "X8C6392": "B5B1TP4",
    "X84D1F8": "B57R0L9",
    # "X8C6397": "",
    # "X84D1F7": "",
    # "X84CF24": "",
    # "X8C4FD3": "",
    # "X8C4FD9": "",
    # "X84C975": "",
}

isin_map = {
    "X8C6397":"RU000A108KL3",
    "X84D1F7": "RU000A0DQZE3",
    "X84CF24": "US33835G2057",
    "X8C4FD3": "RU000A107UL4",
    "X8C4FD9": "RU0009046510",
    "X84C975": "RU0009046510",
}

# seen_sedols = {}

# for k, v in sedol_map.items():
#     sedol = v
#     if sedol == "":
#         r = latest_data[latest_data[sedol_col] == k].iloc[0]
#         display(f"sedol: {k} - {r[desc_col]}")
#     else:
#         print(f"Processing SEDOL {sedol}...")
#         row = latest_data[latest_data[sedol_col] == k].iloc[0]
#         result = query_openfigi_by_sedol(api_key, sedol)
#         display(result)

# for k, v in isin_map.items():
#     isin = v
#     if isin == "":
#         r = latest_data[latest_data[sedol_col] == k].iloc[0]
#         display(f"isin: {k} - {r[desc_col]}")
#     else:
#         print(f"Processing ISIN {isin}...")sedol_map[sedol]
#         row = latest_data[latest_data[sedol_col] == k].iloc[0]
#         result = query_openfigi_by_isin(api_key, isin)
#         display(result)

# %%
for _, row in latest_data.iterrows():
    sedol = row[sedol_col]

    # Fix fucked SEDOLS
    if sedol in sedol_map:
        row[sedol_col] = sedol_map[sedol]
        sedol = sedol_map[sedol]

    use_isin = False
    if sedol in isin_map:
        row[sedol_col] = ""
        row[isin_col] = isin_map[sedol]
        isin = isin_map[sedol]
        use_isin = True

    # if sedol in seen_sedols:
    #     continue


    desc = row[desc_col]

    if use_isin:
        print(f"Processing ISIN {isin} for {desc}...")
        result = query_openfigi_by_isin(api_key, isin)
    else:
        print(f"Processing SEDOL {sedol} for {desc}...")
        result = query_openfigi_by_sedol(api_key, sedol)
    
    try: 
        row[figi_col] = result[0]['data'][0]['figi']
        row[figi_name_col] = result[0]['data'][0]['name']
        row[figi_ticker_col] = result[0]['data'][0]['ticker']
        row[figi_exchange_col] = result[0]['data'][0]['exchCode']
        row[figi_type_col] = result[0]['data'][0]['figi']
        row[figi_market_sector_col] = result[0]['data'][0]['marketSector']
    except Exception as e:
        print(f"Error processing SEDOL {sedol}: {e}")
    # seen_sedols[sedol] = True
    time.sleep(6/25)


display(latest_data)
# Out:
# Processing SEDOL B12LZH9 for AL RAJHI BANK COMMON STOCK SAR 10...
# Processing SEDOL 6280215 for GOLD FIELDS LTD COMMON STOCK ZAR 50...
# Processing SEDOL BSHYYN1 for THE SAUDI NATIONAL BANK...
# Processing SEDOL 6148197 for QATAR NATIONAL BANK QPSC COMMON STOCK QAR 1...
# Processing SEDOL BV2FFX7 for NASPERS LTD COMMON STOCK ZAR 2...
# Processing SEDOL 5263251 for KGHM POLSKA MIEDZ SA COMMON STOCK PLN 10...
# Processing SEDOL B030GJ7 for STANDARD BANK GROUP LTD COMMON STOCK ZAR 10...
# Processing SEDOL 6606996 for FIRSTRAND LTD COMMON STOCK ZAR 1...
# Processing SEDOL B1KDG41 for HALYK SAVINGS BANK OF KAZAKHSTAN JSC GDR USD...
# Processing SEDOL B01RM25 for EMAAR PROPERTIES PJSC COMMON STOCK AED 1...
# Processing SEDOL BGXQL36 for NAC KAZATOMPROM JSC GDR USD...
# Processing SEDOL 6761000 for VALTERRA PLATINUM LTD COMMON STOCK ZAR 10...
# Processing SEDOL B0LX3Y2 for ALDAR PROPERTIES PJSC COMMON STOCK AED 1...
# Processing SEDOL BL0L913 for SIBANYE STILLWATER LTD COMMON STOCK ZAR...
# Processing SEDOL BGRPD22 for NOVA LJUBLJANSKA BANKA DD GDR EUR...
# Processing SEDOL 6777450 for SASOL LTD COMMON STOCK ZAR 0...
# Processing SEDOL 6889526 for NATIONAL BANK OF KUWAIT SAKP COMMON STOCK KWD 100...
# Processing SEDOL 6410562 for HARMONY GOLD MINING CO LTD COMMON STOCK ZAR 50...
# Processing SEDOL BRBN103 for ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983...
# Processing SEDOL BJY21K1 for KASPI.KZ JSC - ADR (SPONSORED) LEVEL III...
# Processing SEDOL 6628008 for NEDBANK GROUP LTD COMMON STOCK ZAR 100...
# Processing SEDOL BL571C1 for OPTIMA BANK SA COMMON STOCK EUR 3.45...
# Processing SEDOL BFX05H3 for ABSA GROUP LTD...
# Processing SEDOL B4XY9X2 for BENEFIT SYSTEMS SA COMMON STOCK PLN 1...
# Processing SEDOL B1FFT76 for IMPALA PLATINUM HOLDINGS LTD COMMON STOCK ZAR 0...
# Processing SEDOL 5157235 for KRKA DD NOVO MESTO COMMON STOCK EUR 1...
# Processing SEDOL BG087C6 for NATIONAL BANK OF GREECE SA COMMON STOCK EUR 1...
# Processing SEDOL 6801575 for SHOPRITE HOLDINGS LTD COMMON STOCK ZAR 113.4...
# Processing SEDOL B12LR51 for ETIHAD ETISALAT CO COMMON STOCK SAR 10...
# Processing SEDOL BTQGS77 for METLEN ENERGY & METALS PLC COMMON STOCK EUR 1...
# Processing SEDOL BN2BZT5 for BANK OF CYPRUS HOLDINGS PLC COMMON STOCK EUR 0.1...
# Processing SEDOL 6283452 for DUBAI ISLAMIC BANK PJSC COMMON STOCK AED 1...
# Processing SEDOL BW9DW63 for EUROBANK SA COMMON STOCK EUR 0.22...
# Processing SEDOL BDG1977 for EMAAR DEVELOPMENT PJSC COMMON STOCK AED 1...
# Processing SEDOL B63DG21 for POWSZECHNY ZAKLAD UBEZPIECZEN SA COMMON STOCK PLN 0.1...
# Processing SEDOL BKBF694 for ARABIAN CENTRES CO COMMON STOCK SAR 10...
# Processing SEDOL B0L6750 for SANLAM LTD COMMON STOCK ZAR 1...
# Processing SEDOL BR56KM3 for ADES HOLDING CO COMMON STOCK SAR 1...
# Processing SEDOL B1G4262 for KUMBA IRON ORE LTD COMMON STOCK ZAR 0.01...
# Processing SEDOL B4PTLY0 for KRUK SA COMMON STOCK PLN 1...
# Processing SEDOL BVLKBV3 for PIRAEUS BANK SA COMMON STOCK EUR 0.93...
# Processing SEDOL 6001728 for ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1...
# Processing SEDOL B12LZW4 for RIYAD BANK COMMON STOCK SAR 10...
# Processing SEDOL B59SNS8 for LUKOIL PJSC COMMON STOCK RUB 0.025 RUB...
# Processing SEDOL B59SNS8 for LUKOIL PJSC COMMON STOCK RUB...
# Processing SEDOL B12W5L6 for JSE LTD...
# Processing SEDOL BTJZ707 for ALPHA BANK SA COMMON STOCK EUR 0.3...
# Processing SEDOL 7124958 for SARANTIS SA EUR1.53...
# Processing SEDOL BMZ1NS0 for NORTHAM PLATINUM HOLDINGS LTD COMMON STOCK ZAR...
# Processing SEDOL 6177878 for DISCOVERY LTD COMMON STOCK ZAR 0.1...
# Processing SEDOL 5216385 for GRUPA KETY SA COMMON STOCK PLN 2.5...
# Processing SEDOL BRXH266 for ANGLOGOLD ASHANTI PLC ZAR...
# Processing SEDOL B0MLBC9 for QATAR GAS TRANSPORT CO LTD COMMON STOCK QAR 1...
# Processing SEDOL B4P2SD7 for UNITED ELECTRONICS CO COMMON STOCK SAR...
# Processing SEDOL B13TMN7 for EMIRATES INTEGRATED TELECOMMUNICATIONS CO PJSC COMMON STOCK AED 1...
# Processing SEDOL BNBPXW7 for RIYADH CABLES GROUP CO COMMON STOCK SAR 10...
# Processing SEDOL BRRGQF6 for PARKIN CO PJSC COMMON STOCK AED 0.02...
# Processing SEDOL 4364928 for GAZPROM PJSC COMMON STOCK RUB...
# Processing SEDOL 4364928 for GAZPROM PJSC ADR...
# Processing SEDOL BN33QN1 for ALKHORAYEF WATER & POWER TECHNOLOGIES CO COMMON STOCK SAR 10...
# Processing SEDOL BPYS8N3 for ATHENS INTERNATIONAL AIRPORT SA COMMON STOCK EUR 1...
# Processing SEDOL 5393307 for BANCA TRANSILVANIA SA COMMON STOCK RON 1...
# Processing SEDOL 4767981 for SBERBANK OF RUSSIA PJSC PREFERENCE RUB 3...
# Processing SEDOL 4767981 for SBERBANK OF RUSSIA PJSC...
# Processing SEDOL BNYDSH8 for ELM CO COMMON STOCK SAR 10...
# Processing SEDOL B12LSY7 for SAUDI AWWAL BANK COMMON STOCK SAR 10...
# Processing SEDOL BSMSY94 for ELECTRICAL INDUSTRIES CO COMMON STOCK SAR 0.5...
# Processing SEDOL B0J4PP2 for TIGER BRANDS LTD COMMON STOCK ZAR 10...
# Processing SEDOL BD3CQ16 for MONETA MONEY BANK AS COMMON STOCK CZK 20...
# Processing SEDOL BLDC8Q1 for TECOM GROUP PJSC COMMON STOCK AED 0.1...
# Processing SEDOL B59HPK1 for NOVATEK PJSC COMMON STOCK RUB 0.1...
# Processing SEDOL B59HPK1 for NOVATEK PJSC COMMON STOCK RUB 0.1...
# Processing SEDOL B128FF8 for ALDREES PETROLEUM AND TRANSPORT SERVICES CO COMMON STOCK SAR 10...
# Processing SEDOL B03MTD8 for TURKIYE SIGORTA AS COMMON STOCK TRY 1...
# Processing SEDOL BSB8C80 for WE BUY CARS HOLDINGS LTD COMMON STOCK ZAR...
# Processing SEDOL BYYTJ69 for SAUDI GROUND SERVICES CO COMMON STOCK SAR 10...
# Processing SEDOL B12LZK2 for ARAB NATIONAL BANK COMMON STOCK SAR 10...
# Processing SEDOL B5B1TX2 for MMC NORILSK NICKEL PJSC COMMON STOCK RUB 1...
# Processing SEDOL B59SS16 for ROSNEFT OIL CO PJSC COMMON STOCK RUB 0.01...
# Processing SEDOL B59SS16 for ROSNEFT OIL CO PJSC COMMON STOCK RUB...
# Processing SEDOL B2493D0 for UNITED INTERNATIONAL TRANSPORTATION CO COMMON STOCK SAR 10...
# Processing SEDOL B59FPC7 for NOVOLIPETSK STEEL PJSC COMMON STOCK RUB...
# Processing SEDOL B59GLW2 for MAGNIT PJSC COMMON STOCK RUB 0.01...
# Processing SEDOL B59L417 for GAZPROM NEFT PJSC COMMON STOCK RUB...
# Processing SEDOL B5B1TJ8 for TATNEFT PJSC COMMON STOCK RUB...
# Processing SEDOL B5B1TJ8 for TATNEFT PJSC PREFERENCE RUB 1...
# Processing SEDOL 2150259 for ROSTELECOM PJSC COMMON STOCK RUB...
# Processing SEDOL B5B1TP4 for VTB BANK PJSC COMMON STOCK RUB 0.01...
# Processing SEDOL B57R0L9 for POLYUS PJSC COMMON STOCK RUB...
# Processing ISIN RU000A108KL3 for MD MEDICAL GROUP INVESTMENTS PLC GDR USD...
# Processing ISIN RU000A0DQZE3 for SISTEMA PJSFC COMMON STOCK RUB 0.09...
# Processing ISIN US33835G2057 for FIX PRICE GROUP LTD GDR...
# Processing ISIN RU000A107UL4 for TCS GROUP HOLDING PLC GDR...
# Processing ISIN RU0009046510 for X 5 RETAIL GROUP NV-REGS GDR...
# Processing SEDOL 7253766 for JPM USD LIQUIDITY LVNAV X (DIST.)...
# Processing ISIN RU0009046510 for SEVERSTAL PAO GDR USD...
#       Holding                               Security Description    SEDOL  \
# 1       52919                  AL RAJHI BANK COMMON STOCK SAR 10  B12LZH9
# 2       26569                GOLD FIELDS LTD COMMON STOCK ZAR 50  6280215
# 3       97150                            THE SAUDI NATIONAL BANK  BSHYYN1
# 4      185253        QATAR NATIONAL BANK QPSC COMMON STOCK QAR 1  6148197
# 5       16183                     NASPERS LTD COMMON STOCK ZAR 2  BV2FFX7
# 6       10004           KGHM POLSKA MIEDZ SA COMMON STOCK PLN 10  5263251
# 7       45628        STANDARD BANK GROUP LTD COMMON STOCK ZAR 10  B030GJ7
# 8      145007                   FIRSTRAND LTD COMMON STOCK ZAR 1  6606996
# 9       25227       HALYK SAVINGS BANK OF KAZAKHSTAN JSC GDR USD  B1KDG41
# 10     196579           EMAAR PROPERTIES PJSC COMMON STOCK AED 1  B01RM25
# 11       9743                        NAC KAZATOMPROM JSC GDR USD  BGXQL36
# 12       7775          VALTERRA PLATINUM LTD COMMON STOCK ZAR 10  6761000
# 13     278047           ALDAR PROPERTIES PJSC COMMON STOCK AED 1  B0LX3Y2
# 14     141197            SIBANYE STILLWATER LTD COMMON STOCK ZAR  BL0L913
# 15      14767                  NOVA LJUBLJANSKA BANKA DD GDR EUR  BGRPD22
# 16      90498                       SASOL LTD COMMON STOCK ZAR 0  6777450
# 17     206580  NATIONAL BANK OF KUWAIT SAKP COMMON STOCK KWD 100  6889526
# 18      27699     HARMONY GOLD MINING CO LTD COMMON STOCK ZAR 50  6410562
# 19     411462  ADNOC LOGISTICS & SERVICES COMMON STOCK AED 1.983  BRBN103
# 20       8223           KASPI.KZ JSC - ADR (SPONSORED) LEVEL III  BJY21K1
# 21      35976             NEDBANK GROUP LTD COMMON STOCK ZAR 100  6628008
# 22      57840               OPTIMA BANK SA COMMON STOCK EUR 3.45  BL571C1
# 23      37303                                     ABSA GROUP LTD  BFX05H3
# 24        536              BENEFIT SYSTEMS SA COMMON STOCK PLN 1  B4XY9X2
# 25      28699    IMPALA PLATINUM HOLDINGS LTD COMMON STOCK ZAR 0  B1FFT76
# 26       2055              KRKA DD NOVO MESTO COMMON STOCK EUR 1  5157235
# 27      31425      NATIONAL BANK OF GREECE SA COMMON STOCK EUR 1  BG087C6
# 28      33424       SHOPRITE HOLDINGS LTD COMMON STOCK ZAR 113.4  6801575
# 29      27826             ETIHAD ETISALAT CO COMMON STOCK SAR 10  B12LR51
# 30       9516      METLEN ENERGY & METALS PLC COMMON STOCK EUR 1  BTQGS77
# 31      42976   BANK OF CYPRUS HOLDINGS PLC COMMON STOCK EUR 0.1  BN2BZT5
# 32     180593         DUBAI ISLAMIC BANK PJSC COMMON STOCK AED 1  6283452
# 33      93766                  EUROBANK SA COMMON STOCK EUR 0.22  BW9DW63
# 34      97455          EMAAR DEVELOPMENT PJSC COMMON STOCK AED 1  BDG1977
# 35      22525  POWSZECHNY ZAKLAD UBEZPIECZEN SA COMMON STOCK ...  B63DG21
# 36      84990             ARABIAN CENTRES CO COMMON STOCK SAR 10  BKBF694
# 37      69192                      SANLAM LTD COMMON STOCK ZAR 1  B0L6750
# 38      83169                 ADES HOLDING CO COMMON STOCK SAR 1  BR56KM3
# 39      18739           KUMBA IRON ORE LTD COMMON STOCK ZAR 0.01  B1G4262
# 40       3037                         KRUK SA COMMON STOCK PLN 1  B4PTLY0
# 41      41300              PIRAEUS BANK SA COMMON STOCK EUR 0.93  BVLKBV3
# 42      62573     ABU DHABI ISLAMIC BANK PJSC COMMON STOCK AED 1  6001728
# 43      54728                     RIYAD BANK COMMON STOCK SAR 10  B12LZW4
# 44     362649             LUKOIL PJSC COMMON STOCK RUB 0.025 RUB  B59SNS8
# 45     262047                       LUKOIL PJSC COMMON STOCK RUB  B59SNS8
# 47      43588                                            JSE LTD  B12W5L6
# 48      83221                 ALPHA BANK SA COMMON STOCK EUR 0.3  BTJZ707
# 49      24341                                SARANTIS SA EUR1.53  7124958
# 50      15071     NORTHAM PLATINUM HOLDINGS LTD COMMON STOCK ZAR  BMZ1NS0
# 51      24432                 DISCOVERY LTD COMMON STOCK ZAR 0.1  6177878
# 52       1210                 GRUPA KETY SA COMMON STOCK PLN 2.5  5216385
# 53       3669                          ANGLOGOLD ASHANTI PLC ZAR  BRXH266
# 54     257026      QATAR GAS TRANSPORT CO LTD COMMON STOCK QAR 1  B0MLBC9
# 55      14337             UNITED ELECTRONICS CO COMMON STOCK SAR  B4P2SD7
# 56     115911  EMIRATES INTEGRATED TELECOMMUNICATIONS CO PJSC...  B13TMN7
# 57       8636         RIYADH CABLES GROUP CO COMMON STOCK SAR 10  BNBPXW7
# 58     178126               PARKIN CO PJSC COMMON STOCK AED 0.02  BRRGQF6
# 59    8860909                      GAZPROM PJSC COMMON STOCK RUB  4364928
# 60    5365084                                   GAZPROM PJSC ADR  4364928
# 62       8582  ALKHORAYEF WATER & POWER TECHNOLOGIES CO COMMO...  BN33QN1
# 63      20939  ATHENS INTERNATIONAL AIRPORT SA COMMON STOCK E...  BPYS8N3
# 64      36498           BANCA TRANSILVANIA SA COMMON STOCK RON 1  5393307
# 65   14455036           SBERBANK OF RUSSIA PJSC PREFERENCE RUB 3  4767981
# 66    2355925                            SBERBANK OF RUSSIA PJSC  4767981
# 68       1219                         ELM CO COMMON STOCK SAR 10  BNYDSH8
# 69      26440               SAUDI AWWAL BANK COMMON STOCK SAR 10  B12LSY7
# 70      68742      ELECTRICAL INDUSTRIES CO COMMON STOCK SAR 0.5  BSMSY94
# 71      11872               TIGER BRANDS LTD COMMON STOCK ZAR 10  B0J4PP2
# 72      23477           MONETA MONEY BANK AS COMMON STOCK CZK 20  BD3CQ16
# 73     228871              TECOM GROUP PJSC COMMON STOCK AED 0.1  BLDC8Q1
# 74    1268490                  NOVATEK PJSC COMMON STOCK RUB 0.1  B59HPK1
# 75     103572                  NOVATEK PJSC COMMON STOCK RUB 0.1  B59HPK1
# 77       6921  ALDREES PETROLEUM AND TRANSPORT SERVICES CO CO...  B128FF8
# 78     737944              TURKIYE SIGORTA AS COMMON STOCK TRY 1  B03MTD8
# 79      72103          WE BUY CARS HOLDINGS LTD COMMON STOCK ZAR  BSB8C80
# 80      20014       SAUDI GROUND SERVICES CO COMMON STOCK SAR 10  BYYTJ69
# 81      30202             ARAB NATIONAL BANK COMMON STOCK SAR 10  B12LZK2
# 82    7119200         MMC NORILSK NICKEL PJSC COMMON STOCK RUB 1  B5B1TX2
# 83    2041744          ROSNEFT OIL CO PJSC COMMON STOCK RUB 0.01  B59SS16
# 84    1677948               ROSNEFT OIL CO PJSC COMMON STOCK RUB  B59SS16
# 86       6420  UNITED INTERNATIONAL TRANSPORTATION CO COMMON ...  B2493D0
# 87    3657350            NOVOLIPETSK STEEL PJSC COMMON STOCK RUB  B59FPC7
# 88     180877                  MAGNIT PJSC COMMON STOCK RUB 0.01  B59GLW2
# 89    1265335                 GAZPROM NEFT PJSC COMMON STOCK RUB  B59L417
# 90     730066                      TATNEFT PJSC COMMON STOCK RUB  B5B1TJ8
# 91     571359                      TATNEFT PJSC PREFERENCE RUB 1  B5B1TJ8
# 93    6156103                   ROSTELECOM PJSC COMMON STOCK RUB  2150259
# 94    4246654                VTB BANK PJSC COMMON STOCK RUB 0.01  B5B1TP4
# 95     297730                       POLYUS PJSC COMMON STOCK RUB  B57R0L9
# 96     432517           MD MEDICAL GROUP INVESTMENTS PLC GDR USD
# 97   12313057                SISTEMA PJSFC COMMON STOCK RUB 0.09
# 98     577525                            FIX PRICE GROUP LTD GDR
# 99      75226                          TCS GROUP HOLDING PLC GDR
# 100    275182                       X 5 RETAIL GROUP NV-REGS GDR
# 101   1011.54                  JPM USD LIQUIDITY LVNAV X (DIST.)  7253766
# 102    552780                              SEVERSTAL PAO GDR USD
#
#              FIGI          ISIN                     FIGI Name FIGI Ticker  \
# 1    BBG000FBK1L0                               AL RAJHI BANK        RJHI
# 2    BBG000G5S250                             GOLD FIELDS LTD         GFI
# 3    BBG0069P8N84                     THE SAUDI NATIONAL BANK         SNB
# 4    BBG000BBDH91                         QATAR NATIONAL BANK        QNBK
# 5    BBG000CTYB91                           NASPERS LTD-N SHS         NPN
# 6    BBG000CJ6JT5                        KGHM POLSKA MIEDZ SA         KGH
# 7    BBG000BQR991                     STANDARD BANK GROUP LTD         SBK
# 8    BBG000BNTS67                               FIRSTRAND LTD         FSR
# 9    BBG000K0CZL2                HALYK SAVINGS BANK-GDR REG S        HSBK
# 10   BBG000BV4SB0                       EMAAR PROPERTIES PJSC       EMAAR
# 11   BBG00MJM7K82                NAC KAZATOMPROM JSC-GDR REGS         KAP
# 12   BBG000BTXNT5                   VALTERRA PLATINUM LIMITED         VAL
# 13   BBG000BB4YW8                       ALDAR PROPERTIES PJSC       ALDAR
# 14   BBG00R3JTQ15                      SIBANYE STILLWATER LTD         SSW
# 15   BBG00MFCG359                NOVA LJUBLJANSKA B-GDR REG S         NLB
# 16   BBG000BTZ0H6                                   SASOL LTD         SOL
# 17   BBG000BTFD35                     NATIONAL BANK OF KUWAIT         NBK
# 18   BBG000BTZG27                  HARMONY GOLD MINING CO LTD         HAR
# 19   BBG00WH12RQ8                  ADNOC LOGISTICS & SERVICES     ADNOCLS
# 20   BBG00NNN9QQ8                            JSC KASPI.KZ ADR        KSPI
# 21   BBG000BFSBW3                           NEDBANK GROUP LTD         NED
# 22   BBG01JKTQ324                              OPTIMA BANK SA      OPTIMA
# 23   BBG000BF9DG8                              ABSA GROUP LTD         ABG
# 24   BBG001N9TPG8                          BENEFIT SYSTEMS SA         BFT
# 25   BBG000BTZK82                IMPALA PLATINUM HOLDINGS LTD         IMP
# 26   BBG000BX4G04                                        KRKA        KRKG
# 27   BBG000BGF166                     NATIONAL BANK OF GREECE         ETE
# 28   BBG000BFNXZ7                       SHOPRITE HOLDINGS LTD         SHP
# 29   BBG000GCBLL3                          ETIHAD ETISALAT CO         EEC
# 30   BBG01WH3R003                      METLEN ENERGY & METALS        MTLN
# 31   BBG01PXDJP57                 BANK OF CYPRUS HOLDINGS PLC      BOCHGR
# 32   BBG000BFMXR7                          DUBAI ISLAMIC BANK         DIB
# 33   BBG01YX032D5                                 EUROBANK SA       EUROB
# 34   BBG00GW2XPN7                      EMAAR DEVELOPMENT PJSC    EMAARDEV
# 35   BBG000BTY1D9                POWSZECHNY ZAKLAD UBEZPIECZE         PZU
# 36   BBG00NWP9G12                      ARABIAN CENTRES CO LTD    CENOMICE
# 37   BBG000CDQK77                                  SANLAM LTD         SLM
# 38   BBG01J3CKT01                             ADES HOLDING CO        ADES
# 39   BBG000PPVK43                          KUMBA IRON ORE LTD         KIO
# 40   BBG001MGPLT2                                     KRUK SA         KRU
# 41   BBG01YZHXRG5                             PIRAEUS BANK SA       TPEIR
# 42   BBG000BLB908                      ABU DHABI ISLAMIC BANK        ADIB
# 43   BBG000H1XBB5                                  RIYAD BANK        RIBL
# 44   BBG004731032                                 LUKOIL PJSC        LKOH
# 45   BBG004731032                                 LUKOIL PJSC        LKOH
# 47   BBG000HNQV12                                     JSE LTD         JSE
# 48   BBG01VL7C1Q7                               ALPHA BANK SA       ALPHA
# 49   BBG000DGXW57                                 SARANTIS SA         SAR
# 50   BBG0125542Z0                NORTHAM PLATINUM HOLDINGS LT         NPH
# 51   BBG000DD6054                               DISCOVERY LTD         DSY
# 52   BBG000MH5H77                               GRUPA KETY SA         KTY
# 53   BBG01HGVLP51                       ANGLOGOLD ASHANTI PLC          AU
# 54   BBG000G9QXS1                QATAR GAS TRANSPORT(NAKILAT)        QGTS
# 55   BBG0027F7RQ9                       UNITED ELECTRONICS CO       EXTRA
# 56   BBG000L4BB82                EMIRATES INTEGRATED TELECOMM          DU
# 57   BBG01BBBYZJ2                      RIYADH CABLES GROUP CO    RIYADHCA
# 58   BBG01LQR3VB0                              PARKIN CO PJSC      PARKIN
# 59   BBG000BV8964                                GAZPROM PJSC        GAZP
# 60   BBG000BV8964                                GAZPROM PJSC        GAZP
# 62   BBG00Z480G04                ALKHORAYEF WATER & POWER TEC        AWPT
# 63   BBG01L5Q3BX5                ATHENS INTERNATIONAL AIRPORT         AIA
# 64   BBG000BRQQP4                       BANCA TRANSILVANIA SA         TLV
# 65   BBG004730N88                     SBERBANK OF RUSSIA PJSC        SBER
# 66   BBG004730N88                     SBERBANK OF RUSSIA PJSC        SBER
# 68   BBG014BFQ5S4                                      ELM CO         ELM
# 69   BBG000FRFYJ2                            SAUDI AWWAL BANK        SABB
# 70   BBG007611SF6                    ELECTRICAL INDUSTRIES CO         EIC
# 71   BBG000C3KV44                            TIGER BRANDS LTD         TBS
# 72   BBG001C7KTW7                        MONETA MONEY BANK AS       MONET
# 73   BBG000TD6H50                            TECOM GROUP PJSC       TECOM
# 74   BBG00475KKY8                                NOVATEK PJSC        NVTK
# 75   BBG00475KKY8                                NOVATEK PJSC        NVTK
# 77   BBG000C3KQJ9                ALDREES PETROLEUM AND TRANSP     ALDREES
# 78   BBG000DT2LJ2                          TURKIYE SIGORTA AS       TURSG
# 79   BBG01M0QW8K7                    WE BUY CARS HOLDINGS LTD         WBC
# 80   BBG008N1HVT6                    SAUDI GROUND SERVICES CO         SGS
# 81   BBG000FRFZ09                          ARAB NATIONAL BANK        ARNB
# 82   BBG004731489                     MMC NORILSK NICKEL PJSC        GMKN
# 83   BBG004731354                         ROSNEFT OIL CO PJSC        ROSN
# 84   BBG004731354                         ROSNEFT OIL CO PJSC        ROSN
# 86   BBG000RJ3KH2                UNITED INTERNATIONAL TRANSPO      BUDGET
# 87   BBG004S681B4                      NOVOLIPETSK STEEL PJSC        NLMK
# 88   BBG004RVFCY3                                 MAGNIT PJSC        MGNT
# 89   BBG004S684M6                           GAZPROM NEFT PJSC        SIBN
# 90   BBG004S68829                         TATNEFT PJSC - PREF       TATNP
# 91   BBG004S68829                         TATNEFT PJSC - PREF       TATNP
# 93   BBG000JQFFH3                    ROSTELECOM-SPONSORED ADR       ROSYY
# 94   BBG004730ZJ9                               VTB BANK PJSC        VTBR
# 95   BBG000R607Y3                                 POLYUS PJSC        PLZL
# 96   BBG003GTV1S5  RU000A108KL3  MD MEDICAL GROUP INVESTMENTS        MDMG
# 97   BBG000DFMPG4  RU000A0DQZE3                 SISTEMA PJSFC        AFKS
# 98   BBG00ZDPWZS9  US33835G2057  FIX PRICE GROUP PLC-GDR REGS        FIXP
# 99   BBG01LR40593  RU000A107UL4         TKS HOLDING MKPAO JSC        TCSG
# 100  BBG000FDR567  RU0009046510                SEVERSTAL PJSC        CHMF
# 101  BBG000CG07V0                    JPM USD LIQ LVNAV-X DIST     JPMULXD
# 102  BBG000FDR567  RU0009046510                SEVERSTAL PJSC        CHMF
#
#     FIGI Exchange Code FIGI Security Type FIGI Market Sector
# 1                   AB       BBG000FBK1L0             Equity
# 2                   SJ       BBG000G5S250             Equity
# 3                   AB       BBG0069P8N84             Equity
# 4                   QD       BBG000BBDH91             Equity
# 5                   SJ       BBG000CTYB91             Equity
# 6                   PW       BBG000CJ6JT5             Equity
# 7                   SJ       BBG000BQR991             Equity
# 8                   SJ       BBG000BNTS67             Equity
# 9                   LI       BBG000K0CZL2             Equity
# 10                  UH       BBG000BV4SB0             Equity
# 11                  LI       BBG00MJM7K82             Equity
# 12                  SJ       BBG000BTXNT5             Equity
# 13                  UH       BBG000BB4YW8             Equity
# 14                  SJ       BBG00R3JTQ15             Equity
# 15                  LI       BBG00MFCG359             Equity
# 16                  SJ       BBG000BTZ0H6             Equity
# 17                  KK       BBG000BTFD35             Equity
# 18                  SJ       BBG000BTZG27             Equity
# 19                  UH       BBG00WH12RQ8             Equity
# 20                  US       BBG00NNN9QQ8             Equity
# 21                  SJ       BBG000BFSBW3             Equity
# 22                  GA       BBG01JKTQ324             Equity
# 23                  SJ       BBG000BF9DG8             Equity
# 24                  PW       BBG001N9TPG8             Equity
# 25                  SJ       BBG000BTZK82             Equity
# 26                  SV       BBG000BX4G04             Equity
# 27                  GA       BBG000BGF166             Equity
# 28                  SJ       BBG000BFNXZ7             Equity
# 29                  AB       BBG000GCBLL3             Equity
# 30                  LN       BBG01WH3R003             Equity
# 31                  GA       BBG01PXDJP57             Equity
# 32                  UH       BBG000BFMXR7             Equity
# 33                  GA       BBG01YX032D5             Equity
# 34                  UH       BBG00GW2XPN7             Equity
# 35                  PW       BBG000BTY1D9             Equity
# 36                  AB       BBG00NWP9G12             Equity
# 37                  SJ       BBG000CDQK77             Equity
# 38                  AB       BBG01J3CKT01             Equity
# 39                  SJ       BBG000PPVK43             Equity
# 40                  PW       BBG001MGPLT2             Equity
# 41                  GA       BBG01YZHXRG5             Equity
# 42                  UH       BBG000BLB908             Equity
# 43                  AB       BBG000H1XBB5             Equity
# 44                  RM       BBG004731032             Equity
# 45                  RM       BBG004731032             Equity
# 47                  SJ       BBG000HNQV12             Equity
# 48                  GA       BBG01VL7C1Q7             Equity
# 49                  GA       BBG000DGXW57             Equity
# 50                  SJ       BBG0125542Z0             Equity
# 51                  SJ       BBG000DD6054             Equity
# 52                  PW       BBG000MH5H77             Equity
# 53                  US       BBG01HGVLP51             Equity
# 54                  QD       BBG000G9QXS1             Equity
# 55                  AB       BBG0027F7RQ9             Equity
# 56                  UH       BBG000L4BB82             Equity
# 57                  AB       BBG01BBBYZJ2             Equity
# 58                  UH       BBG01LQR3VB0             Equity
# 59                  RU       BBG000BV8964             Equity
# 60                  RU       BBG000BV8964             Equity
# 62                  AB       BBG00Z480G04             Equity
# 63                  GA       BBG01L5Q3BX5             Equity
# 64                  RO       BBG000BRQQP4             Equity
# 65                  RM       BBG004730N88             Equity
# 66                  RM       BBG004730N88             Equity
# 68                  AB       BBG014BFQ5S4             Equity
# 69                  AB       BBG000FRFYJ2             Equity
# 70                  AB       BBG007611SF6             Equity
# 71                  SJ       BBG000C3KV44             Equity
# 72                  CP       BBG001C7KTW7             Equity
# 73                  UH       BBG000TD6H50             Equity
# 74                  RM       BBG00475KKY8             Equity
# 75                  RM       BBG00475KKY8             Equity
# 77                  AB       BBG000C3KQJ9             Equity
# 78                  TI       BBG000DT2LJ2             Equity
# 79                  SJ       BBG01M0QW8K7             Equity
# 80                  AB       BBG008N1HVT6             Equity
# 81                  AB       BBG000FRFZ09             Equity
# 82                  RM       BBG004731489             Equity
# 83                  RM       BBG004731354             Equity
# 84                  RM       BBG004731354             Equity
# 86                  AB       BBG000RJ3KH2             Equity
# 87                  RM       BBG004S681B4             Equity
# 88                  RM       BBG004RVFCY3             Equity
# 89                  RM       BBG004S684M6             Equity
# 90                  RM       BBG004S68829             Equity
# 91                  RM       BBG004S68829             Equity
# 93                  US       BBG000JQFFH3             Equity
# 94                  RM       BBG004730ZJ9             Equity
# 95                  RM       BBG000R607Y3             Equity
# 96                  RM       BBG003GTV1S5             Equity
# 97                  RU       BBG000DFMPG4             Equity
# 98                  RM       BBG00ZDPWZS9             Equity
# 99                  RM       BBG01LR40593             Equity
# 100                 RU       BBG000FDR567             Equity
# 101                 LX       BBG000CG07V0             Equity
# 102                 RU       BBG000FDR567             Equity
